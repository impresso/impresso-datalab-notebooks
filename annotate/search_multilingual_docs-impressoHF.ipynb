# %% [markdown]
# # Searching Relevant texts within an Embedding spaces
#
# This notebook demonstrates how to use a pre-trained multilingual embedding model downloaded from Hugging Face to search for relevant texts across languages.
#
# We'll load the model, embed the texts and demonstrate use cases on how to find relevant texts across the German/French language pair within Impresso. Through these use cases we will get familiar with how to use the utilities functions we provide so that you can extend this to your user case of interest.
#
# Reccomended Hardware: GPU support, the colab free one (T4) is sufficient. Alternatively, calculations with CPU are possible but much slower.

# %% [markdown]
# ## 1. Install Dependencies
#
# First, we need to install `sentence-transformers`

# %%
# !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.2.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.44.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.5.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.24.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.8.30)
# Downloading sentence_transformers-3.2.1-py3-none-any.whl (255 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.8/255.8 kB 9.8 MB/s eta 0:00:00
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-3.2.1

# %% [markdown]
# ## 2. Model Information
#
# In this example, we are using an off the shelf multilingual embedding model hosted on Huggingface: `gte-multilingual-base'.
#
# Note: Newer impresso version of the model is in the works.
#
# This model predicts an embedding representation (list of numbers that stores the "meaning") of a given text (sentence, paragraph, article) that can be used to measure similarity between two texts.

# %% [markdown]
# ## 3. Loading the embedding model
#
# This class downloads the model from Hugging Face and loads it ready for prediction. We use the SentenceTransformers library to benefit from their functionality and documentation.

# %%
from sentence_transformers import SentenceTransformer
from scipy.spatial.distance import cosine

embedding_model = SentenceTransformer("Alibaba-NLP/gte-multilingual-base", trust_remote_code=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/123k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/55.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# configuration.py:   0%|          | 0.00/7.13k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Alibaba-NLP/new-impl:
# - configuration.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling.py:   0%|          | 0.00/59.0k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Alibaba-NLP/new-impl:
# - modeling.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/611M [00:00<?, ?B/s]
# Some weights of the model checkpoint at Alibaba-NLP/gte-multilingual-base were not used when initializing NewModel: ['classifier.bias', 'classifier.weight']
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ### Simple Test

# %%
sentence1_en = "This is an example test sentence"
sentence2_en = "This constitutes a sample sentence"

# %%
embedding1_en = embedding_model.encode(sentence1_en)
embedding2_en = embedding_model.encode(sentence2_en)

print("Embedding Representation of sentence1 starts with ... " + str(embedding1_en[:5]))
print("Embedding Representation of sentence2 starts with ... " + str(embedding2_en[:5]))
# Out:
# Embedding Representation of sentence1 starts with ... [-0.03899017  0.05060311 -0.05112957  0.04195484 -0.01264444]
# Embedding Representation of sentence2 starts with ... [-0.03233603  0.05431601 -0.04902024  0.01571231 -0.00125108]

# %% [markdown]
# Those numbers look intriguing, but do they really mean something?
#
# Answer: Yes, they can show us the similarity of the two texts

# %%
similarity_value = round(1 - cosine(embedding1_en, embedding2_en),2)
print("Sentence1 and Sentence2 have a cosine similarity of " + str(similarity_value))
# Out:
# Sentence1 and Sentence2 have a cosine similarity of 0.87

# %% [markdown]
# FAQ:
#
# Cosine similarity is not the percentage of similarity between the two texts.
#
# The higher the cosine similarity, the more similar the two texts are. Range of what is considered "high" varies per model and domain.
#
# Based on our experiments on contemporary texts, cosine similarity of 0.85+ means the two texts are mostly equivalent

# %% [markdown]
# ### Simple Test Across Languages

# %%
sentence1_de = "Das ist ein Beispieltestsatz"

# %%
embedding1_de = embedding_model.encode(sentence1_de)

# %%
similarity_value = round(1 - cosine(embedding1_en, embedding1_de),2)
print("Sentence1 in English and Sentence1 in German have a cosine similarity of " + str(similarity_value))
# Out:
# Sentence1 in English and Sentence1 in German have a cosine similarity of 0.73

# %% [markdown]
# ### Try your own similarity calculation

# %%
input1 = input()
# Out:
# This is a test sentence

# %%
input2 = input()
# Out:
# Wow what a cool sentence

# %%
embedding1 = embedding_model.encode(input1)
embedding2 = embedding_model.encode(input2)

# %%
similarity_value = round(1 - cosine(embedding1, embedding2),2)
print("Input1 and Input2 have a cosine similarity of " + str(similarity_value))
# Out:
# Input1 and Input2 have a cosine similarity of 0.71

# %% [markdown]
# Note: You can also calculate the similarity of inputs from different languages

# %% [markdown]
# ## 4. Finding similar texts within collections using the embedding model
#
# Now that we have seen how the model creates a representation and how we can use it to get the similarity of two texts, let's apply it to a couple of collections.

# %% [markdown]
# ## Setting up utility functions
#
# Here we setup utilities functions that we use for later. You can safely ignore details of the implementation. You simply need to have the code cell executed
#
# For these functions we just need to have a high level understanding of the following key information:
#
# ***create_embedding_collection(texts, embedding_model)***
#
# This function creates a collection of embeddings from a list of sentences, texts, using the embedding model which we already loaded. It outputs a list of tuples pairing each text with its embedding
#
# ***find_best_match_in_collection(source_collection, target_collection)***
#
# This function finds the most similar text in a target_collection for each text in a source_collection based on their precomputed embeddings. Each collection should be a list of tuples (direct output of the create_embedding_collection function) where each tuple contains a sentence and its embedding.
#
# ***print_matches_formatted(matches, link=False, threshold=0)***
#
# This function formats and prints each match from the matches output of find_best_match_in_collection. It takes an optional threshold value to display only matches with a similarity above a certain value.
#
#
# Example usage can be found on Section 4.1

# %%
from scipy.spatial.distance import cosine

def create_embedding_collection(texts, embedding_model, uids=None):
    # Encode the sentences using the model
    embeddings = embedding_model.encode(texts)

    # Zip the sentences with their corresponding embeddings
    if uids:
      texts_embedding_collection = list(zip(texts, embeddings, uids))
    else:
      texts_embedding_collection = list(zip(texts, embeddings))

    return texts_embedding_collection

def find_best_match_in_collection(source_collection, target_collection, matches_sorted=False, link=False):
    """
    Finds the most similar sentence in the target collection for each sentence in the source collection
    based on cosine similarity of their embeddings.

    Args:
        source_collection (list of tuples): A list of tuples where each tuple contains a source sentence and its corresponding embedding.
        target_collection (list of tuples): A list of tuples where each tuple contains a target sentence and its corresponding embedding.

    Returns:
        list of dict: A list of dictionaries, each containing:
            - 'source_text' (str): The original sentence from the source collection.
            - 'best_match' (str): The most similar sentence from the target collection.
            - 'similarity' (float): The cosine similarity score between the source sentence and the best match, rounded to two decimal places.

    Example:
        source = [("sentence in German", embedding_vector)]
        target = [("sentence in French", embedding_vector)]
        matches = find_best_match_in_collection(source, target)

    Note:
        The function assumes the embeddings are already precomputed and provided in the source and target collections.
    """

    matches = []  # List to store the best matches
    for source in source_collection:
        source_embedding = source[1]  # Get the embedding of the source sentence
        best_match_text = ""  # Initialize the best match text
        best_match_similarity = 0  # Initialize the best match similarity score
        best_match_content_id = ""
        # Iterate through the target collection to find the best match
        for target in target_collection:
            if source[0] == target[0]:  # Skip if comparing the same sentence
                continue
            target_embedding = target[1]  # Get the embedding of the target sentence
            # Calculate cosine similarity between source and target embeddings
            similarity_value = 1 - cosine(source_embedding, target_embedding)
            # Update if the current similarity is higher than the previous best
            if similarity_value > best_match_similarity:
                best_match_similarity = similarity_value
                best_match_text = target[0]
                if link:
                  best_match_content_id = target[2]

        # Append the source sentence, best match, and similarity score to the results list
        if link:
            matches.append({
                "source_text": source[0],
                "best_match": best_match_text,
                "similarity": round(best_match_similarity, 2),  # Round to 2 decimal places
                "Content Item Source": f"https://impresso-project.ch/app/article/{source[2]}",  # Corrected f-string for URL
                "Content Item Matched": f"https://impresso-project.ch/app/article/{best_match_content_id}"  # Corrected f-string for URL
            })
        else:
            matches.append({
                "source_text": source[0],
                "best_match": best_match_text,
                "similarity": round(best_match_similarity, 2)  # Round to 2 decimal places
            })


    if matches_sorted:
      # Sort the matches by similarity in descending order if specified
      matches = sorted(matches, key=lambda x: x['similarity'], reverse=True)

    return matches

# Function to print the matches in a nicely formatted way
def print_matches_formatted(matches, link=False, threshold=0):
    for match_dict in matches:
        if threshold > match_dict['similarity']: # if not a good match, skip the match
            continue
        print("Source Text:")
        print(f"  {match_dict['source_text']}\n")

        print("Best Match:")
        print(f"  {match_dict['best_match']}\n")

        print(f"Similarity: {match_dict['similarity']}\n")

        # If 'link' is True, print the URLs for the source and matched content
        if link and 'Content Item Source' in match_dict and 'Content Item Matched' in match_dict:
            print("Content Item Source:")
            print(f"  {match_dict['Content Item Source']}\n")

            print("Content Item Matched:")
            print(f"  {match_dict['Content Item Matched']}\n")

        print("-" * 50)  # Print a separator line for readability

# %% [markdown]
# ## 4.1 Searching in a Dummy Sentence Level Collection

# %% [markdown]
# Here we create a sample sentence text collection to see what the model matches as most similar using minimal additional code.

# %%
german_sentences = [
    "Mit diesen drei Kernkraftwerken wird die Schweiz 1972 die höchste installierte nukleare Kapazität pro Kopf der Bevölkerung aller kontinentaleuropäischer Länder aufweisen .",
    "In anderen Gegenden wiederum wirbt man gegen den Bau von Wasserkraftwerken aus Gründen des Natur- und Heimatschutzes und wäre mit der Aufstellung thermischer Kraftwerke mittlerer Leistung einverstanden , vorausgesetzt , dass deren Abgase keine unzulässige Verschmutzung der Luft verursachen",
    "In Baden beabsichtigt , mit einem Kostenaufwand von 480 Millionen Franken iii Kaiseraugst ein Kernkraftwerk mit einer Leistung von 500 Megawatt zu errichten",
    "Der Bürger akzeptiert das Prinzip des doppelten politischen Programms nicht mehr, bei dem das erste dazu dient, gewählt zu werden, und das zweite zum Regieren verwendet wird.",
]

french_sentences = [
    "Indemnités pour Kaiseraugst Contestées par une minorité au National Le Conseil national a entamé hier de débat sur l'abandon du projet de la centrale nucléaire de Kaiseraugst mais n'a pas encore voté l'entrée enmatière.",
    "Certains milieux voués à la protection de l'environnement s'élèvent non seulement contre la construction de centrales mais même contre l'accroissement de la consommation d'énergie.",
    "En revanche, le projet retenu pour Kaiseraugst, soit un réacteur à eau légère de 500 MW, coûterait 480 millions de francs et produirait de l'électricité au prix de 2,5 centimes par kwh. ",
    "La Suisse disposera en 1972, par habitant, de la capacité nucléaire installée la plus élevée de tous les pays d'Europe continentale."
]

german_collection = create_embedding_collection(german_sentences, embedding_model)
french_collection = create_embedding_collection(french_sentences, embedding_model)

# %%
# Example of finding and printing the best matches
matches = find_best_match_in_collection(source_collection=german_collection, target_collection=french_collection)  # Find best matches
print_matches_formatted(matches)  # Print the matches
# Out:
# Source Text:
#   Mit diesen drei Kernkraftwerken wird die Schweiz 1972 die höchste installierte nukleare Kapazität pro Kopf der Bevölkerung aller kontinentaleuropäischer Länder aufweisen .
#
# Best Match:
#   La Suisse disposera en 1972, par habitant, de la capacité nucléaire installée la plus élevée de tous les pays d'Europe continentale.
#
# Similarity: 0.92
#
# --------------------------------------------------
# Source Text:
#   In anderen Gegenden wiederum wirbt man gegen den Bau von Wasserkraftwerken aus Gründen des Natur- und Heimatschutzes und wäre mit der Aufstellung thermischer Kraftwerke mittlerer Leistung einverstanden , vorausgesetzt , dass deren Abgase keine unzulässige Verschmutzung der Luft verursachen
#
# Best Match:
#   Certains milieux voués à la protection de l'environnement s'élèvent non seulement contre la construction de centrales mais même contre l'accroissement de la consommation d'énergie.
#
# Similarity: 0.73
#
# --------------------------------------------------
# Source Text:
#   In Baden beabsichtigt , mit einem Kostenaufwand von 480 Millionen Franken iii Kaiseraugst ein Kernkraftwerk mit einer Leistung von 500 Megawatt zu errichten
#
# Best Match:
#   En revanche, le projet retenu pour Kaiseraugst, soit un réacteur à eau légère de 500 MW, coûterait 480 millions de francs et produirait de l'électricité au prix de 2,5 centimes par kwh.
#
# Similarity: 0.8
#
# --------------------------------------------------
# Source Text:
#   Der Bürger akzeptiert das Prinzip des doppelten politischen Programms nicht mehr, bei dem das erste dazu dient, gewählt zu werden, und das zweite zum Regieren verwendet wird.
#
# Best Match:
#   Indemnités pour Kaiseraugst Contestées par une minorité au National Le Conseil national a entamé hier de débat sur l'abandon du projet de la centrale nucléaire de Kaiseraugst mais n'a pas encore voté l'entrée enmatière.
#
# Similarity: 0.48
#
# --------------------------------------------------

# %% [markdown]
# ## 4.2 Searching in an Article collection exported from the interface

# %% [markdown]
# Here we are working with collections exported directly from the Impresso Interface. We create a new utility function to transform the csv files into the collection format we used before to use the same functions we have already seen. For this new utility, you only need to provide the file loaded through pandas as well as the embedding model.
#
# In this example, we work on article level and filter for articles with a minimum length of 2000 characters. You can customise this filter by changing the parameter minimum_characters_in_article or pre-filter your dataframe in any way you please before providing it to the function.

# %%
def interface_exported_csv_to_collection(df, embedding_model, batch_size=16, minimum_characters_in_article=2000):
    """
    Converts a DataFrame into a collection of (text, embedding, uid) tuples,
    filtering rows where the 'content' column has at least 2000 characters.
    The encoding is done in batches to handle large datasets efficiently.

    Args:
        df (pd.DataFrame): Input DataFrame containing 'content' (text) and 'uid' (unique identifier).
        embedding_model (object): Embedding model with an `encode()` method to generate text embeddings.
        batch_size (int, optional): The size of batches for the encoding process. Defaults to 32.

    Returns:
        list of tuples: Each tuple contains (source text, embedding, uid) for rows with 'content' >= 2000 characters.
    """

    # Filter rows where 'content' has at least 2000 characters
    df_filtered = df[df['content'].apply(lambda x: len(str(x)) >= 2000)]

    # Extract the 'content' and 'uid' columns
    texts = df_filtered['content'].tolist()
    uids = df_filtered['uid'].tolist()

    # Initialize an empty list to hold the embeddings
    embeddings = []

    # Process the texts in batches
    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i + batch_size]
        batch_embeddings = embedding_model.encode(batch_texts)
        embeddings.extend(batch_embeddings)

    # Create a collection of tuples (source text, embedding, uid)
    collection = list(zip(texts, embeddings, uids))

    return collection

# %% [markdown]
# I setup the file on my google drive so you can also replicate with these files using this code. For another collection, you can simply drag and drop the files into the file interface of the notebook

# %%
# !pip install gdown
import gdown
# Step 1: Set the file IDs
file_id_french = '1-xHR5Oxlo1iVBpAKnwsxYxPGBZ0r86-3'
file_id_german = '1LGdbdvJVl1tIouYoPJPcL0u45_GftwoB'

# Step 2: Download the files using gdown
gdown.download(f"https://drive.google.com/uc?export=download&id={file_id_french}", "mariecurie_french.csv", quiet=True)
gdown.download(f"https://drive.google.com/uc?export=download&id={file_id_german}", "mariecurie_german.csv", quiet=True)

# %%
import pandas as pd


marie_curie_df_german = pd.read_csv("mariecurie_german.csv", sep=";")
marie_curie_df_french = pd.read_csv("mariecurie_french.csv", sep=";")

# %%
marie_curie_german_collection = interface_exported_csv_to_collection(marie_curie_df_german, embedding_model, minimum_characters_in_article=2000)
print("German articles prepared: " + str(len(marie_curie_german_collection)))
marie_curie_french_collection = interface_exported_csv_to_collection(marie_curie_df_french[:15], embedding_model, minimum_characters_in_article=2000) # I only prepare the first 15 for compute reasons.
print("French articles prepared: " + str(len(marie_curie_french_collection)))
# Out:
# German articles prepared: 141
# French articles prepared: 10

# %% [markdown]
# Now we have reached the same data format and so we can use the same utility functions as before. An addition to earlier I add a hyperlink to the interface so we can browse all the details. To do so, we set the value of "link" to True.

# %%
# Example of finding and printing the best matches
matches = find_best_match_in_collection(source_collection=marie_curie_french_collection, target_collection=marie_curie_german_collection, link=True)  # Find best matches
print_matches_formatted(matches, link=True, threshold=0.70)  # Print the matches
# Out:
# Source Text:
#   Le merveilleux radium Parmi tous les miracles dont pourra s'enorgueillir un siècle fécond en découvertes et en inventions de toutes sortes, le plus merveilleux peut-être est celui du radium. Or, écrire l'histoire de celuici, c'est écrire l'histoire de Mme Curie, à laquelle, assure-t-on, le gouvernement français doit décerner sous peu la plus haute récompense nationale qui ait jamais été accordée à une femme : la croix de commandeur de la Légion d'honneur. Nous ne les séparerons donc pas l'un de l'autre. Qu'est-ce que le radium, dont on parle beaucoup, mais que bien peu de personnes connaissent ? C'est le dernier état chimique de l'uranium, qui constitue avec le thorium et l'actinium, les trois corps radio-actifs. Quels sont ses effets ? Il excite la phosphorescence des substances alcalines, du verre, du diamant, de l'épiderme. Il est conducteur de l'électricité. Il est « auto-lumineux ». Chimiquement, il colore le verre, l'eau, le diamant, décompose l'eau, coagule l'albumine et transforme l'oxygène en ozone. On voit déjà l'influence considérable, nocive ou bienfaisante qu'un tel corps peut avoir sur les cellules et les tissus. Il s'agissait donc, après l'avoir isolé et réduit à l'état pur, de chercher ses applications pratiques, de le, domestiquer, si l'on peut dire, et de l'asservir à l'usage de l'humanité. C'est là toute l'œuvre de Mme Curie et de ses collaborateurs. C'est par hasard, dans le cabinet de Becquerel, en 1895, qu'elle découvrit les émanations du radium. Deux ans après, elle était parvenue à l'isoler, avec l'aide de son mari et des chimistes Bémont et Debierne. Le jeune couple — Marie Sklodowska venait d'épouser Pierre Curie — va tirer bientôt de sa découverte des conséquences formidables : il constatera que le radium a les mêmes propriétés que les rayons X de Rœntgen et qu'il peut émettre indéfiniment, sans perte de poids, chaleur, lumière. et électricité. C'est ainsi que Pierre Curie s'est brûlé profondément au bras et au sternum pour avoir porté sur lui pendant trois heures et sans protection, une parcelle de radium. C'est donc que cette matière détruit les cellules vivantes. Cela étant, pourquoi ne pas l'employer à détruire les cellules vivantes malades, à l'exclusion des autres ? Par exemple, le cancer n'est qu'une maladie contagieuse des cellules : le radium luttera contre ce mal. Nous n'indiquons, bien entendu, ici, qu'une des applications les plus courantes. Mais l'Institut du radium, fondé en 1919 et installé à Paris rue Pierre Curie, se livre à bien d'autres recherches et on est parvenu à des résultats encourageants. Par exemple, le radium est utilement employé dans les dermatoses. Il guérit le lupus, le zona, les névralgies. En agriculture, si son prix prohibitif — un million le gramme — ne rendait pas son emploi impossible, il bouleverserait la culture. Utilisé rationnellement, et il convient d'insister sur cet adverbe, car les corps radio-actifs, armes à deux tranchants, détruiraient jusqu'aux racines une plante ou décupleraient sa vigueur, suivant le mode d'emploi, il nous donnerait, assure-t-on, des épis de blé de la grosseur d'un épi de maïs, des cerises comme des poires, des poires comme des melons. A cette heure où de toutes parts on annonce l'épuisement des mines, quel appoint ne représenterait pas le radium ! Des spécialistes ont calculé, en partant de cette hypothèse : impossible qu'on puisse rassembler une tonne du précieux corps, que pendant trente années cette tonne suffirait à faire marcher, à quinze lieues à l'heure, un navire de quinze mille tonnes faisant quinze mille vaux-vapeur. Elle suffirait au chauffage, pendant la même époque, d'une ville comme Toulouse. Elle éclairerait Paris pendant quatre ans et demi. On voit par ces simples chiffres l'énergie prodigieuse que dégage le radium et l'infini des promesses qu'il contient. Mais c'est aussi une matière délicate à manier. Nous disions tout à l'heure crue c'est une arme à deux tranchants. L'expression est exacte. Tous ceux qui sont a ...
#
# Best Match:
#   Marie Curie , die Entdeckerin des Radiums Vor hundert Jahren , am 7 . November 1867 , wurde Marie Curie in Warschau geboren . Ihr Name ist aui der ganzen Well bekannt . Sie hat mit ihrem Manne Pierre Curie zusammen in den Jahren von 18 . 8 his 1902 das Radium entdeckt und dadurch verholten , ein neues / . eilaller heraufzuführen , das Zeitalter der Radioaktivität . Sie steht als Frau ebenbürtig neben den anderen , die einen ahnlichen Beitrag leisteten ; Heinrich Hertz im Jahre 18 K l » für das / . eilaller der drahtlosen Wellen und des Rundfunks , Wilhelm Conrad Königen für eine neue Epoche der Technik und Medizin , Max Planck für das Atomzeitalter , Alhert Einstein für das Zeitalter der Relativität und das damit verbundene neue physikalisch-astronomische Weltbild . Sie alle schufen ihr bahnbrechendes Werk um das Jahr 1900 , so dass dns 20 . Jahrhundert durch sie sein Gepräge bekommen hat , Marie Curie war die erste bedeutende Forscherin aui dem Gebiet der Naturwissenschaften , ihr Ruhm verbreitete sich schnell über die ganze Erde . Sogar in einem Konfuzius-Tempel in einer alten chinesischen Provinzstadt findet man ihr liild . Die Weisen des Landes hahen es unter die Wohltäter der Menschheit auf genommen , nehen dem Begründer der neueren Philosophie , dem Franzosen Descartes , neben Newton , Buddha und den grossen chinesischen Kaisern . Wir erinnern auch daran , dass Robert Kochs Büste in einem anderen Tempel des Buddhismus in Ostasien steht . CS war ganz natürlich , dass insbesondere die Frauen Marie Curie ihre Aufmerksamkeit und Bewunderung widmeten , ja stolz darauf sind , dass eine Frau nicht nur berufen war , eine der wichtigsten Entdeckungen der Neuzeit zu machen , sondern auch als einziger Nobelpreisträger in den bisher 66 Jahren der Preisverleihungen zweimal einen wissenschaftlichen Nobelpreis bekam , den für Physik und den für Chemie . Ausser ihr hat nur einmal ein anderer zwei Nobelpreise bekommen , der Amerikaner Linus Pauling . Er bekam den wissenschaftlichen Preis für Chemie und den Nobel-Friedens-Prei « . Viele Frauen , aber auch Männer , mögen sie Weh schwierigen wissenschaftlichen Fragen der Physik nd Chemie ferner stehen , haben die Biographie Marie ur es aus der Feder ihrer zweiten Tochter Eve gelesen , nd alle sind angetan von dem Zauber , den diese einlache und oft einsame , nach dem Tode ihres Mannes . an * auf gich gestellte Forscherin zu Lebzeiten auszahlte und weiter ausstrahlen wird . wir stellen an den Anfang unserer Würdigung die neiden prägnanten Begründungen des Nobelkomitees . CS verlieh ihr den Physikpreis zusammen mit ihrem Manne bereits 1903 « als Anerkennung des ausserordentlichen Verdienstes , das sic sich für ihre gemeinsamen Arbeiten über die von Henri Becquerel entdeckten Strahlungsphänomene erworben haben . » Und als das Radium schon in der ganzen Welt bekannt wnr , erhielt sie im Jahre 1911 den Nobelpreis für Chemie « als Anerkennung des Verdienstes , das sie sich um die Entwicklung der Chemie erworben hat durch die Entdeckung der Elemente Radium und Polonium , durch e Charakterisierung des Radiums und dessen Isolierung in metallischem Zustand und durch ihre Untersuchungen über die Natur und die chemischen Verbindungen dieses wichtigen Elements . » Wiederum ein Glücksfall war es , dass sich aus den vielen Briefen und I fgebüchern Marie Curies ihr menschlicher und ihr wissenschaftlicher Entwicklungsgang gleich deutlich > esen lässt — j , „ Unterschied von den Pionieren er Forschung , auch den bereits genannten , die nur in der Fachliteratur ihre Erkenntnisse niederlegten , So konnle die Oeffentlichkeit über deren persönliches Erleben und die kritischen Phasen ihrer Arbeit kaum elwas erfahren . Marie Curie war hei aller Reserve gegenüber den Menschen , irolz ihrer ständi gen Flucht vor der Oeffcntlichkeil und ihrer völli gen Gleichgültigkeit gegenüber Ruhm nd Reichtum eine Frau , die mit innerer Leidenschaft ihren Weg durch die persönliche , geistige und wissenschaftliche Entwicklung gin ...
#
# Similarity: 0.77
#
# Content Item Source:
#   https://impresso-project.ch/app/article/EXP-1930-01-18-a-i0006
#
# Content Item Matched:
#   https://impresso-project.ch/app/article/DTT-1967-11-03-a-i0135
#
# --------------------------------------------------
# Source Text:
#   LA SCIENCE EN POLOGNE (Suite de la première page) Dans tous les autres domaines scientifiques, les Polonais se sont également illustrés par leurs remarquables travaux. Bornons-nous à mentionner M. T. Banachiewicz, directeur de l'Observatoire de Cracovie, le plus grand astronome polonais après Copernic, M. M. Kamienski, directeur de l'Observatoire de Varsovie, MM. Pienkowski, Rubinowicz et Wolfke, physiciens, Marchlewski, I. Moscicki (président de la République polonaise) et Swietoslawski _, chimistes, Thugutt, minéralogiste, Woycicki et Baehr, botanistes, E. Loth et Tur, anatomistes. La plus grande physicienne de notre temps, Mme Curie-Sklodowska, décédée le 4 juillet 1934, était une Polonaise. Différentes sociétés spéciales réunissent les savants qui travaillent dans un même domaine. Telles sont les sociétés de mathématique, d'astronomie, de physique, de chimie, de géologie, de botanique, etc. Ce sont des sociétés générales pour toute la Pologne qui ont des sections dans chaque centre universitaire. Ces tions déploient une activité fébrile Les membres exposent les résultats de leurs recherches, ils discutent, ils posent de nouveaux problèmes, rendent compte des dernières publications relatives aux sujets traités, etc. Nous avons déjà indiqué plus haut qu'il existe en Pologne différentes fondations destinées à protéger les savants et à faciliter leur travail scientifique. Parmi ces institutions, il faut, avant tout, citer la célèbre Caisse Mianovski qui déploie son activité depuis 1881 et dont les subsides, ont permis de publier un nombre considérable de travaux scientifiques et d'aider un grand nombre de savants polonais dans la gêne. Trois maisons de repos pour intellectuels sont entretenues par cette fondation. Le même but est poursuivi par le Fonds de culture nationale, créé par décret du 2 avril 1928. Ce fonds protège l'activité créatrice scientifique et artistique en Pologne. Des liens scientifiques serrés unissent la Pologne à d'autres Etats. Un échange de revues scientifiques a lieu avec des pays du monde entier. Des grands savants étrangers font partie d'académies polonaises et sont invités à donner des conférences dans les universités de ce pays, de même que des savants polonais sont souvent appelés à l'étranger et sont membres de diverses académies Les Polonais participent activement à tous les congrès scientifiques internationaux et plusieurs d'entre eux se sont déroulés sur territoire polonais. Les progrès réalises par la science polonaise apparaissent d'autant plus méritoires si l'on songe que ce pays a dû vaincre maintes difficultés économiques et politiques au cours des quinze dernières années. '.. S. PICCARD.
#
# Best Match:
#   Marie Curie Berta und Ernst Bösiger: Madame Curie-Sklodowska ist wohl die einzige Gelehrte, die Weltberiihmtheit erlangt hat. Zweimal wurde ihr die höchste Forscherauszeichnung in Europa, der Nobelpreis, zuerkannt. 1903 erhielten Pierre und Marie Curie den Nobelpreis für Physik zusammen mit dem Physiker Henri Becquerel; 1911 wurde ihr der Preis für Chemie zugesprochen. Sie war die erste Frau, die zum Professor an der Sorbonne ernannt wurde. Sie schuf das Radiuminstitut in Paris und leitete als dessen Vorsteherin die Forschungsarbeiten, die den Namen dieses Institutes in die ganze Welt hinaustrugen. Pierre und Marie Curie entdeckten zusammen zwei neue Elemente, das Polonium und das Radium. Diese beiden Stoffe zeigten neuartige Erscheinungen. Sie geben Strahlen ab, zersetzen sich selber und erzeugen fortwährend Wärme. Mit der Erforschung dieser überraschenden Eigenschaften schuf das geniale Wissenschafter-Ehepaar die neue Wissenschaft der Radioaktivität, die auf die Weiterentwicklung der Chemie und Physik einen enormen Einﬂuß gehabt hat. Außerdem zeigte Madame Curie, daß die Strahlen des Radiums als Heilmittel gegen den früher unheilbaren Krebs verwendet werden können. Damit hat sie nicht nur indirekt, in der Form bedeutendster Forschungsergehnisse, sondern auch direkt mit einem Heilmittel der leidenden Menschheit unschätzbare Dienste erwiesen. Viele Ehrendoktorate, Preise, Medaillen und andere Auszeichnungen bedeuten, wie sehr Madame Curies außergewöhnliche wissenschaftliche Arbeit geehrt wurde. Reaktionäre Autoren haben die Behauptung aufgestellt, die Frau könne keine großen geistigen Leistungen vollhringen, weil ihr Gehirngewicht im Durchschnitt niedriger sei als das des Mannes. Es stimmt zwar, daß das Gehirn des Mannes durchschnittlich 150 Gramm mehr wiegt als das der Frau. Aber das Hirngewicht ist kein direkter Maßstab für die Intelligenz. Madame Curie hat den Beweis angetreten, daß die Frau zu genialen wissenschaftlichen Leistungen fähig ist. Madame Curie hat auch gezeigt,daß nicht nur Mannweiber, deren Hormonproduktion nicht richtig funktioniert, sich der Wissenschaft widmen. Marie und Pierre Curie lebten in einer selten schönen, harmonischen Ehe. Gattenliehe und Forscherkameradschaft verbanden die beiden Gelehrten in gleichem Maße. Madame Curies Gesichtsziige zeichneten sich aus durch ausgeglichene, hoch differenzierte und zarte Schönheit. Sie pﬂegte liebevoll ihre beiden Töchterchen. Mit Recht beklagte sie sich allerdings manchmal darüber, daß in unserer Gesellschaft die verantwortungsvolle Erziehung der Kinder und die Haushaltarbeiten die Frau an den Herd binden, ihr die Pﬂege geistiger Interessen oder gar die Forschertätigkeit nahezu verunmöglichen. Nur dank ihrer unerhörten Energie konnte Madame Curie ihren Hausfrauen- und Mutterpﬂichten gerecht werden, als Lehrerin tätig sein, um den magern Lohn Pierres aufzubessern, und nicht zuletzt seriöse Forscherarheit leisten. Marie Curie hat es deutlich spüren müssen, was es heißt, sich in unserer Gesellschaftsord-_ nung mittellos der Forschung zu widmen. Dreifach lastete der schwere Druck unserer Zustände auf ihr. Als Polin litt sie unter der brutalen Unterdrückung ihres Vaterlandes durch das zaristische Rußland. Sie unterstützte den nationalen Unabhängigkeitskampf ihres Volkes, soweit ihr das als Forscherin möglich war. Sie demonstrierte für ihr geliebtes Polen, als sie ihr neues Element «Polonium» nannte. Später bedauerte sie immer wieder, daß nicht das Polonium, sondern das andere neu entdeckte Element, das Radium, zu großer Berühmtheit gelangte. Als Frau litt Marie Curie unter den Vorurteilen, den Widerständen, den traditionellen Schwierigkeiten, die sich ihrem Studium und ihrer wissenschaftlichen Tätigkeit entgegenstellten. Vor allem litt Marie Curie unter dem schweren Druck der Armut. Ihr Vater war ein schlecht bezahlter Lehrer in Polen. Marie Sklodowska mußte sich während ihrer Studienzeit in Paris durchhungern. Mehr als einmal stand sie vor dem Zusammenbruch ihrer  ...
#
# Similarity: 0.71
#
# Content Item Source:
#   https://impresso-project.ch/app/article/EXP-1935-07-12-a-i0085
#
# Content Item Matched:
#   https://impresso-project.ch/app/article/OIZ-1946-04-18-a-i0005
#
# --------------------------------------------------

# %% [markdown]
# U might want to save the results into a csv file, here is a utility function to do that. Within Google colab, just download the resulting file as an extra step.

# %%
def save_matches_to_csv(matches, filename, link=False, threshold=0):
    """
    Saves the match results to a CSV file with specified formatting using pandas.

    Args:
        matches (list of dict): The match results from `find_best_match_in_collection`.
        filename (str): The name of the CSV file to save results.
        link (bool): If True, includes URLs for the source and matched content in the file.
        threshold (float): Minimum similarity score to include a match.
    """
    # Filter matches based on the threshold
    filtered_matches = [
        match for match in matches if match['similarity'] >= threshold
    ]

    # Create a DataFrame from the filtered matches
    df = pd.DataFrame(filtered_matches)

    # Drop URL columns if link is False
    if not link:
        df = df.drop(columns=['Content Item Source', 'Content Item Matched'], errors='ignore')

    # Save the DataFrame to a CSV file
    df.to_csv(filename, index=False, encoding='utf-8')

# Call this function after generating matches
save_matches_to_csv(matches, "marie_curie_first10french_matches.csv", link=True, threshold=0)

# %% [markdown]
# ## 4.3 Searching in an Article collection sourced from DataLab (Current Substitute API)

# %% [markdown]
# This is not how it will look within Datalab. Details about that go to Daniele, but let's just showcase the programmatic access through our API

# %%
# %pip install --upgrade --force-reinstall impresso
import impresso
impresso_session = impresso.connect()

# %%
# some search and get data
fr_result = impresso_session.search.find(
    q="recette",
    order_by="-date")

fr_texts = []
fr_uids = []

for uri in fr_result.df.index[:40]:
    article = impresso_session.content_items.get(uri)
    if len(article.df.content[0]) > 400: # 400 characters minimum length
      fr_texts.append(article.df.content[0])
      fr_uids.append(article.df.uid[0])

# %%
# some search and get data
de_result = impresso_session.search.find(
    q="rezept",
    order_by="-date")

de_texts = []
de_uids = []

for uri in de_result.df.index[:400]:
    article = impresso_session.content_items.get(uri)
    if len(article.df.content[0]) > 400: # 400 characters minimum length
      de_texts.append(article.df.content[0])
      de_uids.append(article.df.uid[0])

# %%
recipes_fr_collection = create_embedding_collection(fr_texts, embedding_model, uids=fr_uids)
recipes_de_collection = create_embedding_collection(de_texts, embedding_model, uids=de_uids)

# %%
# Example of finding and printing the best matches
matches = find_best_match_in_collection(source_collection=recipes_fr_collection, target_collection=recipes_de_collection, link=True)  # Find best matches
print_matches_formatted(matches, link=True, threshold=0.60)  # Print the matches
# Out:
# Source Text:
#   TV MARDI RTS UN 7.00 7 h-8 h de La Première 8.00 Euronews 8.20 Top Secret 9.05 Top Models 8 9.25 Quel temps fait-il ? 9.45 Escapade princière Film TV. Drame. 11.10 Les feux de l’amour 11.45 Demain nous appartient 12.15 Plus belle la vie 12.45 Le 12 h 45 13.00 Une superstar pour Noël Film TV. Comédie dramatique. 14.40 Les enquêtes de Murdoch 16.10 Cendrillon Film. Conte. 17.50 Top Models 8 18.15 Top Secret 18.55 Météo régionale 19.00 Couleurs locales 8 19.30 Le 19 h 30 8 20.05 Federer, l’année 8 CAMPING PARADIS Série. Comédie. Fra. 2017. Saison 9. Avec Laurent Ournac. Mon beau-frère et moi. Inédit. Tom et l’équipe sont tout excités à l’idée d’accueillir Elsa. 22.35 Pension complète 8 Film. Comédie. Fra. 2014. Réalisation : Florent Siri. 1 h 25. Avec Gérard Lanvin, Franck Dubosc, Pascale Arbillot. Un couple gérant d’hôtel se retrouve déstabilisé par le retour d’un ex-mari qu’il croyait mort. 23.35 Pitch Perfect 2 Film. Comédie. 1.45 Couleurs locales CANAL + 15.50 Star Trek sans limites 8 Film 17.50 The Big Bang Theory 18.20 Rendez-vous avec Kevin Razy 18.45 Jamel Comedy Kids 19.50 Le tube 20.45 Canalbis 21.00 Dalida Film. Biographie 23.00 Profession 0.00 La danseuse Film. Biographie. FRANCE 4 13.00 Frankie et les ZhuZhu Pets 813.30 Fort Boyard 8 15.40 Yakari 16.30 Les Minikeums 19.20 Défis cobayes 820.00 Love Divina 820.55 Les fugitifs 8 Film 22.20 Un monde de jouets 82.50 Monte le son, le live-Francofolies 8 NUMÉRO 23 15.40 Révélations 817.15 Super vétérinaire-Technologies bioniques 818.10 Super vétérinaire 820.55 D’Artagnan et les trois mousquetaires Film TV. Cape et d’épée. (1 / 2) 22.50 D’Artagnan et les trois mousquetaires Film TV. (2 / 2). MTV 6.00 MTV Music 6.45 Friendzone 10.00 16 ans et enceinte 11.45 Avant j’étais gros 13.30 17 ans et maman 16.10 Veronica Mars 18.45 The Big Bang Theory 21.00 Are You The One ? Deuxième chance 22.40 MTV Super Shore 2.05 Ex on the Beach RSI LA 1 19.00 Il quotidiano 819.45 Sul cocuzzolo della montagna 820.00 Telegiornale 820.40 Svizzera e dintorni 821.05 The Catch 821.50 Major Crimes 8 22.35 Info Notte 22.55 L’ultimo lupo Film. Aventures 0.50 CSI-Scena del crimine 8 RTS DEUX 6.30 RTS Kids Jeunesse. 11.30 Le chant de la mer Film. Animation. 12.55 Quel temps fait-il ? Magazine. 13.20 Le 12 h 45 13.40 Pinocchio Film. Animation 15.05 Suisse / Dinamo Riga 8 Hockey sur glace. Coupe Spengler. Groupe Torriani. En direct de la Vaillant Arena. 17.35 Déluge à Sous-Bois-Les-Bains 18.05 Snoopy et les Peanuts-Le film Film. Animation. EU. 2015. VM. Réal. : S. Martino. 1 h 35. 19.30 Le 19 h 30 signé 8 20.00 Résultats du Trio Magic, Magic 4 et Banco MOUNTFIELD HK / CANADA Coupe Spengler. Groupe Cattini. En direct de la Vaillant Arena, à Davos. Dans le groupe Cattini, le Canada affrontera le Mountfield HK (dès ce soir) puis le HC Davos. 22.30 Tirage Euro Millions 22.33 Résultats du Trio Magic, Magic 4 et Banco 22.35 Girls Série. Comédie. EU. 2016. Saison 5. Avec Lena Dunham. 10 épisodes. Inédits. Hannah met ses projets d’écriture entre parenthèses et continue de travailler en tant que professeur. 3.10 Couleurs locales 8 FRANCE 5 16.00 Sri Lanka, l’île Émeraude 817.30 C à dire ?! 817.45 C dans l’air 819.00 C à vous 8 20.00 C à vous, la suite 820.20 Entrée libre 820.50 Rendezvous en terre inconnue 822.45 C dans l’air 823.55 C à vous 8 0.50 C à vous, la suite 8 CSTAR 10.30 Top CStar 11.00 Top France 12.15 Les 50 clips les plus vus de tous les temps 15.10 Top 90 16.20 Top France 17.30 Top albums 18.30 Pawn Stars-Les rois des enchères 20.50 Le zap de Noël 22.35 Pinot, simple flic Film. Comédie. RMC DÉCOUVERTE 11.55 Les constructeurs de l’extrême 16.20 Seuls face à l’Alaska 20.50 Le secret des Templiers 822.20 Les Templiers, de l’histoire à la légende 823.20 La dernière bataille des templiers 0.15 La dernière bataille des templiers MEZZO 20.10 Intermezzo 20.30 La Belle au bois dormant 22.40 Intermezzo 23.30 Nate Smith + Kinfolk au Winter Jazz Fest 0.30 Oscar Peterson et Roy Eldridge à l’Olympia-Jazz Archives 1. ...
#
# Best Match:
#   TSR 1 20.45 Prémonitions 7.00 EuroNews 7.35 Quel temps fait-il ? 7.55 Tout le monde aime Raymond 8.20 Dolce vita 8.50 Top Models 9.10 Leçons de séduction 10.40 EuroNews 11.05 Les Feux de l'amour 11.50 Le Rêve de Diana 12.10 Plus belle la vie 12.45 Le journal 13.25 Toute une histoire 14.30 Arabesque 15.30 7 à la maison 16.20 Desperate Housewives 17.05 Plus belle la vie 17.35 Dolce vita 18.05 Le court du jour 18.10 Tapis rouge 18.30 Top Models 18.55 Couleurs locales 19.30 Le journal 20.10 T. T. C. (Toutes taxes comprises) T. T. C. se décline au féminin. 20.45 Prémonitions Film. Thriller. EU. 2007. Réal .: Mennan Yapo. 1 h 40. Avec : Sandra Bullock, Julian McMahon, Shyann McClure, Courtney Taylor Burness. Une femme est hantée par des cauchemars mettant en scène la mort de son mari. 22.25 New York, section criminelle Série. Policière. EU. 2009. Réal .: Norberto Barba. 40 minutes. 15 / 16. Inédit. Sauvés des flammes. Un top model passe la nuit avec une femme mystérieuse. Il est retrouvé mort le lendemain. 23.05 Cinhebdo 23.25 Le journal 23.40 Journeyman 0.20 Couleurs locales 0.40 Le journal TV 5 MONDE 19.00 Roxy. 19.30 Journal (TSR). 20.00 Catherine. 20.30 Journal (France 2). 21.00 Den Muso. Film. Drame psychologique. 22.25 Lumière et caméra. 22.55 TV 5 MONDE, le journal. 23.05 Le journal de l'éco. 23.10 TV 5 MONDE, le journal Afrique. EUROSPORT 15.15 Paris-Nice 2010. Cyclisme. 1 re étape : Saint-Arnoult-en-Yvelines-Contres (201,5 km). En direct. 18.00 Coupe du monde. Saut à skis. HS 127. Qualifications. En direct. 20.15 Laval / Metz. Football. Championnat de France Ligue 2. En direct. CANAL + 18.15 Les Simpson (C). 18.40 Le JT de Canal + (C). 19.05 Le grand journal de Canal + (C). 19.55 Les Guignols de l'info (C). 20.10 Le grand journal, la suite (C). 20.50 Welcome. Film. Drame. Inédit. 22.35 82 e cérémonie des Oscars. Les meilleurs moments. PLANETE 17.20 Vivre de sang froid. 18.15 Devenir un homme en Sibérie. 19.10 Bandes de lémuriens. 19.40 Que le meilleur gagne !. 20.40 Dakinis, le féminin de la sagesse. 21.40 Libéria, le combat des femmes. 22.45 La terre. 23.45 Les derniers maîtres de la Martinique. TSR 2 20.45 Classe Politique 6.30 Mabule 10.25 Les Zozios 12.05 Mabule 12.15 tsrinfo 12.45 Quel temps fait-il ? 13.20 Le journal 13.55 tsrinfo 14.25 Grand angle 14.35 Mise au point Au sommaire : « URI : « Nous sommes tous des Noirs »».-« Le MCG fait des bébés ».-« Une prison modèle pour femmes en Afghanistan ». 15.25 Temps présent Tu n'iras pas en EMS. 16.20 Le passager Invité : Johan Djourou, footballeur. 16.55 Melrose Place 17.45 Les Simpson 18.35 Kyle XY Soif d'apprendre. 19.30 Le journal 20.00 Banco Jass 20.10 La boîte à musique 20.45 Classe Politique Débat. En direct. 1 heure. Invités : Doris Leuthard, Didier Berberat, Ueli Leuenberger, Urs Schwaller, Charles Favre, Jean-François Rime. Depuis Berne. Comment sortir rance-chômage et ses 6 milliards de dettes ? 21.45 La machine à remonter le temps Documentaire. Sciences. Sui. 2008. Réal .: Yariv Friedman. 55 minutes. Le nouvel accélérateur de particules du CERN va permettre de générer des températures 100 000 fois supérieures à celles du centre du Soleil. 22.40 Vu à la télé 23.10 Géopolitis 23.40 Main basse sur le riz AB 1 17.10 Premiers Baisers. 17.40 Hélène et les Garçons. 18.35 Extreme Make Over : Home Edition. La famille Hawkins. 19.20 La Vie de famille. 20.40 Profiler. 23.10 Commando de la peur. Film TV. Action. EU. 2001. Réal .: Ian Gilmore. 1 h 35. RSI 1 18.00 Telegiornale flash. 18.10 Zerovero. 19.00 Il Quotidiano. 19.40 Contesto. 20.00 Telegiornale. 20.35 Meteo. 20.40 Attenti a quei due . 21.05 A Mighty Heart : Un cuore grande . Film. Drame. 22.55 Criminal Minds. 23.45 Telegiornale notte. SF 1 19.30 Tagesschau. 20.05 Al dente. Die Koch- und Quizshow von Betty Bossi. 21.05 Puls. 21.50 10 vor 10.22.15 Meteo. 22.20 Eco. 22.50 Keine zu klein, eine Miss zu sein. Wie Mütter ihre Töchter auf dem Laufsteg drängen. 23.50 Tagesschau Nacht. ARD 20.00 Tagesschau. 20.15 Kaltblütig. ...
#
# Similarity: 0.75
#
# Content Item Source:
#   https://impresso-project.ch/app/article/IMP-2017-12-23-a-i0254
#
# Content Item Matched:
#   https://impresso-project.ch/app/article/EXP-2010-03-08-a-i0260
#
# --------------------------------------------------
# Source Text:
#   TV DIMANCHE RTS UN 7.00 RTS info 7.15 Euronews 7.54 Sur mesure 7.55 Quand Beethoven rencontre Orphée 8.55 Sport dernière 9.25 Une rivière en Irlande 8 10.20 En ce temps-là 11.20 Pêcheurs des extrêmes 12.15 Géopolitis 12.30 Ensemble 12.45 Le 12 h 45 13.25 Pardonnez-moi 14.10 Modern Family 14.35 Chicago Med 16.10 MacGyver 16.55 Chicago Fire 8 18.25 Sport dimanche 8 Magazine. 19.30 Le 19 h 30 8 20.15 Mise au point 8 Magazine. ESPRITSCRIMINELS Série. Policière. EU. 2017. Saison 13. Avec Kirsten Vangsness. Nouveau départ. Inédit. Garcia se rend sur le lieu de l’accident qui a frappé les membres de l’unité. 21.55 Esprits criminels : unité sans frontières 8 Série. Policière. EU. 2017. Saison 2. Avec Gary Sinise, Alana De La Garza. Le souffle du diable. Inédit. Bogota, l’unité internationale doit travailler avec les tés locales. 22.40 Modus Série. 2 épisodes. Inédits. 1.05 Sport dimanche 8 CANAL + 18.40 Canal rugby club 19.20 Canal football club 21.00 Montpellier / Marseille. Football. Ligue 1.16 journée. En direct du stade de la Mosson, à Montpellier 22.55 Canal football club, le débrief 23.10 J + 1 0.10 Canal e-sport club FRANCE 4 13.45 Seuls à la maison 815.45 37 festival international du cirque de Monte-Carlo 818.15 Un gars, une fille 820.55 La consolation 8 Film TV. Drame 22.25 La permission de minuit 8 Film. Drame 0.10 Line of Duty : enquêtes internes 8 NUMÉRO 23 12.05 Révélations 815.40 Faut pas pousser ! 815.50 Pitbulls et prisonniers 817.40 Les colliers de l’espoir 820.40 Faut pas pousser ! 820.55 Le huitième jour Film 23.10 Détective Dee : le mystère de la flamme fantôme Film. MTV 6.00 MTV Music 7.35 World’s Funniest Videos 9.20 Veronica Mars 13.40 The Big Bang Theory 18.05 La salle de bain est libre ?! 20.45 Promposal : la déclaration 22.25 Are You The One ? Deuxième chance 1.50 MTV Super Shore RSI LA 1 16.10 I cuccioli della savana 8 17.00 Cherif 18.00 Telegiornale flash 818.10 Il giardino di Albert 819.00 Il quotidiano 8 19.15 Il gioco del mondo 820.00 Telegiornale 820.39 Storie 8 20.40 Banzai Switzerland 22.00 I Testimoni 0.00 Info Notte RTS DEUX 6.30 RTS Kids 10.50 Adrénaline 11.10 Monstres Academy Film. Animation. 12.55 Signes 8 13.35 Le 12 h 45 14.15 RTS info 15.15 Au coeur du sport 8 Magazine. Combativité. 15.45 Grasshopper Zurich / FC Lugano 8 Football. Super League. En direct. 18.00 Ski alpin 8 Coupe du monde. Slalom géant messieurs, 1 manche. 18.55 Ski alpin 8 Coupe du monde. Super-G dames. En direct. OU Pardonnez-moi 19.30 Ensemble 20.20 Tous les buts ! 8 COUPEDUMONDE Slalom géant messieurs, 2 manche. En direct de Beaver Creek. L’Autrichien Marcel Hirscher, de retour de blessure, dominera-t-il l’épreuve du slalom géant ? 21.50 Une histoire finlandaise Documentaire. Historique. Fra. 2017. Réalisation : Olivier Horn. 0 h 55. Inédit. Ce documentaire retrace les événements qui ont marqué cette jeune nation péenne, créée en 1917. 22.45 Jumping the Shadows 0.00 Le Barbier de Séville Opéra. 2.40 Le 19 h 30 signé 8 FRANCE 5 20.50 Quand la nostalgie fait recette 821.40 Centres commerciaux : la grande illusion 822.40 Quand l’extrême droite resistait1939-1945 823.35 Flexibilité -Le mirage de l’emploi 80.25 L’air du temps 8 CSTAR 12.40 Top clip 14.30 Top Streaming 15.45 Top 2000 17.00 Top albums 18.05 Pawn Stars -Les rois des enchères 20.50 The People v. O. J. Simpson : American Crime Story 22.40 Vilaines pensées Film TV. Erotique. EU. 2016.1 h 34. RMC DÉCOUVERTE 9.55 Top Gear France 11.45 Wheeler Dealers France 8 16.25 Aux frontières de l’Alaska 20.50 Comment Hitler a perdu la guerre du pétrole 21.50 1939-45 : la guerre du pétrole 22.55 Les énigmes de l’Histoire 23.45 Portraits d’Hitler MEZZO 20.30 Monteverdi 22.15 Musique sacrée et profane de Buxtehude avec Vox Luminis et l’Ensemble Masques : Buxtehude 23.40 Gregory Porter au Festival International de Jazz de Montréal 0.35 Badbadnotgood -festival SingJazz RSI LA 2 20.15 La domenica sportiva 820.40 Ski alpin. Coppa del mondo. Slalom gigante maschile, 2. prova. En direct d ...
#
# Best Match:
#   RTS Un 7.30 Euronews 8.10 Chansons à aimer 8.30 Top Models 8 9.15 Journal intime d’un prince charmant Film TV. Avec Jennifer Ulrich. 10.45 Quel temps fait-il ? 11.05 Le court du jour 11.10 The Glades 11.50 Scènes de ménages 12.15 Plus belle la vie 12.45 Le 12 h 45 13.20 Toute une histoire 14.20 L’histoire continue 14.50 Inspecteur Barnaby 16.35 Rizzoli & Isles 8 18.00 Le court du jour 18.05 Top Models 8 18.50 Météo régionale 18.55 Couleurs locales 8 19.30 Le 19 h 30 8 20.10 Descente en cuisine 8 Série. Policière. Fra. Saison 1. Le portrait de sa mère. Inédit. Avec Gérard Jugnot. Alexandre voit son existence bouleversée lorsqu’il prend la défense d’une femme accusée de meurtre. 22.55 Downton Abbey 8 Série. Drame. GB. 2014. Saison 5. Avec Hugh Bonneville, Laura Carmichael, Jim Carter. 2 épisodes. Le projet local pour un mémorial de guerre voit Mr Carson en désaccord avec Robert et Mme Hughes. 0.55 Laisse-moi entrer Film. Horreur. Avec Chloe Moretz, Kodi Smit-McPhee. Canal + 18.35 L’album de la semaine 18.50 Le Grand journal 20.10 Le petit journal 20.50 Les Guignols 20.55 Papa ou maman 8 Film. Comédie 22.20 L’émission d’Antoine 23.20 Une heure de tranquillité 8 Film 0.40 Le supplément France 4 17.55 Les As de la jungle : à la rescousse 18.45 Automobile. Dakar 2016 19.55 Une saison au zoo 20.45 Monte le son ! 20.50 Fort Boyard 0.25 Maurice et Patapon 0.40 Rick & Morty 2.00 Monte le son-les nuits claires Numéro 23 8.30 Community 8.55 Trop chou 9.10 Révélations 12.45 The Listener 14.20 Tattoo Nightmares Miami 15.15 Cabinet de curiosités 17.20 Face Off 8 18.50 Madrid Ink 8 20.45 Ink Master : Redemption 8 0.05 Pitbulls et prisonniers 8 MTV 10.10 How I Met Your Mother 11.55 The Big Bang Theory 13.3516 ans et enceinte 14.25 Lip Sync Battle 16.10 How I Met Your Mother 17.50 The Big Bang Theory 21.00 Ridiculous 22.30 Tosh. 0 23.20 Inside Amy Schumer 1.50 Geordie Shore RSI 1 18.10 Zerovero 19.00 Il quotidiano 8 19.35 Il rompiscatole 20.00 Telegiornale 8 20.40 Black Jack 8 21.10 Patti chiari 8 22.25 Tempi moderni 8 22.50 CSI : Miami 23.45 Anchorman 2 Film 1.35 Repliche continuate RTS Deux 6.30 RTS kids 10.25 Temps présent 8 Magazine. 11.25 Ski nordique Tour de ski. 10 km libre messieurs. En direct. 11.26 Il était une forêt Film. Documentaire. Fra. 2012. Réalisation : Luc Jacquet. 1 h 18. 12.45 Quel temps fait-il ? 13.20 Le 12 h 45 13.55 RTSinfo 14.55 Nouvo 15.10 Ça va le chalet ? 16.55 Toute une histoire 18.00 Revenge Série. Retour providentielSeconde noce. 19.30 Le 19 h 30 signé 20.00 Résultats du Trio Magic, Magic 4 et Banco 20.05 Hawaii 5-0 8 Film. Comédie. Fra. 2013. Réal. : Tristan Séguela. 1 h 28. Avec Laurent Lafitte. Arnaud Mustier, un trentenaire coincé, est métamorphosé par une crise de puberté tardive. 22.20 Sport dernière 22.55 Tirage Euro Millions 23.00 Le court du jour 23.05 Sleepy Hollow Série. Fantastique. EU. Saison 2. Avec Tom Mison, Nicole Beharie. 2 épisodes. Inédits. Pendant un dîner, Grant Hollister, un restaurateur d’oeuvres d’art, est retrouvé assassiné. 0.35 Descente en cuisine 8 1.25 Couleurs locales France 5 20.00 C à vous, la suite 20.15 Une maison, un artiste 8 20.45 La maison France 5 8 21.45 Silence, ça pousse ! 8 22.40 C dans l’air 8 23.50 Nos animaux, doux dehors sauvages dedans 8 0.15 Japon-Tokyo, la ville phoenix 8 D 17 10.30 Top D 17 11.00 Top U 2 12.00 Top clip 15.30 Top U 2 16.30 Top club 17.30 Top Streaming 18.30 Pawn Stars-Les rois des enchères 20.45 LolyWood 20.50 U 2 : Innocence + Experience Tour-Live in Paris 23.30 Top U 2 RMC découverte 16.10 Highway Thru Hell USA 17.00 Le Liquidateur 8 20.45 Goering, le numéro 2 21.45 Himmler, l’exécuteur 22.45 Les junkies d’Hitler 23.45 Dossiers secrets du III Reich 0.45 La garde rapprochée de Mitterrand MEZZO 19.25 Intermezzo 20.30 Concert de la Fondation SOS Talents 22.15 Musique à l’Auditorium du Louvre : Stephen Waarts et Chang-Yong Shin 23.15 Intermezzo 23.30 David Krakauer Ancestral Groove au festival Jazz à Porquerolles RSI 2 19.30 I misteri di Murdoch  ...
#
# Similarity: 0.76
#
# Content Item Source:
#   https://impresso-project.ch/app/article/IMP-2017-12-02-a-i0136
#
# Content Item Matched:
#   https://impresso-project.ch/app/article/EXP-2016-01-08-a-i0081
#
# --------------------------------------------------
# Source Text:
#   . ¦ ÐÐ `½ Î ! Ð ` ÎÎÄ `!»`! ß' !»¦ Ó •` ÓÄ 27. Zg"pDZU !>‘ äã ‹½ £ ‘½ y ‹ ä ‹ Üãä ‘ èä ›¸ õ `‹› Àä )‹ ãä ‘› ãä £ ‹ äô › ô ›‹ äfä ›‘ ä Üy ‘½ £ ›½‘ ô ‹ QBS ! EBOJFM ! HPO [BMF [² Âá’ ¼› Úä Q ¦ èãäfä ›‘ ä »¦› Üä ½‘ ãè ›‹› ä ‹ ãäy ¸‘›‹ è ›‹ èò ¢ ä ›› ä ‘ ³³ ¦› ã ‹ äè ½‹ äã ¦ è › y ¸‹ ä £ Ö ‘ èã ¸‹½ ã › y › ã › ä ‹ ãä £ ‹ ä Ü ›¬ ³ ›› y › ã › Àä )‹ ä ¬‘ ã ›››‘ èä Ü ‹ ä ³ › fiã ‹ ä ‘ è ÜÜ › ä n ›‹½ ä ‘ èä ›‹ ôfiã ‹¬‹½ ãä Ëè Ö ‘ èä ¬¦ n ›››‹› ä ¦ èä ‘ èòä ¦ nº ‹ ã ÜÀ ä + N é Âá’ ¼ ê ¿›« Úä L › è Üä Ëè ‹ äº ‘¬‘› Üäfä ›‘ ä ¬¦ £ ‹ ¢ ä ‹››‹ Üäã ›¦ èô ‹½ ãä ›‹ è › ä ³ ›‘ y ‹ ä £ ‘½ Üäã ¦ è Üä ›‹ Üä ›‹ y ¦›½ ÜÀ ä + Nä ã Âá (›« ß ››‹« ä S ½ ä ¬¦ £ –›‹ äfä › ã ¸‘½¦› ä ³ ‹ èãäfiã ›‹ ä ›½ Üã ‘››› ä ³ ‘› ã ¦ èã Àä + N Selon le World Happiness Report 2017 – le rapport mondial sur le bonheur établi chaque année par l’ONU – la Suisse se classe quatrième dans la liste des pays les plus heureux. Pour autant, elle échoue au pied d’un podium entièrement scandinave avec la Norvège en tête, devant le Danemark et l’Islande. Qu’est-ce qui fait que les Nordiques seraient plus heureux ? Une partie de la réponse est peut-être à chercher dans le « hygge » – il se prononce houga. Ce mot d’origine danoise et norvégienne est une sorte de recette du bonheur qui se fonde sur le plaisir des choses simples. Cette dolce vita nordique s’incarne notamment dans la décoration. Bref, il suffit de quelques petits aménagements chez soi pour passer un automne tout en douceur à la façon scandinave. = _ áºêß ››¼ Ú › à ‹ á ¢ êá” « êá Il n’y a pas de hygge sans la présence d’un foyer. La cheminée (3) est un essentiel du mode de vie à la danoise, car elle réchauffe. Contrairement à ce que l’on imagine, elle est à la portée du plus grand nombre. On trouve des foyers à petits prix comme les cheminées à éthanol. Ces dernières peuvent être installées partout, car elles ne nécessitent pas de conduit. Hormis sa chaleur, le feu diffuse une lumière apaisante et enveloppante. De quoi faire dire au Danois Meik Wiking dans son « Livre sur le hygge » que « plus la température est basse, plus elle est hygge. Le flash d’un appareil photo, c’est environ 5500 kelvins (K), les tubes fluorescents 5000 K, les lampes incandescentes 3000 K, alors que le coucher de soleil, !›!!!! Kºê Úáº _ áà « ßð ‹ Ò _ àê Ò « á « Úàám _ ÚÚ «¡ áðºê Úá « ºº « á « Úàá ¯› ö ¿¿«› Âá (Ó « Úàáº « áx _ Úá ¢ « Úá ”º _ ßß « Úá ¢ Óê › á” « êá ¢ « á x ›« ß ››‹« á ¼ êá ¢ Óê ›« á m ¼ ê ¿›« Â ¿! ä ä @‹› aeä Y › ae ›½` ¢ ä £ ››‹ yã ‹ è › ä £ ‹ ä › Ö 7 ½ Üã › ãèãä £ ‹ ä ›‹ y ¸‹› y ¸‹ ä Üè › ä ›‹ än ¦½¸‹ è › ä ‹ ãä ‘ èã ‹ è › ä £ èä ›>› ô ›‹ ä Üè › ä ›‹ ä ¸ õ ``‹›
#
# Best Match:
#   d'Ländchen hilft Überforderten Wie erzwinge ich Glück? Dr. Akula „Glück ist eine warme Waffe." „Gegensätze ziehen sich an." „Glück kann man nicht erzwingen." Was haben diese Sinnsprüche gemeinsam? Sie sind alle von Trägern der Schuhgröße 41 erdacht worden und sind so nützlich wie ein Schuhlöffel beim safer sex. Zurück zum Thema: Wann haben Sie zuletzt das Gefühl des inneren Friedens, der harmonischen Beglückung verspürt? Bei der Vollnarkose vor der Blinddarmoperation? Dann haben Sie wohl daran getan, diese Zeitung an den Fernseher zu kleben, um beim Teleshopping den einen oder anderen Artikel zu überfliegen. Ihr Schnarchpartner wird es Ihnen danken. Doch wie haben Sie es geschafft, im Land der Glücklichen eine negative Grundstimmung aufrechtzuerhalten? Eine englische Universität hat kürzlich die erste „Weltkarte des Glücks" erstellt, laut welcher die Luxemburger die Zwölftglücklichsten weltweit sind. Ihr Rezept: Geld, soziale Sicherheit, Zusammenarbeit mit der Heiligen Maria (Schwester aller, die im Glauben ihr Glück suchen) sowie Wellness-Pilgerfahrten mit luxuriösen Erlebnisbussen zu außergewöhnlichen Zielen wie Hawaï, Tibet oder Niederwampach. Amen. Allerdings rangiert Luxemburg laut einer anderen Studie weit hinten, irgendwo zwischen Uganda und dem Pluto, der neuerdings nicht mal mehr als Planet gilt: Untersucht wurden Zufriedenheit, Lebenserwartung und der durchschnittliche Weichheitsindex des Toilettenpapiers. Nun gut, Sie sind unglücklich und warten auf Rat. Zuerst die schlechten Nachrichten: Die Familie hat als Glücksspender ausgedient. Immer weniger Ehen werden geschlossen, immer weniger Kinder geboren, jede zweite Ehe wird geschieden. Der Talmud sagt: „Drei Sachen führen ins Paradies [Glück]: die Sonne, der Sabbat und das Umarmen." Wir brauchen Menschen, die - Sonnenstrahlen gleich - unser Leben erhellen und wärmen. Wir brauchen die Unterbrechung von Hektik und Stress. Wir brauchen Umarmungen, die Geborgenheit schenken. Da die Familie dafür nicht mehr zur Verfügung steht, bleibt das Warten auf die Schließung der Lücke durch den Dienstleistungssektor. Für das Empfinden von Glück sind nicht objektive Tatsachen entscheidend, sondern ihre subjektive Bewertung. Statt von „Glück" sprechen Forscher von „subjektivem Wohlbefinden" und befürworten die Ichlüg-mir-die-Welt-schön-Strategie, auch positives Denken genannt. Meist fehlen jedoch die dazu nötigen mentalen Ressourcen. „Glück empfinden" kommt in zwei Varianten daher: ( 1 ) Glücksmomente während einer kurzen Zeitdauer (pleasure) , etwa bei Sex, Verdauung, Trunkenheit; (2) ein dauerhaftes Gefühl (happiness), zum Beispiel bei aufeinanderfolgenden Glücksmomenten oder Dummheit. Beide Varianten sind unzuverlässig und teuer (deswegen das Sprichwort: „Geld macht glücklich"). Jetzt die gute Nachricht: Glück kann man erzwingen. Zunächst empfehle ich die Bicrce'sche Optik: „Glück: Angenehmes Gefühl; erblüht aus der Betrachtung fremden Elends". Ihr Umfeld ist übersät von Tränensäcken wie Sie einer sind? Beobachten Sie forciert das Schauspiel ihrer Armseligkeit und laden Sie so die Euphoriespeicher auf. Tiefgreifender und zuverlässiger ist ICSS, die Intracranielle Selbstreizung. Olds und Milner, Gründerväter des Internationalen Tierquälerverbaads, haben in den 50-er Jahren beobachtet, dass Ratten bis zur völligen Erschöpfung Tausende von Malen pro Stunde einen Hebel herunterdrückten, mit dem sie sich selbst kurze Stromstöße in bestimmte Hirnregionen verabreichten (ins Belohnungs beziehungsweise Glückszentrum). Das Internationale Institut für Angewandte Volksverarschung, Entwickler des Nullintelligendo DSDS, präsentierte kürzlich den neuartigen ICSS-Skulltop, eine Spezialmütze, die mit einer nanostereotaktischen Vorrichtung wohldosierte intracranielle Reize verabreicht. Mein Rat: Kaufen Sie das Gerät! Zum Schluss ein Beispiel aus dem Leben: Meine Tante urgroßmütterlicherseits hat einen aufstrebenden Profikiller damit beauftragt, die Katze ihres verhassten Nachbarn zu liquidieren. De ...
#
# Similarity: 0.64
#
# Content Item Source:
#   https://impresso-project.ch/app/article/IMP-2017-11-21-a-i0193
#
# Content Item Matched:
#   https://impresso-project.ch/app/article/luxland-2007-03-09-a-i0066
#
# --------------------------------------------------
# Source Text:
#   Rester calmes et jouer avec la tête « Nous devons faire preuve de caractère, montrer que nous méritons notre place à la Coupe du monde après des bonnes qualifications. » Xherdan Shaqiri n’envisage rien d’autre qu’une issue favorable dans ces barrages, même s’il est bien conscient que les Nord-Irlandais vendront chèrement leur peau. « On l’a vu à l’Euro, leurs supporters sont bruyants. Nous serons en terrain hostile. Mais nous allons relever ce défi en équipe », poursuivait le lutin de Stoke City hier, comme pour se décharger des attentes placées en lui. « Je peux être décisif, c’est mon rôle. Mais j’ai besoin de l’équipe. C’est ensemble que l’on gagne. » Pour y parvenir, les Suisses connaissent la recette. « Nous devrons mettre la même passion que nos adversaires dans notre jeu. Il faudra avoir la bonne mentalité, mais il s’agira aussi de jouer avec la tête et de rester calmes », préconisait Yann Sommer. Au passage, signalons que sept joueurs pourraient être privés de match retour en cas d’avertissement ce soir. A savoir : Dzemaili, Gelson, Freuler, Lang, Mehmedi, Rodriguez et Zakaria. Comme à son habitude, Vladimir Petkovic n’a pas dévoilé ses plans. « J’ai déjà mon équipe en tête et je suis conforté dans mes choix par ce que je vois à l’entraînement », lâchait le sélectionneur qui, s’il se serait évidemment passé de ce barrage, est bien conscient du caractère exceptionnel de cette double confrontation. « On ne dispute pas des matches comme ceux-là tous les jours », glissait-il. « Nous connaissons notre adversaire, mais nous devrons nous servir de nos armes. » Des armes parmi lesquelles ne figurent pas, sauf miracle, Valon Behrami. Blessé, le joueur de l’Udinese a été malgré lui au centre de l’attention hier. En effet, son club a exigé qu’il rentre immédiatement en Italie pour se faire soigner, avançant la préconvocation trop tardive voyée par l’Association suisse de football (ASF). « Nous avons effectivement communiqué hors délais avec les clubs. Mais nous avons toujours procédé ainsi en raison des calendriers très chargés. Et cela n’a jamais posé de problèmes. Udinese fait preuve d’un formalisme extrême », relevait Claudio Sulser, le délégué aux équipes nationale. « Valon restera avec nous, sauf si une commission de discipline de la Fifa statue en urgence contre nous. » Quelle que soit l’issue de ce « psychodrame », l’ASF ne sort en tous les cas pas grandie par un pareil amateurisme. ›
#
# Best Match:
#   Die Gotteronfans brauchen Geduld Playout-Vorbereitung mit Spielen gegen Zürich und Ambri Am Dienstag ist Gotteron ui Genf gegen Servette mit einer 5 : 3-Niederlage schlecht in die zweite Hälfte der Qualifikation gestartet . Heute Abend gegen Zürich im Hallenstadion und am Sonntagnachmittag gegen Ambri-Piotta geht die für die Drachen lange Playout-Vorbereitung weiter . Von KURT MING In den nächsten Wochen und Monaten brauchen die Gotteronfans mit ihren Lieblingen viel Geduld und gute Nerven . Ihre Mannschaft wird sich in den verbleibenden 21 Qualifikationsrunden damit beschäftigen , mit einigen Siegen gut gerüstet in die Playouts oder wie vergangene Saison sogar in die Ligaqualifikationsmühle zu steigen . Trainer Serge Pelletiei darf ab sofort nicht mehr kurzfristig denken und Leistungsträger oder angeschlagene Spieler forcieren , um unter allen Umständen Punkte füi die Playoffs zu sammeln . Pelletier : Chancen besser nutzen Der Fokus muss jetzt darauf ausgerichtet werden , die Mannschaft gezielt auf die Meisterschaftsentscheidung im kommenden Frühling zu trimmen . Der Francokanadier kann sich dabei beim SCL-Coach Christian Weber erkundigen , welches Rezept für den Erfolg in der Saisonschlussphase am besten anzuwenden ist . Die Emmentaler waren vergangene Saison in der gleichen kritischen Situation wie der HCF zurzeit , gewannen dann aber in den Playouts als Zwölfte mit fast 20 Punkten Rückstand gegen das da g . & ?? 1 «^ P ^ I mm W +. PJB ^ 3 ^^^^ Jrlm wk wSmimiä i . afeÄ a-. KaaaaaaaaaaaaaaaK aJB ^ Taaaa ^^ aaaaaT- \ aaa >^? aaaaaa ^ 4 . W aV \ jjgMp gi ^ y ~ ifrL ¦ ¦ gjHjr f . ¦ rnm ^ -y- \ y \ rjB • ^ Vergangenen Sonntag : Die Freiburger Sprunger ( 2 . v . I . ) und Monnet ( r . ) gegen die Luganesi ( in Weiss von links ) Vauclair , Romy und Zager . Bild Keystone mais neuntplatzierte Gotteron im Coach Serge Pelletier mit seiner Schnellzugsverfahren . Mannschaft nicht unzufrieden : « Die Trotz der Niederlage in Genf war Einstellung und der Einsatz stimmten . Aber wir haben einmal mehr in den wichtigen Phasen unsere Chancen nicht genutzt . Beim Stande von 3 : 3 zu Beginn des letzten Drittels liefen drei von meinen Spielern allein auf Mona zu , keiner traf . So kann man eben nicht gewinnen . » Kamen noch ein paar defensive Schnitzer von Shawn Heins dazu , die das Übrige zu dieser weiteren unnötigen Niederlage taten . Insgesamt zeigte die Mannschaft jedoch in diesem Westschweizer Derby einen Aufwärtstrend , der für die nächsten Spiele etwas hoffen lässt . Punkto Verstärkungsspieler gab es gestern noch nichts Neues . Manager Mike McParland verhandelt weiterhin mit verschiedenen Spielern , Fehleinkäufe kann er sich jetzt nicht mehr leisten . Im Freitagstraining fehlten weiterhin die verletzten Berger , Vauclair und Haldimann .
#
# Similarity: 0.63
#
# Content Item Source:
#   https://impresso-project.ch/app/article/IMP-2017-11-09-a-i0176
#
# Content Item Matched:
#   https://impresso-project.ch/app/article/FZG-2006-12-02-a-i0104
#
# --------------------------------------------------
# Source Text:
#   TÉLÉVISION RTS UN 8.00 Euronews 8.15 Top Models 8 8.40 C’est ma question ! 9.10 Quel temps fait-il ? 9.25 Madam Secretary 8 10.55 Le court du jour 11.05 Les feux de l’amour 11.40 Demain nous appartient 12.10 Plus belle la vie 12.45 Le 12 h 45 13.25 D’amour et de glace Film TV. Aventures. 15.25 Brokenwood 17.05 Grey’s Anatomy 8 17.50 Le court du jour 17.55 Top Models 8 18.20 C’est ma question ! 18.50 Météo régionale 18.55 Les titres du 19 h 30 8 19.00 Couleurs locales 8 19.30 Le 19 h 30 8 20.10 À bon entendeur 8 JOSÉPHINE, ANGEGARDIEN Série. Comédie. Fra. 2015. Saison 16. Avec Mimie Mathy. Dans la tête d’Antoine. Joséphine doit soutenir la famille d’un homme qui a été victime d’un accident. 22.35 Un jour mon père viendra Film. Comédie. Fra. 2011. Réalisation : Martin Valente. 1 h 35. Avec Gérard Jugnot, François Berléand, Olivia Ruiz. Chloé a tout pour être heureuse. Elle va épouser l’homme qu’elle aime. Ne lui manque que le père idéal. 0.10 The Walking Dead 0.55 Couleurs locales 8 1.15 Le 19 h 30 8 CANAL + 18.05 Catherine et Liliane 18.15 Surprises 18.40 L’info du vrai 20.45 Canalbis 20.58 Catherine et Liliane 21.00 Moi, Daniel Blake 8 Film. Drame 22.40 Tchi tcha 23.30 The Tonight Show Starring Jimmy Fallon 0.15 Une vie 8 Film. Drame. FRANCE 4 18.50 Défis cobayes 820.00 Un gars, une fille 820.50 Monte le son ! 820.55 The Big Lebowski 8 Film. Comédie 22.50 Favelas 8 Film. Drame 0.40 Line of Duty : enquêtes internes 8 2.45 Monte le son, le live-Festival Fnac live 8 NUMÉRO 23 13.10 Non élucidé 816.45 Gros plan 818.15 Pitbulls et prisonniers 820.55 René Bousquet ou le grand arrangement Film TV. Drame 22.50 Maldonne Film TV. Comédie dramatique 0.45 Un fils Film TV. Drame. MTV 6.45 Friendzone 9.45 16 ans et enceinte 12.25 Avant j’étais gros 14.10 17 ans et maman 15.55 Veronica Mars 18.30 The Big Bang Theory 20.45 Ridiculous Made in France 21.10 Ridiculous 22.25 MTV Super Shore 1.50 Geordie Shore RSI LA 1 19.00 Il quotidiano 819.45 Il rompiscatole 820.00 Telegiornale 820.40 Via col venti 821.10 Rizzoli & Isles 8 21.55 Major Crimes 822.35 Info Notte 23.00 Dheepan-Una nuova vita 23 8 Film. Drame 0.50 CSI-Scena del crimine 8 RTS DEUX 6.30 RTS Kids Jeunesse. 10.25 T. T. C. (Toutes taxes comprises) 8 10.50 Pardonnez-moi 11.15 Faut pas croire 8 11.45 Passe-moi les jumelles 8 12.50 Quel temps fait-il ? 13.20 Le 12 h 45 14.20 RTS info 15.20 Einstein 15.50 Interface 16.00 Géopolitis 16.20 Mise au point 8 17.15 Les feux de l’amour 17.55 The Good Wife 19.30 Le 19 h 30 signé 8 20.00 Résultats du Trio Magic, Magic 4 et Banco 20.10 Les Simpson 8 Série. Homer aux mains d’argent. LETEMPSD’ANNA Film TV. Comédie dramatique. Suisse. 2015. Réal. : G. Zglinski. 1 h 31. Avec G. Bona. Lors de la Première Guerre mondiale, l’histoire croisée de quatre amis. 22.15 L’âme du tigre Film. Drame. Suisse-Fra-B. 2016. Réal. : F. Yang. Inédit. 1 h 31. Avec Frédéric Siuen. Au décès de son frère, Alex enquête sur sa mystérieuse disparition. 23.50 Le court du jour 23.51 Tirage Euro Millions 23.53 Résultats du Trio Magic, Magic 4 et Banco 23.55 Pl 3 in le poste on Tour FRANCE 5 17.30 C à dire ?! 817.45 C dans l’air 819.00 C à vous 820.00 C à vous, la suite 820.20 Entrée libre 820.50 Le jour où les dinosaures ont disparu 821.40 Le muséum prend vie 822.45 C dans l’air 823.55 C à vous 8 0.50 C à vous, la suite 8 CSTAR 6.00 Lâche ta couette 8.30 Top clip 10.30 Top CStar 11.00 Top France 12.15 Top clip 14.30 Top 2000 15.45 Top France 17.00 Top albums 18.05 Pawn Stars-Les rois des enchères 20.50 DC : Legends of Tomorrow 22.40 DC : Legends of Tomorrow RMC DÉCOUVERTE 11.50 Wheeler Dealers-Occasions à saisir 816.15 Les constructeurs de l’extrême USA 817.10 Les constructeurs de l’extrême 820.50 Champs de bataille 21.50 1914-1918 : le sport à l’épreuve du feu 22.50 Champs de bataille 8 MEZZO 20.30 Hommage à Hans Van Manen, Dutch National Ballet, Festival de Danse de Montpellier 21.50 Love Chapter 2 22.55 Gnosis 23.35 David Krakauer Ancestral Groove au festival Jazz à Porquerolles ...
#
# Best Match:
#   TSR 1 20.45 Prémonitions 7.00 EuroNews 7.35 Quel temps fait-il ? 7.55 Tout le monde aime Raymond 8.20 Dolce vita 8.50 Top Models 9.10 Leçons de séduction 10.40 EuroNews 11.05 Les Feux de l'amour 11.50 Le Rêve de Diana 12.10 Plus belle la vie 12.45 Le journal 13.25 Toute une histoire 14.30 Arabesque 15.30 7 à la maison 16.20 Desperate Housewives 17.05 Plus belle la vie 17.35 Dolce vita 18.05 Le court du jour 18.10 Tapis rouge 18.30 Top Models 18.55 Couleurs locales 19.30 Le journal 20.10 T. T. C. (Toutes taxes comprises) T. T. C. se décline au féminin. 20.45 Prémonitions Film. Thriller. EU. 2007. Réal .: Mennan Yapo. 1 h 40. Avec : Sandra Bullock, Julian McMahon, Shyann McClure, Courtney Taylor Burness. Une femme est hantée par des cauchemars mettant en scène la mort de son mari. 22.25 New York, section criminelle Série. Policière. EU. 2009. Réal .: Norberto Barba. 40 minutes. 15 / 16. Inédit. Sauvés des flammes. Un top model passe la nuit avec une femme mystérieuse. Il est retrouvé mort le lendemain. 23.05 Cinhebdo 23.25 Le journal 23.40 Journeyman 0.20 Couleurs locales 0.40 Le journal TV 5 MONDE 19.00 Roxy. 19.30 Journal (TSR). 20.00 Catherine. 20.30 Journal (France 2). 21.00 Den Muso. Film. Drame psychologique. 22.25 Lumière et caméra. 22.55 TV 5 MONDE, le journal. 23.05 Le journal de l'éco. 23.10 TV 5 MONDE, le journal Afrique. EUROSPORT 15.15 Paris-Nice 2010. Cyclisme. 1 re étape : Saint-Arnoult-en-Yvelines-Contres (201,5 km). En direct. 18.00 Coupe du monde. Saut à skis. HS 127. Qualifications. En direct. 20.15 Laval / Metz. Football. Championnat de France Ligue 2. En direct. CANAL + 18.15 Les Simpson (C). 18.40 Le JT de Canal + (C). 19.05 Le grand journal de Canal + (C). 19.55 Les Guignols de l'info (C). 20.10 Le grand journal, la suite (C). 20.50 Welcome. Film. Drame. Inédit. 22.35 82 e cérémonie des Oscars. Les meilleurs moments. PLANETE 17.20 Vivre de sang froid. 18.15 Devenir un homme en Sibérie. 19.10 Bandes de lémuriens. 19.40 Que le meilleur gagne !. 20.40 Dakinis, le féminin de la sagesse. 21.40 Libéria, le combat des femmes. 22.45 La terre. 23.45 Les derniers maîtres de la Martinique. TSR 2 20.45 Classe Politique 6.30 Mabule 10.25 Les Zozios 12.05 Mabule 12.15 tsrinfo 12.45 Quel temps fait-il ? 13.20 Le journal 13.55 tsrinfo 14.25 Grand angle 14.35 Mise au point Au sommaire : « URI : « Nous sommes tous des Noirs »».-« Le MCG fait des bébés ».-« Une prison modèle pour femmes en Afghanistan ». 15.25 Temps présent Tu n'iras pas en EMS. 16.20 Le passager Invité : Johan Djourou, footballeur. 16.55 Melrose Place 17.45 Les Simpson 18.35 Kyle XY Soif d'apprendre. 19.30 Le journal 20.00 Banco Jass 20.10 La boîte à musique 20.45 Classe Politique Débat. En direct. 1 heure. Invités : Doris Leuthard, Didier Berberat, Ueli Leuenberger, Urs Schwaller, Charles Favre, Jean-François Rime. Depuis Berne. Comment sortir rance-chômage et ses 6 milliards de dettes ? 21.45 La machine à remonter le temps Documentaire. Sciences. Sui. 2008. Réal .: Yariv Friedman. 55 minutes. Le nouvel accélérateur de particules du CERN va permettre de générer des températures 100 000 fois supérieures à celles du centre du Soleil. 22.40 Vu à la télé 23.10 Géopolitis 23.40 Main basse sur le riz AB 1 17.10 Premiers Baisers. 17.40 Hélène et les Garçons. 18.35 Extreme Make Over : Home Edition. La famille Hawkins. 19.20 La Vie de famille. 20.40 Profiler. 23.10 Commando de la peur. Film TV. Action. EU. 2001. Réal .: Ian Gilmore. 1 h 35. RSI 1 18.00 Telegiornale flash. 18.10 Zerovero. 19.00 Il Quotidiano. 19.40 Contesto. 20.00 Telegiornale. 20.35 Meteo. 20.40 Attenti a quei due . 21.05 A Mighty Heart : Un cuore grande . Film. Drame. 22.55 Criminal Minds. 23.45 Telegiornale notte. SF 1 19.30 Tagesschau. 20.05 Al dente. Die Koch- und Quizshow von Betty Bossi. 21.05 Puls. 21.50 10 vor 10.22.15 Meteo. 22.20 Eco. 22.50 Keine zu klein, eine Miss zu sein. Wie Mütter ihre Töchter auf dem Laufsteg drängen. 23.50 Tagesschau Nacht. ARD 20.00 Tagesschau. 20.15 Kaltblütig. ...
#
# Similarity: 0.77
#
# Content Item Source:
#   https://impresso-project.ch/app/article/IMP-2017-11-07-a-i0107
#
# Content Item Matched:
#   https://impresso-project.ch/app/article/EXP-2010-03-08-a-i0260
#
# --------------------------------------------------
# Source Text:
#   TÉLÉVISION 25 RTS UN 8.20 Top Models 8.40 C’est ma question ! 9.10 Quel temps fait-il ? 9.30 Madam Secretary 8 10.55 Le court du jour 11.05 Les feux de l’amour 11.40 Demain nous appartient 12.10 Plus belle la vie 12.45 Le 12 h 45 13.25 Le défi de Kate Film TV. Thriller. 15.10 Les enquêtes de Vera 8 16.40 The Middle 17.05 Grey’s Anatomy 8 17.50 Le court du jour 17.55 Top Models 8 18.25 C’est ma question ! 18.50 Météo régionale 18.55 Les titres du 19 h 30 19.00 Couleurs locales 8 19.30 Le 19 h 30 8 20.05 À bon entendeur L’ÉTUDIANTE ETMONSIEURHENRI Film. Comédie. Fra. 2015. Réal. : I. Calbérac. 1 h 40. Avec C. Brasseur. À cause de sa santé vacillante, Henri Voizot ne peut plus vivre seul. 22.35 Comme des frères Film. Comédie. Fra. 2012. Réalisation : Hugo Gélin. 1 h 44. Avec François-Xavier Demaison. Après le décès d’une femme qu’ils ont aimée, trois hommes se retrouvent embarqués dans un voyage. 0.15 The Walking Dead 1.50 Couleurs locales 8 2.05 Le 19 h 30 8 CANAL + 18.40 L’info du vrai 20.45 Canalbis 20.55 Catherine et Liliane 21.00 La fille de Brest 8 Film. Drame 23.05 Insidious : Chapitre 3 8 Film. Horreur 0.40 Ça continue encore et encore 0.50 Conjuring 2 : le cas Enfield 8 Film. FRANCE 4 16.30 Ninjago 817.40 Les As de la jungle à la rescousse ! 18.50 Défis cobayes 820.00 Il était une fois... la vie 820.55 Les rois du bêtisier 823.25 D’Jal : « Just D’Jal » 80.45 On va rire de tout ! 82.35 Monte le son, le live-Rock en Seine 8 NUMÉRO 23 13.45 Ces crimes qui ont choqué le monde 16.30 Révélations 818.15 Pitbulls et prisonniers 820.55 La volière aux enfants Film TV. Historique 22.45 Un fils Film TV. Drame 0.40 Le silence de la mer 8 Film TV. MTV 6.45 Friendzone 9.45 16 ans et enceinte 12.25 Avant j’étais gros 14.10 17 ans et maman 15.55 Veronica Mars 18.30 The Big Bang Theory 20.45 Ridiculous Made in France 21.10 Ridiculous 22.25 MTV Super Shore 1.50 Geordie Shore RSI LA 1 19.45 Il rompiscatole 820.00 Telegiornale 820.40 Via col venti 821.10 Rizzoli & Isles 821.50 Le regole del delitto perfetto 822.40 Info Notte 23.05 Bernie 8 Film. Comédie 0.40 CSI-Scena del crimine 8 1.25 Repliche informazione RTS DEUX 6.30 RTS Kids Jeunesse. 9.05 L’étrange pouvoir de Norman Film. Animation. 10.25 T. T. C. (Toutes taxes comprises) 8 11.20 Pardonnez-moi 11.50 Faut pas croire 8 12.20 Passe-moi les jumelles 8 13.25 Le 12 h 45 14.00 Svizra Rumantscha 14.25 RTS info 15.20 Einstein 15.45 Interface 16.00 Géopolitis 16.15 Mise au point 8 17.10 Les feux de l’amour 17.50 The Good Wife 19.30 Le 19 h 30 signé 8 20.00 Résultats du Trio Magic, Magic 4 et Banco BÂLE / CSKAMOSCOU Ligue des champions. Gourpe A, 4 journée. En direct du Parc Saint-Jacques de Bâle. Le FC Bâle avait réalisé un carton face au Benfica Lisbonne (5-0). 23.10 Le court du jour 23.15 Tirage Euro Millions 23.17 Résultats du Trio Magic, Magic 4 et Banco 23.20 Le court du jour 23.25 Occupy the Pool Film. Doc. Suisse. 2013. Réal. : Kim Seob Boninsegni. 1 h 14. Ce film s’intéresse à un groupe de jeunes adultes passant de fêtes en fêtes. 0.45 À bon entendeur 8 FRANCE 5 16.35 Le marcheur du Nil 8 17.30 C à dire ?! 817.45 C dans l’air 819.00 C à vous 820.00 C à vous, la suite 820.20 Entrée libre 820.50 Les derniers trésors d’É gypte 822.15 C dans l’air 823.25 C à vous 80.20 C à vous, la suite 8 CSTAR 8.30 Top clip 10.30 Top CStar 11.00 Top France 12.15 Le Zap d’Halloween 14.00 Top clip 14.30 Top 90 15.45 Top France 17.00 Top albums 18.05 Pawn Stars-Les rois des enchères 20.50 DC : Legends of Tomorrow 22.40 DC : Legends of Tomorrow RMC DÉCOUVERTE 8.35 Coupable ou non coupable ? 812.00 Ultime garage 16.15 Les maîtres de la construction 820.50 Vampires, mythe ou réalité ? 21.50 Guerriers légendaires 22.40 La vérité sur les zombies 23.30 A la recherche du secret de l’alchimie MEZZO 15.15 Intermezzo 16.30 Lady Macbeth de Mzensk 19.20 Intermezzo 20.30 Déesses et Démones 21.50 Robot 23.15 Intermezzo 23.30 The Bad Plus au Skoda Jazz Festival 0.35 Jimmy Owens quintet « Monk project » au Festival Jazz à ...
#
# Best Match:
#   TÉLÉVISION RTS Un 8.30 Top Models 8 8.50 C’est ma question ! 9.15 Quel temps fait-il ? 9.30 Royal Pains 10.55 Le court du jour 11.00 Les feux de l’amour 11.40 Scènes de ménages 12.10 Plus belle la vie 12.45 Le 12 h 45 13.20 Guerre froide sous les tropiques Film TV. Comédie. 14.55 Louis la Brocante 16.25 Monk 17.10 Les mystères de Laura 8 17.50 Le court du jour 18.00 Top Models 8 18.25 C’est ma question ! 18.50 Météo régionale 18.55 Couleurs locales 8 19.30 Le 19 h 30 8 20.10 36,9° 21.15 MAGAZINE Infrarouge Magazine. Présentation : Romaine Morard. 1 h 00. Sous forme d’un débat qui se déroule en public, « Infrarouge » aborde les thèmes qui font l’actualité. 22.15 Swiss Loto 22.25 Sherlock Série. Policière. GB. 2016. Saison 4. Avec Benedict Cumberbatch, Martin Freeman ,. Le dernier problème. Inédit. Sherlock Holmes a découvert l’existence d’Eurus Holmes, sa soeur, psychopathe à l’intelligence redoutable. 0.05 The Missing 8 1.05 Couleurs locales 8 Canal + 19.25 Le Gros journal 20.00 Les Guignols 20.15 Le petit journal 20.50 Les Guignols 21.00 Le plateau télé de Catherine et Liliane 22.35 21 cm Invité : Jean d’Ormesson 23.25 Joséphine s’arrondit Film. Comédie 0.55 Versailles 8 France 4 20.00 Une saison chez les bonobos 8 20.45 Monte le son ! 8 20.54 Mercredi, c’est ciné 8 20.55 Le vélo de Ghislain Lambert 8 Film. Comédie 22.50 La nuit nous appartient 8 Film. Policier 0.40 Monte le son, les sessions 8 Numéro 23 6.45 Un flic 8.20 Révélations 8 10.00 Les grandes gueules : débat, société, diversité 13.10 Non élucidé 8 16.25 Révélations 8 18.15 Profession vétérinaire 8 20.55 Generation War 22.50 Ripper Street 8 0.50 Orange is the New Black MTV 11.35 How I Met Your Mother 13.20 Avant j’étais gros 14.55 Veronica Mars 17.25 How I Met Your Mother 18.40 The Big Bang Theory 20.45 Catfish Brésil 22.45 Catfish : fausse identité 23.35 Black Ink Crew 3.10 The Valleys RSI 1 19.00 Il quotidiano 8 19.45 Il rompiscatole 8 20.00 Telegiornale 8 20.40 Via col venti 8 21.10 Criminal Minds 8 21.55 Blacklist 8 22.40 Suits 23.30 Lotto Svizzero 23.45 Tutti i nostri desideri Film. Drame 1.40 Repliche continuate RTS Deux 6.30 RTS Kids 10.35 À bon entendeur 8 11.10 Mise au point 8 12.05 RTS info 12.45 Quel temps fait-il ? 13.15 Le 12 h 45 13.40 Faló 14.05 Fievel et le mystère du monstre de la nuit Film TV. Animation. 15.20 RTS Kids 17.25 The Middle Série. Orlando. 17.50 Heartland Série. Retrouvailles.Ce qu’on a perdu. 19.30 Le 19 h 30 signé 8 20.00 Résultats du Trio Magic, Magic 4 et Banco 20.10 Au coeur du sport 8 Magazine. Invité : Nino Schurter. 20.40 FILM Working Girl Film. Comédie. EU. 1988. VM. Réal. : M. Nichols. 1 h 45. Avec M. Griffith. Quand sa patronne s’absente pour accident, une secrétaire new-yorkaise prend sa place en secret. 22.35 Swiss Loto 22.39 Résultats du Trio Magic, Magic 4 et Banco 22.40 Le court du jour 22.50 Comme un chien enragé Film. Drame. EU. 1986. VM. Réalisation : James Foley. 1 h 55. Avec Sean Penn. Le quotidien d’un desoeuvré est bouleversé quand il tombe amoureux et retrouve son père. 0.45 36,9° France 5 17.30 C à dire ?! 8 17.45 C dans l’air 8 19.00 C à vous 8 20.00 C à vous, la suite 20.20 Entrée libre 8 20.50 Aux sources d’Angkor 8 21.40 La Grande Muraille de Chine 8 22.35 C dans l’air 8 23.45 Entrée libre 8 0.10 Déserts 8 CSTAR 11.30 Le Morning 11.50 Top CStar 12.30 Top clip 14.30 Top hip-hop 15.45 Top CStar 17.00 Top Streaming 18.05 Pawn Stars-Les rois des enchères 20.50 La loi du tueur Film TV. Thriller 22.25 Double riposte Film TV. Action. RMC découverte 5.55 Bourdin direct 8.40 Non élucidé 8 12.00 Car S. O. S 8 13.35 Les justiciers des mers 8 16.10 Enchères à tout prix spécial British 20.50 Vintage Mecanic 21.50 Vintage Mecanic 22.50 Vintage garage : occaz à tous prix MEZZO 16.30 Vicente Amigo 17.30 Tinissima quartet-Banlieues Bleues 18.30 Nox. 3-Jazz à Vienne 19.15 Intermezzo 20.30 Don Giovanni 23.40 Golden Gate Quartet au Festival Jazz à Vienne 1.10 Roscoe Mitchell au Skopje Jazz Festival RSI 2 19.30 Last Cop-L’ulti ...
#
# Similarity: 0.77
#
# Content Item Source:
#   https://impresso-project.ch/app/article/IMP-2017-10-31-a-i0234
#
# Content Item Matched:
#   https://impresso-project.ch/app/article/EXP-2017-03-29-a-i0225
#
# --------------------------------------------------
# Source Text:
# ...
#
# Best Match:
#   TÉLÉVISION RTS Un 8.30 Top Models 8 8.50 C’est ma question ! 9.15 Quel temps fait-il ? 9.30 Royal Pains 10.55 Le court du jour 11.00 Les feux de l’amour 11.40 Scènes de ménages 12.10 Plus belle la vie 12.45 Le 12 h 45 13.20 Guerre froide sous les tropiques Film TV. Comédie. 14.55 Louis la Brocante 16.25 Monk 17.10 Les mystères de Laura 8 17.50 Le court du jour 18.00 Top Models 8 18.25 C’est ma question ! 18.50 Météo régionale 18.55 Couleurs locales 8 19.30 Le 19 h 30 8 20.10 36,9° 21.15 MAGAZINE Infrarouge Magazine. Présentation : Romaine Morard. 1 h 00. Sous forme d’un débat qui se déroule en public, « Infrarouge » aborde les thèmes qui font l’actualité. 22.15 Swiss Loto 22.25 Sherlock Série. Policière. GB. 2016. Saison 4. Avec Benedict Cumberbatch, Martin Freeman ,. Le dernier problème. Inédit. Sherlock Holmes a découvert l’existence d’Eurus Holmes, sa soeur, psychopathe à l’intelligence redoutable. 0.05 The Missing 8 1.05 Couleurs locales 8 Canal + 19.25 Le Gros journal 20.00 Les Guignols 20.15 Le petit journal 20.50 Les Guignols 21.00 Le plateau télé de Catherine et Liliane 22.35 21 cm Invité : Jean d’Ormesson 23.25 Joséphine s’arrondit Film. Comédie 0.55 Versailles 8 France 4 20.00 Une saison chez les bonobos 8 20.45 Monte le son ! 8 20.54 Mercredi, c’est ciné 8 20.55 Le vélo de Ghislain Lambert 8 Film. Comédie 22.50 La nuit nous appartient 8 Film. Policier 0.40 Monte le son, les sessions 8 Numéro 23 6.45 Un flic 8.20 Révélations 8 10.00 Les grandes gueules : débat, société, diversité 13.10 Non élucidé 8 16.25 Révélations 8 18.15 Profession vétérinaire 8 20.55 Generation War 22.50 Ripper Street 8 0.50 Orange is the New Black MTV 11.35 How I Met Your Mother 13.20 Avant j’étais gros 14.55 Veronica Mars 17.25 How I Met Your Mother 18.40 The Big Bang Theory 20.45 Catfish Brésil 22.45 Catfish : fausse identité 23.35 Black Ink Crew 3.10 The Valleys RSI 1 19.00 Il quotidiano 8 19.45 Il rompiscatole 8 20.00 Telegiornale 8 20.40 Via col venti 8 21.10 Criminal Minds 8 21.55 Blacklist 8 22.40 Suits 23.30 Lotto Svizzero 23.45 Tutti i nostri desideri Film. Drame 1.40 Repliche continuate RTS Deux 6.30 RTS Kids 10.35 À bon entendeur 8 11.10 Mise au point 8 12.05 RTS info 12.45 Quel temps fait-il ? 13.15 Le 12 h 45 13.40 Faló 14.05 Fievel et le mystère du monstre de la nuit Film TV. Animation. 15.20 RTS Kids 17.25 The Middle Série. Orlando. 17.50 Heartland Série. Retrouvailles.Ce qu’on a perdu. 19.30 Le 19 h 30 signé 8 20.00 Résultats du Trio Magic, Magic 4 et Banco 20.10 Au coeur du sport 8 Magazine. Invité : Nino Schurter. 20.40 FILM Working Girl Film. Comédie. EU. 1988. VM. Réal. : M. Nichols. 1 h 45. Avec M. Griffith. Quand sa patronne s’absente pour accident, une secrétaire new-yorkaise prend sa place en secret. 22.35 Swiss Loto 22.39 Résultats du Trio Magic, Magic 4 et Banco 22.40 Le court du jour 22.50 Comme un chien enragé Film. Drame. EU. 1986. VM. Réalisation : James Foley. 1 h 55. Avec Sean Penn. Le quotidien d’un desoeuvré est bouleversé quand il tombe amoureux et retrouve son père. 0.45 36,9° France 5 17.30 C à dire ?! 8 17.45 C dans l’air 8 19.00 C à vous 8 20.00 C à vous, la suite 20.20 Entrée libre 8 20.50 Aux sources d’Angkor 8 21.40 La Grande Muraille de Chine 8 22.35 C dans l’air 8 23.45 Entrée libre 8 0.10 Déserts 8 CSTAR 11.30 Le Morning 11.50 Top CStar 12.30 Top clip 14.30 Top hip-hop 15.45 Top CStar 17.00 Top Streaming 18.05 Pawn Stars-Les rois des enchères 20.50 La loi du tueur Film TV. Thriller 22.25 Double riposte Film TV. Action. RMC découverte 5.55 Bourdin direct 8.40 Non élucidé 8 12.00 Car S. O. S 8 13.35 Les justiciers des mers 8 16.10 Enchères à tout prix spécial British 20.50 Vintage Mecanic 21.50 Vintage Mecanic 22.50 Vintage garage : occaz à tous prix MEZZO 16.30 Vicente Amigo 17.30 Tinissima quartet-Banlieues Bleues 18.30 Nox. 3-Jazz à Vienne 19.15 Intermezzo 20.30 Don Giovanni 23.40 Golden Gate Quartet au Festival Jazz à Vienne 1.10 Roscoe Mitchell au Skopje Jazz Festival RSI 2 19.30 Last Cop-L’ulti ...
#
# Similarity: 0.81
#
# Content Item Source:
#   https://impresso-project.ch/app/article/EXP-2017-10-23-a-i0088
#
# Content Item Matched:
#   https://impresso-project.ch/app/article/EXP-2017-03-29-a-i0225
#
# --------------------------------------------------
# Source Text:
#   TÉLÉVISION RTS UN 9.05 Top Models 8 10.55 Le court du jour 11.05 Les feux de l’amour 11.40 Demain nous appartient 12.10 Plus belle la vie 12.45 Le 12 h 45 13.20 Ensemble 13.30 Un papa au garde-à-vous 3 Film TV. Comédie. 15.05 Les enquêtes de Vera 16.40 The Middle 17.05 Grey’s Anatomy 8 17.50 Le court du jour 17.55 Top Models 8 18.25 C’est ma question ! 18.50 Météo régionale 18.55 Les titres du 19 h 30 19.00 Couleurs locales 8 19.30 Le 19 h 30 8 20.10 T. T. C. (Toutes taxes comprises) 8 ADALINE Film. Drame. EU. 2015. VM. Réal. : L. Toland Krieger. 1 h 52. Avec Blake Lively. Adaline Bowman, 30 ans, se retrouve immunisée contre les ravages du temps. 22.35 Trois mondes Film. Drame. Fra. 2012. Réalisation : Catherine Corsini. 1 h 41. Avec Raphaël Personnaz. Un jeune homme sur le point de se marier renverse un inconnu et s’enfuit. Mais une femme à tout vu. 0.15 You’re the Worst 0.40 Couleurs locales 8 0.55 Le 19 h 30 8 1.45 Euronews CANAL + 18.00 Surprises 18.10 Canalbis 18.20 Catherine et Liliane 18.30 L’info du vrai 20.45 Canalbis 20.55 Catherine et Liliane 21.00 Engrenages 823.05 L’effet papillon 23.55 The Tonight Show Starring Jimmy Fallon 0.40 Baccalauréat Film. FRANCE 4 16.05 Scooby-Doo et la cybertraque 8 Film TV. 17.15 Ninjago 818.30 Les As de la jungle à la rescousse ! 20.00 Une saison au Puy du Fou 8 20.55 Les copains d’abord en Bretagne 23.05 On va rire de tout ! 0.50 D’Jal : « Just D’Jal » 8 NUMÉRO 23 5.45 JT Morning 6.00 Enquêtes réservées 88.15 Révélations 810.00 Les grandes gueules : débat, société, diversité 13.20 Dossiers criminels 16.30 Révélations 818.15 Pitbulls et prisonniers 820.55 Révélations 822.45 Révélations 8 MTV 6.00 MTV Music 6.45 Friendzone 9.45 17 ans et maman 2 12.25 Catfish : fausse identité 14.10 16 ans et enceinte 15.55 Veronica Mars 18.30 The Big Bang Theory 20.45 Too Fat For 15 22.25 Ex on the Beach 0.15 MTV Super Shore RSI LA 1 20.00 Telegiornale 820.40 Via col venti 821.10 Io e lei Film. Comédie sentimentale. Ital. 2015.1 h 42 22.55 Info Notte 23.20 Segni dei tempi 23.45 Mentalist 80.25 KnockoutResa dei conti 8 Film. Action. EU. 2011. VM. 1 h 33 RTS DEUX 6.25 RTS Kids Jeunesse. 10.20 Infrarouge 8 11.20 Al dente 8 12.10 Pardonnez-moi 12.35 RTS info 12.45 Quel temps fait-il ? 13.00 Le 12 h 45 13.35 RTS info 13.50 Alors, on danse ? 8 14.45 Passe-moi les jumelles 15.50 Temps présent 16.50 Les feux de l’amour 17.30 The Good Wife 18.15 Les Simpson 18.40 Nouvo 8 19.00 Tennis Tournoi ATP de Bâle. 16 de finale. En direct de la St. Jakobshalle. 20.40 Résultats du Trio Magic, Magic 4 et Banco JURA- ENRACINÉS ÀLEURSTERRES Doc. Nature. 2017. Réal. : Daniel Künzi. 1 h 15. Inédit. En Suisse, de plus en plus d’agriculteurs ont bien du mal à joindre les deux bouts. 22.05 Le court du jour 22.10 Résultats du Trio Magic, Magic 4 et Banco 22.15 Géopolitis 22.35 Pardonnez-moi Magazine. Présentation : Darius Rochebin. 0 h 25. Darius Rochebin conduit un entretien en face-à-face avec une personnalité. 23.00 Gorbatchev-ReaganDuel au sommet FRANCE 5 16.35 Papouasie, l’expédition extrême 817.30 C à dire ?! 8 17.45 C dans l’air 819.00 C à vous 820.00 C à vous, la suite 820.20 Entrée libre 820.50 Le guépard 8 Film. Drame 23.55 C dans l’air 81.10 C à vous 82.05 C à vous, la suite 8 CSTAR 11.00 Top Streaming 12.15 Top clip 14.30 Top 80 15.45 Top CStar 17.00 Top France 18.05 Pawn Stars-Les rois des enchères 20.50 France / Ghana. Football. Match amical féminin. En direct de Reims 22.50 La story du clip RMC DÉCOUVERTE 5.55 Bourdin direct 8.35 Coupable ou non coupable ? 812.00 Constructions hors limites 816.15 Yukon Gold : l’or à tout prix 20.50 Wheeler Dealers France. Série doc. Alpine A 110 21.50 Wheeler Dealers France MEZZO 20.30 Yuri Temirkanov dirige Prokofiev et Tchaïkovski avec l’Orchestre de Paris 21.55 Christoph Eschenbach dirige le Gustav Mahler Jugendorchester à Abu Dhabi 23.04 Intermezzo 23.30 Kneebody au Festival Jazz à la Villette RSI LA 2 16.35 Timbavati-Le terre dei re 17.30 DiAD à 18.40 Sportmix 19.00 Tennis. S ...
#
# Best Match:
#   TÉLÉVISION RTS Un 8.30 Top Models 8 8.50 C’est ma question ! 9.15 Quel temps fait-il ? 9.30 Royal Pains 10.55 Le court du jour 11.00 Les feux de l’amour 11.40 Scènes de ménages 12.10 Plus belle la vie 12.45 Le 12 h 45 13.20 Guerre froide sous les tropiques Film TV. Comédie. 14.55 Louis la Brocante 16.25 Monk 17.10 Les mystères de Laura 8 17.50 Le court du jour 18.00 Top Models 8 18.25 C’est ma question ! 18.50 Météo régionale 18.55 Couleurs locales 8 19.30 Le 19 h 30 8 20.10 36,9° 21.15 MAGAZINE Infrarouge Magazine. Présentation : Romaine Morard. 1 h 00. Sous forme d’un débat qui se déroule en public, « Infrarouge » aborde les thèmes qui font l’actualité. 22.15 Swiss Loto 22.25 Sherlock Série. Policière. GB. 2016. Saison 4. Avec Benedict Cumberbatch, Martin Freeman ,. Le dernier problème. Inédit. Sherlock Holmes a découvert l’existence d’Eurus Holmes, sa soeur, psychopathe à l’intelligence redoutable. 0.05 The Missing 8 1.05 Couleurs locales 8 Canal + 19.25 Le Gros journal 20.00 Les Guignols 20.15 Le petit journal 20.50 Les Guignols 21.00 Le plateau télé de Catherine et Liliane 22.35 21 cm Invité : Jean d’Ormesson 23.25 Joséphine s’arrondit Film. Comédie 0.55 Versailles 8 France 4 20.00 Une saison chez les bonobos 8 20.45 Monte le son ! 8 20.54 Mercredi, c’est ciné 8 20.55 Le vélo de Ghislain Lambert 8 Film. Comédie 22.50 La nuit nous appartient 8 Film. Policier 0.40 Monte le son, les sessions 8 Numéro 23 6.45 Un flic 8.20 Révélations 8 10.00 Les grandes gueules : débat, société, diversité 13.10 Non élucidé 8 16.25 Révélations 8 18.15 Profession vétérinaire 8 20.55 Generation War 22.50 Ripper Street 8 0.50 Orange is the New Black MTV 11.35 How I Met Your Mother 13.20 Avant j’étais gros 14.55 Veronica Mars 17.25 How I Met Your Mother 18.40 The Big Bang Theory 20.45 Catfish Brésil 22.45 Catfish : fausse identité 23.35 Black Ink Crew 3.10 The Valleys RSI 1 19.00 Il quotidiano 8 19.45 Il rompiscatole 8 20.00 Telegiornale 8 20.40 Via col venti 8 21.10 Criminal Minds 8 21.55 Blacklist 8 22.40 Suits 23.30 Lotto Svizzero 23.45 Tutti i nostri desideri Film. Drame 1.40 Repliche continuate RTS Deux 6.30 RTS Kids 10.35 À bon entendeur 8 11.10 Mise au point 8 12.05 RTS info 12.45 Quel temps fait-il ? 13.15 Le 12 h 45 13.40 Faló 14.05 Fievel et le mystère du monstre de la nuit Film TV. Animation. 15.20 RTS Kids 17.25 The Middle Série. Orlando. 17.50 Heartland Série. Retrouvailles.Ce qu’on a perdu. 19.30 Le 19 h 30 signé 8 20.00 Résultats du Trio Magic, Magic 4 et Banco 20.10 Au coeur du sport 8 Magazine. Invité : Nino Schurter. 20.40 FILM Working Girl Film. Comédie. EU. 1988. VM. Réal. : M. Nichols. 1 h 45. Avec M. Griffith. Quand sa patronne s’absente pour accident, une secrétaire new-yorkaise prend sa place en secret. 22.35 Swiss Loto 22.39 Résultats du Trio Magic, Magic 4 et Banco 22.40 Le court du jour 22.50 Comme un chien enragé Film. Drame. EU. 1986. VM. Réalisation : James Foley. 1 h 55. Avec Sean Penn. Le quotidien d’un desoeuvré est bouleversé quand il tombe amoureux et retrouve son père. 0.45 36,9° France 5 17.30 C à dire ?! 8 17.45 C dans l’air 8 19.00 C à vous 8 20.00 C à vous, la suite 20.20 Entrée libre 8 20.50 Aux sources d’Angkor 8 21.40 La Grande Muraille de Chine 8 22.35 C dans l’air 8 23.45 Entrée libre 8 0.10 Déserts 8 CSTAR 11.30 Le Morning 11.50 Top CStar 12.30 Top clip 14.30 Top hip-hop 15.45 Top CStar 17.00 Top Streaming 18.05 Pawn Stars-Les rois des enchères 20.50 La loi du tueur Film TV. Thriller 22.25 Double riposte Film TV. Action. RMC découverte 5.55 Bourdin direct 8.40 Non élucidé 8 12.00 Car S. O. S 8 13.35 Les justiciers des mers 8 16.10 Enchères à tout prix spécial British 20.50 Vintage Mecanic 21.50 Vintage Mecanic 22.50 Vintage garage : occaz à tous prix MEZZO 16.30 Vicente Amigo 17.30 Tinissima quartet-Banlieues Bleues 18.30 Nox. 3-Jazz à Vienne 19.15 Intermezzo 20.30 Don Giovanni 23.40 Golden Gate Quartet au Festival Jazz à Vienne 1.10 Roscoe Mitchell au Skopje Jazz Festival RSI 2 19.30 Last Cop-L’ulti ...
#
# Similarity: 0.81
#
# Content Item Source:
#   https://impresso-project.ch/app/article/IMP-2017-10-23-a-i0078
#
# Content Item Matched:
#   https://impresso-project.ch/app/article/EXP-2017-03-29-a-i0225
#
# --------------------------------------------------

# %% [markdown]
# ## 5. Summary and Next Steps
#
# The pipeline, models and codes we provide is not the only method to find similar texts. You can always experiment with different models. pipelines and data filtering methods. Feel free to re-use our code!
