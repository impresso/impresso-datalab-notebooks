# %% [markdown]
# # Impresso API SETUP

# %%
# !pip install git+https://github.com/impresso/impresso-py.git@embeddings-search
# Out:
# Collecting git+https://github.com/impresso/impresso-py.git@embeddings-search
#   Cloning https://github.com/impresso/impresso-py.git (to revision embeddings-search) to /tmp/pip-req-build-xphgqihk
#   Running command git clone --filter=blob:none --quiet https://github.com/impresso/impresso-py.git /tmp/pip-req-build-xphgqihk
#   Running command git checkout -b embeddings-search --track origin/embeddings-search
#   Switched to a new branch 'embeddings-search'
#   Branch 'embeddings-search' set up to track remote branch 'embeddings-search' from 'origin'.
#   Resolved https://github.com/impresso/impresso-py.git to commit a5fd1a1fbb4b130b3b96d7483e92e6eadf763f71
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from impresso==0.9.13) (2.10.1)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in /usr/local/lib/python3.12/dist-packages (from impresso==0.9.13) (6.0.3)
# Collecting attrs<24.0.0,>=23.2.0 (from impresso==0.9.13)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting httpx<0.28.0,>=0.27.0 (from impresso==0.9.13)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from impresso==0.9.13) (3.10.0)
# Requirement already satisfied: pandas<3.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from impresso==0.9.13) (2.2.2)
# Requirement already satisfied: pandas-stubs<3.0.0.0,>=2.2.1.240316 in /usr/local/lib/python3.12/dist-packages (from impresso==0.9.13) (2.2.2.240909)
# Collecting protobuf<7.0.0,>=6.32.1 (from impresso==0.9.13)
#   Downloading protobuf-6.33.0-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.4 in /usr/local/lib/python3.12/dist-packages (from impresso==0.9.13) (2.11.10)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from impresso==0.9.13) (2.9.0.post0)
# Collecting types-PyYAML<7.0.0.0,>=6.0.12.20240311 (from impresso==0.9.13)
#   Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl.metadata (1.7 kB)
# Collecting types-protobuf<6.0.0.0,>=5.27.0.20240626 (from impresso==0.9.13)
#   Downloading types_protobuf-5.29.1.20250403-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<0.28.0,>=0.27.0->impresso==0.9.13) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<0.28.0,>=0.27.0->impresso==0.9.13) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<0.28.0,>=0.27.0->impresso==0.9.13) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<0.28.0,>=0.27.0->impresso==0.9.13) (3.11)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from httpx<0.28.0,>=0.27.0->impresso==0.9.13) (1.3.1)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->impresso==0.9.13) (0.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->impresso==0.9.13) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->impresso==0.9.13) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->impresso==0.9.13) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->impresso==0.9.13) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->impresso==0.9.13) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->impresso==0.9.13) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->impresso==0.9.13) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->impresso==0.9.13) (3.2.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.1.0->impresso==0.9.13) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.1.0->impresso==0.9.13) (2025.2)
# Requirement already satisfied: types-pytz>=2022.1.1 in /usr/local/lib/python3.12/dist-packages (from pandas-stubs<3.0.0.0,>=2.2.1.240316->impresso==0.9.13) (2025.2.0.20250809)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.6.4->impresso==0.9.13) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.6.4->impresso==0.9.13) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.6.4->impresso==0.9.13) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.6.4->impresso==0.9.13) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.8.0->impresso==0.9.13) (1.17.0)
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 5.4 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 8.1 MB/s eta 0:00:00
# Downloading protobuf-6.33.0-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.2/323.2 kB 34.3 MB/s eta 0:00:00
# Downloading types_protobuf-5.29.1.20250403-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 8.2 MB/s eta 0:00:00
# Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl (20 kB)
# Building wheels for collected packages: impresso
#   Building wheel for impresso (pyproject.toml) ... done
#   Created wheel for impresso: filename=impresso-0.9.13-py3-none-any.whl size=197413 sha256=e308ee7c8b2ba9970ae4a46d7a7c8fde207fe2357a2d6258723e94047b0983ec
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dcng6xne/wheels/5c/fa/46/8bd8da224c0d40e05a7a0a299c317cfb5ea5261d13798dc263
# Successfully built impresso
# Installing collected packages: types-PyYAML, types-protobuf, protobuf, attrs, httpx, impresso
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
#   Attempting uninstall: attrs
#     Found existing installation: attrs 25.4.0
#     Uninstalling attrs-25.4.0:
#       Successfully uninstalled attrs-25.4.0
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.0 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.0 which is incompatible.
# firebase-admin 6.9.0 requires httpx[http2]==0.28.1, but you have httpx 0.27.2 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.0 which is incompatible.
# google-genai 1.46.0 requires httpx<1.0.0,>=0.28.1, but you have httpx 0.27.2 which is incompatible.
# Successfully installed attrs-23.2.0 httpx-0.27.2 impresso-0.9.13 protobuf-6.33.0 types-PyYAML-6.0.12.20250915 types-protobuf-5.29.1.20250403

# %%
from impresso import connect

impresso_session = connect('https://dev.impresso-project.ch/public-api/v1')
# Out:
# Click on the following link to access the login page: https://dev.impresso-project.ch/datalab/token
#  - 🔤 Enter your email/password on this page.
#  - 🔑 Once logged in, a secret token will be generated for you.
#  - 📋 Copy this token and paste it into the input field below. Then press "Enter". 👇🏼.
#
# 🔑 Enter your token: ··········
# 🎉 You are now connected to the Impresso API!  🎉
# 🔗 Using API: https://dev.impresso-project.ch/public-api/v1

# %%
# ---embed and search---

question_q1 = "What happened in Zurich in the year 1950?"

question_q2 = "How many water fountains are there in Zurich?"

embedding_q1 = impresso_session.tools.embed_text(text=question_q1, target="text")

embedding_q2 = impresso_session.tools.embed_text(text=question_q2, target="text")

# %% [markdown]
# # RETRIEVAL PREPARATION

# %%
search_result_q1 = impresso_session.search.find(embedding=embedding_q1, limit=20)

# using the embedding to search in impresso
# get ids of search results
result_uids_q1 = [r["uid"] for r in search_result_q1.raw["data"]]

result_articles_q1 = [impresso_session.content_items.get(uid) for uid in result_uids_q1]

# %%
search_result_q2 = impresso_session.search.find(embedding=embedding_q2, limit=20)

# using the embedding to search in impresso
# get ids of search results
result_uids_q2 = [r["uid"] for r in search_result_q2.raw["data"]]

result_articles_q2 = [impresso_session.content_items.get(uid) for uid in result_uids_q2]

# %%
def format_and_display_articles(articles, fields=["title", "publicationDate", "languageCode", "transcript"], transcript_line_characters=100, max_transcript_characters=1500, return_string=False):
  """
  Formats a list of article objects into a string representation and optionally prints it.
  Includes transcript length and allows limiting the printed transcript length.

  Args:
    articles: A list of article objects (with a .raw attribute containing a dictionary).
    fields: A list of strings representing the fields to include for each article.
    transcript_line_length: The maximum number of characters per line for the transcript when printed.
    max_transcript_length: The maximum number of characters to print for the transcript.
                           If None, the entire transcript is printed.
    return_string: If True, the function returns a single string containing the formatted
                   article information. If False, it prints the information.
  """
  formatted_output = []
  for i, article in enumerate(articles):
    article_output = [f"--- Article {i+1} ---"]
    for field in fields:
      if field == "title":
        title = article.raw.get(field)
        article_output.append(f"Title: {title if title is not None else 'No Title Found'}")
      elif field == "publicationDate":
        date = article.raw.get(field)
        if date is not None:
          article_output.append(f"Publicationdate: {date.split('T')[0]}")
      elif field == "languageCode":
        lang = article.raw.get(field)
        if lang is not None:
            article_output.append(f"Languagecode: {lang}")
      elif field == "transcript":
        transcript = article.raw.get(field)
        if transcript is not None:
            transcript_length = len(transcript)
            article_output.append(f"Transcript Length: {transcript_length} characters")
            article_output.append(f"{field.capitalize()}:")
            transcript_to_print = transcript[:max_transcript_characters] if max_transcript_characters is not None else transcript
            if max_transcript_characters is not None and len(transcript) > max_transcript_characters:
                transcript_to_print += "... [truncated]"
            # Split transcript into chunks for better readability
            for j in range(0, len(transcript_to_print), transcript_line_characters):
              article_output.append(transcript_to_print[j:j+transcript_line_characters])

    article_output.append("-" * (len(f"--- Article {i+1} ---")))
    formatted_output.append("\n".join(article_output))

  if return_string:
    return "\n\n".join(formatted_output)
  else:
    print("\n\n".join(formatted_output))

# %%
format_and_display_articles(result_articles_q1)
# Out:
# --- Article 1 ---
# Title: EN SUISSE : A ZURICH, DES ÉMEUTIERS FONT METTRE EN LIBERTÉ UN PRISONNI[...]
# Publicationdate: 1919-06-16
# Languagecode: fr
# Transcript Length: 1669 characters
# Transcript:
# ZURICH, -15 juin. — Des troubles assez sérieux ont éclaté à Zurich, où, comme on le sait, existe une
#  minorité socialiste extrémiste des plus actives. Une grande manifestation avait été organisée, vend
# redi soir, pair l'Union ouvrière zurichoise, pour honorer la mémoire de Posa Luxembourg. Le préfet d
# e police de Zurich, le socialiste Greber, sur la promesse que la manifestation se déroulerait dans l
# e calme, avait donné des instructions pour que la polioe.se tînt éloignée de la réunion. Celle-ci co
# mmença bien; mais un orateur vint annoncer que le délégué socialiste suisse. Conrad Wyss venait, en
# rentrant d'Allemagne, d'être arrêté par les autorités fédérales, pour avoir introduit des brochures
# et des tracts de propagande. Aussi tôt la foule se porta vers la prison et réclama la mi.se en liber
# té du prisonnier. Vainement les gardiens tentèrent, d'abord par des coups de feu à blanc, ensuite au
#  moyen de pompes à incendie, d'arrêter les manifestants. Pour les c'almer, Conrad Wyss fut mis en 'l
# iberté; mais cette mesure ne suffit point et il fallut se servir d'une mitrailleuse pour empêcher la
#  foule de pénétrer dans la prison. Enfin, vers 2 heures du matin, seulement. le calme revint. Ces év
# énements produisent dans toute la Suisse une grosse émotion. L'opinion générale est que tout 'le mou
# vement révolutionna.ire dont Zurich est le centre depuis plusieurs mois est organisé par 'des agents
#  de l'élrange!' et réclame une attitude énergique'de-s-autorités. Le Conseil d'Etat a pris, déjà. di
# ... [truncated]
# -----------------
#
# --- Article 2 ---
# Title: "hreuie vor
# Publicationdate: 1953-10-26
# Languagecode: de
# Transcript Length: 838 characters
# Transcript:
# hreuie vor 50 Jahren wurde Zizers von einem Großbrand heimgesucht, der vierzehn Firsten einäscherte.
#  * 40 Jahren war die Schweiz am Pariser Automobil-Salon durch die Personenwagen Martini und Picard-P
# ictet vertreten. Die am Salon ausgestellten io—12-PS-Personenwagen waren zum Preis von rund 5000 Fr.
#  erhältlich. 30 Jahren verzichtete der Stadtrat von Zürich auf die Leuchtfontäne im unteren Zürichse
# ebecken, die ein privates Komitee anläßlich der Zürcher Lichtwoche schenken wollte. 20 Jahren wurde
# bekanntgegeben, daß 3 6 Personen beim großen Eisenbahnunglück bei Evreux — dei Schnellzug Cherbourg—
# Paris entgleiste und stürzte in einen Fluß — den Tod fanden. 10 Jahren erklärte der englische Luftfa
# hrtminister Sinclair, daß in den letzten vier Wochen mehr als 17 00 c Tonnen Bomben auf deutsches Ge
# biet abgeworfen worden seien. /. G. M,
# -----------------
#
# --- Article 3 ---
# Title: L'ACTUALITÉ SUISSE
# Publicationdate: 1959-04-24
# Languagecode: fr
# Transcript Length: 969 characters
# Transcript:
# L'ACTUALITÉ SUISSE Meurtre à Zurich ZURICH, 24. — Un drame s'est produit jeudi après-midi, peu avant
#  14 heures, dans une entreprise de machines à écrire de la Schaffhauserstrasse, No 272, à Zurich.. L
# c directeur de la maison avait fait savoir à un ouvrier de 45 ans, M. Adolf Buechi, employé dans l'e
# ntreprise depuis septembre 1958, qu'il pourrait y rester jusqu'à ce qu'il ait trouvé une autre place
# . Jeudi après-midi, Buechi arriva dans la maison et tira un coup de feu sur un contremaître, M. Fran
# cesco Naegelin, âgé de 30 ans. Celuici fut atteint dans le dos et, la balle ayant sectionné, l'aorte
# , il fut tué sur le coup. Buechi se rendit alors dans une autre pièce où il menaça des ouvriers, qui
#  purent cependant s'enfuir. Le meurtrier tourna alors son arme contre lui-même cl se tira une balle
# dans la lêtc. Il est dans un état désespéré. Le contremaître tué laisse une femme et deux enfants. U
# n conflit de travail mineur semble être le motif de l'acte de Buechi.
# -----------------
#
# --- Article 4 ---
# Title: * Banque cantonale zurichoise.
# Publicationdate: 1951-02-14
# Languagecode: fr
# Transcript Length: 1944 characters
# Transcript:
# * Banque cantonale zurichoise. Après déduction et amortissements, le compte de la Banque cantonale d
# e Zurich pour l'année 1950 laisse un bénéfice net disponible de fr. 5,175,560. Suivant la loi sur la
#  banque, fr. 2 millions 200,000 vont au compte de réserve, fr. 2,200,000 au canton, dont fr. 1,760,0
# 00 à la caisse de l'Etat et fr. 440 mille au fonds cantonal d'utilité publique. D'autre part, le con
# seil de banque a décidé à l'occasion du 600 e anniversaire de l'entrée dans la Confédération de vers
# er une somme de fr. 500,000 pour améliorer la situation des tuberculeux qui ont leur domicile dans l
# e canton de Zurich ou qui, citoyens zurichois, résident en dehors du canton. Usines de I'Etzel, Eins
# icdcln. Les usines de I'Etzel ont réalisé pendant l'exercice 1949-1050 un bénéfice de fr. 842,105.5
# % iront au fonds de réserve légal et le reste, fr .. 800,000, servira au versement d'un dividende de
#  4 % sur le capital-actions de 20 millions. Au cours de cet exercice les usines ont produit 206,077
# millions de kWh. qui ont été repris en grande partie par les CFF et les usines hydrauliques du nord-
# est suisse. Au cours de l'exercice, 30,07 millions de mètres cubes d'eau ont été pompés du lac de Zu
# rich pour être déservés dans le Sihlsee, ce qui a amélioré de 15 % le niveau du petit lac. General M
# otors. Lia General Motors déclare un dividende de S 1 sur ses 88,000 actions ordinaires en circulati
# on comme premier versement pour l'exercice en cours. Ce montant est le même que celui payé en décemb
# ... [truncated]
# -----------------
#
# --- Article 5 ---
# Title: d octobre 1950 BULLETIN DE BOURSE
# Publicationdate: 1950-10-05
# Languagecode: fr
# Transcript Length: 2103 characters
# Transcript:
# d octobre 1950 BULLETIN DE BOURSE u E Zurich :. Cour _.', Obligations A 5 VA% Féd. 42 / ms 101-25 d'
# «» 3%% Féd. 43 / av. 10675 d 1 t) 6-8° 3%% Féd. 44 / mal 1 ( wfid 10 < _"° 3% Fédéral 49.. _™ _' 9°
# 104. 75 3% C. F. F. 38.. 1 t) 3 _- 65 m 50 Actions Swissair.... 220 215 d B. Com. de Bâle 263 265 Ba
# nque Fédérale 178 179 Union B. Suisses 900 902 Société B. Suisse 786 786 Crédit Suisse.. 797 796 d C
# onli Linoléum. 216 218 Electro Watt.. 715 717 interhandel... 668 667 Motor Colombus. 509 510 S. A. E
# . G. Sér. 1 66 66 Indelec.... 267 274 Italo-Suisse prior. 83 83 Réassurances.. 5650 5710 Winterthour
#  Ace. 5790 5800 Zurich Assuranc. 7900 d 7990 o Aar-Tessin i.. 1180 1180 Zurich : Cou. ra du Actions
# 4 5 Saurer ¦ _<,, 880 890 Aluminium B ¦ s 2075 2098 Bally... a a -, 725 725 Brown-Boveri.. 925 930 F
# . Mot. Suisse C. 1360 d 1360 Fischer.,, «, 890 725 Laufenburg... 1340 1355 d Linol. Giubiasco _. 118
#  118 Lonza.... t 840 850 Nestlé Alimenl.. •1440 1450 Sulzer..... 1775 1800 Baltimore. ;. „ 61 62% _P
# ennsylvanie RR > 86 87 Italo-Argentina.. 49 48 Royal Dutch, » -. 219 217 Sodec..,, » 43 43 Vt Standa
# rd-Oil. _., 363 368 Union Carbide.-> 208 209 A. E. G.... ¦ 27 27 Du Pont de Nem. 350 359 Eastman Kod
# ak. 206 203 Général Electric.. 210 210 Général Motors. 430 463 Internat. Nickel. 148 150 Kennecott..
# .. 276 281 Montgomery W.. 277 283 National Distillers 113 114 Allumettes B.,. 30 29% Un. States Staë
# l ¦ 165 173 Cours du Zurich :'7 ~ " p 4 5 AMCA, s _,. $ 28. 35 28. 45 SAFIT » s.. £ 10. 12. 6 10. 11
# ... [truncated]
# -----------------
#
# --- Article 6 ---
# Title: Après la manifestation communiste de Zurich
# Publicationdate: 1929-03-26
# Languagecode: fr
# Transcript Length: 2088 characters
# Transcript:
# Après la manifestation communiste de Zurich * De Zurich, le 25 rjnars : Le comité du parti socialist
# e de la ville de Zurich s'est réuni dans la soirée de dimanche afin de prendre position à l'égard de
# s nouveaux événements qui ont trait à la manifestation com muniste de Zurich. La résolution adoptée
# par le comité du parti et par quelques hommes de confiance qui se trouvaient là se prononce à l'unan
# imité, dans sa première partie, et cela conformément à l'opinion du groupe socialiste du Conseil nat
# ional et des socialistes bâlois, contre l'interdiction de réunion prononcée par le Conseil fédéral.
# La seconde partie de la résolution s'élève con tre la manière absolument grotesque et enfantine des
# communistes à cette occasion, attitude qui n'a absolument rien de commun avec une politique prolétar
# ienne et avec la défense des intérêts des travailleurs. Comme dans tous les autres pays, les communi
# stes sont en Suisse les courriers de la réaction ; ils connaissent l'interdiction et les mesures pol
# icières envisagées et ont provoqué les autorités avec intention. Appel est fait à la classe ouvrière
#  pour qu'elle s'oppose à la politique néfaste des communistes, politique qui a jeté le discrédit sur
#  la cause du prolétariat zuricois. La participation extraordinairement faible de l'assemblée communi
# ste de dimanche après-midi à Zurich montre d'une manière éclatante combien la masse des ouvriers zur
# icois est loin de faire cause commune avec ceux qui organisèrent des actions aussi peu sérieuses. L'
# ... [truncated]
# -----------------
#
# --- Article 7 ---
# Title: Les communistes a rœuure a Zurich
# Publicationdate: 1932-06-17
# Languagecode: fr
# Transcript Length: 1974 characters
# Transcript:
# Les communistes a rœuure a Zurich Un commissaire de police et plusieurs agents blessés Zurich, 15 ju
# in. Le Conseil de la ville de Zurich avait interdit les démonstrations projetées pour mercredi soir
# et- l'assemblée des monteurs en grève avait décidé de ne pas l'organiser. Cependant dès 20 heures qu
# elques centaines de personnes se réunirent sur l'Helvetia Platz, tandis qu'une centaine d'agents de
# police stationnaient dans les bâtiments voisins. Peu après 21 heures on comptait 2000 personnes rass
# emblées sur la place. Trois jeunes gens harangèrent la foule après quoi le communiste Fluck invita t
# out le monde à se former en cortège. C'est alors que la police entra en action. Au milieu des cris e
# t des coups de sifflets, elle fit évacuer les lieux, pressant la masse des manifestants vers la Land
# strasse. Des coups de feu furent même tirés en l'air par la police après que les manifestants eurent
#  de leur côté ouvert un bombardement en règle contre les gendarmes avec des pavés. Plusieurs agents
# et le commissaire de police Scheidegger furent plus ou moins sérieusement blessés par des pro jectil
# es alors qu'ils se trouvaient à l' -mgle de la Turnhalle et de la Hohlstrasse, près du restaurant So
# nne, où les monteurs engrève s'étaient réunis l'après-midi. Deux grandes vitres d'un magasin de chau
# ssures furent tièrement brisées. La police procéda ensuite à l'évacuation systématique des diverses
# rues. On entendit des coups de feu jusqu'à 22 heures. A 22 h. 30 on signalait environ deux douzaines
# ... [truncated]
# -----------------
#
# --- Article 8 ---
# Title: LA CHAUX-DE-FONDS Assemblée générale du Parti EN SUISSE
# Publicationdate: 1950-01-16
# Languagecode: fr
# Transcript Length: 4173 characters
# Transcript:
# LA CHAUX-DE-FONDS Assemblée générale du Parti EN SUISSE La ville tentaculaire Au cours de l’année 19
# 49, la population de la ville de Zurich s’est accrue de 2336 âmes. Elle était de 385.276 personnes c
# ontre 382,940 à fin 1948. Le courage d’un garçonnet A Bergun (Grisons), un bambin de 3 ans est tombé
#  du pont de l’Albula, d’une hauteur de 10 mètres, dans la rivière. Un autre garçon, un peu plus âgé,
#  est parvenu, malgré une épaisse neige et au péril de sa vie, à ramener le bambin sur le rivage. Le
# petit n’a pas de blessures graves. Sur les routes argoviennes Pendant le mois de décembre 1949, il s
# ’est produit, dans le canton d’Argovie, 105 accidents de la circulation, causant la mort de 3 person
# nes. Onze permis de conduire ont été retirés pour ivresse. Une forêt protégée Sur demande de la Comm
# ission vaudoise de la nature, le Conseil communal de Ballaigue a décidé d’interdire toutes coupes ex
# agérées et les dépôts de matériaux entraînant une modifica­ modification de la forêt de la Roche, au
# x Perce-Neige, , à l’altitude de 670 à 700 mètres, d’une superficie de 6350 mètres carrés, et peuplé
# e de frênes et d’érables, qui constitue un exemple de peuple­ peuplements naturels. Le succès d’un v
# ieux « flingot » L’Administration du matériel militaire com­ communique que vu la forte demande cons
# tante du fusil d’ordonnance 89, au prix de 5 francs, la vente est prolongée jusqu’au 31 mars 1950. L
# es munitions pour ce modèle seront à l’avenir uni­ uniquement fournies par les sociétés de tir et le
# ... [truncated]
# -----------------
#
# --- Article 9 ---
# Title: 1613 Radovic Dusan Zuchwil 1948 1828 Rad...
# Publicationdate: 1991-03-18
# Languagecode: de
# Transcript Length: 5811 characters
# Transcript:
# 1613 Radovic Dusan Zuchwil 1948 1828 Radovic Zorica Zuchwil 1954 1054 Raemy Pirmin Granges-Paccot 19
# 49 586 Ramseyer Daniel Thierachern 1967 854 Rapin Jean-Marc Domdidier 1952 173 Rappo Alfons Bern 194
# 9 1821 Rappo Jean-Jacques Fribourg 1951 1741 Rau Dominique Payerne 1956 1860 Ravessoud Andre Yverdon
#  1931 1663 Rawyler Jürg Biel 1961 1163 Reber Arthur Ostermundigen 1947 1170 Reber Walter Fraubrunnen
#  1953 1047 Regez Raymond Studen 1946 1127 Reinhard Ursula Rüeggisberg 1954 343 Reist Hansruedi Zollb
# rück 1949 ^™ 224 Rellstab Werner Zürich 1954 86 Repond Beat Düdingen 1962 725 Repond Jean-Bernhard B
# ulle 1958 1114 Repond Maurice Thun 1948 31 1312 Reubi Charles Ins 1939 25 1907 Reusser Fritz Uttigen
#  1937 460 36 g Reusser Jakob Heiligenschwendi 1953 608 Reusser Philipp Wilderswil 1954 261 971 Reute
# ler Erich Interlaken 1955 311 652 Rey Jacob Fleurier 1948 46 1562 Rey Jean-Daniel Peseux 1950 14 361
#  Rey Marc Faoug 1957 13 300 Reynand David Romont 1975 346 55 Richli Erich Beromünster 1966 87 1910 R
# ickenbacher Friedy Meyrin 161 362 Rickli Eric Meyrin 16 1776 Rieder Fritz Köniz 220 145 Rieder Kurt
# Wichtrach 117 576 Rieder Walter Matten 26 1043 Riesen Paul Gümmenen 257 1847 Riesen Werner Köniz 57
# 396 Riesen Willi Bern 131 363 RihmBeat Bern 109 222 Rihm Stefan Biel 191 573 Rihm Thomas Zürich 26 1
# 059 Rime Auguste Bulle 75 1232 Rime Francoise Fribourg 276 69 Rindlisbacher Jost Biel 102 240 Ringge
# nberg Fritz Uetendorf 808 Risler Bruno Lyss 66 Robadey Jacques Epagny 1769 Robinson John Belfaux 178
# ... [truncated]
# -----------------
#
# --- Article 10 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-10-11
# Languagecode: fr
# Transcript Length: 2123 characters
# Transcript:
# BULLETIN DE BOURSE du 11 octobre 1950 _., Cours du Zurich :,. Obligation » 10 11 71'Cl _EAH 41 ; m.
# 1 D 1 _% 101. 30 3 _' 4% Féd. 42 / ms „ v 3 li% féd. 43 / av. J **,., _^ _SV & tt Féd. 44 / mal _^ n
#  4 H 3% Fédéral 49.. 1 " _£ _* 3% C. F. F. 38.. mA 103 M Actions Swissair.... 215 d 215 B. Com. de B
# âle 265 263 Banque Fédérale 178 177 Union B. Suisses 912 913 Société B. Suisse 795 797 Crédit Suisse
# .. 805 806 Conti Linoléum. 217 216 Electro Watt.. 712 713 Interhandel... 684 680 Motor Colombus. 515
#  518 S. A. E. G. Sér. 1 67 66 li Indelec.... 275 276 " Ilalo-Sulsse prior. 82 d 82 Réassurances.. 57
# 00 5630 Winterthour Ace. 5775 5755 Zurich Assuranc. 7975 d 8000 o Aar-Tessin... 1180 1180 ! Zurich :
#  Cou » 'du [ Actions 10 11 Saurer. -.,.. 915 910 d Aluminium «.. 2100 2095 Bally...... 728 723 d Bro
# wn-Boverl.. 935 935 F. Mot. Suisse C. 1400 d 1400 Fischer..... 917 915 Laufenburg... 1355 d 1355 Lin
# ol. Giubiasco. 120 120 d Lonza 845 848 o Nestlé Aliment.. 1447 1448 Sulzer 1795 d 1805 Baltimore....
#  66 _% 66 Pennsylvania RR. 87 li 86 Italo-Argentina.. 49'. i 50 Royal Dutch... 216 217 Sodec.... . .
#  4414 44 d Standard-Oil... 376 370 Union Carbide.. 206 o 204 A. E. G 27 27% o Du Pont de Nem. 358 35
# 6 Eastman Kodak. 205 204 Général Electric.. 214 213 Général Motors. 467 458 Internat. Nickel. 149 14
# 3 Kennecott.... 287 282 Montgomery W.. 287 284 National Distillers 11, 5 113 Allumettes B... 30 _% d
#  30 li Un. States Steel. 177 173 Court du Zurich : 10 11 AMCA. « -. -. $ 28. 50 28. 30 SAFIT.... £ 1
# ... [truncated]
# ------------------
#
# --- Article 11 ---
# Title: LES RÉSULTATS de la " propagande pacifiste pratique "
# Publicationdate: 1917-11-19
# Languagecode: fr
# Transcript Length: 3569 characters
# Transcript:
# e. La révolution maximalisle a eu en Suisse un contre-coup inattendu. Des « agitateurs pacifistes Y)
#  — si Olt peut employer cette expression bizarre — y ont VIL l'occasion de traduire leurs théories d
# ans les faits en contraignant par violence deux fa-briques de munitinns à fermer leurs por--tes. Ces
#  deux établissements travaillaient pour rAllemagne, mais il semble évident que leur sort eût été le
# même si elles avaient travaillé pour VEnt-enle. En réalité les manifestations étaient dirigées contr
# e la guerre en général et contre Vannée suisse en particulier. L'un des nieneurs de l'affaire. le co
# mpagnon Deltwyler, a prononcé les paroles suivantes qui sont %Out un programme: « Assez causé! Il ne
#  u suffit pas de sympathiser de loin avec les frères russes. Il faut agir. Maintenant, la révolution
#  doit être portée en fait dans notre pays, et avant tout au milieu de nos soldats qui doivent reluse
# r en masse le ser- Vice militaire. » La police a été impuissante à réprimer l'émeute soudainement dé
# chaînée et il a fallu appeler la troupe qui a fait usage de ses armes. Les premières dépêches semble
# nt révéler un certain affolement et en tout cas une tendance à l'exagération. Mais la situation n'en
#  est pas moins assez sérieuse. La neutralité suisse a l'a plus grande importance pour les Alliés, ma
# is il ne faut pàs oublier qu'inversement tous- les prétextes à sa violation seraient bons pour l'All
# emagne. Et si, celle-ci n'est pour rien 'dans ces troubles subits (encore. faudra-t-il voir), elle s
# ... [truncated]
# ------------------
#
# --- Article 12 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-08-18
# Languagecode: fr
# Transcript Length: 2139 characters
# Transcript:
# BULLETIN DE BOURSE du 18 août 1950 Zurich :, Cour 9 du s Obligations 17 18 PA% Féd. 42 / ms 101-55 1
# 01. 55 d 3%% Féd. 43 / av. 107. 15 d 107. 10 3%% Féd. 44 / mal 107 _% 107-60 3% Fédéral 49.. 105. 50
#  105. 35 3% C. F. F. 38.. _- _*° HM-40 Actions Swissair.... 185 190 B. Com. de Bâle 234 233 Banque F
# édérale 162 161 Union B. Suisses 851 B 50 Société B. Suisse 766 766 Crédit Suisse.. 776 775 Conti Li
# noléum. 207 d 207 d Electro Watt.. 676 676 Interhandel... 622 617 Motor Colombus. 517 514 S. A. E. G
# . Sér. 1 74 73% Indelec.... 242 242 Halo-Suisse prlor.'74 d 74 Réassurances.. 5560 5550 Winterthour
# Ace. 5350 o 5300 d Zurich Assuranc. 7850 d 7850 Aar-Tossin s. „ 1170 d 1185 d Zurich : Cour 9 du Act
# ions 17 18 Saurer. : ¦ > > 820 818 Aluminium v ». 1935 1935, Bally...= _= » 670 670 Brown-Boveri.. 8
# 77 878 F. Mot. Suisse C. 1320 d 1320 d Fischer... «. 841 840 Laufenburg.. -. ¦ 1345 1345 Llnol. Giub
# iasco. 117 d 117 d lonza 792 d 800 Nestlé Aliment.. 1367 1370 Sulzer. g a » « 1652 1640 d Baltimore
# i ». n 51% 52 Pennsylvania RR _. 7914 79 VÎ : Italo-Argentina. ¦ 60 60 Royal Dutch.,, 205 206 Sodec.
# . * _= « 50 50 V _1 Standard-Oil. ï F 350 351 Union Carbide « _= 195 d 197% A. E. G..... 22 22 Du Po
# nt de Nem. 340 344 Eastman Kodak 1 187 187 Général Electric.. 205 206 Général Motors. 398 402 Intern
# at. Nickel. 138% 140 _% Kennecott.... 269 269 Montgomery W.. 241 239 National Dlsllllers 103 103 All
# umettes B.. ¦ ; 28% 28 Un, States Steel » 161 d 165 Cours du Zurich :'_ÏT " _^ P AMCA _< ;, _, $ 26.
# ... [truncated]
# ------------------
#
# --- Article 13 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-09-19
# Languagecode: fr
# Transcript Length: 2094 characters
# Transcript:
# BULLETIN DE BOURSE du 19 septembre 1950 Zurich : Cou _- ", Obligation » 15 19 VA% Féd. 42 / ms 101.
# 45 101. 40 3%% Féd. 43 / av. 1° 7 107 d 5%% Féd. 44 / mal 1° _?% 10 _™° 3% Fédéral 4 ?.. 105. 40 105
# -25 3% C. F. F. 38.. 1° _" _- « m-K Action » Swissair.... 230 225 B. Com. de Bâle 253 252 Banque Féd
# érale 171 175 Union B. Suisses 886 890 Société B. Suisse 784 784 Crédit Suisse.. 796 794 Contl Linol
# éum. 217 215 Electro Watt.. 730 725 Interhandel... 687 661 Motor Colombus. 516 517 S. A. E. G. Sér.
# 1 68 « 7% Indelec.... 257 261 Itaio-Suisse prior. 80 _' / 2 82 o Réassurances.. 5575 5580 Winterthou
# r Ace. 5690 5700 Zurich Assuranc. 7850 7525 d Aar-Tesjln 5, ¦ 1185 d 1190 Zurich : Cou I Actions 15
# 19 Saurer.-i » » ¦ 880 870 Aluminium, _, i 2090 2030 Bally...,,, 740 740 Brown-Boveri ». 905 933 F.
# Mot. Suisse Ci 1350 d 1350 d Fischer.. » > s 890 900 Lautenburg.. ¦< 1368 d 1360 Linol. Giubiasco «
# 122 120 Lonza 828 S 30 Nestlé Aliment. 5 1437 1449 Sulzer... > ¦ 1770 1780 Baltimore.,.. 60 VÉ 59% P
# ennsylvanla RR ¦ 86 V 2 85% Italo-Argentina. * 54% 53 Royal Dutch. s « 214 213 Sodec... ; e 46 45 _'
# , i Standard-Oil. « -, 376 d 373 Union'Carbide. « 206 213 A. E. G 25 25% Du Pont de Nem. 357 363 Eas
# tman Kodak. 194 198 Général Electric.. 207 209 Général Motors. 407 412 Internat. Nickel. 151 153 Va
# Kennecott.... 290 286 Montgomery W.. — 259 National Distillers — — Allumettes B.. « — — Un. State »
# Steel < —— Cours du Zurich : 15 _^ AMCA, s _,, $ 27. 55 27. 75 SAFIT, «,. £ 10. 13. 0 If-13- ? FONSA
# ... [truncated]
# ------------------
#
# --- Article 14 ---
# Title: Meurtre à Zurich
# Publicationdate: 1959-04-24
# Languagecode: fr
# Transcript Length: 1394 characters
# Transcript:
# Meurtre à Zurich Zurich, 23. — Un drame s’est pro­ produit jeudi après midi, peu avant 14 heures, da
# ns une entreprise de machi­ machines à écrire de la Schaffhauserstrasse 272, à Zurich. Le directeur
# de la mai­ maison avait fait savoir à un ouvrier de 45 ans, M. Adolf Buchi, employé dans l’entrepris
# e depuis septembre 1958, qu’il pourrait y rester jusqu’à ce qu’il ait trouvé une autre place. Jeudi
# après midi, Buchi arriva dans la maison et tira un coup de feu sur un contremaître, M. Francesco Nae
# gelin, âgé de 30 ans. Celui-ci fut atteint dans le dos et, la balle ayant sectionné l'aorte, il fut
# tué sur le coup. Buchi se rendit alors dans une autre pièce, où il menaça des ouvriers, qui purent c
# ependant s’enfuir. Le meurtrier tour­ tourna alors son arme contre lui-même et se tira une balle dan
# s la tête. Il est dans un état désespéré. Le contremaître tué laisse une fem­ femme et deux enfants.
#  Un conflit de tra­ travail mineur semble être le motif de l’acte de Buchi. ?* Ç ? *'› '-- ....... X
# SSMii Il faudra bâtir une nouvelle cure dans le village schwyzois de Wilerzell, cure dont les fondat
# ions devront être absolument imperméables à l’eau pour résister à la pression du lac de Sihl : C’est
#  pourquoi la cure a été mise sur des rouleaux et déplacée de 200 mètres en attendant la construction
#  des nouvelles fondations. Ce petit voyage, illustré par notre photo, a duré plusieurs jours !
# ------------------
#
# --- Article 15 ---
# Title: EN SUISSE La pénurie des logements à Zurich
# Publicationdate: 1950-01-18
# Languagecode: fr
# Transcript Length: 6178 characters
# Transcript:
# EN SUISSE La pénurie des logements à Zurich Au 1 er janvier 1950, sur 115,393 appartements dans la v
# ille de Zurich, il n’y en avait plus que 70 de libres, dont 27 dans des villas à vendre. Sur les 43
# autres appartements, 16 sont d’un loyer de plus de 3000 francs. Dans les 1 er et 5 e ar­ arrondissem
# ents, il n’y a plus un seul appartement. Un garçonnet écrasé par un camion à Zurich Le chauffeur d’u
# n camion-citerne contenant trois mille litres de carburant se préparait à faire marche arrière et av
# ait chassé trois gamins qui tournaient autour du véhicule. Ayant fait quelques mètres, le chauffeur
# sentit que son ca­ camion passait sur un obstacle. Il arrêta immédia­ immédiatement pour voir ce qui
#  se passait et s’aperçut qu’un garçon avait passé sous les roues. Ce dernier, un garçonnet de 10 ans
# , nommé René Leu, était monté au dernier moment sur le mar­ marchepied, puis était tombé sous les ro
# ues. Conduit à l’Hôpital cantonal, le pauvre petit n’a pas tardé à succomber. L'art universitaire Au
#  Palais de Rumine s’est ouverte, en présen­ présence de M. J. Peitrequin, syndic de Lausanne, et de
# M. Fl. Cosandey, recteur, la première exposition nationale d’art universitaire, organisée par l’Unio
# n nationale des étudiants de Suisse et l’As­ l’Association générale des étudiants de Lausanne. Auton
# omie communale L’Assemblée communale de Frasnacht a refu­ sé à l’unanimité une proposition de fusion
#  avec la commune d’Arbon. Elle veut conserver son autonomie. Un voleur condamné La Cour pénale de Be
# ... [truncated]
# ------------------
#
# --- Article 16 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-01-10
# Languagecode: fr
# Transcript Length: 1793 characters
# Transcript:
# BULLETIN DE BOURSE du 10 janvier 1950 Zurich : Co " " Obligations 9 10 31 / 4% Féd. 42 / ms 102. 50
# 102. 50 3'/ 2 o / 0 Féd. 43 / av. 107. 85 107. 90 31 / 2% Fd. 44 / mai 107. 90 107. 90 30 / 0 Fédéra
# l 49. 106. 25 106. 40 3 _" / o C. F. F. 38.. 104. 25 104. 40 Actions Union B. Suisses 895 895 Sociét
# é B. Suisse 792 795 Crédit Suisse... 805 807 Conti Lino 208 208 d Electro-Watt... 638 637 Interhande
# l.... 756 _/ 60 Motor Colombus 491 493 Sœg Sériel.... 62 >/ 2 71 Indelec 294 295 Halo-Suisse pr.. 84
#  84 Réassurances.. 5300 5310 Winterthour Ac 4400 d 4550 Zurich Assur... 8725 d 8825 Aar-Tessin.... 1
# 098 1099 Zurich : Co " _. Actions 9 10 Oerlikon Accu. 380 d 375 d Ad. Saurer.... 805 d 810 Aluminium
# .... 1880 1880 Bally 690 690 d Brown Boveri. 785 783 Aciéries Fischer 785 787 Lonza 760 / 70 Atel. O
# erlikon. 550 d 560 d Nestlé 1261 1275 Entrep. Sulzer. 1560 d 1585 Baltimore 48 _' / 4 48 _' / 2 Penn
# sylvan. RR 78 / 63 / 4 Sodec 65 i / 2 66 Italo-Argentina 71 71 _' / 2 Royal Dutch... 231 228 St. Oil
#  N.-Jersey 302 298 _' / 2 Eastman Kodak 216 213 Internat. Nickel 125 _' / 2 d 1241 / 2 Montgomery W.
#  248 248 Allumettes B... 33 331 / 2 AMCA $ 25. 95 25. 95 SAFIT £ 10. 9. 0 10. 9. 0 FONSA, c. préc. 1
# 06. 25 10650 Genève : Cours du Actions 9 10 Am. Sec. ord... 851 / 2 851 / 2 Canadian Pac.. 66 66 Ins
# t. Phys. au p. 212 d 212 Sécheron nom.. 350 d 350 Separator 108 109 S. K. F 200 198 Bâle : Ciba 1990
#  2005 Schappe Bâle.. 820 d 815 Chimiq. Sandoz 2790 2800 Hoffmann-La R. 3900 3910 Billets étrangers D
# ... [truncated]
# ------------------
#
# --- Article 17 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-02-07
# Languagecode: fr
# Transcript Length: 1832 characters
# Transcript:
# BULLETIN DE BOURSE du 7 lévrier 1950 Zurich : _Cours du Obligations 6 7 3 i / 4 o / 0 Féd. 42 / ms 1
# 03.- 103. — 3 **/ 2° / oFéd. 43 / av. 107. 90 10 /. 90 31 / 2% Fd. 44 / mal 107. 9 ( Jd 107. 90 30 /
#  0 Fédéral 49. 107.- 107.-30 _/ o CF. F. 38.. 104. 75 104. 80 Actions Union B. Suisses » 87 S 85 Soc
# iété B. Suisse / 93 791 Crédit Suisse... 804 603 Conti Lino, 218 0 218 Electro-Watt... 676 675 Inter
# handel.... 772 ( 85 Motor Colombus 507 500 Sœg Série I.... 72 71 »/ _jd Indelec 298 293 Halo-Suisse
# pr.. 85 ci 841 / 2 Réassurances.. 5375 J 250 d Winterthour Ac 4300 0 4600 o Zurich Assur... 8900 d 8
# 960 Aar-TesBln.... 1132 d 1138 d Zurich : Cours du'Actions 6 7 Oerlikon Accu. 390 o 370 d Ad. Saurer
# .... 822 d 825 Aluminium.... 1863 1840 Bally 680 680 d Brown Boveri. / 80 d 780 d Aciéries Fischer 7
# 90 790 Lonza 785 d / 85 Atel. Oerlikon. 575 o 572 d Nestlé 1276 1276 Entrep. Sulzer. 1610 d I 575 d
# Baltimore 4 V' / 4 46 V 4 Pennsylvan. RR 74 733 / 4 Sodec 63 d 63 Italo-Argentlna 67 _' / 2 66 Royal
#  Dutch... 231 230 St. 011 N.-Jersey Ï 9 S 299 Eastman Kodak'A 4 214 Internat. Nickel 124 'fc 1241 /
# 2 Montgomery W. 251 248 Allumettes B.. i'i 12 AMCA $ 26. 60 26. 25 SAFIT £ 10. 5. 6 10. 5. 0 F 0 NSA
# , c. préc. 107 i / a 107. 50 Genève 1 Com * " Actions 6 7 Am. Sec. ord... 843 / 4 833 / 4 Canadien P
# ac.. _66 >/ a 66 _' / 4 Inst. Phys. au p. 218 220 Sécheron nom.. 365 d 368 d Separator 110 111 d S.
# K. F 197 d 198 _BSIe : Ciba 2050 2050 Schappe Bâle.. 820 d 820 Chlmlq. Sandoz 28 U 0 2885 Hoffmann-L
# ... [truncated]
# ------------------
#
# --- Article 18 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-02-24
# Languagecode: fr
# Transcript Length: 1843 characters
# Transcript:
# BULLETIN DE BOURSE du 24 février 1950 Zurich :, Ç _£ _BSJ 2. Obligations 23 24 31 / 4% Féd. 42 / ms
# _lOSV _^ d 103. 15 3 _' / 2° / o Féd. 43 / av. 108. 50 d 108. 60 3 </ 2° / o Fd. 44 / mai ! 083 / 4
# 108. 65 d 30 / o Fédéral 49. 107. 15 107. 20 3 _" / o C. F. F. 38.. 105. 20 105'/ 4 Actions Union B.
#  Suisses 895 893 Société B. Suisse 799 765 Crédit Suisse... 814 808 Conti Lino 219 218 d Electro-Wat
# t... o 79 678 Interhandel.... 772 762 Motor Colombus 502 502 Sa ? g Série I... 72 7 U / 2 _indelec 2
# 92 <! 87 italo-Suisse pr. & 'fed 82 _' / 2 d Réassurances. 5475 > 460 Winterthour Ai 1650 il 4 ô 50
# d Zurich Assur.. < 250 cl J 3 Cto Aar-Tessin.... 1182 U / 7 Zurich : Coars du Actions 23 24 Oerlikon
#  Accu. 396 399 o Ad. Saurer.... 840 840 Aluminium.... 1882 1877 Bally 6 / 5 680 Brown Boveri. 793 (
# 91 Aciéries Fischer 790 d 792 d Lonza 788 785 d Atel. Oerlikon. 572 d 575 Nestlé 1277 1280 Entrep. S
# ulzer. 1610 1610 Baltimore 47 453 / 4 Pennsylvan. RR 73 73 Sodec 591 / 2 60 Italo-Argentina 66 d 66
# d Royal Dutch.. 233 231 St. Oil N.-Jersey 291 _' / 2 : 91 Eastman Kodak 20 / 205 d Internat. Nickel
# 122 _122 «/ j Montgomery W 243 cl 242 d Allumettes B... 32 d _I 2 l / 2 d AMCA... $ 26. 2 26. 25 SAF
# IT £ 10. 6. 1 10. 9 X FONSA, c. préc. 1083 / 4 10 & 3 / 4 Genève i Com _- Actions 23 24 Am. Sec. ord
# ... 84 84 Canadian Pac.. 663 /,, 66 _inst. Phys. au p. 220 d 222 Sécheron nom.. 370 370 Separator 10
# 9 d 110 S. K. F 197 d 197 d Bâle : Ciba 2085 2070 Schappe Bâle.. 850 d 850 d Chimiq. Sandoz 2950 d 2
# ... [truncated]
# ------------------
#
# --- Article 19 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-03-15
# Languagecode: fr
# Transcript Length: 1864 characters
# Transcript:
# BULLETIN DE BOURSE du 15 mars 1950 Zurich : Cou ? : Obligations 14 15 3 >/ 4° / o Féd. 42 / ms 102.
# 55 102 " d _Ji _/ 2° 'oFéd. 43 / av. 108. 15 d I 08. 30 d 3 _t / 2° / o Fd. 44 / mai 108 108. 15 jo
# / o Fédéral 49. 106. 80 106. 90 30 / o C. F. F. 38.. 104. 85 104. B 0 d Actions Union B. Suisses « 6
# 7 868 Société B. Suisse'74 777 Crédit Suisse.. 785 787 Conti Lino.... 217 _' / 2 217 l / 2 Electro-W
# att... 668 672 Interhandel.... 7 £ 6 760 Motor Colombus 498 5 C 4 _Seeg Série 1.... 71 _Vj 73 Indele
# c 286 <! 90 Italo-Suisse pr.. 84 84 Réassurances.. 54 i 0 5485 Winterthour Ac 4600 o 4600 o Zurich A
# ssur... 9000 9100 Aar-Tessin.... 1160 d 1160 1 Zurich : _SSB ! Actions 14 15 Oerlikon Accu. 389 o 38
# 0 d Ad. Saurer.... 831 d S 32 d Aluminium.... 1860 d 1865 Baily û / 5 670 d Brown Boveri. 782 7 t 8
# Aciéries Fischer 780 790 Lonza 795 795 Atel. Oerlikon. 5 ? 0 d 572 d Nestlé 1285 1290 Entrep. Sulzer
# . 1610 1610 d Baltimore 46'/ 4 47 >/ 2 Pennsylvan. RR 75 >/ 4 75 >/ 2 Sodec 60 60 d Italo-Argentina
# 66 66 Royal Dutch... 227 2 _^ 6 St. Oil N.-Jersey 294 296 Eastman Kodak 204 204 Internat. Nickel 119
#  _118 i / 2 MontgomeryW. 238 240 o Allumettes B... 313 /., 32 AMCA S 26. 45 26. 50 SAF 1 T £ 10. 10.
#  6 10. 10. 6 FONSA, c. préc. 108. i / 2 _lOfc _Vz o Genève : Cours du Actions 14 15 Am. Sec. ord...
# 343 / 4 851 / 4 Canadian Pac.. 64 V 2 d 64 «/ 2 lnst. Phys. au p. 212 213 d Sécheron nom.. 365 d 365
#  d Separator 114 d 115 S. K. F 202 2 L 2 Bâle : Ciba 2135 2150 Schappe Bàle.. 851 d 850 Chimiq. Sand
# ... [truncated]
# ------------------
#
# --- Article 20 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-11-27
# Languagecode: fr
# Transcript Length: 2088 characters
# Transcript:
# BULLETIN DE BOURSE du 27 novembre 1950 Cours du Zurich :'24 27 Obligations 3%% Féd. 42 / ms « J « J
# » 3%% Féd. 43 / av. 10475 10475 3%% Féd. 44 / mai 104. 60 d 104% 3% Fédéral 49.. 1 ( _M 1 tM d 3% C.
#  F. F. 38.. 1° V _= 102 Actions Swissair.... 200 o 195 d B. Com. de Bâle 268 266 Banque Fédérale 168
#  165 Union B Suisses 899 896 d Société B. Suisse 788 783 Crédit Suisse.. 798 793 Contl Linoléum 216
# 217 Electro Watt. 700 700 Interhandel.. 707 700 Motor Colombus 500 497 S. A. E. G. Sér. 1 65% 64% In
# delec.... 277 272 Halo-Suisse prlor. 92 d 82 Réassurances.. 5703 5700 Winterthour Ace. 5 ( 58 n r 56
# 5 u d Zurich Assuranc. 7 Ç, 5 () 790 o d Aar-Tessin ¦ ¦ > H _^ _nso d I j ! Zurich : Cou [* t '"'-s
# Actions 24 27 Saurer..... 915 910 d Aluminium... 2130 2110 Bally 732 o 730 d Brown-Boverl.. 950 945
# F. Mot. Suisse C. " 90 d 1370 Fischer "O " 2 o Laufenburg... 1350 d 1360 Llnol. Giublasco. 120 d 120
#  d Lonza 831 835 Nestlé Aliment.. 1485 1486 Sulzer 1825 1810 Baltimore.... 67 65% Pennsylvanie RR. 8
# 7% 8714 Italo-Argentina.. 46 46 Royal Dutch... 229 225 Sodec 44% 42 ex. c. Standard-OII... 395 354 U
# nion Carbide. 228 228 A. E. G.... 260 25 ?. id Du Pont de Nem 361 360 Eastman Kodak 225% 223% Généra
# l Electric. 219 218 ; Général Motors. 219% 220 Internat. Nickel. 1551 _^ 155 Kennecott.... 315 321%
# Montgemery W.. 288 d 287 National Distlllers _114 11, 5 Allumettes B. s. 29 d Z 0% Un, State » Steel
#  « 134 isa _% i Zurich : Cour 9 du, 24 27 AMCA.... $ 2 ?. 05 29. 10 SAFIT.... £ 10-11 i 0 1 rx 13. _
# ... [truncated]
# ------------------

# %%
format_and_display_articles(result_articles_q2)
# Out:
# --- Article 1 ---
# Title: isi Siiiss®
# Publicationdate: 1928-07-19
# Languagecode: fr
# Transcript Length: 2732 characters
# Transcript:
# _isi _Siiiss _® Ne gaspillons pas l'eau ! ZURICH, 19. — Le Service des eaux de la ville de Zurich vi
# ent de publier un avis concernant la consommation de l'eau, avis motivé par le -fait qu'en ces temps
#  de chaleur excessive, on a coutume de mettre le lait et d'autres aliments dans l'eau courante pour
# les rafraîchir, d'arroser les jardins par trop copieusement, bref, de gaspiller l'eau. Ces jours der
# niers, la consommation d'eau a dépassé 100, 000 m 3, ce qui représente une moyenne de 425 litres par
#  personne et par jour, tandis que jusqu'ici, la consommation la plus forte n'avait pas dépassé 83 mi
# lle m 3. Zurich possède, il est vrai, un réservoir inépuisable — en l'espèce son lac — mais il n'en
# reste pas moins que les installations de filtrage et de transport ont des capacités limitées. Samedi
#  dernier, la consommation a même atteint 103, 000 m 3, ce qui est manifestement exagéré et ne corres
# pond nullement aux besoins réels de la population. Aussi la direction du Service des eaux de Zurich
# déclare-t-elle que les gaspilleurs seront punis conformément au règlement. Les merveilles du télépho
# ne. — On cause de Genève à New-York... pour commander des montres ! GENEVE, 19. — La première conver
# sation téléphonique de l'Amérique avec Genève a eu lieu hier entre la maison d'importation d'horloge
# rie Wittnauer et Cie de New-York et sa succursale de Genève. Cette conversation a duré 6 minutes et
# a coûté 495 francs. Elle fut très claire et l'on se comprit d'un bout à l'autre du fil comme s'il n'
# ... [truncated]
# -----------------
#
# --- Article 2 ---
# Title: Vingt-six fontaines
# Publicationdate: 1962-08-04
# Languagecode: fr
# Transcript Length: 968 characters
# Transcript:
# Vingt-six fontaines Le Service de l'Eau nous a fourni d'intéressantes indications statistiques sur n
# os fontaines, à défaut de renseignements historiques. Par exemple, nous avons appris que l'on compta
# it 26 fontaines sur le territoire communal, desservies par le réseau public. Quelques autres fontain
# es font appel à des eaux de sources privées, telles la Bonne fontaine des Eplatures. L'ensemble de c
# es fontaines débite 200 litres / minute ; comme elles sont en service durant six mois environ, cela
# représente annuellement une quantité de 55, 000 mètres cubes d'eau. Il, faut relever encore que deux
#  grandes fontaines, la « Monu » et la fontaine du parc de la gare ( Chambre suisse de l'horlogerie),
#  fonctionnent en circuit continu ; leur eau n'est donc pas potable. Il ne s'agit que d'ouvrage décor
# atif. Trois fontaines, celles de la Place du Sentier, de la Place du Marché et du jardin de l'Ouest
# fournissent une eau destinée à l'alimentation, parfaitement potable.
# -----------------
#
# --- Article 3 ---
# Title: Les villes suisses consomment trop
# Publicationdate: 2014-03-27
# Languagecode: fr
# Transcript Length: 1094 characters
# Transcript:
# Les villes suisses consomment trop EAU Les villes suisses consomment en moyenne plus d’eau par habit
# ant que celles des pays péens, alors que les prix y sont parfois plus élevés. Selon un audit de l’Of
# fice fédéral de la statistique, Lugano se place au premier rang, avec 250 m 3 d’eau consommés par ha
# bitant en 2012, soit le double des autres villes étudiées : dix chefs-lieux suisses et dix péens, no
# rdiques principalement. La cité tessinoise est suivie par Genève, Bâle, Lausanne, Zurich, Bienne, Lu
# cerne, Berne, Saint-Gall et Winterthour. Ces dernières villes enregistrent une consommation d’eau an
# nuelle par habitant variant entre 85 et 135 mètres cubes. En onzième place figure la ville suédoise
# de Göteborg, talonnée par Helsinki, en Finlande, les tés allemandes Stuttgart et Munich et des ville
# s belges, comme Gand et Bruxelles. La consommation d’eau n’est pas liée aux prix. A Saint-Gall, où l
# es habitants consomment en moyenne 85 m 3 d’eau par an, les prix sont aussi élevés (2,4 francs par m
#  3) qu’à Munich, où la moyenne est de 60 mètres cubes. ATS A Lugano, on aime l’eau... KEYSTONE
# -----------------
#
# --- Article 4 ---
# Title: Les villes suisses consomment trop
# Publicationdate: 2014-03-27
# Languagecode: fr
# Transcript Length: 1096 characters
# Transcript:
# Les villes suisses consomment trop EAU Les villes suisses consomment en moyenne plus d’eau par habit
# ant que celles des pays péens, alors que les prix y sont parfois plus élevés. Selon un audit de l’Of
# fice fédéral de la statistique, Lugano se place au premier rang, avec 250 m 3 d’eau consommés par ha
# bitant en 2012, soit le double des autres villes étudiées : dix chefs-lieux suisses et dix péens, no
# rdiques principalement. La cité tessinoise est suivie par Genève, Bâle, Lausanne, Zurich, Bienne, Lu
# cerne, Berne, Saint-Gall et Winterthour. Ces dernières villes enregistrent une consommation d’eau an
# nuelle par habitant variant entre 85 et 135 mètres cubes. En onzième place figure la ville suédoise
# de Göteborg, talonnée par Helsinki, en Finlande, les tés allemandes Stuttgart et Munich et des ville
# s belges, comme Gand et Bruxelles. La consommation d’eau n’est pas liée aux prix. A Saint-Gall, où l
# es habitants consomment en moyenne 85 m 3 d’eau par an, les prix sont aussi élevés ( 2, 4 francs par
#  m 3) qu’à Munich, où la moyenne est de 60 mètres cubes. ATS A Lugano, on aime l’eau... KEYSTONE
# -----------------
#
# --- Article 5 ---
# Title: Une ville est née...
# Publicationdate: 1939-05-09
# Languagecode: fr
# Transcript Length: 3313 characters
# Transcript:
# Une ville est née... Sur l « s bords du lac de Zurich En l'espace de onze mois, une nouvelle cite es
# t née sur les bords du lac de Zurich. Les travaux de construction de l'Exposition nationale ont duré
#  un peu moins d'un an. Se doute-t-on de l'effort énorme qu'exige la mise au point d'une manifestatio
# n de cette envergure i Oar, a côté de tout ce qui se voit, — de tout ce qu on admire — il y a tout c
# e qui ne se voit pas, et qui représente un travail dont le profane ne se fait guère une idée.'_Quelq
# ues chiffres ue seront peut-être pas ete trop pour illustrer ce que nous venons de dire. L'Expositio
# n occupe, sur les deux rives du lac de Zurich, une superfice d'environ 300, 000 mètres carrés ; 125,
#  000 mètres carrés sont pés par des constructions, dont le volume atteint au total 700, 000 mètres c
# ubes. Pour édifier les nombreux pavillons de l'Exposition, les charpentiers ont utilisé 14, 000 mètr
# es cubes de bois l «'** de construction, et le volume du bois d oeuvre atteint 370, 000 mètres cubes
# . Voilà pour la su perstructure. Et le visiteur serait plus étonne encore s'il pouvait voir le résea
# u de canalisations qui s'étend sous ses pieds : conduites d'eau, conduites pour les eaux usées, cabl
# es électriques et câbles téléphoniques, canalisations pour le gaz, sillonnent le sous-sol de l'Expos
# ition. Les conduites d'eau — il s'agit uniquement des conduites souterraines — ont une longueur de 5
# 200 mètres, ce qui n'est pas exagéré si l'on songe que la consommation d'eau pendant la durée de l'E
# ... [truncated]
# -----------------
#
# --- Article 6 ---
# Title: Glous-slous dans la ville
# Publicationdate: 1989-07-24
# Languagecode: fr
# Transcript Length: 4715 characters
# Transcript:
# Glous-slous dans la ville Les fontaines ne coulent pas sans soucis A la claire fontaine, s'en allant
#  promener, les Chaux-de-Fonniers ont 56 sources auxquelles se rafraîchir. Leur ville, triste de ne p
# ouvoir se mirer dans les eaux d'un lac et frustrée de ne point se bercer au rythme d'une rivière, se
#  venge par ses multiples fontaines. Mais la sécheresse des dernières semaines et l'attention général
# e portée à la consommation d'eau met en pianissimo la chanson cristalline des robinets. Le service d
# e l'énergie se penche sérieusement sur ce débit et appelle le soleil à la rescousse. Dans cet invent
# aire de 56 points d'eau, les travaux publics comptabilisent tous les robinets et autres jets sur le
# domaine public ; du petit bassin de préau d'école à la Grande Fontaine en passant par les nombreuses
#  fontaines des cimetières, des parcs publics, du Bois du Petit-Château, etc. Autant d'histoires d'ea
# u s'écoulant d'une motivation des autorités. « L'eau est toujours intimement liée à la vie ; partout
#  où il y a des gens, il y a de l'eau » remarque le conseiller communal Alain Bringolf, responsable d
# es TP. Outre les fontaines inscrites dans la vie d'antan du bétail s'abreuvant et des lavandières Mi
# se en eau en juin, une ancienne fontaine agrémente la rue Fritz-Courvoisier, ajoutant son gazouillis
#  à un parc de bassins impressionnant. ( Photo Impar-Gerber) papotant, et celles placées pour l'utili
# té dans les cours d'école, parcs publics ou à proximité des piscines, d'autres bassins ont été insta
# ... [truncated]
# -----------------
#
# --- Article 7 ---
# Title: Tempêtes dans des piscines
# Publicationdate: 1983-07-18
# Languagecode: fr
# Transcript Length: 1670 characters
# Transcript:
# Tempêtes dans des piscines ZURICH Zurich (de notre correspondant).-Economies d'abord, mais pas au dé
# triment de la natation et donc de la santé publique : c'est sur ce thème qu'un groupe de Zurichois v
# ient de partir en guerre contre l'Office municipal de la santé publique, qui envisage de fermer prém
# aturément à fin août un certain nombre de bains publics et de piscines en plein air de Zurich, alors
#  qu'en principe le temps de la baignade dure jusqu'à mi-septembre. La mesure s'appliquerait à des ét
# ablissements de quartiers, comme la baignade de Letten, sur la Limmat, la piscine d'Allenmoos à Œrli
# kon ou la plage de Wollishofen. Tout d'abord, l'information avait tré un scepticisme étonné, une foi
# s confirmée ce fut la levée de boucliers. 2 & ". "..'..'1 .... Les opposants, qui ont lancé une péti
# tion, font valoir que cette mesure est antisociale. Elle frappe tout d'abord le personnel, saisonnie
# r, des baignades « condamnées », mais porte préjudice à l'organisation des loisirs de nombreuses fam
# illes. En outre, les migrations, obligatoires, vers d'autres piscines encore ouvertes accroîtraient
# les frais en même temps que cela créerait à coup sûr des engorgements au bord des plans d'eau « tolé
# rés ». Les milieux politiques se sont aussi émus, et une interpellation émanant de l'Alliance des in
# dépendants exige des explications de la part des autorités. Celles-ci ont jusqu'au 15 août pour pren
# dre une décision définitive, en raison des délais de licenciement du personnel temporaire. Le chef d
# ... [truncated]
# -----------------
#
# --- Article 8 ---
# Title: Les cinémas à Zurich
# Publicationdate: 1927-03-09
# Languagecode: fr
# Transcript Length: 3722 characters
# Transcript:
# Les cinémas à Zurich CDe notre eorr. de Zurich) Il n'y a pas à dire : la ville de Zurich est en trai
# n de battre tous les records en matière d'industrie cinématographique, par quoi veuille. entendre, j
# e vous prie, le nombre d'établissements cinématographiques sollicitant la faveur du public. Une noti
# ce, parue dernièrement, n'a pas manqué de faire quelque sensation, puisqu'elle annonçait l'ouverture
#  prochaine de pas moins de six théâtres nouveaux, à côté de ceux que nous possédons déjà. A ce propo
# s, il n'est peut-être pas sans intérêt de s'arrêter à quelques chiffres _. D'après le dernier recens
# ement, la population de la ville de Zurich s'élève à 214.000 âmes ; or, pour oette population, il y
# a actuellement 14 cinématographes en exploitation, ce qui est largement suffisant. Les 20 établissem
# ents que nous" risquons de posséder prochainement contiennent environ 15.000 places, ce qui est un c
# hiffre coquet ; si l'on veut qu'elles soient occupées tous les soirs, le flot des spectateurs devra
# prendre des proportions inaccoutumées. Mais ce n'est pas tout, car nous avons à côté de cela de nomb
# reux établissements de distraction qui veulent vivre aussi. C'est tout d'abord le grand théâtre, ave
# o ses 1400 places, puis le théâtre du Pfauen, qui en compte 900 ; ensuite, il y a deux cabarets, qui
#  jouent chaque jour, et qui peuvent accueillir 550 spectateurs ; cela fait déjà des occasions de dis
# traction pour 2850 personnes. Avec les cinémas, au nombre de 20, nous arrivons ainsi à 24 théâtres,
# ... [truncated]
# -----------------
#
# --- Article 9 ---
# Title: Zürich im Schutze der Deiche «Sie sind a...
# Publicationdate: 1965-02-11
# Languagecode: de
# Transcript Length: 3118 characters
# Transcript:
# Zürich im Schutze der Deiche « Sie sind auf der Suche nach Ortschaften mit dem Namen Zürich gerade a
# n den rechten Mann gekommen, denn auch ich habe mich schon für die anderen Städte der Weltkarte, die
#  den Namen Zürich tragen, interessiert. Nicht nur habe ich des öfteren herzlichen Kontakt mit Schwei
# zer Zürchern die durch unser Darf kommen, sei es durch Zufall, oder weil sie dem Namensvetter ihrer
# Heimatstadt einen Besuch abstatten wollen. loh habe vielmehr auch selber schon einige der anderen Zü
# richs besucht. So besuchte ich im Jahre 1960 mit meiner Familie das Schweizer Zürich, wobei die Stad
# tverwaltung uns auf sehr herzliche Weise begrüsste. Unser Zürich gehört mit 26 anderen Dörfern zur G
# emeinde Wonseradeel und hat daher kein eigenes Postamt und somit auch keinen Poststempel. Die Post w
# ird vielmehr von der benachbarten Stadt Hariingen aus besangt. Leben unter der Drohung des Meeres Wo
# hl aber hat Zürich eine eigene Fahne, die ich Ihnen aufgezeichnet habe. Das brennende Rot spricht vo
# n der Gefahr die droht, wenn der brüllende Sturm das Meerwasser über die Deiche jagt. Der diagonal v
# erlaufende goldene Streifen aber bedeutet den Schutz durch den Deich — der auoh « goldenes Band » ge
# nannt wird — durch den die Bevölkerung Schutz erhält ». den Stadtpräsidenten von Yver- j don, Andre
# Martin: In verschiedenen Gebieten der Schweiz hat die Austrocknung von Quellen und die Verschmutzung
#  von Gewässern einen chronischen Wassermangel hervorgerufen. In einigen Gemeinden in der Umgebung vo
# ... [truncated]
# -----------------
#
# --- Article 10 ---
# Title: SUSSE « Celte ville est le paradis des célibataires»
# Publicationdate: 1958-07-29
# Languagecode: fr
# Transcript Length: 2435 characters
# Transcript:
# SUSSE « Celte ville est le paradis des célibataires » Jamais la saison touristique n'a paru si animé
# e à Zurich. La SAFFA y est sans doute pour quelque chose et, grâce à cette exposition, les heures d'
# ouverture des lieux de divertissement ont été prolongées au-delà de minuit. Il est intéressant de no
# ter que les statistiques concernant les étrangers de passage donnent maintenant à Zurich là cinquièm
# e place en Europe pour le nombre des nuits d'hôtels — après Londres, Rome, Paris et Milan. Pour une
# ville qui n'a connu l'an dernier que trente-trois jours de vrai beau temps, l'arrivée de 732,231 tou
# ristes étrangers semble un paradoxe. H est vrai que le tourisme moderne attire de plus en plus de mo
# nde vers les grandes villes. Et à cet égard, Zurich offre beaucoup : plus de 1000 restaurants, repré
# sentant les cuisines les plus diverses du globe, une quarantaine de cinémas (dont le dernier vient d
# 'être ouvert à l'intérieur de la gare centrale), une trentaine de musées, galeries d'art, etc. Dans
# le dernier numéro de la Weltwoche, un article sur le développement touristique de Zurich donne d'int
# éressantes indications sur l'intérêt des Américains pour la plus grande ville de Suisse. Relevons de
# ux citations particulièrement saillantes. « Zurich est 'a seule ville d'Europe où je pourrais vivre
# », à déclaré l'écrivain Thornton Wilder. « Zurich est un paradis pour les célibataires », a écrit la
#  célèbre revue Esquire qui précisait : « Cette vilie compte entre 15,000 et 25,000 prostituées, qui
# ... [truncated]
# ------------------
#
# --- Article 11 ---
# Title: CRITIQUE ET ESSAIS Un exemple à suivre A Zurich, Services industriels [...]
# Publicationdate: 1980-07-12
# Languagecode: fr
# Transcript Length: 2754 characters
# Transcript:
# Un exemple à suivre A Zurich, Services industriels et Bureau d'archéologie travaillent de conserve L
# es canalisations du centre historique de Zurich, sur les deux rives de la Limmat, étaient plus que c
# entenaires ; une votation populaire a approuvé, en 1975, leur remplacement intégral. On aurait pu se
#  borner à défoncer les rues pour y placer de nouvelles conduites, mais on en profita pour examiner s
# cientifiquement le sous-sol urbain : l'ensemble des travaux fut planifié avec le Bureau d'archéologi
# e de la ville, ce qui permit d'explorer la totalité des voies et places faisant l'objet de l'opérati
# on et, accessoirement, de refaire tous les pavements en supprimant les trottoirs. Aujourd'hui, la pr
# emière phase est achevée, qui couvre un tiers du projet. Ses résultats sont si intéressants qu'on le
# s a exposés au public (et au contribuable), sous le titre Kanalisationssanierung und Archâologie (Ha
# us Zum Rech, Neumarkt 4, jusqu'au 23 août). On savait que Zurich constituait au Bas-Empire un point
# d'appui sur la rive occidentale de la Limmat, avec le fort de Turicum, à l'emplacement du Lindenhof.
#  Puis la bourgade réapparaissait en quelque sorte au IXe siècle après une longue éclipse documentair
# e. Les fouilles ont permis de compléter largement la connaissance de la Zurich romaine : la tête du
# pont sur la rive gauche, la position de la rive droite à la Niederdorfstrasse, diverses fondations a
# ntiques difficiles à interpréter, tels sont quelques-uns des résultats de cette première campagne. D
# ... [truncated]
# ------------------
#
# --- Article 12 ---
# Title: CONGRÈS À ZURICH La Suisse, château d'eau de l'Europe
# Publicationdate: 1982-09-07
# Languagecode: fr
# Transcript Length: 1809 characters
# Transcript:
# CONGRÈS À ZURICH La Suisse, château d'eau de l'Europe Zurich, 6 (ATS).-Le 14 e congrès mondial de l'
# Association des distributions d'eau (AIDE) s'est ouvert lundi à Zurich. Jusqu'au 10 septembre, plus
# de deux mille délégués de toutes les régions du monde débattront de problèmes liés au thème général
# « sans eau pas de vie ». Lors de leurs allocutions d'ouverture, le conseiller fédéral Hans Hiirliman
# n et le président de la ville de Zurich Thomas Wagner ont relevé que la Suisse peut être considérée
# comme le château d'eau de l'Europe. Les problèmes qui se posent chez nous ne touchent pas à la quant
# ité mais à la qualité. Selon M. Hùrlimann, l'exiguïté de notre pays, sa forte densité démographique
# et ses intenses activités économiques sont également sources de problèmes. Une statistique de la Soc
# iété suisse de l'industrie du gaz et des eaux montre que près de 580 millions de mètres cubes d'eau
# potable ont été distribués dans notre pays en 1981. Cela représente une consommation quotidienne de
# 248 litres par habitant. L'eau, a encore indiqué M. Hùrlimann, est la seule ressource naturelle que
# la Suisse ne doit pas importer. Mais, parallèlement à l'augmentation de la population, de la product
# ion et de la consommation, la pollution est devenue de plus en plus préoccupante. Pour faire face à
# cette situation, d'énormes efforts financiers ont été consentis. M. Hùrlimann a rappelé que plus de
# 20 milliards de francs ont été investis en Suisse pour résoudre le problème de la pollution. Cela éq
# ... [truncated]
# ------------------
#
# --- Article 13 ---
# Title: DERNIER RÊVE MUNICIPAL
# Publicationdate: 1941-05-23
# Languagecode: fr
# Transcript Length: 4052 characters
# Transcript:
# DERNIER RÊVE MUNICIPAL LETTRE DE ZURICH (De notre correspondant particulier) Il y a quelque trente à
#  trente-cinq ans, nous prenions chaque semaine le chemin du Tunnel à Lausanne pour aller nous baigne
# r en troupe, dans une sorte de buanderie, qui tenait alors lieu de piscine. Un bâtiment au teint jau
# nâtre coiffé d'une casquette grise. A travers un brouillard de vapeur, les petits grimauds de collèg
# e s'ébattaient bruyamment sous le regard de leur maître de gymnastique. Tout cela était primitif et
# touchant. Il n'en va pas de même sur les bords de la Sihl, au coeur du Grand-Zurich. Dans leur désir
#  de faire bien les choses, les autorités municipales apportent autant de soin que de temps à réalise
# r leurs grands projets. Cela peut durer vingt à trente ans et coûter quelques millions. Peu importe
# ! Aujourd'hui Zurich ne possède pas seulement son jardin zoologique et son Palais des congrès. Elle
# vient d'inaugurer une piscine communale, dont les premiers plans remontent avant la dernière guerre
# mondiale. C'est là peut-être ce qu'il y a de mieux aujourd'hui dans notre pays. Extérieurement, l'as
# pect d'une belle et vaste centrale électrique. D'immenses baies vitrées qui donnent sur les arbres d
# e la Kleine Schanze. Lorsque l'on nage dans l'eau bleutée, on croirait se baigner au milieu d'un par
# c. Le comble de l'organisation, de l'hygiène et de l'agrément. Cabines, douches d'eau tiède et d'air
#  chaud. Un univers chatoyant, animé et lumineux. Tout ici est bleu et blanc, jusqu'aux hortensias et
# ... [truncated]
# ------------------
#
# --- Article 14 ---
# Title: Des fontaines dont on parle et dont on parlera
# Publicationdate: 1945-07-26
# Languagecode: fr
# Transcript Length: 956 characters
# Transcript:
# Des fontaines dont on parle et dont on parlera De tous les endroits de Suisse où les fontaines sont
# en honneur — et Dieu sait s'il en existe — il en est peu qui soient plus attirants que le Landeron,
# ce bourg gracieux, pittoresque et cossu dont le canton de Neuchâtel s'_enorgueillit si justement. Le
# s fontaines du Landeron sont en effet parmi les plus anciennes et les plus belles qui se puissent vo
# ir. Sculptées et enihiminêes, bénéficiant de la part de la population de soins attentifs et touchant
# s, elles mettent dans ce paysage de vignoble, de forêts et de lac proche le sceau d'un passé somptue
# ux et fier. A toutes ces fontaines s'en ajoutera bientôt une qui, bien que symbolique, sera bientôt
# célèbre puisque d'elle couleront te. oie et l'aisance. La loterie romande installera prochainement a
# u Landeron, en effet, sa source de chance puisque c'est là que se déroulera le prochain tirage. Hâte
# z-vous si vous voulez profiter de son débit bienfaisant.
# ------------------
#
# --- Article 15 ---
# Title: • • 111111
# Publicationdate: 2007-04-13
# Languagecode: fr
# Transcript Length: 1445 characters
# Transcript:
# • • 111111 ret. 4. Il y a les piscines qui restent dans le domaine du confort, de la détente avec de
# s variations SPA, sauna, coin détente, massage, etc. 5 II y a, enfin, les thermes dont l'eau possède
#  des qualités curatives particulières. Parmi ceux-ci, il y a les thermes reconnus tant par les or ga
# nismes officiels que par les assurances, l'aspect thérapeutique domine. Et puis il y des centres the
# rmaux qui regroupent les qualités des cinq catégories énoncées ci-dessus. D'Yverdon-les-Bains à Brig
# erbad Parmi les lieux balnéaires qui ont une reconnaissance et surtout une histoire citons Loèche-le
# s-Bains, les- Bains, Lavey-les Bains. La première est toujours une des plus prestigieuses, elle l'ét
# ait déjà au 18 ième siècle et l'on venait de France et d'Allemagne pour s'y baigner. Brigerbad a aus
# si une histoire tandis que Saillon, même si les Romains y avaient installé des thermes et les joueur
# s du Casino de Saxon, au 19 siècle y faisaient trempette, est une création plus récente. Tout comme
# Ovronnaz ou Val-d'llliez et la plus récente : les Bains de la Gruyère à Charmey. Des projets sont en
#  cours à Crans-Montana, Griment et àThyon-les Collons. Et puis existe-t-il déjà en plus des centres
# d'eaux existants et les projets d'autres concepts dans les tiroirs ? Quoi qu'il en soit on recense d
# onc pas moins de 11 centres d'eau en Suisse romande, dont 7 en Valais, existants et en projets, c'es
# t dire l'accroissement de ce type de concept.
# ------------------
#
# --- Article 16 ---
# Title: Jeux de société...
# Publicationdate: 1928-01-23
# Languagecode: fr
# Transcript Length: 2714 characters
# Transcript:
# Jeux de société... CDe notro corresp. de Zurich.) Connaissez-vous le proverbe qui dit que là où deux
#  Suisses se rencontrent, ils fondent une société ? L'en a dit parfois que c'étaient de mauvaises lan
# gues qui avaient répandu ce bruit, lequel, cependant, ne me paraît pas être tout à fait une légende,
#  à en juger par le nombre de sociétés de toutes sortes dont nous sommes gratifiés. Oyez plutôt, en c
# e qui concerne la ville de Zurich. D'après une statistique qui vient d'être dressée, l'Athènes des b
# ords de la Limmat comptait dernièrement, pour une population de 220,000 âmes environ, 1150 sociétés
# et groupements divers, et dans ce chiftre ne sont pas même comprises les associations de jeunes gens
#  des deux sexes, les sous-sections, etc ., parce que celles-ci sont considérées comme se rattachant
# à d'autres sociétés ; sinon l'en arriverait à un chiffre passablement plus élevé. L'on compte : 185
# associations professionnelles, 11 sociétés dramatiques, 206 sociétés d'utilité publique, 115 société
# s de chant, 59 sociétés de divertissement, 82 caisses maladie ou de secours, 37 sociétés scientifiqu
# es, 19 sociétés militaires, 40 sociétés de musique, 47 groupements politiques, 15 sociétés de quarti
# er, 47 sociétés religieuses, 3 clubs d'échecs, 61 sociétés de tir, 67 sociétés de « port, 3 associat
# ions de sténographie, 15 sociétés universitaires, 43 sociétés de gymnastique, S sociétés patriotique
# s, 22 corporations, etc. A ees chiffres, il convient encore d'ajouter 28 sociétés de bibliothèque, p
# ... [truncated]
# ------------------
#
# --- Article 17 ---
# Title: engpasse
# Publicationdate: 1976-07-07
# Languagecode: de
# Transcript Length: 967 characters
# Transcript:
# engpasse bps. Die Wasserversorgung in einigen Zürcher Quartieren ist durch den schlagartig gestiegen
# en Verbrauch an der Grenze ihrer Leistungsfähigkeit angelangt. Wie die Abteilung Wasserversorgung de
# r Industriellen Betriebe der Stadt ZUrich mitteilte, betrifft dies in erster Linie die peripher gele
# genen Versorgungsgebicte Seebach, Höngg, Waidberg, Friesenberg, Leimbach und Witikon. Wohl gehört zu
# rzeit die Wasserversorgung der Stadt Zürich zu den modernsten und leistungsfähigsten ihrer Art in Eu
# ropa. Doch die endgültige Sicherstellung der Wasserlieferungen für das gesamte Stadtgebiet wird erst
#  ab etwa 1982 bewerkstelligt sein, da sich momentan verschiedene in der Gemeindeabstimmung vom 4. Mä
# rz 1973 bewilligte Projekte noch im Stadium der Realisierung befinden. So steht beispielsweise das G
# rundwasserwerk Hardhof im Neubau. Darüberhinaus werden verschiedene Verteilanlagen wie Pumpwerke, Re
# servoire und Transportleitungen gegenwärtig erneuert. Schluss S. 14
# ------------------
#
# --- Article 18 ---
# Title: Les bains publies en Suisse
# Publicationdate: 1931-08-07
# Languagecode: fr
# Transcript Length: 2053 characters
# Transcript:
# Les bains publies en Suisse Le service de publictié des C. F. F. a organisé dans tout le pays une en
# quête sur les établissements de bain. Au total 111 villes et stations touristiques disposent de bain
# s de rivière, de plages ou de piscines, ce nombre s'est même accru depuis la fin de l'enquête. 24 de
#  ces établissements se trouvent dans la Suisse orientale entre Zurich et le lac de Constance, 19 dan
# s la Suisse centrale, 18 dans l'Oberland bernois (Berne y compris), 17 dans les Grisons, 15 dans la
# Suisse septentrionale et occidentale, 8 le long du lac Léman, etc. Il existe 19 piscines artificiell
# es, dont 6 chauffablee ; 70 autres établissements sont situés au bord des lacs, et le reste sur les
# cours d'eau. L'installation de ces bains est des plus variés ; il en est de luxueuses, de raffinées,
#  comme aussi de très simples. 6880 cabines individuelles ont été annoncées ; Bâle vient en tête avec
#  487, et Lucerne suit avec 404. Il existe en outre des cabines communes ainsi que divercabines commu
# nes ainsi que diverses installations servant de vestiaires. Il va sans dire qu'il est partout possib
# le de prendre des bains de soleil, aujourd hui si en vogue ; cependant 78 établissements disposent d
# 'emplacements spéciaux. 70 établissements ont des terrains de gymnastique ou de jeu, 92 des pelouses
# . La gymnastique enseignée dans 29 bains permet aux personnes corpulentes de perdre quelque peu de l
# eur embonpoint. 82 bains offrent les délices de la douche. 75 disposent d'engins destinés aux jeux n
# ... [truncated]
# ------------------
#
# --- Article 19 ---
# Title: LE PASSE GLORIEUX ET LOINTAIN DE LA VILLE DE ZURICH
# Publicationdate: 1935-12-20
# Languagecode: fr
# Transcript Length: 5790 characters
# Transcript:
# LE PASSE GLORIEUX ET LOINTAIN DE LA VILLE DE ZURICH Promenade dans les pays suisses (De notre corres
# pondant particulier) Il m'est agréable de saisir l'occasion qui m'est offerte de rédiger un article
# sur la ville de Zurich. Je le fais avec d'autant plus de plaisir qu'établi à Zurich depuis plus de q
# uinze ans, j'ai eu l'occasion fort souvent d'apprécier l'entregent et l'esprit de bienveillance de s
# es habitants. Loin de son coin de pays, le welsche se sent toujours un peu un « déraciné » ; c'est d
# onc pour lui un grand bienfait que de se trouver au milieu d'une population cordiale, dont les quali
# tés d'assiduité et de sérieux sont bien connues. Il y aurait évidemment beaucoup à dire sur le sujet
#  faisant l'objet de la présente chronique ; je me bornerai cependant à n'insister que sur quelques f
# aits permettant de situer dans son véritable milieu l'Athènes des bords de la Limmat qui, depuis que
# lques dizaines d'années, a pris un prodigieux essor. ? * * Déjà à l'époque préhistorique, les rives
# du lac de Zurich — 40 km. de long — étaient habitées. C'est ainsi qu'en 1854 l'on a découvert à Meil
# en des restes d'habitations lacustres ; sauf erreur, cette découverte a été la première du genre. Da
# ns la suite, l'on a fait une ample récolte d'objets préhistoriques dans la région du lac inférieur,
# là même où s'élève aujourd'hui la fière et popu-JLa cathédrale de Zurich d'après une ancienne gravur
# e. Ieuse ville de Zurich. Le musée national possède du reste une incomparable collection d'objets de
# ... [truncated]
# ------------------
#
# --- Article 20 ---
# Title: Le canton de Zurich compte 3200 débits d...
# Publicationdate: 1914-02-07
# Languagecode: fr
# Transcript Length: 1536 characters
# Transcript:
# Le canton de Zurich compte 3200 débits de boissons et 1800 magasins de vente à l'emporter de boisson
# s alcooliques, dont 1000 pour la seule ville de Zurich. Aussi ne faut-il pas s'étonner d'y voir mont
# er la marée de l'alcoolisme. Le Conseil d'Etat entend l'endiguer par une loi dont voici les disposit
# ions les plus importantes. Le nombre des débits de boissons ne pourra pas dépasser une proportion d'
# un débit pour une sphère de population de 200 âmes. Les patentes ne seront pas accordées aux établis
# sements mais aux personnes. Elles pourront définitivement être retirées aux tenanciers qui se seront
#  fait citer deux fois pour violation des règlements de police. Les communes auront le droit de fixer
#  des heures de fermeture des débits plus restrictives aue le maximum autorisé. Les débits ne pourron
# t être ouverts le dimanche et les jours fériés avant 11 heures du matin. Tout employé d'un établisse
# ment aura droit à un temps de sommeil d'au moins 8 heures, et de plus à un repos inintei-rompu de 6
# heures de temps, dont 3 pendant la journée. Toutes les trois semaines, les ployés auront droit à 1 j
# our de repos de 24 heures, qui, tous les deux mois au moins, devra tomber sur un dimanche. Il sera i
# nterdit aux garçons et aux sommelières de boire avec les consommateurs. Les magasins de vente au dét
# ail de boissons alcooliques ne pourront vendre le dimanche, et la semaine ils ne pourront débiter ap
# rès 8 heures du soir. Ce projet de loi contribuera, s'il est adopté, à une notable amélioration des
# ... [truncated]
# ------------------

# %% [markdown]
# # Reranking Utilities

# %%
from scipy.stats import spearmanr

def calculate_overlap_between_rank_and_reranking(original_articles, reranked_articles):
  """
  Calculates and prints ranking metrics between the original and reranked article lists.

  Args:
    original_articles: The original list of article objects.
    reranked_articles: The reranked list of article objects.
  """
  # Get the UIDs of the articles in the original and reranked lists
  original_uids = [article.raw["uid"] for article in original_articles]
  reranked_uids = [article.raw["uid"] for article in reranked_articles]

  # Create ranking lists based on UIDs
  original_ranking = [original_uids.index(uid) for uid in reranked_uids]
  reranked_ranking = list(range(len(reranked_uids)))

  # Calculate Spearman correlation
  spearman_corr, _ = spearmanr(original_ranking, reranked_ranking)

  print(f"Spearman correlation between original and reranked rankings: {spearman_corr:.4f}")

  # Calculate overlap in top 5 and top 10
  original_top_3 = set(original_uids[:3])
  reranked_top_3 = set(reranked_uids[:3])
  overlap_3 = len(original_top_3.intersection(reranked_top_3))
  print(f"Overlap in top 3 results: {overlap_3}")

  # Calculate overlap in top 5 and top 10
  original_top_5 = set(original_uids[:5])
  reranked_top_5 = set(reranked_uids[:5])
  overlap_5 = len(original_top_5.intersection(reranked_top_5))
  print(f"Overlap in top 5 results: {overlap_5}")

  original_top_10 = set(original_uids[:10])
  reranked_top_10 = set(reranked_uids[:10])
  overlap_10 = len(original_top_10.intersection(reranked_top_10))
  print(f"Overlap in top 10 results: {overlap_10}")

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

def rerank_articles_by_other_embedding_model(original_articles, question, embedding_model):
  """
  Reranks a list of articles based on their relevance to a given question using a different embedding model.

  Args:
    articles: A list of article objects (with a .raw attribute containing a dictionary).
    question: The question string.
    embedding_model: The SentenceTransformer model to use for generating embeddings.

  Returns:
    A list of article objects, sorted by relevance to the question in descending order.
  """
  # Combine title and transcript for article text
  article_texts = [str(article.raw.get("title")) + " " + article.raw.get("transcript") for article in original_articles]

  # Generate embeddings for articles and question
  article_embeddings = embedding_model.encode(article_texts)
  question_embedding = embedding_model.encode(question)

  # Calculate cosine similarity using numpy
  similarity_scores = np.dot(article_embeddings, question_embedding.reshape(-1, 1)).flatten() / (np.linalg.norm(article_embeddings, axis=1) * np.linalg.norm(question_embedding))

  # Pair articles with their scores and sort
  scored_articles = sorted(zip(original_articles, similarity_scores), key=lambda x: x[1], reverse=True)

  # Return only the sorted articles
  reranked_articles = [article for article, score in scored_articles]

  calculate_overlap_between_rank_and_reranking(original_articles=original_articles, reranked_articles=reranked_articles)
  return reranked_articles
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'

# %%
embedding_model_denoising = SentenceTransformer('impresso-project/halloween_workshop_ocr_robust_preview', trust_remote_code=True)
embedding_model_lux = SentenceTransformer('impresso-project/halloween_workshop_ocr_robust_with_lux_preview', trust_remote_code=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/283 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/58.0 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# configuration.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/impresso-project/halloween_workshop_ocr_robust_preview:
# - configuration.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/impresso-project/halloween_workshop_ocr_robust_preview:
# - modeling.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/312 [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/283 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/58.0 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# configuration.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/impresso-project/halloween_workshop_ocr_robust_with_lux_preview:
# - configuration.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/impresso-project/halloween_workshop_ocr_robust_with_lux_preview:
# - modeling.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/312 [00:00<?, ?B/s]

# %% [markdown]
# # Retrieval Augmented Generation

# %%
# 1. Install the 'openai' library
# !pip install openai -q

# %%
def generate_interface_links(articles, url_format_string):
  """
  Generates a formatted string of interface links using the 'guid' from each article.

  Args:
    articles: A list of article objects (with a .raw attribute containing a dictionary).
    url_format_string: A string representing the URL format, expecting a '{guid}' placeholder.

  Returns:
    A single string containing all the formatted URLs, each on a new line.
  """
  interface_links = []
  for article in articles:
    guid = article.raw.get("uid")
    if guid:
      formatted_url = url_format_string.format(guid=guid)
      interface_links.append(formatted_url)
  return "\n".join(interface_links)

# %% [markdown]
# ## RERANKING

# %% [markdown]
# ### Q1

# %%
reranked_articles_q1 = rerank_articles_by_other_embedding_model(result_articles_q1, question_q1, embedding_model=embedding_model_denoising)
# Out:
# Spearman correlation between original and reranked rankings: -0.4556
# Overlap in top 3 results: 0
# Overlap in top 5 results: 1
# Overlap in top 10 results: 3

# %%
format_and_display_articles(result_articles_q1)
# Out:
# --- Article 1 ---
# Title: EN SUISSE : A ZURICH, DES ÉMEUTIERS FONT METTRE EN LIBERTÉ UN PRISONNI[...]
# Publicationdate: 1919-06-16
# Languagecode: fr
# Transcript Length: 1669 characters
# Transcript:
# ZURICH, -15 juin. — Des troubles assez sérieux ont éclaté à Zurich, où, comme on le sait, existe une
#  minorité socialiste extrémiste des plus actives. Une grande manifestation avait été organisée, vend
# redi soir, pair l'Union ouvrière zurichoise, pour honorer la mémoire de Posa Luxembourg. Le préfet d
# e police de Zurich, le socialiste Greber, sur la promesse que la manifestation se déroulerait dans l
# e calme, avait donné des instructions pour que la polioe.se tînt éloignée de la réunion. Celle-ci co
# mmença bien; mais un orateur vint annoncer que le délégué socialiste suisse. Conrad Wyss venait, en
# rentrant d'Allemagne, d'être arrêté par les autorités fédérales, pour avoir introduit des brochures
# et des tracts de propagande. Aussi tôt la foule se porta vers la prison et réclama la mi.se en liber
# té du prisonnier. Vainement les gardiens tentèrent, d'abord par des coups de feu à blanc, ensuite au
#  moyen de pompes à incendie, d'arrêter les manifestants. Pour les c'almer, Conrad Wyss fut mis en 'l
# iberté; mais cette mesure ne suffit point et il fallut se servir d'une mitrailleuse pour empêcher la
#  foule de pénétrer dans la prison. Enfin, vers 2 heures du matin, seulement. le calme revint. Ces év
# énements produisent dans toute la Suisse une grosse émotion. L'opinion générale est que tout 'le mou
# vement révolutionna.ire dont Zurich est le centre depuis plusieurs mois est organisé par 'des agents
#  de l'élrange!' et réclame une attitude énergique'de-s-autorités. Le Conseil d'Etat a pris, déjà. di
# ... [truncated]
# -----------------
#
# --- Article 2 ---
# Title: "hreuie vor
# Publicationdate: 1953-10-26
# Languagecode: de
# Transcript Length: 838 characters
# Transcript:
# hreuie vor 50 Jahren wurde Zizers von einem Großbrand heimgesucht, der vierzehn Firsten einäscherte.
#  * 40 Jahren war die Schweiz am Pariser Automobil-Salon durch die Personenwagen Martini und Picard-P
# ictet vertreten. Die am Salon ausgestellten io—12-PS-Personenwagen waren zum Preis von rund 5000 Fr.
#  erhältlich. 30 Jahren verzichtete der Stadtrat von Zürich auf die Leuchtfontäne im unteren Zürichse
# ebecken, die ein privates Komitee anläßlich der Zürcher Lichtwoche schenken wollte. 20 Jahren wurde
# bekanntgegeben, daß 3 6 Personen beim großen Eisenbahnunglück bei Evreux — dei Schnellzug Cherbourg—
# Paris entgleiste und stürzte in einen Fluß — den Tod fanden. 10 Jahren erklärte der englische Luftfa
# hrtminister Sinclair, daß in den letzten vier Wochen mehr als 17 00 c Tonnen Bomben auf deutsches Ge
# biet abgeworfen worden seien. /. G. M,
# -----------------
#
# --- Article 3 ---
# Title: L'ACTUALITÉ SUISSE
# Publicationdate: 1959-04-24
# Languagecode: fr
# Transcript Length: 969 characters
# Transcript:
# L'ACTUALITÉ SUISSE Meurtre à Zurich ZURICH, 24. — Un drame s'est produit jeudi après-midi, peu avant
#  14 heures, dans une entreprise de machines à écrire de la Schaffhauserstrasse, No 272, à Zurich.. L
# c directeur de la maison avait fait savoir à un ouvrier de 45 ans, M. Adolf Buechi, employé dans l'e
# ntreprise depuis septembre 1958, qu'il pourrait y rester jusqu'à ce qu'il ait trouvé une autre place
# . Jeudi après-midi, Buechi arriva dans la maison et tira un coup de feu sur un contremaître, M. Fran
# cesco Naegelin, âgé de 30 ans. Celuici fut atteint dans le dos et, la balle ayant sectionné, l'aorte
# , il fut tué sur le coup. Buechi se rendit alors dans une autre pièce où il menaça des ouvriers, qui
#  purent cependant s'enfuir. Le meurtrier tourna alors son arme contre lui-même cl se tira une balle
# dans la lêtc. Il est dans un état désespéré. Le contremaître tué laisse une femme et deux enfants. U
# n conflit de travail mineur semble être le motif de l'acte de Buechi.
# -----------------
#
# --- Article 4 ---
# Title: * Banque cantonale zurichoise.
# Publicationdate: 1951-02-14
# Languagecode: fr
# Transcript Length: 1944 characters
# Transcript:
# * Banque cantonale zurichoise. Après déduction et amortissements, le compte de la Banque cantonale d
# e Zurich pour l'année 1950 laisse un bénéfice net disponible de fr. 5,175,560. Suivant la loi sur la
#  banque, fr. 2 millions 200,000 vont au compte de réserve, fr. 2,200,000 au canton, dont fr. 1,760,0
# 00 à la caisse de l'Etat et fr. 440 mille au fonds cantonal d'utilité publique. D'autre part, le con
# seil de banque a décidé à l'occasion du 600 e anniversaire de l'entrée dans la Confédération de vers
# er une somme de fr. 500,000 pour améliorer la situation des tuberculeux qui ont leur domicile dans l
# e canton de Zurich ou qui, citoyens zurichois, résident en dehors du canton. Usines de I'Etzel, Eins
# icdcln. Les usines de I'Etzel ont réalisé pendant l'exercice 1949-1050 un bénéfice de fr. 842,105.5
# % iront au fonds de réserve légal et le reste, fr .. 800,000, servira au versement d'un dividende de
#  4 % sur le capital-actions de 20 millions. Au cours de cet exercice les usines ont produit 206,077
# millions de kWh. qui ont été repris en grande partie par les CFF et les usines hydrauliques du nord-
# est suisse. Au cours de l'exercice, 30,07 millions de mètres cubes d'eau ont été pompés du lac de Zu
# rich pour être déservés dans le Sihlsee, ce qui a amélioré de 15 % le niveau du petit lac. General M
# otors. Lia General Motors déclare un dividende de S 1 sur ses 88,000 actions ordinaires en circulati
# on comme premier versement pour l'exercice en cours. Ce montant est le même que celui payé en décemb
# ... [truncated]
# -----------------
#
# --- Article 5 ---
# Title: d octobre 1950 BULLETIN DE BOURSE
# Publicationdate: 1950-10-05
# Languagecode: fr
# Transcript Length: 2103 characters
# Transcript:
# d octobre 1950 BULLETIN DE BOURSE u E Zurich :. Cour _.', Obligations A 5 VA% Féd. 42 / ms 101-25 d'
# «» 3%% Féd. 43 / av. 10675 d 1 t) 6-8° 3%% Féd. 44 / mal 1 ( wfid 10 < _"° 3% Fédéral 49.. _™ _' 9°
# 104. 75 3% C. F. F. 38.. 1 t) 3 _- 65 m 50 Actions Swissair.... 220 215 d B. Com. de Bâle 263 265 Ba
# nque Fédérale 178 179 Union B. Suisses 900 902 Société B. Suisse 786 786 Crédit Suisse.. 797 796 d C
# onli Linoléum. 216 218 Electro Watt.. 715 717 interhandel... 668 667 Motor Colombus. 509 510 S. A. E
# . G. Sér. 1 66 66 Indelec.... 267 274 Italo-Suisse prior. 83 83 Réassurances.. 5650 5710 Winterthour
#  Ace. 5790 5800 Zurich Assuranc. 7900 d 7990 o Aar-Tessin i.. 1180 1180 Zurich : Cou. ra du Actions
# 4 5 Saurer ¦ _<,, 880 890 Aluminium B ¦ s 2075 2098 Bally... a a -, 725 725 Brown-Boveri.. 925 930 F
# . Mot. Suisse C. 1360 d 1360 Fischer.,, «, 890 725 Laufenburg... 1340 1355 d Linol. Giubiasco _. 118
#  118 Lonza.... t 840 850 Nestlé Alimenl.. •1440 1450 Sulzer..... 1775 1800 Baltimore. ;. „ 61 62% _P
# ennsylvanie RR > 86 87 Italo-Argentina.. 49 48 Royal Dutch, » -. 219 217 Sodec..,, » 43 43 Vt Standa
# rd-Oil. _., 363 368 Union Carbide.-> 208 209 A. E. G.... ¦ 27 27 Du Pont de Nem. 350 359 Eastman Kod
# ak. 206 203 Général Electric.. 210 210 Général Motors. 430 463 Internat. Nickel. 148 150 Kennecott..
# .. 276 281 Montgomery W.. 277 283 National Distillers 113 114 Allumettes B.,. 30 29% Un. States Staë
# l ¦ 165 173 Cours du Zurich :'7 ~ " p 4 5 AMCA, s _,. $ 28. 35 28. 45 SAFIT » s.. £ 10. 12. 6 10. 11
# ... [truncated]
# -----------------
#
# --- Article 6 ---
# Title: Après la manifestation communiste de Zurich
# Publicationdate: 1929-03-26
# Languagecode: fr
# Transcript Length: 2088 characters
# Transcript:
# Après la manifestation communiste de Zurich * De Zurich, le 25 rjnars : Le comité du parti socialist
# e de la ville de Zurich s'est réuni dans la soirée de dimanche afin de prendre position à l'égard de
# s nouveaux événements qui ont trait à la manifestation com muniste de Zurich. La résolution adoptée
# par le comité du parti et par quelques hommes de confiance qui se trouvaient là se prononce à l'unan
# imité, dans sa première partie, et cela conformément à l'opinion du groupe socialiste du Conseil nat
# ional et des socialistes bâlois, contre l'interdiction de réunion prononcée par le Conseil fédéral.
# La seconde partie de la résolution s'élève con tre la manière absolument grotesque et enfantine des
# communistes à cette occasion, attitude qui n'a absolument rien de commun avec une politique prolétar
# ienne et avec la défense des intérêts des travailleurs. Comme dans tous les autres pays, les communi
# stes sont en Suisse les courriers de la réaction ; ils connaissent l'interdiction et les mesures pol
# icières envisagées et ont provoqué les autorités avec intention. Appel est fait à la classe ouvrière
#  pour qu'elle s'oppose à la politique néfaste des communistes, politique qui a jeté le discrédit sur
#  la cause du prolétariat zuricois. La participation extraordinairement faible de l'assemblée communi
# ste de dimanche après-midi à Zurich montre d'une manière éclatante combien la masse des ouvriers zur
# icois est loin de faire cause commune avec ceux qui organisèrent des actions aussi peu sérieuses. L'
# ... [truncated]
# -----------------
#
# --- Article 7 ---
# Title: Les communistes a rœuure a Zurich
# Publicationdate: 1932-06-17
# Languagecode: fr
# Transcript Length: 1974 characters
# Transcript:
# Les communistes a rœuure a Zurich Un commissaire de police et plusieurs agents blessés Zurich, 15 ju
# in. Le Conseil de la ville de Zurich avait interdit les démonstrations projetées pour mercredi soir
# et- l'assemblée des monteurs en grève avait décidé de ne pas l'organiser. Cependant dès 20 heures qu
# elques centaines de personnes se réunirent sur l'Helvetia Platz, tandis qu'une centaine d'agents de
# police stationnaient dans les bâtiments voisins. Peu après 21 heures on comptait 2000 personnes rass
# emblées sur la place. Trois jeunes gens harangèrent la foule après quoi le communiste Fluck invita t
# out le monde à se former en cortège. C'est alors que la police entra en action. Au milieu des cris e
# t des coups de sifflets, elle fit évacuer les lieux, pressant la masse des manifestants vers la Land
# strasse. Des coups de feu furent même tirés en l'air par la police après que les manifestants eurent
#  de leur côté ouvert un bombardement en règle contre les gendarmes avec des pavés. Plusieurs agents
# et le commissaire de police Scheidegger furent plus ou moins sérieusement blessés par des pro jectil
# es alors qu'ils se trouvaient à l' -mgle de la Turnhalle et de la Hohlstrasse, près du restaurant So
# nne, où les monteurs engrève s'étaient réunis l'après-midi. Deux grandes vitres d'un magasin de chau
# ssures furent tièrement brisées. La police procéda ensuite à l'évacuation systématique des diverses
# rues. On entendit des coups de feu jusqu'à 22 heures. A 22 h. 30 on signalait environ deux douzaines
# ... [truncated]
# -----------------
#
# --- Article 8 ---
# Title: LA CHAUX-DE-FONDS Assemblée générale du Parti EN SUISSE
# Publicationdate: 1950-01-16
# Languagecode: fr
# Transcript Length: 4173 characters
# Transcript:
# LA CHAUX-DE-FONDS Assemblée générale du Parti EN SUISSE La ville tentaculaire Au cours de l’année 19
# 49, la population de la ville de Zurich s’est accrue de 2336 âmes. Elle était de 385.276 personnes c
# ontre 382,940 à fin 1948. Le courage d’un garçonnet A Bergun (Grisons), un bambin de 3 ans est tombé
#  du pont de l’Albula, d’une hauteur de 10 mètres, dans la rivière. Un autre garçon, un peu plus âgé,
#  est parvenu, malgré une épaisse neige et au péril de sa vie, à ramener le bambin sur le rivage. Le
# petit n’a pas de blessures graves. Sur les routes argoviennes Pendant le mois de décembre 1949, il s
# ’est produit, dans le canton d’Argovie, 105 accidents de la circulation, causant la mort de 3 person
# nes. Onze permis de conduire ont été retirés pour ivresse. Une forêt protégée Sur demande de la Comm
# ission vaudoise de la nature, le Conseil communal de Ballaigue a décidé d’interdire toutes coupes ex
# agérées et les dépôts de matériaux entraînant une modifica­ modification de la forêt de la Roche, au
# x Perce-Neige, , à l’altitude de 670 à 700 mètres, d’une superficie de 6350 mètres carrés, et peuplé
# e de frênes et d’érables, qui constitue un exemple de peuple­ peuplements naturels. Le succès d’un v
# ieux « flingot » L’Administration du matériel militaire com­ communique que vu la forte demande cons
# tante du fusil d’ordonnance 89, au prix de 5 francs, la vente est prolongée jusqu’au 31 mars 1950. L
# es munitions pour ce modèle seront à l’avenir uni­ uniquement fournies par les sociétés de tir et le
# ... [truncated]
# -----------------
#
# --- Article 9 ---
# Title: 1613 Radovic Dusan Zuchwil 1948 1828 Rad...
# Publicationdate: 1991-03-18
# Languagecode: de
# Transcript Length: 5811 characters
# Transcript:
# 1613 Radovic Dusan Zuchwil 1948 1828 Radovic Zorica Zuchwil 1954 1054 Raemy Pirmin Granges-Paccot 19
# 49 586 Ramseyer Daniel Thierachern 1967 854 Rapin Jean-Marc Domdidier 1952 173 Rappo Alfons Bern 194
# 9 1821 Rappo Jean-Jacques Fribourg 1951 1741 Rau Dominique Payerne 1956 1860 Ravessoud Andre Yverdon
#  1931 1663 Rawyler Jürg Biel 1961 1163 Reber Arthur Ostermundigen 1947 1170 Reber Walter Fraubrunnen
#  1953 1047 Regez Raymond Studen 1946 1127 Reinhard Ursula Rüeggisberg 1954 343 Reist Hansruedi Zollb
# rück 1949 ^™ 224 Rellstab Werner Zürich 1954 86 Repond Beat Düdingen 1962 725 Repond Jean-Bernhard B
# ulle 1958 1114 Repond Maurice Thun 1948 31 1312 Reubi Charles Ins 1939 25 1907 Reusser Fritz Uttigen
#  1937 460 36 g Reusser Jakob Heiligenschwendi 1953 608 Reusser Philipp Wilderswil 1954 261 971 Reute
# ler Erich Interlaken 1955 311 652 Rey Jacob Fleurier 1948 46 1562 Rey Jean-Daniel Peseux 1950 14 361
#  Rey Marc Faoug 1957 13 300 Reynand David Romont 1975 346 55 Richli Erich Beromünster 1966 87 1910 R
# ickenbacher Friedy Meyrin 161 362 Rickli Eric Meyrin 16 1776 Rieder Fritz Köniz 220 145 Rieder Kurt
# Wichtrach 117 576 Rieder Walter Matten 26 1043 Riesen Paul Gümmenen 257 1847 Riesen Werner Köniz 57
# 396 Riesen Willi Bern 131 363 RihmBeat Bern 109 222 Rihm Stefan Biel 191 573 Rihm Thomas Zürich 26 1
# 059 Rime Auguste Bulle 75 1232 Rime Francoise Fribourg 276 69 Rindlisbacher Jost Biel 102 240 Ringge
# nberg Fritz Uetendorf 808 Risler Bruno Lyss 66 Robadey Jacques Epagny 1769 Robinson John Belfaux 178
# ... [truncated]
# -----------------
#
# --- Article 10 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-10-11
# Languagecode: fr
# Transcript Length: 2123 characters
# Transcript:
# BULLETIN DE BOURSE du 11 octobre 1950 _., Cours du Zurich :,. Obligation » 10 11 71'Cl _EAH 41 ; m.
# 1 D 1 _% 101. 30 3 _' 4% Féd. 42 / ms „ v 3 li% féd. 43 / av. J **,., _^ _SV & tt Féd. 44 / mal _^ n
#  4 H 3% Fédéral 49.. 1 " _£ _* 3% C. F. F. 38.. mA 103 M Actions Swissair.... 215 d 215 B. Com. de B
# âle 265 263 Banque Fédérale 178 177 Union B. Suisses 912 913 Société B. Suisse 795 797 Crédit Suisse
# .. 805 806 Conti Linoléum. 217 216 Electro Watt.. 712 713 Interhandel... 684 680 Motor Colombus. 515
#  518 S. A. E. G. Sér. 1 67 66 li Indelec.... 275 276 " Ilalo-Sulsse prior. 82 d 82 Réassurances.. 57
# 00 5630 Winterthour Ace. 5775 5755 Zurich Assuranc. 7975 d 8000 o Aar-Tessin... 1180 1180 ! Zurich :
#  Cou » 'du [ Actions 10 11 Saurer. -.,.. 915 910 d Aluminium «.. 2100 2095 Bally...... 728 723 d Bro
# wn-Boverl.. 935 935 F. Mot. Suisse C. 1400 d 1400 Fischer..... 917 915 Laufenburg... 1355 d 1355 Lin
# ol. Giubiasco. 120 120 d Lonza 845 848 o Nestlé Aliment.. 1447 1448 Sulzer 1795 d 1805 Baltimore....
#  66 _% 66 Pennsylvania RR. 87 li 86 Italo-Argentina.. 49'. i 50 Royal Dutch... 216 217 Sodec.... . .
#  4414 44 d Standard-Oil... 376 370 Union Carbide.. 206 o 204 A. E. G 27 27% o Du Pont de Nem. 358 35
# 6 Eastman Kodak. 205 204 Général Electric.. 214 213 Général Motors. 467 458 Internat. Nickel. 149 14
# 3 Kennecott.... 287 282 Montgomery W.. 287 284 National Distillers 11, 5 113 Allumettes B... 30 _% d
#  30 li Un. States Steel. 177 173 Court du Zurich : 10 11 AMCA. « -. -. $ 28. 50 28. 30 SAFIT.... £ 1
# ... [truncated]
# ------------------
#
# --- Article 11 ---
# Title: LES RÉSULTATS de la " propagande pacifiste pratique "
# Publicationdate: 1917-11-19
# Languagecode: fr
# Transcript Length: 3569 characters
# Transcript:
# e. La révolution maximalisle a eu en Suisse un contre-coup inattendu. Des « agitateurs pacifistes Y)
#  — si Olt peut employer cette expression bizarre — y ont VIL l'occasion de traduire leurs théories d
# ans les faits en contraignant par violence deux fa-briques de munitinns à fermer leurs por--tes. Ces
#  deux établissements travaillaient pour rAllemagne, mais il semble évident que leur sort eût été le
# même si elles avaient travaillé pour VEnt-enle. En réalité les manifestations étaient dirigées contr
# e la guerre en général et contre Vannée suisse en particulier. L'un des nieneurs de l'affaire. le co
# mpagnon Deltwyler, a prononcé les paroles suivantes qui sont %Out un programme: « Assez causé! Il ne
#  u suffit pas de sympathiser de loin avec les frères russes. Il faut agir. Maintenant, la révolution
#  doit être portée en fait dans notre pays, et avant tout au milieu de nos soldats qui doivent reluse
# r en masse le ser- Vice militaire. » La police a été impuissante à réprimer l'émeute soudainement dé
# chaînée et il a fallu appeler la troupe qui a fait usage de ses armes. Les premières dépêches semble
# nt révéler un certain affolement et en tout cas une tendance à l'exagération. Mais la situation n'en
#  est pas moins assez sérieuse. La neutralité suisse a l'a plus grande importance pour les Alliés, ma
# is il ne faut pàs oublier qu'inversement tous- les prétextes à sa violation seraient bons pour l'All
# emagne. Et si, celle-ci n'est pour rien 'dans ces troubles subits (encore. faudra-t-il voir), elle s
# ... [truncated]
# ------------------
#
# --- Article 12 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-08-18
# Languagecode: fr
# Transcript Length: 2139 characters
# Transcript:
# BULLETIN DE BOURSE du 18 août 1950 Zurich :, Cour 9 du s Obligations 17 18 PA% Féd. 42 / ms 101-55 1
# 01. 55 d 3%% Féd. 43 / av. 107. 15 d 107. 10 3%% Féd. 44 / mal 107 _% 107-60 3% Fédéral 49.. 105. 50
#  105. 35 3% C. F. F. 38.. _- _*° HM-40 Actions Swissair.... 185 190 B. Com. de Bâle 234 233 Banque F
# édérale 162 161 Union B. Suisses 851 B 50 Société B. Suisse 766 766 Crédit Suisse.. 776 775 Conti Li
# noléum. 207 d 207 d Electro Watt.. 676 676 Interhandel... 622 617 Motor Colombus. 517 514 S. A. E. G
# . Sér. 1 74 73% Indelec.... 242 242 Halo-Suisse prlor.'74 d 74 Réassurances.. 5560 5550 Winterthour
# Ace. 5350 o 5300 d Zurich Assuranc. 7850 d 7850 Aar-Tossin s. „ 1170 d 1185 d Zurich : Cour 9 du Act
# ions 17 18 Saurer. : ¦ > > 820 818 Aluminium v ». 1935 1935, Bally...= _= » 670 670 Brown-Boveri.. 8
# 77 878 F. Mot. Suisse C. 1320 d 1320 d Fischer... «. 841 840 Laufenburg.. -. ¦ 1345 1345 Llnol. Giub
# iasco. 117 d 117 d lonza 792 d 800 Nestlé Aliment.. 1367 1370 Sulzer. g a » « 1652 1640 d Baltimore
# i ». n 51% 52 Pennsylvania RR _. 7914 79 VÎ : Italo-Argentina. ¦ 60 60 Royal Dutch.,, 205 206 Sodec.
# . * _= « 50 50 V _1 Standard-Oil. ï F 350 351 Union Carbide « _= 195 d 197% A. E. G..... 22 22 Du Po
# nt de Nem. 340 344 Eastman Kodak 1 187 187 Général Electric.. 205 206 Général Motors. 398 402 Intern
# at. Nickel. 138% 140 _% Kennecott.... 269 269 Montgomery W.. 241 239 National Dlsllllers 103 103 All
# umettes B.. ¦ ; 28% 28 Un, States Steel » 161 d 165 Cours du Zurich :'_ÏT " _^ P AMCA _< ;, _, $ 26.
# ... [truncated]
# ------------------
#
# --- Article 13 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-09-19
# Languagecode: fr
# Transcript Length: 2094 characters
# Transcript:
# BULLETIN DE BOURSE du 19 septembre 1950 Zurich : Cou _- ", Obligation » 15 19 VA% Féd. 42 / ms 101.
# 45 101. 40 3%% Féd. 43 / av. 1° 7 107 d 5%% Féd. 44 / mal 1° _?% 10 _™° 3% Fédéral 4 ?.. 105. 40 105
# -25 3% C. F. F. 38.. 1° _" _- « m-K Action » Swissair.... 230 225 B. Com. de Bâle 253 252 Banque Féd
# érale 171 175 Union B. Suisses 886 890 Société B. Suisse 784 784 Crédit Suisse.. 796 794 Contl Linol
# éum. 217 215 Electro Watt.. 730 725 Interhandel... 687 661 Motor Colombus. 516 517 S. A. E. G. Sér.
# 1 68 « 7% Indelec.... 257 261 Itaio-Suisse prior. 80 _' / 2 82 o Réassurances.. 5575 5580 Winterthou
# r Ace. 5690 5700 Zurich Assuranc. 7850 7525 d Aar-Tesjln 5, ¦ 1185 d 1190 Zurich : Cou I Actions 15
# 19 Saurer.-i » » ¦ 880 870 Aluminium, _, i 2090 2030 Bally...,,, 740 740 Brown-Boveri ». 905 933 F.
# Mot. Suisse Ci 1350 d 1350 d Fischer.. » > s 890 900 Lautenburg.. ¦< 1368 d 1360 Linol. Giubiasco «
# 122 120 Lonza 828 S 30 Nestlé Aliment. 5 1437 1449 Sulzer... > ¦ 1770 1780 Baltimore.,.. 60 VÉ 59% P
# ennsylvanla RR ¦ 86 V 2 85% Italo-Argentina. * 54% 53 Royal Dutch. s « 214 213 Sodec... ; e 46 45 _'
# , i Standard-Oil. « -, 376 d 373 Union'Carbide. « 206 213 A. E. G 25 25% Du Pont de Nem. 357 363 Eas
# tman Kodak. 194 198 Général Electric.. 207 209 Général Motors. 407 412 Internat. Nickel. 151 153 Va
# Kennecott.... 290 286 Montgomery W.. — 259 National Distillers — — Allumettes B.. « — — Un. State »
# Steel < —— Cours du Zurich : 15 _^ AMCA, s _,, $ 27. 55 27. 75 SAFIT, «,. £ 10. 13. 0 If-13- ? FONSA
# ... [truncated]
# ------------------
#
# --- Article 14 ---
# Title: Meurtre à Zurich
# Publicationdate: 1959-04-24
# Languagecode: fr
# Transcript Length: 1394 characters
# Transcript:
# Meurtre à Zurich Zurich, 23. — Un drame s’est pro­ produit jeudi après midi, peu avant 14 heures, da
# ns une entreprise de machi­ machines à écrire de la Schaffhauserstrasse 272, à Zurich. Le directeur
# de la mai­ maison avait fait savoir à un ouvrier de 45 ans, M. Adolf Buchi, employé dans l’entrepris
# e depuis septembre 1958, qu’il pourrait y rester jusqu’à ce qu’il ait trouvé une autre place. Jeudi
# après midi, Buchi arriva dans la maison et tira un coup de feu sur un contremaître, M. Francesco Nae
# gelin, âgé de 30 ans. Celui-ci fut atteint dans le dos et, la balle ayant sectionné l'aorte, il fut
# tué sur le coup. Buchi se rendit alors dans une autre pièce, où il menaça des ouvriers, qui purent c
# ependant s’enfuir. Le meurtrier tour­ tourna alors son arme contre lui-même et se tira une balle dan
# s la tête. Il est dans un état désespéré. Le contremaître tué laisse une fem­ femme et deux enfants.
#  Un conflit de tra­ travail mineur semble être le motif de l’acte de Buchi. ?* Ç ? *'› '-- ....... X
# SSMii Il faudra bâtir une nouvelle cure dans le village schwyzois de Wilerzell, cure dont les fondat
# ions devront être absolument imperméables à l’eau pour résister à la pression du lac de Sihl : C’est
#  pourquoi la cure a été mise sur des rouleaux et déplacée de 200 mètres en attendant la construction
#  des nouvelles fondations. Ce petit voyage, illustré par notre photo, a duré plusieurs jours !
# ------------------
#
# --- Article 15 ---
# Title: EN SUISSE La pénurie des logements à Zurich
# Publicationdate: 1950-01-18
# Languagecode: fr
# Transcript Length: 6178 characters
# Transcript:
# EN SUISSE La pénurie des logements à Zurich Au 1 er janvier 1950, sur 115,393 appartements dans la v
# ille de Zurich, il n’y en avait plus que 70 de libres, dont 27 dans des villas à vendre. Sur les 43
# autres appartements, 16 sont d’un loyer de plus de 3000 francs. Dans les 1 er et 5 e ar­ arrondissem
# ents, il n’y a plus un seul appartement. Un garçonnet écrasé par un camion à Zurich Le chauffeur d’u
# n camion-citerne contenant trois mille litres de carburant se préparait à faire marche arrière et av
# ait chassé trois gamins qui tournaient autour du véhicule. Ayant fait quelques mètres, le chauffeur
# sentit que son ca­ camion passait sur un obstacle. Il arrêta immédia­ immédiatement pour voir ce qui
#  se passait et s’aperçut qu’un garçon avait passé sous les roues. Ce dernier, un garçonnet de 10 ans
# , nommé René Leu, était monté au dernier moment sur le mar­ marchepied, puis était tombé sous les ro
# ues. Conduit à l’Hôpital cantonal, le pauvre petit n’a pas tardé à succomber. L'art universitaire Au
#  Palais de Rumine s’est ouverte, en présen­ présence de M. J. Peitrequin, syndic de Lausanne, et de
# M. Fl. Cosandey, recteur, la première exposition nationale d’art universitaire, organisée par l’Unio
# n nationale des étudiants de Suisse et l’As­ l’Association générale des étudiants de Lausanne. Auton
# omie communale L’Assemblée communale de Frasnacht a refu­ sé à l’unanimité une proposition de fusion
#  avec la commune d’Arbon. Elle veut conserver son autonomie. Un voleur condamné La Cour pénale de Be
# ... [truncated]
# ------------------
#
# --- Article 16 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-01-10
# Languagecode: fr
# Transcript Length: 1793 characters
# Transcript:
# BULLETIN DE BOURSE du 10 janvier 1950 Zurich : Co " " Obligations 9 10 31 / 4% Féd. 42 / ms 102. 50
# 102. 50 3'/ 2 o / 0 Féd. 43 / av. 107. 85 107. 90 31 / 2% Fd. 44 / mai 107. 90 107. 90 30 / 0 Fédéra
# l 49. 106. 25 106. 40 3 _" / o C. F. F. 38.. 104. 25 104. 40 Actions Union B. Suisses 895 895 Sociét
# é B. Suisse 792 795 Crédit Suisse... 805 807 Conti Lino 208 208 d Electro-Watt... 638 637 Interhande
# l.... 756 _/ 60 Motor Colombus 491 493 Sœg Sériel.... 62 >/ 2 71 Indelec 294 295 Halo-Suisse pr.. 84
#  84 Réassurances.. 5300 5310 Winterthour Ac 4400 d 4550 Zurich Assur... 8725 d 8825 Aar-Tessin.... 1
# 098 1099 Zurich : Co " _. Actions 9 10 Oerlikon Accu. 380 d 375 d Ad. Saurer.... 805 d 810 Aluminium
# .... 1880 1880 Bally 690 690 d Brown Boveri. 785 783 Aciéries Fischer 785 787 Lonza 760 / 70 Atel. O
# erlikon. 550 d 560 d Nestlé 1261 1275 Entrep. Sulzer. 1560 d 1585 Baltimore 48 _' / 4 48 _' / 2 Penn
# sylvan. RR 78 / 63 / 4 Sodec 65 i / 2 66 Italo-Argentina 71 71 _' / 2 Royal Dutch... 231 228 St. Oil
#  N.-Jersey 302 298 _' / 2 Eastman Kodak 216 213 Internat. Nickel 125 _' / 2 d 1241 / 2 Montgomery W.
#  248 248 Allumettes B... 33 331 / 2 AMCA $ 25. 95 25. 95 SAFIT £ 10. 9. 0 10. 9. 0 FONSA, c. préc. 1
# 06. 25 10650 Genève : Cours du Actions 9 10 Am. Sec. ord... 851 / 2 851 / 2 Canadian Pac.. 66 66 Ins
# t. Phys. au p. 212 d 212 Sécheron nom.. 350 d 350 Separator 108 109 S. K. F 200 198 Bâle : Ciba 1990
#  2005 Schappe Bâle.. 820 d 815 Chimiq. Sandoz 2790 2800 Hoffmann-La R. 3900 3910 Billets étrangers D
# ... [truncated]
# ------------------
#
# --- Article 17 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-02-07
# Languagecode: fr
# Transcript Length: 1832 characters
# Transcript:
# BULLETIN DE BOURSE du 7 lévrier 1950 Zurich : _Cours du Obligations 6 7 3 i / 4 o / 0 Féd. 42 / ms 1
# 03.- 103. — 3 **/ 2° / oFéd. 43 / av. 107. 90 10 /. 90 31 / 2% Fd. 44 / mal 107. 9 ( Jd 107. 90 30 /
#  0 Fédéral 49. 107.- 107.-30 _/ o CF. F. 38.. 104. 75 104. 80 Actions Union B. Suisses » 87 S 85 Soc
# iété B. Suisse / 93 791 Crédit Suisse... 804 603 Conti Lino, 218 0 218 Electro-Watt... 676 675 Inter
# handel.... 772 ( 85 Motor Colombus 507 500 Sœg Série I.... 72 71 »/ _jd Indelec 298 293 Halo-Suisse
# pr.. 85 ci 841 / 2 Réassurances.. 5375 J 250 d Winterthour Ac 4300 0 4600 o Zurich Assur... 8900 d 8
# 960 Aar-TesBln.... 1132 d 1138 d Zurich : Cours du'Actions 6 7 Oerlikon Accu. 390 o 370 d Ad. Saurer
# .... 822 d 825 Aluminium.... 1863 1840 Bally 680 680 d Brown Boveri. / 80 d 780 d Aciéries Fischer 7
# 90 790 Lonza 785 d / 85 Atel. Oerlikon. 575 o 572 d Nestlé 1276 1276 Entrep. Sulzer. 1610 d I 575 d
# Baltimore 4 V' / 4 46 V 4 Pennsylvan. RR 74 733 / 4 Sodec 63 d 63 Italo-Argentlna 67 _' / 2 66 Royal
#  Dutch... 231 230 St. 011 N.-Jersey Ï 9 S 299 Eastman Kodak'A 4 214 Internat. Nickel 124 'fc 1241 /
# 2 Montgomery W. 251 248 Allumettes B.. i'i 12 AMCA $ 26. 60 26. 25 SAFIT £ 10. 5. 6 10. 5. 0 F 0 NSA
# , c. préc. 107 i / a 107. 50 Genève 1 Com * " Actions 6 7 Am. Sec. ord... 843 / 4 833 / 4 Canadien P
# ac.. _66 >/ a 66 _' / 4 Inst. Phys. au p. 218 220 Sécheron nom.. 365 d 368 d Separator 110 111 d S.
# K. F 197 d 198 _BSIe : Ciba 2050 2050 Schappe Bâle.. 820 d 820 Chlmlq. Sandoz 28 U 0 2885 Hoffmann-L
# ... [truncated]
# ------------------
#
# --- Article 18 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-02-24
# Languagecode: fr
# Transcript Length: 1843 characters
# Transcript:
# BULLETIN DE BOURSE du 24 février 1950 Zurich :, Ç _£ _BSJ 2. Obligations 23 24 31 / 4% Féd. 42 / ms
# _lOSV _^ d 103. 15 3 _' / 2° / o Féd. 43 / av. 108. 50 d 108. 60 3 </ 2° / o Fd. 44 / mai ! 083 / 4
# 108. 65 d 30 / o Fédéral 49. 107. 15 107. 20 3 _" / o C. F. F. 38.. 105. 20 105'/ 4 Actions Union B.
#  Suisses 895 893 Société B. Suisse 799 765 Crédit Suisse... 814 808 Conti Lino 219 218 d Electro-Wat
# t... o 79 678 Interhandel.... 772 762 Motor Colombus 502 502 Sa ? g Série I... 72 7 U / 2 _indelec 2
# 92 <! 87 italo-Suisse pr. & 'fed 82 _' / 2 d Réassurances. 5475 > 460 Winterthour Ai 1650 il 4 ô 50
# d Zurich Assur.. < 250 cl J 3 Cto Aar-Tessin.... 1182 U / 7 Zurich : Coars du Actions 23 24 Oerlikon
#  Accu. 396 399 o Ad. Saurer.... 840 840 Aluminium.... 1882 1877 Bally 6 / 5 680 Brown Boveri. 793 (
# 91 Aciéries Fischer 790 d 792 d Lonza 788 785 d Atel. Oerlikon. 572 d 575 Nestlé 1277 1280 Entrep. S
# ulzer. 1610 1610 Baltimore 47 453 / 4 Pennsylvan. RR 73 73 Sodec 591 / 2 60 Italo-Argentina 66 d 66
# d Royal Dutch.. 233 231 St. Oil N.-Jersey 291 _' / 2 : 91 Eastman Kodak 20 / 205 d Internat. Nickel
# 122 _122 «/ j Montgomery W 243 cl 242 d Allumettes B... 32 d _I 2 l / 2 d AMCA... $ 26. 2 26. 25 SAF
# IT £ 10. 6. 1 10. 9 X FONSA, c. préc. 1083 / 4 10 & 3 / 4 Genève i Com _- Actions 23 24 Am. Sec. ord
# ... 84 84 Canadian Pac.. 663 /,, 66 _inst. Phys. au p. 220 d 222 Sécheron nom.. 370 370 Separator 10
# 9 d 110 S. K. F 197 d 197 d Bâle : Ciba 2085 2070 Schappe Bâle.. 850 d 850 d Chimiq. Sandoz 2950 d 2
# ... [truncated]
# ------------------
#
# --- Article 19 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-03-15
# Languagecode: fr
# Transcript Length: 1864 characters
# Transcript:
# BULLETIN DE BOURSE du 15 mars 1950 Zurich : Cou ? : Obligations 14 15 3 >/ 4° / o Féd. 42 / ms 102.
# 55 102 " d _Ji _/ 2° 'oFéd. 43 / av. 108. 15 d I 08. 30 d 3 _t / 2° / o Fd. 44 / mai 108 108. 15 jo
# / o Fédéral 49. 106. 80 106. 90 30 / o C. F. F. 38.. 104. 85 104. B 0 d Actions Union B. Suisses « 6
# 7 868 Société B. Suisse'74 777 Crédit Suisse.. 785 787 Conti Lino.... 217 _' / 2 217 l / 2 Electro-W
# att... 668 672 Interhandel.... 7 £ 6 760 Motor Colombus 498 5 C 4 _Seeg Série 1.... 71 _Vj 73 Indele
# c 286 <! 90 Italo-Suisse pr.. 84 84 Réassurances.. 54 i 0 5485 Winterthour Ac 4600 o 4600 o Zurich A
# ssur... 9000 9100 Aar-Tessin.... 1160 d 1160 1 Zurich : _SSB ! Actions 14 15 Oerlikon Accu. 389 o 38
# 0 d Ad. Saurer.... 831 d S 32 d Aluminium.... 1860 d 1865 Baily û / 5 670 d Brown Boveri. 782 7 t 8
# Aciéries Fischer 780 790 Lonza 795 795 Atel. Oerlikon. 5 ? 0 d 572 d Nestlé 1285 1290 Entrep. Sulzer
# . 1610 1610 d Baltimore 46'/ 4 47 >/ 2 Pennsylvan. RR 75 >/ 4 75 >/ 2 Sodec 60 60 d Italo-Argentina
# 66 66 Royal Dutch... 227 2 _^ 6 St. Oil N.-Jersey 294 296 Eastman Kodak 204 204 Internat. Nickel 119
#  _118 i / 2 MontgomeryW. 238 240 o Allumettes B... 313 /., 32 AMCA S 26. 45 26. 50 SAF 1 T £ 10. 10.
#  6 10. 10. 6 FONSA, c. préc. 108. i / 2 _lOfc _Vz o Genève : Cours du Actions 14 15 Am. Sec. ord...
# 343 / 4 851 / 4 Canadian Pac.. 64 V 2 d 64 «/ 2 lnst. Phys. au p. 212 213 d Sécheron nom.. 365 d 365
#  d Separator 114 d 115 S. K. F 202 2 L 2 Bâle : Ciba 2135 2150 Schappe Bàle.. 851 d 850 Chimiq. Sand
# ... [truncated]
# ------------------
#
# --- Article 20 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-11-27
# Languagecode: fr
# Transcript Length: 2088 characters
# Transcript:
# BULLETIN DE BOURSE du 27 novembre 1950 Cours du Zurich :'24 27 Obligations 3%% Féd. 42 / ms « J « J
# » 3%% Féd. 43 / av. 10475 10475 3%% Féd. 44 / mai 104. 60 d 104% 3% Fédéral 49.. 1 ( _M 1 tM d 3% C.
#  F. F. 38.. 1° V _= 102 Actions Swissair.... 200 o 195 d B. Com. de Bâle 268 266 Banque Fédérale 168
#  165 Union B Suisses 899 896 d Société B. Suisse 788 783 Crédit Suisse.. 798 793 Contl Linoléum 216
# 217 Electro Watt. 700 700 Interhandel.. 707 700 Motor Colombus 500 497 S. A. E. G. Sér. 1 65% 64% In
# delec.... 277 272 Halo-Suisse prlor. 92 d 82 Réassurances.. 5703 5700 Winterthour Ace. 5 ( 58 n r 56
# 5 u d Zurich Assuranc. 7 Ç, 5 () 790 o d Aar-Tessin ¦ ¦ > H _^ _nso d I j ! Zurich : Cou [* t '"'-s
# Actions 24 27 Saurer..... 915 910 d Aluminium... 2130 2110 Bally 732 o 730 d Brown-Boverl.. 950 945
# F. Mot. Suisse C. " 90 d 1370 Fischer "O " 2 o Laufenburg... 1350 d 1360 Llnol. Giublasco. 120 d 120
#  d Lonza 831 835 Nestlé Aliment.. 1485 1486 Sulzer 1825 1810 Baltimore.... 67 65% Pennsylvanie RR. 8
# 7% 8714 Italo-Argentina.. 46 46 Royal Dutch... 229 225 Sodec 44% 42 ex. c. Standard-OII... 395 354 U
# nion Carbide. 228 228 A. E. G.... 260 25 ?. id Du Pont de Nem 361 360 Eastman Kodak 225% 223% Généra
# l Electric. 219 218 ; Général Motors. 219% 220 Internat. Nickel. 1551 _^ 155 Kennecott.... 315 321%
# Montgemery W.. 288 d 287 National Distlllers _114 11, 5 Allumettes B. s. 29 d Z 0% Un, State » Steel
#  « 134 isa _% i Zurich : Cour 9 du, 24 27 AMCA.... $ 2 ?. 05 29. 10 SAFIT.... £ 10-11 i 0 1 rx 13. _
# ... [truncated]
# ------------------

# %%
format_and_display_articles(reranked_articles_q1)
# Out:
# --- Article 1 ---
# Title: d octobre 1950 BULLETIN DE BOURSE
# Publicationdate: 1950-10-05
# Languagecode: fr
# Transcript Length: 2103 characters
# Transcript:
# d octobre 1950 BULLETIN DE BOURSE u E Zurich :. Cour _.', Obligations A 5 VA% Féd. 42 / ms 101-25 d'
# «» 3%% Féd. 43 / av. 10675 d 1 t) 6-8° 3%% Féd. 44 / mal 1 ( wfid 10 < _"° 3% Fédéral 49.. _™ _' 9°
# 104. 75 3% C. F. F. 38.. 1 t) 3 _- 65 m 50 Actions Swissair.... 220 215 d B. Com. de Bâle 263 265 Ba
# nque Fédérale 178 179 Union B. Suisses 900 902 Société B. Suisse 786 786 Crédit Suisse.. 797 796 d C
# onli Linoléum. 216 218 Electro Watt.. 715 717 interhandel... 668 667 Motor Colombus. 509 510 S. A. E
# . G. Sér. 1 66 66 Indelec.... 267 274 Italo-Suisse prior. 83 83 Réassurances.. 5650 5710 Winterthour
#  Ace. 5790 5800 Zurich Assuranc. 7900 d 7990 o Aar-Tessin i.. 1180 1180 Zurich : Cou. ra du Actions
# 4 5 Saurer ¦ _<,, 880 890 Aluminium B ¦ s 2075 2098 Bally... a a -, 725 725 Brown-Boveri.. 925 930 F
# . Mot. Suisse C. 1360 d 1360 Fischer.,, «, 890 725 Laufenburg... 1340 1355 d Linol. Giubiasco _. 118
#  118 Lonza.... t 840 850 Nestlé Alimenl.. •1440 1450 Sulzer..... 1775 1800 Baltimore. ;. „ 61 62% _P
# ennsylvanie RR > 86 87 Italo-Argentina.. 49 48 Royal Dutch, » -. 219 217 Sodec..,, » 43 43 Vt Standa
# rd-Oil. _., 363 368 Union Carbide.-> 208 209 A. E. G.... ¦ 27 27 Du Pont de Nem. 350 359 Eastman Kod
# ak. 206 203 Général Electric.. 210 210 Général Motors. 430 463 Internat. Nickel. 148 150 Kennecott..
# .. 276 281 Montgomery W.. 277 283 National Distillers 113 114 Allumettes B.,. 30 29% Un. States Staë
# l ¦ 165 173 Cours du Zurich :'7 ~ " p 4 5 AMCA, s _,. $ 28. 35 28. 45 SAFIT » s.. £ 10. 12. 6 10. 11
# ... [truncated]
# -----------------
#
# --- Article 2 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-09-19
# Languagecode: fr
# Transcript Length: 2094 characters
# Transcript:
# BULLETIN DE BOURSE du 19 septembre 1950 Zurich : Cou _- ", Obligation » 15 19 VA% Féd. 42 / ms 101.
# 45 101. 40 3%% Féd. 43 / av. 1° 7 107 d 5%% Féd. 44 / mal 1° _?% 10 _™° 3% Fédéral 4 ?.. 105. 40 105
# -25 3% C. F. F. 38.. 1° _" _- « m-K Action » Swissair.... 230 225 B. Com. de Bâle 253 252 Banque Féd
# érale 171 175 Union B. Suisses 886 890 Société B. Suisse 784 784 Crédit Suisse.. 796 794 Contl Linol
# éum. 217 215 Electro Watt.. 730 725 Interhandel... 687 661 Motor Colombus. 516 517 S. A. E. G. Sér.
# 1 68 « 7% Indelec.... 257 261 Itaio-Suisse prior. 80 _' / 2 82 o Réassurances.. 5575 5580 Winterthou
# r Ace. 5690 5700 Zurich Assuranc. 7850 7525 d Aar-Tesjln 5, ¦ 1185 d 1190 Zurich : Cou I Actions 15
# 19 Saurer.-i » » ¦ 880 870 Aluminium, _, i 2090 2030 Bally...,,, 740 740 Brown-Boveri ». 905 933 F.
# Mot. Suisse Ci 1350 d 1350 d Fischer.. » > s 890 900 Lautenburg.. ¦< 1368 d 1360 Linol. Giubiasco «
# 122 120 Lonza 828 S 30 Nestlé Aliment. 5 1437 1449 Sulzer... > ¦ 1770 1780 Baltimore.,.. 60 VÉ 59% P
# ennsylvanla RR ¦ 86 V 2 85% Italo-Argentina. * 54% 53 Royal Dutch. s « 214 213 Sodec... ; e 46 45 _'
# , i Standard-Oil. « -, 376 d 373 Union'Carbide. « 206 213 A. E. G 25 25% Du Pont de Nem. 357 363 Eas
# tman Kodak. 194 198 Général Electric.. 207 209 Général Motors. 407 412 Internat. Nickel. 151 153 Va
# Kennecott.... 290 286 Montgomery W.. — 259 National Distillers — — Allumettes B.. « — — Un. State »
# Steel < —— Cours du Zurich : 15 _^ AMCA, s _,, $ 27. 55 27. 75 SAFIT, «,. £ 10. 13. 0 If-13- ? FONSA
# ... [truncated]
# -----------------
#
# --- Article 3 ---
# Title: 1613 Radovic Dusan Zuchwil 1948 1828 Rad...
# Publicationdate: 1991-03-18
# Languagecode: de
# Transcript Length: 5811 characters
# Transcript:
# 1613 Radovic Dusan Zuchwil 1948 1828 Radovic Zorica Zuchwil 1954 1054 Raemy Pirmin Granges-Paccot 19
# 49 586 Ramseyer Daniel Thierachern 1967 854 Rapin Jean-Marc Domdidier 1952 173 Rappo Alfons Bern 194
# 9 1821 Rappo Jean-Jacques Fribourg 1951 1741 Rau Dominique Payerne 1956 1860 Ravessoud Andre Yverdon
#  1931 1663 Rawyler Jürg Biel 1961 1163 Reber Arthur Ostermundigen 1947 1170 Reber Walter Fraubrunnen
#  1953 1047 Regez Raymond Studen 1946 1127 Reinhard Ursula Rüeggisberg 1954 343 Reist Hansruedi Zollb
# rück 1949 ^™ 224 Rellstab Werner Zürich 1954 86 Repond Beat Düdingen 1962 725 Repond Jean-Bernhard B
# ulle 1958 1114 Repond Maurice Thun 1948 31 1312 Reubi Charles Ins 1939 25 1907 Reusser Fritz Uttigen
#  1937 460 36 g Reusser Jakob Heiligenschwendi 1953 608 Reusser Philipp Wilderswil 1954 261 971 Reute
# ler Erich Interlaken 1955 311 652 Rey Jacob Fleurier 1948 46 1562 Rey Jean-Daniel Peseux 1950 14 361
#  Rey Marc Faoug 1957 13 300 Reynand David Romont 1975 346 55 Richli Erich Beromünster 1966 87 1910 R
# ickenbacher Friedy Meyrin 161 362 Rickli Eric Meyrin 16 1776 Rieder Fritz Köniz 220 145 Rieder Kurt
# Wichtrach 117 576 Rieder Walter Matten 26 1043 Riesen Paul Gümmenen 257 1847 Riesen Werner Köniz 57
# 396 Riesen Willi Bern 131 363 RihmBeat Bern 109 222 Rihm Stefan Biel 191 573 Rihm Thomas Zürich 26 1
# 059 Rime Auguste Bulle 75 1232 Rime Francoise Fribourg 276 69 Rindlisbacher Jost Biel 102 240 Ringge
# nberg Fritz Uetendorf 808 Risler Bruno Lyss 66 Robadey Jacques Epagny 1769 Robinson John Belfaux 178
# ... [truncated]
# -----------------
#
# --- Article 4 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-03-15
# Languagecode: fr
# Transcript Length: 1864 characters
# Transcript:
# BULLETIN DE BOURSE du 15 mars 1950 Zurich : Cou ? : Obligations 14 15 3 >/ 4° / o Féd. 42 / ms 102.
# 55 102 " d _Ji _/ 2° 'oFéd. 43 / av. 108. 15 d I 08. 30 d 3 _t / 2° / o Fd. 44 / mai 108 108. 15 jo
# / o Fédéral 49. 106. 80 106. 90 30 / o C. F. F. 38.. 104. 85 104. B 0 d Actions Union B. Suisses « 6
# 7 868 Société B. Suisse'74 777 Crédit Suisse.. 785 787 Conti Lino.... 217 _' / 2 217 l / 2 Electro-W
# att... 668 672 Interhandel.... 7 £ 6 760 Motor Colombus 498 5 C 4 _Seeg Série 1.... 71 _Vj 73 Indele
# c 286 <! 90 Italo-Suisse pr.. 84 84 Réassurances.. 54 i 0 5485 Winterthour Ac 4600 o 4600 o Zurich A
# ssur... 9000 9100 Aar-Tessin.... 1160 d 1160 1 Zurich : _SSB ! Actions 14 15 Oerlikon Accu. 389 o 38
# 0 d Ad. Saurer.... 831 d S 32 d Aluminium.... 1860 d 1865 Baily û / 5 670 d Brown Boveri. 782 7 t 8
# Aciéries Fischer 780 790 Lonza 795 795 Atel. Oerlikon. 5 ? 0 d 572 d Nestlé 1285 1290 Entrep. Sulzer
# . 1610 1610 d Baltimore 46'/ 4 47 >/ 2 Pennsylvan. RR 75 >/ 4 75 >/ 2 Sodec 60 60 d Italo-Argentina
# 66 66 Royal Dutch... 227 2 _^ 6 St. Oil N.-Jersey 294 296 Eastman Kodak 204 204 Internat. Nickel 119
#  _118 i / 2 MontgomeryW. 238 240 o Allumettes B... 313 /., 32 AMCA S 26. 45 26. 50 SAF 1 T £ 10. 10.
#  6 10. 10. 6 FONSA, c. préc. 108. i / 2 _lOfc _Vz o Genève : Cours du Actions 14 15 Am. Sec. ord...
# 343 / 4 851 / 4 Canadian Pac.. 64 V 2 d 64 «/ 2 lnst. Phys. au p. 212 213 d Sécheron nom.. 365 d 365
#  d Separator 114 d 115 S. K. F 202 2 L 2 Bâle : Ciba 2135 2150 Schappe Bàle.. 851 d 850 Chimiq. Sand
# ... [truncated]
# -----------------
#
# --- Article 5 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-08-18
# Languagecode: fr
# Transcript Length: 2139 characters
# Transcript:
# BULLETIN DE BOURSE du 18 août 1950 Zurich :, Cour 9 du s Obligations 17 18 PA% Féd. 42 / ms 101-55 1
# 01. 55 d 3%% Féd. 43 / av. 107. 15 d 107. 10 3%% Féd. 44 / mal 107 _% 107-60 3% Fédéral 49.. 105. 50
#  105. 35 3% C. F. F. 38.. _- _*° HM-40 Actions Swissair.... 185 190 B. Com. de Bâle 234 233 Banque F
# édérale 162 161 Union B. Suisses 851 B 50 Société B. Suisse 766 766 Crédit Suisse.. 776 775 Conti Li
# noléum. 207 d 207 d Electro Watt.. 676 676 Interhandel... 622 617 Motor Colombus. 517 514 S. A. E. G
# . Sér. 1 74 73% Indelec.... 242 242 Halo-Suisse prlor.'74 d 74 Réassurances.. 5560 5550 Winterthour
# Ace. 5350 o 5300 d Zurich Assuranc. 7850 d 7850 Aar-Tossin s. „ 1170 d 1185 d Zurich : Cour 9 du Act
# ions 17 18 Saurer. : ¦ > > 820 818 Aluminium v ». 1935 1935, Bally...= _= » 670 670 Brown-Boveri.. 8
# 77 878 F. Mot. Suisse C. 1320 d 1320 d Fischer... «. 841 840 Laufenburg.. -. ¦ 1345 1345 Llnol. Giub
# iasco. 117 d 117 d lonza 792 d 800 Nestlé Aliment.. 1367 1370 Sulzer. g a » « 1652 1640 d Baltimore
# i ». n 51% 52 Pennsylvania RR _. 7914 79 VÎ : Italo-Argentina. ¦ 60 60 Royal Dutch.,, 205 206 Sodec.
# . * _= « 50 50 V _1 Standard-Oil. ï F 350 351 Union Carbide « _= 195 d 197% A. E. G..... 22 22 Du Po
# nt de Nem. 340 344 Eastman Kodak 1 187 187 Général Electric.. 205 206 Général Motors. 398 402 Intern
# at. Nickel. 138% 140 _% Kennecott.... 269 269 Montgomery W.. 241 239 National Dlsllllers 103 103 All
# umettes B.. ¦ ; 28% 28 Un, States Steel » 161 d 165 Cours du Zurich :'_ÏT " _^ P AMCA _< ;, _, $ 26.
# ... [truncated]
# -----------------
#
# --- Article 6 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-02-24
# Languagecode: fr
# Transcript Length: 1843 characters
# Transcript:
# BULLETIN DE BOURSE du 24 février 1950 Zurich :, Ç _£ _BSJ 2. Obligations 23 24 31 / 4% Féd. 42 / ms
# _lOSV _^ d 103. 15 3 _' / 2° / o Féd. 43 / av. 108. 50 d 108. 60 3 </ 2° / o Fd. 44 / mai ! 083 / 4
# 108. 65 d 30 / o Fédéral 49. 107. 15 107. 20 3 _" / o C. F. F. 38.. 105. 20 105'/ 4 Actions Union B.
#  Suisses 895 893 Société B. Suisse 799 765 Crédit Suisse... 814 808 Conti Lino 219 218 d Electro-Wat
# t... o 79 678 Interhandel.... 772 762 Motor Colombus 502 502 Sa ? g Série I... 72 7 U / 2 _indelec 2
# 92 <! 87 italo-Suisse pr. & 'fed 82 _' / 2 d Réassurances. 5475 > 460 Winterthour Ai 1650 il 4 ô 50
# d Zurich Assur.. < 250 cl J 3 Cto Aar-Tessin.... 1182 U / 7 Zurich : Coars du Actions 23 24 Oerlikon
#  Accu. 396 399 o Ad. Saurer.... 840 840 Aluminium.... 1882 1877 Bally 6 / 5 680 Brown Boveri. 793 (
# 91 Aciéries Fischer 790 d 792 d Lonza 788 785 d Atel. Oerlikon. 572 d 575 Nestlé 1277 1280 Entrep. S
# ulzer. 1610 1610 Baltimore 47 453 / 4 Pennsylvan. RR 73 73 Sodec 591 / 2 60 Italo-Argentina 66 d 66
# d Royal Dutch.. 233 231 St. Oil N.-Jersey 291 _' / 2 : 91 Eastman Kodak 20 / 205 d Internat. Nickel
# 122 _122 «/ j Montgomery W 243 cl 242 d Allumettes B... 32 d _I 2 l / 2 d AMCA... $ 26. 2 26. 25 SAF
# IT £ 10. 6. 1 10. 9 X FONSA, c. préc. 1083 / 4 10 & 3 / 4 Genève i Com _- Actions 23 24 Am. Sec. ord
# ... 84 84 Canadian Pac.. 663 /,, 66 _inst. Phys. au p. 220 d 222 Sécheron nom.. 370 370 Separator 10
# 9 d 110 S. K. F 197 d 197 d Bâle : Ciba 2085 2070 Schappe Bâle.. 850 d 850 d Chimiq. Sandoz 2950 d 2
# ... [truncated]
# -----------------
#
# --- Article 7 ---
# Title: EN SUISSE La pénurie des logements à Zurich
# Publicationdate: 1950-01-18
# Languagecode: fr
# Transcript Length: 6178 characters
# Transcript:
# EN SUISSE La pénurie des logements à Zurich Au 1 er janvier 1950, sur 115,393 appartements dans la v
# ille de Zurich, il n’y en avait plus que 70 de libres, dont 27 dans des villas à vendre. Sur les 43
# autres appartements, 16 sont d’un loyer de plus de 3000 francs. Dans les 1 er et 5 e ar­ arrondissem
# ents, il n’y a plus un seul appartement. Un garçonnet écrasé par un camion à Zurich Le chauffeur d’u
# n camion-citerne contenant trois mille litres de carburant se préparait à faire marche arrière et av
# ait chassé trois gamins qui tournaient autour du véhicule. Ayant fait quelques mètres, le chauffeur
# sentit que son ca­ camion passait sur un obstacle. Il arrêta immédia­ immédiatement pour voir ce qui
#  se passait et s’aperçut qu’un garçon avait passé sous les roues. Ce dernier, un garçonnet de 10 ans
# , nommé René Leu, était monté au dernier moment sur le mar­ marchepied, puis était tombé sous les ro
# ues. Conduit à l’Hôpital cantonal, le pauvre petit n’a pas tardé à succomber. L'art universitaire Au
#  Palais de Rumine s’est ouverte, en présen­ présence de M. J. Peitrequin, syndic de Lausanne, et de
# M. Fl. Cosandey, recteur, la première exposition nationale d’art universitaire, organisée par l’Unio
# n nationale des étudiants de Suisse et l’As­ l’Association générale des étudiants de Lausanne. Auton
# omie communale L’Assemblée communale de Frasnacht a refu­ sé à l’unanimité une proposition de fusion
#  avec la commune d’Arbon. Elle veut conserver son autonomie. Un voleur condamné La Cour pénale de Be
# ... [truncated]
# -----------------
#
# --- Article 8 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-01-10
# Languagecode: fr
# Transcript Length: 1793 characters
# Transcript:
# BULLETIN DE BOURSE du 10 janvier 1950 Zurich : Co " " Obligations 9 10 31 / 4% Féd. 42 / ms 102. 50
# 102. 50 3'/ 2 o / 0 Féd. 43 / av. 107. 85 107. 90 31 / 2% Fd. 44 / mai 107. 90 107. 90 30 / 0 Fédéra
# l 49. 106. 25 106. 40 3 _" / o C. F. F. 38.. 104. 25 104. 40 Actions Union B. Suisses 895 895 Sociét
# é B. Suisse 792 795 Crédit Suisse... 805 807 Conti Lino 208 208 d Electro-Watt... 638 637 Interhande
# l.... 756 _/ 60 Motor Colombus 491 493 Sœg Sériel.... 62 >/ 2 71 Indelec 294 295 Halo-Suisse pr.. 84
#  84 Réassurances.. 5300 5310 Winterthour Ac 4400 d 4550 Zurich Assur... 8725 d 8825 Aar-Tessin.... 1
# 098 1099 Zurich : Co " _. Actions 9 10 Oerlikon Accu. 380 d 375 d Ad. Saurer.... 805 d 810 Aluminium
# .... 1880 1880 Bally 690 690 d Brown Boveri. 785 783 Aciéries Fischer 785 787 Lonza 760 / 70 Atel. O
# erlikon. 550 d 560 d Nestlé 1261 1275 Entrep. Sulzer. 1560 d 1585 Baltimore 48 _' / 4 48 _' / 2 Penn
# sylvan. RR 78 / 63 / 4 Sodec 65 i / 2 66 Italo-Argentina 71 71 _' / 2 Royal Dutch... 231 228 St. Oil
#  N.-Jersey 302 298 _' / 2 Eastman Kodak 216 213 Internat. Nickel 125 _' / 2 d 1241 / 2 Montgomery W.
#  248 248 Allumettes B... 33 331 / 2 AMCA $ 25. 95 25. 95 SAFIT £ 10. 9. 0 10. 9. 0 FONSA, c. préc. 1
# 06. 25 10650 Genève : Cours du Actions 9 10 Am. Sec. ord... 851 / 2 851 / 2 Canadian Pac.. 66 66 Ins
# t. Phys. au p. 212 d 212 Sécheron nom.. 350 d 350 Separator 108 109 S. K. F 200 198 Bâle : Ciba 1990
#  2005 Schappe Bâle.. 820 d 815 Chimiq. Sandoz 2790 2800 Hoffmann-La R. 3900 3910 Billets étrangers D
# ... [truncated]
# -----------------
#
# --- Article 9 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-02-07
# Languagecode: fr
# Transcript Length: 1832 characters
# Transcript:
# BULLETIN DE BOURSE du 7 lévrier 1950 Zurich : _Cours du Obligations 6 7 3 i / 4 o / 0 Féd. 42 / ms 1
# 03.- 103. — 3 **/ 2° / oFéd. 43 / av. 107. 90 10 /. 90 31 / 2% Fd. 44 / mal 107. 9 ( Jd 107. 90 30 /
#  0 Fédéral 49. 107.- 107.-30 _/ o CF. F. 38.. 104. 75 104. 80 Actions Union B. Suisses » 87 S 85 Soc
# iété B. Suisse / 93 791 Crédit Suisse... 804 603 Conti Lino, 218 0 218 Electro-Watt... 676 675 Inter
# handel.... 772 ( 85 Motor Colombus 507 500 Sœg Série I.... 72 71 »/ _jd Indelec 298 293 Halo-Suisse
# pr.. 85 ci 841 / 2 Réassurances.. 5375 J 250 d Winterthour Ac 4300 0 4600 o Zurich Assur... 8900 d 8
# 960 Aar-TesBln.... 1132 d 1138 d Zurich : Cours du'Actions 6 7 Oerlikon Accu. 390 o 370 d Ad. Saurer
# .... 822 d 825 Aluminium.... 1863 1840 Bally 680 680 d Brown Boveri. / 80 d 780 d Aciéries Fischer 7
# 90 790 Lonza 785 d / 85 Atel. Oerlikon. 575 o 572 d Nestlé 1276 1276 Entrep. Sulzer. 1610 d I 575 d
# Baltimore 4 V' / 4 46 V 4 Pennsylvan. RR 74 733 / 4 Sodec 63 d 63 Italo-Argentlna 67 _' / 2 66 Royal
#  Dutch... 231 230 St. 011 N.-Jersey Ï 9 S 299 Eastman Kodak'A 4 214 Internat. Nickel 124 'fc 1241 /
# 2 Montgomery W. 251 248 Allumettes B.. i'i 12 AMCA $ 26. 60 26. 25 SAFIT £ 10. 5. 6 10. 5. 0 F 0 NSA
# , c. préc. 107 i / a 107. 50 Genève 1 Com * " Actions 6 7 Am. Sec. ord... 843 / 4 833 / 4 Canadien P
# ac.. _66 >/ a 66 _' / 4 Inst. Phys. au p. 218 220 Sécheron nom.. 365 d 368 d Separator 110 111 d S.
# K. F 197 d 198 _BSIe : Ciba 2050 2050 Schappe Bâle.. 820 d 820 Chlmlq. Sandoz 28 U 0 2885 Hoffmann-L
# ... [truncated]
# -----------------
#
# --- Article 10 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-10-11
# Languagecode: fr
# Transcript Length: 2123 characters
# Transcript:
# BULLETIN DE BOURSE du 11 octobre 1950 _., Cours du Zurich :,. Obligation » 10 11 71'Cl _EAH 41 ; m.
# 1 D 1 _% 101. 30 3 _' 4% Féd. 42 / ms „ v 3 li% féd. 43 / av. J **,., _^ _SV & tt Féd. 44 / mal _^ n
#  4 H 3% Fédéral 49.. 1 " _£ _* 3% C. F. F. 38.. mA 103 M Actions Swissair.... 215 d 215 B. Com. de B
# âle 265 263 Banque Fédérale 178 177 Union B. Suisses 912 913 Société B. Suisse 795 797 Crédit Suisse
# .. 805 806 Conti Linoléum. 217 216 Electro Watt.. 712 713 Interhandel... 684 680 Motor Colombus. 515
#  518 S. A. E. G. Sér. 1 67 66 li Indelec.... 275 276 " Ilalo-Sulsse prior. 82 d 82 Réassurances.. 57
# 00 5630 Winterthour Ace. 5775 5755 Zurich Assuranc. 7975 d 8000 o Aar-Tessin... 1180 1180 ! Zurich :
#  Cou » 'du [ Actions 10 11 Saurer. -.,.. 915 910 d Aluminium «.. 2100 2095 Bally...... 728 723 d Bro
# wn-Boverl.. 935 935 F. Mot. Suisse C. 1400 d 1400 Fischer..... 917 915 Laufenburg... 1355 d 1355 Lin
# ol. Giubiasco. 120 120 d Lonza 845 848 o Nestlé Aliment.. 1447 1448 Sulzer 1795 d 1805 Baltimore....
#  66 _% 66 Pennsylvania RR. 87 li 86 Italo-Argentina.. 49'. i 50 Royal Dutch... 216 217 Sodec.... . .
#  4414 44 d Standard-Oil... 376 370 Union Carbide.. 206 o 204 A. E. G 27 27% o Du Pont de Nem. 358 35
# 6 Eastman Kodak. 205 204 Général Electric.. 214 213 Général Motors. 467 458 Internat. Nickel. 149 14
# 3 Kennecott.... 287 282 Montgomery W.. 287 284 National Distillers 11, 5 113 Allumettes B... 30 _% d
#  30 li Un. States Steel. 177 173 Court du Zurich : 10 11 AMCA. « -. -. $ 28. 50 28. 30 SAFIT.... £ 1
# ... [truncated]
# ------------------
#
# --- Article 11 ---
# Title: BULLETIN DE BOURSE
# Publicationdate: 1950-11-27
# Languagecode: fr
# Transcript Length: 2088 characters
# Transcript:
# BULLETIN DE BOURSE du 27 novembre 1950 Cours du Zurich :'24 27 Obligations 3%% Féd. 42 / ms « J « J
# » 3%% Féd. 43 / av. 10475 10475 3%% Féd. 44 / mai 104. 60 d 104% 3% Fédéral 49.. 1 ( _M 1 tM d 3% C.
#  F. F. 38.. 1° V _= 102 Actions Swissair.... 200 o 195 d B. Com. de Bâle 268 266 Banque Fédérale 168
#  165 Union B Suisses 899 896 d Société B. Suisse 788 783 Crédit Suisse.. 798 793 Contl Linoléum 216
# 217 Electro Watt. 700 700 Interhandel.. 707 700 Motor Colombus 500 497 S. A. E. G. Sér. 1 65% 64% In
# delec.... 277 272 Halo-Suisse prlor. 92 d 82 Réassurances.. 5703 5700 Winterthour Ace. 5 ( 58 n r 56
# 5 u d Zurich Assuranc. 7 Ç, 5 () 790 o d Aar-Tessin ¦ ¦ > H _^ _nso d I j ! Zurich : Cou [* t '"'-s
# Actions 24 27 Saurer..... 915 910 d Aluminium... 2130 2110 Bally 732 o 730 d Brown-Boverl.. 950 945
# F. Mot. Suisse C. " 90 d 1370 Fischer "O " 2 o Laufenburg... 1350 d 1360 Llnol. Giublasco. 120 d 120
#  d Lonza 831 835 Nestlé Aliment.. 1485 1486 Sulzer 1825 1810 Baltimore.... 67 65% Pennsylvanie RR. 8
# 7% 8714 Italo-Argentina.. 46 46 Royal Dutch... 229 225 Sodec 44% 42 ex. c. Standard-OII... 395 354 U
# nion Carbide. 228 228 A. E. G.... 260 25 ?. id Du Pont de Nem 361 360 Eastman Kodak 225% 223% Généra
# l Electric. 219 218 ; Général Motors. 219% 220 Internat. Nickel. 1551 _^ 155 Kennecott.... 315 321%
# Montgemery W.. 288 d 287 National Distlllers _114 11, 5 Allumettes B. s. 29 d Z 0% Un, State » Steel
#  « 134 isa _% i Zurich : Cour 9 du, 24 27 AMCA.... $ 2 ?. 05 29. 10 SAFIT.... £ 10-11 i 0 1 rx 13. _
# ... [truncated]
# ------------------
#
# --- Article 12 ---
# Title: LA CHAUX-DE-FONDS Assemblée générale du Parti EN SUISSE
# Publicationdate: 1950-01-16
# Languagecode: fr
# Transcript Length: 4173 characters
# Transcript:
# LA CHAUX-DE-FONDS Assemblée générale du Parti EN SUISSE La ville tentaculaire Au cours de l’année 19
# 49, la population de la ville de Zurich s’est accrue de 2336 âmes. Elle était de 385.276 personnes c
# ontre 382,940 à fin 1948. Le courage d’un garçonnet A Bergun (Grisons), un bambin de 3 ans est tombé
#  du pont de l’Albula, d’une hauteur de 10 mètres, dans la rivière. Un autre garçon, un peu plus âgé,
#  est parvenu, malgré une épaisse neige et au péril de sa vie, à ramener le bambin sur le rivage. Le
# petit n’a pas de blessures graves. Sur les routes argoviennes Pendant le mois de décembre 1949, il s
# ’est produit, dans le canton d’Argovie, 105 accidents de la circulation, causant la mort de 3 person
# nes. Onze permis de conduire ont été retirés pour ivresse. Une forêt protégée Sur demande de la Comm
# ission vaudoise de la nature, le Conseil communal de Ballaigue a décidé d’interdire toutes coupes ex
# agérées et les dépôts de matériaux entraînant une modifica­ modification de la forêt de la Roche, au
# x Perce-Neige, , à l’altitude de 670 à 700 mètres, d’une superficie de 6350 mètres carrés, et peuplé
# e de frênes et d’érables, qui constitue un exemple de peuple­ peuplements naturels. Le succès d’un v
# ieux « flingot » L’Administration du matériel militaire com­ communique que vu la forte demande cons
# tante du fusil d’ordonnance 89, au prix de 5 francs, la vente est prolongée jusqu’au 31 mars 1950. L
# es munitions pour ce modèle seront à l’avenir uni­ uniquement fournies par les sociétés de tir et le
# ... [truncated]
# ------------------
#
# --- Article 13 ---
# Title: * Banque cantonale zurichoise.
# Publicationdate: 1951-02-14
# Languagecode: fr
# Transcript Length: 1944 characters
# Transcript:
# * Banque cantonale zurichoise. Après déduction et amortissements, le compte de la Banque cantonale d
# e Zurich pour l'année 1950 laisse un bénéfice net disponible de fr. 5,175,560. Suivant la loi sur la
#  banque, fr. 2 millions 200,000 vont au compte de réserve, fr. 2,200,000 au canton, dont fr. 1,760,0
# 00 à la caisse de l'Etat et fr. 440 mille au fonds cantonal d'utilité publique. D'autre part, le con
# seil de banque a décidé à l'occasion du 600 e anniversaire de l'entrée dans la Confédération de vers
# er une somme de fr. 500,000 pour améliorer la situation des tuberculeux qui ont leur domicile dans l
# e canton de Zurich ou qui, citoyens zurichois, résident en dehors du canton. Usines de I'Etzel, Eins
# icdcln. Les usines de I'Etzel ont réalisé pendant l'exercice 1949-1050 un bénéfice de fr. 842,105.5
# % iront au fonds de réserve légal et le reste, fr .. 800,000, servira au versement d'un dividende de
#  4 % sur le capital-actions de 20 millions. Au cours de cet exercice les usines ont produit 206,077
# millions de kWh. qui ont été repris en grande partie par les CFF et les usines hydrauliques du nord-
# est suisse. Au cours de l'exercice, 30,07 millions de mètres cubes d'eau ont été pompés du lac de Zu
# rich pour être déservés dans le Sihlsee, ce qui a amélioré de 15 % le niveau du petit lac. General M
# otors. Lia General Motors déclare un dividende de S 1 sur ses 88,000 actions ordinaires en circulati
# on comme premier versement pour l'exercice en cours. Ce montant est le même que celui payé en décemb
# ... [truncated]
# ------------------
#
# --- Article 14 ---
# Title: Après la manifestation communiste de Zurich
# Publicationdate: 1929-03-26
# Languagecode: fr
# Transcript Length: 2088 characters
# Transcript:
# Après la manifestation communiste de Zurich * De Zurich, le 25 rjnars : Le comité du parti socialist
# e de la ville de Zurich s'est réuni dans la soirée de dimanche afin de prendre position à l'égard de
# s nouveaux événements qui ont trait à la manifestation com muniste de Zurich. La résolution adoptée
# par le comité du parti et par quelques hommes de confiance qui se trouvaient là se prononce à l'unan
# imité, dans sa première partie, et cela conformément à l'opinion du groupe socialiste du Conseil nat
# ional et des socialistes bâlois, contre l'interdiction de réunion prononcée par le Conseil fédéral.
# La seconde partie de la résolution s'élève con tre la manière absolument grotesque et enfantine des
# communistes à cette occasion, attitude qui n'a absolument rien de commun avec une politique prolétar
# ienne et avec la défense des intérêts des travailleurs. Comme dans tous les autres pays, les communi
# stes sont en Suisse les courriers de la réaction ; ils connaissent l'interdiction et les mesures pol
# icières envisagées et ont provoqué les autorités avec intention. Appel est fait à la classe ouvrière
#  pour qu'elle s'oppose à la politique néfaste des communistes, politique qui a jeté le discrédit sur
#  la cause du prolétariat zuricois. La participation extraordinairement faible de l'assemblée communi
# ste de dimanche après-midi à Zurich montre d'une manière éclatante combien la masse des ouvriers zur
# icois est loin de faire cause commune avec ceux qui organisèrent des actions aussi peu sérieuses. L'
# ... [truncated]
# ------------------
#
# --- Article 15 ---
# Title: Meurtre à Zurich
# Publicationdate: 1959-04-24
# Languagecode: fr
# Transcript Length: 1394 characters
# Transcript:
# Meurtre à Zurich Zurich, 23. — Un drame s’est pro­ produit jeudi après midi, peu avant 14 heures, da
# ns une entreprise de machi­ machines à écrire de la Schaffhauserstrasse 272, à Zurich. Le directeur
# de la mai­ maison avait fait savoir à un ouvrier de 45 ans, M. Adolf Buchi, employé dans l’entrepris
# e depuis septembre 1958, qu’il pourrait y rester jusqu’à ce qu’il ait trouvé une autre place. Jeudi
# après midi, Buchi arriva dans la maison et tira un coup de feu sur un contremaître, M. Francesco Nae
# gelin, âgé de 30 ans. Celui-ci fut atteint dans le dos et, la balle ayant sectionné l'aorte, il fut
# tué sur le coup. Buchi se rendit alors dans une autre pièce, où il menaça des ouvriers, qui purent c
# ependant s’enfuir. Le meurtrier tour­ tourna alors son arme contre lui-même et se tira une balle dan
# s la tête. Il est dans un état désespéré. Le contremaître tué laisse une fem­ femme et deux enfants.
#  Un conflit de tra­ travail mineur semble être le motif de l’acte de Buchi. ?* Ç ? *'› '-- ....... X
# SSMii Il faudra bâtir une nouvelle cure dans le village schwyzois de Wilerzell, cure dont les fondat
# ions devront être absolument imperméables à l’eau pour résister à la pression du lac de Sihl : C’est
#  pourquoi la cure a été mise sur des rouleaux et déplacée de 200 mètres en attendant la construction
#  des nouvelles fondations. Ce petit voyage, illustré par notre photo, a duré plusieurs jours !
# ------------------
#
# --- Article 16 ---
# Title: "hreuie vor
# Publicationdate: 1953-10-26
# Languagecode: de
# Transcript Length: 838 characters
# Transcript:
# hreuie vor 50 Jahren wurde Zizers von einem Großbrand heimgesucht, der vierzehn Firsten einäscherte.
#  * 40 Jahren war die Schweiz am Pariser Automobil-Salon durch die Personenwagen Martini und Picard-P
# ictet vertreten. Die am Salon ausgestellten io—12-PS-Personenwagen waren zum Preis von rund 5000 Fr.
#  erhältlich. 30 Jahren verzichtete der Stadtrat von Zürich auf die Leuchtfontäne im unteren Zürichse
# ebecken, die ein privates Komitee anläßlich der Zürcher Lichtwoche schenken wollte. 20 Jahren wurde
# bekanntgegeben, daß 3 6 Personen beim großen Eisenbahnunglück bei Evreux — dei Schnellzug Cherbourg—
# Paris entgleiste und stürzte in einen Fluß — den Tod fanden. 10 Jahren erklärte der englische Luftfa
# hrtminister Sinclair, daß in den letzten vier Wochen mehr als 17 00 c Tonnen Bomben auf deutsches Ge
# biet abgeworfen worden seien. /. G. M,
# ------------------
#
# --- Article 17 ---
# Title: EN SUISSE : A ZURICH, DES ÉMEUTIERS FONT METTRE EN LIBERTÉ UN PRISONNI[...]
# Publicationdate: 1919-06-16
# Languagecode: fr
# Transcript Length: 1669 characters
# Transcript:
# ZURICH, -15 juin. — Des troubles assez sérieux ont éclaté à Zurich, où, comme on le sait, existe une
#  minorité socialiste extrémiste des plus actives. Une grande manifestation avait été organisée, vend
# redi soir, pair l'Union ouvrière zurichoise, pour honorer la mémoire de Posa Luxembourg. Le préfet d
# e police de Zurich, le socialiste Greber, sur la promesse que la manifestation se déroulerait dans l
# e calme, avait donné des instructions pour que la polioe.se tînt éloignée de la réunion. Celle-ci co
# mmença bien; mais un orateur vint annoncer que le délégué socialiste suisse. Conrad Wyss venait, en
# rentrant d'Allemagne, d'être arrêté par les autorités fédérales, pour avoir introduit des brochures
# et des tracts de propagande. Aussi tôt la foule se porta vers la prison et réclama la mi.se en liber
# té du prisonnier. Vainement les gardiens tentèrent, d'abord par des coups de feu à blanc, ensuite au
#  moyen de pompes à incendie, d'arrêter les manifestants. Pour les c'almer, Conrad Wyss fut mis en 'l
# iberté; mais cette mesure ne suffit point et il fallut se servir d'une mitrailleuse pour empêcher la
#  foule de pénétrer dans la prison. Enfin, vers 2 heures du matin, seulement. le calme revint. Ces év
# énements produisent dans toute la Suisse une grosse émotion. L'opinion générale est que tout 'le mou
# vement révolutionna.ire dont Zurich est le centre depuis plusieurs mois est organisé par 'des agents
#  de l'élrange!' et réclame une attitude énergique'de-s-autorités. Le Conseil d'Etat a pris, déjà. di
# ... [truncated]
# ------------------
#
# --- Article 18 ---
# Title: Les communistes a rœuure a Zurich
# Publicationdate: 1932-06-17
# Languagecode: fr
# Transcript Length: 1974 characters
# Transcript:
# Les communistes a rœuure a Zurich Un commissaire de police et plusieurs agents blessés Zurich, 15 ju
# in. Le Conseil de la ville de Zurich avait interdit les démonstrations projetées pour mercredi soir
# et- l'assemblée des monteurs en grève avait décidé de ne pas l'organiser. Cependant dès 20 heures qu
# elques centaines de personnes se réunirent sur l'Helvetia Platz, tandis qu'une centaine d'agents de
# police stationnaient dans les bâtiments voisins. Peu après 21 heures on comptait 2000 personnes rass
# emblées sur la place. Trois jeunes gens harangèrent la foule après quoi le communiste Fluck invita t
# out le monde à se former en cortège. C'est alors que la police entra en action. Au milieu des cris e
# t des coups de sifflets, elle fit évacuer les lieux, pressant la masse des manifestants vers la Land
# strasse. Des coups de feu furent même tirés en l'air par la police après que les manifestants eurent
#  de leur côté ouvert un bombardement en règle contre les gendarmes avec des pavés. Plusieurs agents
# et le commissaire de police Scheidegger furent plus ou moins sérieusement blessés par des pro jectil
# es alors qu'ils se trouvaient à l' -mgle de la Turnhalle et de la Hohlstrasse, près du restaurant So
# nne, où les monteurs engrève s'étaient réunis l'après-midi. Deux grandes vitres d'un magasin de chau
# ssures furent tièrement brisées. La police procéda ensuite à l'évacuation systématique des diverses
# rues. On entendit des coups de feu jusqu'à 22 heures. A 22 h. 30 on signalait environ deux douzaines
# ... [truncated]
# ------------------
#
# --- Article 19 ---
# Title: L'ACTUALITÉ SUISSE
# Publicationdate: 1959-04-24
# Languagecode: fr
# Transcript Length: 969 characters
# Transcript:
# L'ACTUALITÉ SUISSE Meurtre à Zurich ZURICH, 24. — Un drame s'est produit jeudi après-midi, peu avant
#  14 heures, dans une entreprise de machines à écrire de la Schaffhauserstrasse, No 272, à Zurich.. L
# c directeur de la maison avait fait savoir à un ouvrier de 45 ans, M. Adolf Buechi, employé dans l'e
# ntreprise depuis septembre 1958, qu'il pourrait y rester jusqu'à ce qu'il ait trouvé une autre place
# . Jeudi après-midi, Buechi arriva dans la maison et tira un coup de feu sur un contremaître, M. Fran
# cesco Naegelin, âgé de 30 ans. Celuici fut atteint dans le dos et, la balle ayant sectionné, l'aorte
# , il fut tué sur le coup. Buechi se rendit alors dans une autre pièce où il menaça des ouvriers, qui
#  purent cependant s'enfuir. Le meurtrier tourna alors son arme contre lui-même cl se tira une balle
# dans la lêtc. Il est dans un état désespéré. Le contremaître tué laisse une femme et deux enfants. U
# n conflit de travail mineur semble être le motif de l'acte de Buechi.
# ------------------
#
# --- Article 20 ---
# Title: LES RÉSULTATS de la " propagande pacifiste pratique "
# Publicationdate: 1917-11-19
# Languagecode: fr
# Transcript Length: 3569 characters
# Transcript:
# e. La révolution maximalisle a eu en Suisse un contre-coup inattendu. Des « agitateurs pacifistes Y)
#  — si Olt peut employer cette expression bizarre — y ont VIL l'occasion de traduire leurs théories d
# ans les faits en contraignant par violence deux fa-briques de munitinns à fermer leurs por--tes. Ces
#  deux établissements travaillaient pour rAllemagne, mais il semble évident que leur sort eût été le
# même si elles avaient travaillé pour VEnt-enle. En réalité les manifestations étaient dirigées contr
# e la guerre en général et contre Vannée suisse en particulier. L'un des nieneurs de l'affaire. le co
# mpagnon Deltwyler, a prononcé les paroles suivantes qui sont %Out un programme: « Assez causé! Il ne
#  u suffit pas de sympathiser de loin avec les frères russes. Il faut agir. Maintenant, la révolution
#  doit être portée en fait dans notre pays, et avant tout au milieu de nos soldats qui doivent reluse
# r en masse le ser- Vice militaire. » La police a été impuissante à réprimer l'émeute soudainement dé
# chaînée et il a fallu appeler la troupe qui a fait usage de ses armes. Les premières dépêches semble
# nt révéler un certain affolement et en tout cas une tendance à l'exagération. Mais la situation n'en
#  est pas moins assez sérieuse. La neutralité suisse a l'a plus grande importance pour les Alliés, ma
# is il ne faut pàs oublier qu'inversement tous- les prétextes à sa violation seraient bons pour l'All
# emagne. Et si, celle-ci n'est pour rien 'dans ces troubles subits (encore. faudra-t-il voir), elle s
# ... [truncated]
# ------------------

# %% [markdown]
# ### Q2

# %%
reranked_articles_q2 = rerank_articles_by_other_embedding_model(result_articles_q2, question_q2, embedding_model=embedding_model_denoising)
# Out:
# Spearman correlation between original and reranked rankings: -0.0271
# Overlap in top 3 results: 0
# Overlap in top 5 results: 1
# Overlap in top 10 results: 6

# %%
format_and_display_articles(result_articles_q2)
# Out:
# --- Article 1 ---
# Title: isi Siiiss®
# Publicationdate: 1928-07-19
# Languagecode: fr
# Transcript Length: 2732 characters
# Transcript:
# _isi _Siiiss _® Ne gaspillons pas l'eau ! ZURICH, 19. — Le Service des eaux de la ville de Zurich vi
# ent de publier un avis concernant la consommation de l'eau, avis motivé par le -fait qu'en ces temps
#  de chaleur excessive, on a coutume de mettre le lait et d'autres aliments dans l'eau courante pour
# les rafraîchir, d'arroser les jardins par trop copieusement, bref, de gaspiller l'eau. Ces jours der
# niers, la consommation d'eau a dépassé 100, 000 m 3, ce qui représente une moyenne de 425 litres par
#  personne et par jour, tandis que jusqu'ici, la consommation la plus forte n'avait pas dépassé 83 mi
# lle m 3. Zurich possède, il est vrai, un réservoir inépuisable — en l'espèce son lac — mais il n'en
# reste pas moins que les installations de filtrage et de transport ont des capacités limitées. Samedi
#  dernier, la consommation a même atteint 103, 000 m 3, ce qui est manifestement exagéré et ne corres
# pond nullement aux besoins réels de la population. Aussi la direction du Service des eaux de Zurich
# déclare-t-elle que les gaspilleurs seront punis conformément au règlement. Les merveilles du télépho
# ne. — On cause de Genève à New-York... pour commander des montres ! GENEVE, 19. — La première conver
# sation téléphonique de l'Amérique avec Genève a eu lieu hier entre la maison d'importation d'horloge
# rie Wittnauer et Cie de New-York et sa succursale de Genève. Cette conversation a duré 6 minutes et
# a coûté 495 francs. Elle fut très claire et l'on se comprit d'un bout à l'autre du fil comme s'il n'
# ... [truncated]
# -----------------
#
# --- Article 2 ---
# Title: Vingt-six fontaines
# Publicationdate: 1962-08-04
# Languagecode: fr
# Transcript Length: 968 characters
# Transcript:
# Vingt-six fontaines Le Service de l'Eau nous a fourni d'intéressantes indications statistiques sur n
# os fontaines, à défaut de renseignements historiques. Par exemple, nous avons appris que l'on compta
# it 26 fontaines sur le territoire communal, desservies par le réseau public. Quelques autres fontain
# es font appel à des eaux de sources privées, telles la Bonne fontaine des Eplatures. L'ensemble de c
# es fontaines débite 200 litres / minute ; comme elles sont en service durant six mois environ, cela
# représente annuellement une quantité de 55, 000 mètres cubes d'eau. Il, faut relever encore que deux
#  grandes fontaines, la « Monu » et la fontaine du parc de la gare ( Chambre suisse de l'horlogerie),
#  fonctionnent en circuit continu ; leur eau n'est donc pas potable. Il ne s'agit que d'ouvrage décor
# atif. Trois fontaines, celles de la Place du Sentier, de la Place du Marché et du jardin de l'Ouest
# fournissent une eau destinée à l'alimentation, parfaitement potable.
# -----------------
#
# --- Article 3 ---
# Title: Les villes suisses consomment trop
# Publicationdate: 2014-03-27
# Languagecode: fr
# Transcript Length: 1094 characters
# Transcript:
# Les villes suisses consomment trop EAU Les villes suisses consomment en moyenne plus d’eau par habit
# ant que celles des pays péens, alors que les prix y sont parfois plus élevés. Selon un audit de l’Of
# fice fédéral de la statistique, Lugano se place au premier rang, avec 250 m 3 d’eau consommés par ha
# bitant en 2012, soit le double des autres villes étudiées : dix chefs-lieux suisses et dix péens, no
# rdiques principalement. La cité tessinoise est suivie par Genève, Bâle, Lausanne, Zurich, Bienne, Lu
# cerne, Berne, Saint-Gall et Winterthour. Ces dernières villes enregistrent une consommation d’eau an
# nuelle par habitant variant entre 85 et 135 mètres cubes. En onzième place figure la ville suédoise
# de Göteborg, talonnée par Helsinki, en Finlande, les tés allemandes Stuttgart et Munich et des ville
# s belges, comme Gand et Bruxelles. La consommation d’eau n’est pas liée aux prix. A Saint-Gall, où l
# es habitants consomment en moyenne 85 m 3 d’eau par an, les prix sont aussi élevés (2,4 francs par m
#  3) qu’à Munich, où la moyenne est de 60 mètres cubes. ATS A Lugano, on aime l’eau... KEYSTONE
# -----------------
#
# --- Article 4 ---
# Title: Les villes suisses consomment trop
# Publicationdate: 2014-03-27
# Languagecode: fr
# Transcript Length: 1096 characters
# Transcript:
# Les villes suisses consomment trop EAU Les villes suisses consomment en moyenne plus d’eau par habit
# ant que celles des pays péens, alors que les prix y sont parfois plus élevés. Selon un audit de l’Of
# fice fédéral de la statistique, Lugano se place au premier rang, avec 250 m 3 d’eau consommés par ha
# bitant en 2012, soit le double des autres villes étudiées : dix chefs-lieux suisses et dix péens, no
# rdiques principalement. La cité tessinoise est suivie par Genève, Bâle, Lausanne, Zurich, Bienne, Lu
# cerne, Berne, Saint-Gall et Winterthour. Ces dernières villes enregistrent une consommation d’eau an
# nuelle par habitant variant entre 85 et 135 mètres cubes. En onzième place figure la ville suédoise
# de Göteborg, talonnée par Helsinki, en Finlande, les tés allemandes Stuttgart et Munich et des ville
# s belges, comme Gand et Bruxelles. La consommation d’eau n’est pas liée aux prix. A Saint-Gall, où l
# es habitants consomment en moyenne 85 m 3 d’eau par an, les prix sont aussi élevés ( 2, 4 francs par
#  m 3) qu’à Munich, où la moyenne est de 60 mètres cubes. ATS A Lugano, on aime l’eau... KEYSTONE
# -----------------
#
# --- Article 5 ---
# Title: Une ville est née...
# Publicationdate: 1939-05-09
# Languagecode: fr
# Transcript Length: 3313 characters
# Transcript:
# Une ville est née... Sur l « s bords du lac de Zurich En l'espace de onze mois, une nouvelle cite es
# t née sur les bords du lac de Zurich. Les travaux de construction de l'Exposition nationale ont duré
#  un peu moins d'un an. Se doute-t-on de l'effort énorme qu'exige la mise au point d'une manifestatio
# n de cette envergure i Oar, a côté de tout ce qui se voit, — de tout ce qu on admire — il y a tout c
# e qui ne se voit pas, et qui représente un travail dont le profane ne se fait guère une idée.'_Quelq
# ues chiffres ue seront peut-être pas ete trop pour illustrer ce que nous venons de dire. L'Expositio
# n occupe, sur les deux rives du lac de Zurich, une superfice d'environ 300, 000 mètres carrés ; 125,
#  000 mètres carrés sont pés par des constructions, dont le volume atteint au total 700, 000 mètres c
# ubes. Pour édifier les nombreux pavillons de l'Exposition, les charpentiers ont utilisé 14, 000 mètr
# es cubes de bois l «'** de construction, et le volume du bois d oeuvre atteint 370, 000 mètres cubes
# . Voilà pour la su perstructure. Et le visiteur serait plus étonne encore s'il pouvait voir le résea
# u de canalisations qui s'étend sous ses pieds : conduites d'eau, conduites pour les eaux usées, cabl
# es électriques et câbles téléphoniques, canalisations pour le gaz, sillonnent le sous-sol de l'Expos
# ition. Les conduites d'eau — il s'agit uniquement des conduites souterraines — ont une longueur de 5
# 200 mètres, ce qui n'est pas exagéré si l'on songe que la consommation d'eau pendant la durée de l'E
# ... [truncated]
# -----------------
#
# --- Article 6 ---
# Title: Glous-slous dans la ville
# Publicationdate: 1989-07-24
# Languagecode: fr
# Transcript Length: 4715 characters
# Transcript:
# Glous-slous dans la ville Les fontaines ne coulent pas sans soucis A la claire fontaine, s'en allant
#  promener, les Chaux-de-Fonniers ont 56 sources auxquelles se rafraîchir. Leur ville, triste de ne p
# ouvoir se mirer dans les eaux d'un lac et frustrée de ne point se bercer au rythme d'une rivière, se
#  venge par ses multiples fontaines. Mais la sécheresse des dernières semaines et l'attention général
# e portée à la consommation d'eau met en pianissimo la chanson cristalline des robinets. Le service d
# e l'énergie se penche sérieusement sur ce débit et appelle le soleil à la rescousse. Dans cet invent
# aire de 56 points d'eau, les travaux publics comptabilisent tous les robinets et autres jets sur le
# domaine public ; du petit bassin de préau d'école à la Grande Fontaine en passant par les nombreuses
#  fontaines des cimetières, des parcs publics, du Bois du Petit-Château, etc. Autant d'histoires d'ea
# u s'écoulant d'une motivation des autorités. « L'eau est toujours intimement liée à la vie ; partout
#  où il y a des gens, il y a de l'eau » remarque le conseiller communal Alain Bringolf, responsable d
# es TP. Outre les fontaines inscrites dans la vie d'antan du bétail s'abreuvant et des lavandières Mi
# se en eau en juin, une ancienne fontaine agrémente la rue Fritz-Courvoisier, ajoutant son gazouillis
#  à un parc de bassins impressionnant. ( Photo Impar-Gerber) papotant, et celles placées pour l'utili
# té dans les cours d'école, parcs publics ou à proximité des piscines, d'autres bassins ont été insta
# ... [truncated]
# -----------------
#
# --- Article 7 ---
# Title: Tempêtes dans des piscines
# Publicationdate: 1983-07-18
# Languagecode: fr
# Transcript Length: 1670 characters
# Transcript:
# Tempêtes dans des piscines ZURICH Zurich (de notre correspondant).-Economies d'abord, mais pas au dé
# triment de la natation et donc de la santé publique : c'est sur ce thème qu'un groupe de Zurichois v
# ient de partir en guerre contre l'Office municipal de la santé publique, qui envisage de fermer prém
# aturément à fin août un certain nombre de bains publics et de piscines en plein air de Zurich, alors
#  qu'en principe le temps de la baignade dure jusqu'à mi-septembre. La mesure s'appliquerait à des ét
# ablissements de quartiers, comme la baignade de Letten, sur la Limmat, la piscine d'Allenmoos à Œrli
# kon ou la plage de Wollishofen. Tout d'abord, l'information avait tré un scepticisme étonné, une foi
# s confirmée ce fut la levée de boucliers. 2 & ". "..'..'1 .... Les opposants, qui ont lancé une péti
# tion, font valoir que cette mesure est antisociale. Elle frappe tout d'abord le personnel, saisonnie
# r, des baignades « condamnées », mais porte préjudice à l'organisation des loisirs de nombreuses fam
# illes. En outre, les migrations, obligatoires, vers d'autres piscines encore ouvertes accroîtraient
# les frais en même temps que cela créerait à coup sûr des engorgements au bord des plans d'eau « tolé
# rés ». Les milieux politiques se sont aussi émus, et une interpellation émanant de l'Alliance des in
# dépendants exige des explications de la part des autorités. Celles-ci ont jusqu'au 15 août pour pren
# dre une décision définitive, en raison des délais de licenciement du personnel temporaire. Le chef d
# ... [truncated]
# -----------------
#
# --- Article 8 ---
# Title: Les cinémas à Zurich
# Publicationdate: 1927-03-09
# Languagecode: fr
# Transcript Length: 3722 characters
# Transcript:
# Les cinémas à Zurich CDe notre eorr. de Zurich) Il n'y a pas à dire : la ville de Zurich est en trai
# n de battre tous les records en matière d'industrie cinématographique, par quoi veuille. entendre, j
# e vous prie, le nombre d'établissements cinématographiques sollicitant la faveur du public. Une noti
# ce, parue dernièrement, n'a pas manqué de faire quelque sensation, puisqu'elle annonçait l'ouverture
#  prochaine de pas moins de six théâtres nouveaux, à côté de ceux que nous possédons déjà. A ce propo
# s, il n'est peut-être pas sans intérêt de s'arrêter à quelques chiffres _. D'après le dernier recens
# ement, la population de la ville de Zurich s'élève à 214.000 âmes ; or, pour oette population, il y
# a actuellement 14 cinématographes en exploitation, ce qui est largement suffisant. Les 20 établissem
# ents que nous" risquons de posséder prochainement contiennent environ 15.000 places, ce qui est un c
# hiffre coquet ; si l'on veut qu'elles soient occupées tous les soirs, le flot des spectateurs devra
# prendre des proportions inaccoutumées. Mais ce n'est pas tout, car nous avons à côté de cela de nomb
# reux établissements de distraction qui veulent vivre aussi. C'est tout d'abord le grand théâtre, ave
# o ses 1400 places, puis le théâtre du Pfauen, qui en compte 900 ; ensuite, il y a deux cabarets, qui
#  jouent chaque jour, et qui peuvent accueillir 550 spectateurs ; cela fait déjà des occasions de dis
# traction pour 2850 personnes. Avec les cinémas, au nombre de 20, nous arrivons ainsi à 24 théâtres,
# ... [truncated]
# -----------------
#
# --- Article 9 ---
# Title: Zürich im Schutze der Deiche «Sie sind a...
# Publicationdate: 1965-02-11
# Languagecode: de
# Transcript Length: 3118 characters
# Transcript:
# Zürich im Schutze der Deiche « Sie sind auf der Suche nach Ortschaften mit dem Namen Zürich gerade a
# n den rechten Mann gekommen, denn auch ich habe mich schon für die anderen Städte der Weltkarte, die
#  den Namen Zürich tragen, interessiert. Nicht nur habe ich des öfteren herzlichen Kontakt mit Schwei
# zer Zürchern die durch unser Darf kommen, sei es durch Zufall, oder weil sie dem Namensvetter ihrer
# Heimatstadt einen Besuch abstatten wollen. loh habe vielmehr auch selber schon einige der anderen Zü
# richs besucht. So besuchte ich im Jahre 1960 mit meiner Familie das Schweizer Zürich, wobei die Stad
# tverwaltung uns auf sehr herzliche Weise begrüsste. Unser Zürich gehört mit 26 anderen Dörfern zur G
# emeinde Wonseradeel und hat daher kein eigenes Postamt und somit auch keinen Poststempel. Die Post w
# ird vielmehr von der benachbarten Stadt Hariingen aus besangt. Leben unter der Drohung des Meeres Wo
# hl aber hat Zürich eine eigene Fahne, die ich Ihnen aufgezeichnet habe. Das brennende Rot spricht vo
# n der Gefahr die droht, wenn der brüllende Sturm das Meerwasser über die Deiche jagt. Der diagonal v
# erlaufende goldene Streifen aber bedeutet den Schutz durch den Deich — der auoh « goldenes Band » ge
# nannt wird — durch den die Bevölkerung Schutz erhält ». den Stadtpräsidenten von Yver- j don, Andre
# Martin: In verschiedenen Gebieten der Schweiz hat die Austrocknung von Quellen und die Verschmutzung
#  von Gewässern einen chronischen Wassermangel hervorgerufen. In einigen Gemeinden in der Umgebung vo
# ... [truncated]
# -----------------
#
# --- Article 10 ---
# Title: SUSSE « Celte ville est le paradis des célibataires»
# Publicationdate: 1958-07-29
# Languagecode: fr
# Transcript Length: 2435 characters
# Transcript:
# SUSSE « Celte ville est le paradis des célibataires » Jamais la saison touristique n'a paru si animé
# e à Zurich. La SAFFA y est sans doute pour quelque chose et, grâce à cette exposition, les heures d'
# ouverture des lieux de divertissement ont été prolongées au-delà de minuit. Il est intéressant de no
# ter que les statistiques concernant les étrangers de passage donnent maintenant à Zurich là cinquièm
# e place en Europe pour le nombre des nuits d'hôtels — après Londres, Rome, Paris et Milan. Pour une
# ville qui n'a connu l'an dernier que trente-trois jours de vrai beau temps, l'arrivée de 732,231 tou
# ristes étrangers semble un paradoxe. H est vrai que le tourisme moderne attire de plus en plus de mo
# nde vers les grandes villes. Et à cet égard, Zurich offre beaucoup : plus de 1000 restaurants, repré
# sentant les cuisines les plus diverses du globe, une quarantaine de cinémas (dont le dernier vient d
# 'être ouvert à l'intérieur de la gare centrale), une trentaine de musées, galeries d'art, etc. Dans
# le dernier numéro de la Weltwoche, un article sur le développement touristique de Zurich donne d'int
# éressantes indications sur l'intérêt des Américains pour la plus grande ville de Suisse. Relevons de
# ux citations particulièrement saillantes. « Zurich est 'a seule ville d'Europe où je pourrais vivre
# », à déclaré l'écrivain Thornton Wilder. « Zurich est un paradis pour les célibataires », a écrit la
#  célèbre revue Esquire qui précisait : « Cette vilie compte entre 15,000 et 25,000 prostituées, qui
# ... [truncated]
# ------------------
#
# --- Article 11 ---
# Title: CRITIQUE ET ESSAIS Un exemple à suivre A Zurich, Services industriels [...]
# Publicationdate: 1980-07-12
# Languagecode: fr
# Transcript Length: 2754 characters
# Transcript:
# Un exemple à suivre A Zurich, Services industriels et Bureau d'archéologie travaillent de conserve L
# es canalisations du centre historique de Zurich, sur les deux rives de la Limmat, étaient plus que c
# entenaires ; une votation populaire a approuvé, en 1975, leur remplacement intégral. On aurait pu se
#  borner à défoncer les rues pour y placer de nouvelles conduites, mais on en profita pour examiner s
# cientifiquement le sous-sol urbain : l'ensemble des travaux fut planifié avec le Bureau d'archéologi
# e de la ville, ce qui permit d'explorer la totalité des voies et places faisant l'objet de l'opérati
# on et, accessoirement, de refaire tous les pavements en supprimant les trottoirs. Aujourd'hui, la pr
# emière phase est achevée, qui couvre un tiers du projet. Ses résultats sont si intéressants qu'on le
# s a exposés au public (et au contribuable), sous le titre Kanalisationssanierung und Archâologie (Ha
# us Zum Rech, Neumarkt 4, jusqu'au 23 août). On savait que Zurich constituait au Bas-Empire un point
# d'appui sur la rive occidentale de la Limmat, avec le fort de Turicum, à l'emplacement du Lindenhof.
#  Puis la bourgade réapparaissait en quelque sorte au IXe siècle après une longue éclipse documentair
# e. Les fouilles ont permis de compléter largement la connaissance de la Zurich romaine : la tête du
# pont sur la rive gauche, la position de la rive droite à la Niederdorfstrasse, diverses fondations a
# ntiques difficiles à interpréter, tels sont quelques-uns des résultats de cette première campagne. D
# ... [truncated]
# ------------------
#
# --- Article 12 ---
# Title: CONGRÈS À ZURICH La Suisse, château d'eau de l'Europe
# Publicationdate: 1982-09-07
# Languagecode: fr
# Transcript Length: 1809 characters
# Transcript:
# CONGRÈS À ZURICH La Suisse, château d'eau de l'Europe Zurich, 6 (ATS).-Le 14 e congrès mondial de l'
# Association des distributions d'eau (AIDE) s'est ouvert lundi à Zurich. Jusqu'au 10 septembre, plus
# de deux mille délégués de toutes les régions du monde débattront de problèmes liés au thème général
# « sans eau pas de vie ». Lors de leurs allocutions d'ouverture, le conseiller fédéral Hans Hiirliman
# n et le président de la ville de Zurich Thomas Wagner ont relevé que la Suisse peut être considérée
# comme le château d'eau de l'Europe. Les problèmes qui se posent chez nous ne touchent pas à la quant
# ité mais à la qualité. Selon M. Hùrlimann, l'exiguïté de notre pays, sa forte densité démographique
# et ses intenses activités économiques sont également sources de problèmes. Une statistique de la Soc
# iété suisse de l'industrie du gaz et des eaux montre que près de 580 millions de mètres cubes d'eau
# potable ont été distribués dans notre pays en 1981. Cela représente une consommation quotidienne de
# 248 litres par habitant. L'eau, a encore indiqué M. Hùrlimann, est la seule ressource naturelle que
# la Suisse ne doit pas importer. Mais, parallèlement à l'augmentation de la population, de la product
# ion et de la consommation, la pollution est devenue de plus en plus préoccupante. Pour faire face à
# cette situation, d'énormes efforts financiers ont été consentis. M. Hùrlimann a rappelé que plus de
# 20 milliards de francs ont été investis en Suisse pour résoudre le problème de la pollution. Cela éq
# ... [truncated]
# ------------------
#
# --- Article 13 ---
# Title: DERNIER RÊVE MUNICIPAL
# Publicationdate: 1941-05-23
# Languagecode: fr
# Transcript Length: 4052 characters
# Transcript:
# DERNIER RÊVE MUNICIPAL LETTRE DE ZURICH (De notre correspondant particulier) Il y a quelque trente à
#  trente-cinq ans, nous prenions chaque semaine le chemin du Tunnel à Lausanne pour aller nous baigne
# r en troupe, dans une sorte de buanderie, qui tenait alors lieu de piscine. Un bâtiment au teint jau
# nâtre coiffé d'une casquette grise. A travers un brouillard de vapeur, les petits grimauds de collèg
# e s'ébattaient bruyamment sous le regard de leur maître de gymnastique. Tout cela était primitif et
# touchant. Il n'en va pas de même sur les bords de la Sihl, au coeur du Grand-Zurich. Dans leur désir
#  de faire bien les choses, les autorités municipales apportent autant de soin que de temps à réalise
# r leurs grands projets. Cela peut durer vingt à trente ans et coûter quelques millions. Peu importe
# ! Aujourd'hui Zurich ne possède pas seulement son jardin zoologique et son Palais des congrès. Elle
# vient d'inaugurer une piscine communale, dont les premiers plans remontent avant la dernière guerre
# mondiale. C'est là peut-être ce qu'il y a de mieux aujourd'hui dans notre pays. Extérieurement, l'as
# pect d'une belle et vaste centrale électrique. D'immenses baies vitrées qui donnent sur les arbres d
# e la Kleine Schanze. Lorsque l'on nage dans l'eau bleutée, on croirait se baigner au milieu d'un par
# c. Le comble de l'organisation, de l'hygiène et de l'agrément. Cabines, douches d'eau tiède et d'air
#  chaud. Un univers chatoyant, animé et lumineux. Tout ici est bleu et blanc, jusqu'aux hortensias et
# ... [truncated]
# ------------------
#
# --- Article 14 ---
# Title: Des fontaines dont on parle et dont on parlera
# Publicationdate: 1945-07-26
# Languagecode: fr
# Transcript Length: 956 characters
# Transcript:
# Des fontaines dont on parle et dont on parlera De tous les endroits de Suisse où les fontaines sont
# en honneur — et Dieu sait s'il en existe — il en est peu qui soient plus attirants que le Landeron,
# ce bourg gracieux, pittoresque et cossu dont le canton de Neuchâtel s'_enorgueillit si justement. Le
# s fontaines du Landeron sont en effet parmi les plus anciennes et les plus belles qui se puissent vo
# ir. Sculptées et enihiminêes, bénéficiant de la part de la population de soins attentifs et touchant
# s, elles mettent dans ce paysage de vignoble, de forêts et de lac proche le sceau d'un passé somptue
# ux et fier. A toutes ces fontaines s'en ajoutera bientôt une qui, bien que symbolique, sera bientôt
# célèbre puisque d'elle couleront te. oie et l'aisance. La loterie romande installera prochainement a
# u Landeron, en effet, sa source de chance puisque c'est là que se déroulera le prochain tirage. Hâte
# z-vous si vous voulez profiter de son débit bienfaisant.
# ------------------
#
# --- Article 15 ---
# Title: • • 111111
# Publicationdate: 2007-04-13
# Languagecode: fr
# Transcript Length: 1445 characters
# Transcript:
# • • 111111 ret. 4. Il y a les piscines qui restent dans le domaine du confort, de la détente avec de
# s variations SPA, sauna, coin détente, massage, etc. 5 II y a, enfin, les thermes dont l'eau possède
#  des qualités curatives particulières. Parmi ceux-ci, il y a les thermes reconnus tant par les or ga
# nismes officiels que par les assurances, l'aspect thérapeutique domine. Et puis il y des centres the
# rmaux qui regroupent les qualités des cinq catégories énoncées ci-dessus. D'Yverdon-les-Bains à Brig
# erbad Parmi les lieux balnéaires qui ont une reconnaissance et surtout une histoire citons Loèche-le
# s-Bains, les- Bains, Lavey-les Bains. La première est toujours une des plus prestigieuses, elle l'ét
# ait déjà au 18 ième siècle et l'on venait de France et d'Allemagne pour s'y baigner. Brigerbad a aus
# si une histoire tandis que Saillon, même si les Romains y avaient installé des thermes et les joueur
# s du Casino de Saxon, au 19 siècle y faisaient trempette, est une création plus récente. Tout comme
# Ovronnaz ou Val-d'llliez et la plus récente : les Bains de la Gruyère à Charmey. Des projets sont en
#  cours à Crans-Montana, Griment et àThyon-les Collons. Et puis existe-t-il déjà en plus des centres
# d'eaux existants et les projets d'autres concepts dans les tiroirs ? Quoi qu'il en soit on recense d
# onc pas moins de 11 centres d'eau en Suisse romande, dont 7 en Valais, existants et en projets, c'es
# t dire l'accroissement de ce type de concept.
# ------------------
#
# --- Article 16 ---
# Title: Jeux de société...
# Publicationdate: 1928-01-23
# Languagecode: fr
# Transcript Length: 2714 characters
# Transcript:
# Jeux de société... CDe notro corresp. de Zurich.) Connaissez-vous le proverbe qui dit que là où deux
#  Suisses se rencontrent, ils fondent une société ? L'en a dit parfois que c'étaient de mauvaises lan
# gues qui avaient répandu ce bruit, lequel, cependant, ne me paraît pas être tout à fait une légende,
#  à en juger par le nombre de sociétés de toutes sortes dont nous sommes gratifiés. Oyez plutôt, en c
# e qui concerne la ville de Zurich. D'après une statistique qui vient d'être dressée, l'Athènes des b
# ords de la Limmat comptait dernièrement, pour une population de 220,000 âmes environ, 1150 sociétés
# et groupements divers, et dans ce chiftre ne sont pas même comprises les associations de jeunes gens
#  des deux sexes, les sous-sections, etc ., parce que celles-ci sont considérées comme se rattachant
# à d'autres sociétés ; sinon l'en arriverait à un chiffre passablement plus élevé. L'on compte : 185
# associations professionnelles, 11 sociétés dramatiques, 206 sociétés d'utilité publique, 115 société
# s de chant, 59 sociétés de divertissement, 82 caisses maladie ou de secours, 37 sociétés scientifiqu
# es, 19 sociétés militaires, 40 sociétés de musique, 47 groupements politiques, 15 sociétés de quarti
# er, 47 sociétés religieuses, 3 clubs d'échecs, 61 sociétés de tir, 67 sociétés de « port, 3 associat
# ions de sténographie, 15 sociétés universitaires, 43 sociétés de gymnastique, S sociétés patriotique
# s, 22 corporations, etc. A ees chiffres, il convient encore d'ajouter 28 sociétés de bibliothèque, p
# ... [truncated]
# ------------------
#
# --- Article 17 ---
# Title: engpasse
# Publicationdate: 1976-07-07
# Languagecode: de
# Transcript Length: 967 characters
# Transcript:
# engpasse bps. Die Wasserversorgung in einigen Zürcher Quartieren ist durch den schlagartig gestiegen
# en Verbrauch an der Grenze ihrer Leistungsfähigkeit angelangt. Wie die Abteilung Wasserversorgung de
# r Industriellen Betriebe der Stadt ZUrich mitteilte, betrifft dies in erster Linie die peripher gele
# genen Versorgungsgebicte Seebach, Höngg, Waidberg, Friesenberg, Leimbach und Witikon. Wohl gehört zu
# rzeit die Wasserversorgung der Stadt Zürich zu den modernsten und leistungsfähigsten ihrer Art in Eu
# ropa. Doch die endgültige Sicherstellung der Wasserlieferungen für das gesamte Stadtgebiet wird erst
#  ab etwa 1982 bewerkstelligt sein, da sich momentan verschiedene in der Gemeindeabstimmung vom 4. Mä
# rz 1973 bewilligte Projekte noch im Stadium der Realisierung befinden. So steht beispielsweise das G
# rundwasserwerk Hardhof im Neubau. Darüberhinaus werden verschiedene Verteilanlagen wie Pumpwerke, Re
# servoire und Transportleitungen gegenwärtig erneuert. Schluss S. 14
# ------------------
#
# --- Article 18 ---
# Title: Les bains publies en Suisse
# Publicationdate: 1931-08-07
# Languagecode: fr
# Transcript Length: 2053 characters
# Transcript:
# Les bains publies en Suisse Le service de publictié des C. F. F. a organisé dans tout le pays une en
# quête sur les établissements de bain. Au total 111 villes et stations touristiques disposent de bain
# s de rivière, de plages ou de piscines, ce nombre s'est même accru depuis la fin de l'enquête. 24 de
#  ces établissements se trouvent dans la Suisse orientale entre Zurich et le lac de Constance, 19 dan
# s la Suisse centrale, 18 dans l'Oberland bernois (Berne y compris), 17 dans les Grisons, 15 dans la
# Suisse septentrionale et occidentale, 8 le long du lac Léman, etc. Il existe 19 piscines artificiell
# es, dont 6 chauffablee ; 70 autres établissements sont situés au bord des lacs, et le reste sur les
# cours d'eau. L'installation de ces bains est des plus variés ; il en est de luxueuses, de raffinées,
#  comme aussi de très simples. 6880 cabines individuelles ont été annoncées ; Bâle vient en tête avec
#  487, et Lucerne suit avec 404. Il existe en outre des cabines communes ainsi que divercabines commu
# nes ainsi que diverses installations servant de vestiaires. Il va sans dire qu'il est partout possib
# le de prendre des bains de soleil, aujourd hui si en vogue ; cependant 78 établissements disposent d
# 'emplacements spéciaux. 70 établissements ont des terrains de gymnastique ou de jeu, 92 des pelouses
# . La gymnastique enseignée dans 29 bains permet aux personnes corpulentes de perdre quelque peu de l
# eur embonpoint. 82 bains offrent les délices de la douche. 75 disposent d'engins destinés aux jeux n
# ... [truncated]
# ------------------
#
# --- Article 19 ---
# Title: LE PASSE GLORIEUX ET LOINTAIN DE LA VILLE DE ZURICH
# Publicationdate: 1935-12-20
# Languagecode: fr
# Transcript Length: 5790 characters
# Transcript:
# LE PASSE GLORIEUX ET LOINTAIN DE LA VILLE DE ZURICH Promenade dans les pays suisses (De notre corres
# pondant particulier) Il m'est agréable de saisir l'occasion qui m'est offerte de rédiger un article
# sur la ville de Zurich. Je le fais avec d'autant plus de plaisir qu'établi à Zurich depuis plus de q
# uinze ans, j'ai eu l'occasion fort souvent d'apprécier l'entregent et l'esprit de bienveillance de s
# es habitants. Loin de son coin de pays, le welsche se sent toujours un peu un « déraciné » ; c'est d
# onc pour lui un grand bienfait que de se trouver au milieu d'une population cordiale, dont les quali
# tés d'assiduité et de sérieux sont bien connues. Il y aurait évidemment beaucoup à dire sur le sujet
#  faisant l'objet de la présente chronique ; je me bornerai cependant à n'insister que sur quelques f
# aits permettant de situer dans son véritable milieu l'Athènes des bords de la Limmat qui, depuis que
# lques dizaines d'années, a pris un prodigieux essor. ? * * Déjà à l'époque préhistorique, les rives
# du lac de Zurich — 40 km. de long — étaient habitées. C'est ainsi qu'en 1854 l'on a découvert à Meil
# en des restes d'habitations lacustres ; sauf erreur, cette découverte a été la première du genre. Da
# ns la suite, l'on a fait une ample récolte d'objets préhistoriques dans la région du lac inférieur,
# là même où s'élève aujourd'hui la fière et popu-JLa cathédrale de Zurich d'après une ancienne gravur
# e. Ieuse ville de Zurich. Le musée national possède du reste une incomparable collection d'objets de
# ... [truncated]
# ------------------
#
# --- Article 20 ---
# Title: Le canton de Zurich compte 3200 débits d...
# Publicationdate: 1914-02-07
# Languagecode: fr
# Transcript Length: 1536 characters
# Transcript:
# Le canton de Zurich compte 3200 débits de boissons et 1800 magasins de vente à l'emporter de boisson
# s alcooliques, dont 1000 pour la seule ville de Zurich. Aussi ne faut-il pas s'étonner d'y voir mont
# er la marée de l'alcoolisme. Le Conseil d'Etat entend l'endiguer par une loi dont voici les disposit
# ions les plus importantes. Le nombre des débits de boissons ne pourra pas dépasser une proportion d'
# un débit pour une sphère de population de 200 âmes. Les patentes ne seront pas accordées aux établis
# sements mais aux personnes. Elles pourront définitivement être retirées aux tenanciers qui se seront
#  fait citer deux fois pour violation des règlements de police. Les communes auront le droit de fixer
#  des heures de fermeture des débits plus restrictives aue le maximum autorisé. Les débits ne pourron
# t être ouverts le dimanche et les jours fériés avant 11 heures du matin. Tout employé d'un établisse
# ment aura droit à un temps de sommeil d'au moins 8 heures, et de plus à un repos inintei-rompu de 6
# heures de temps, dont 3 pendant la journée. Toutes les trois semaines, les ployés auront droit à 1 j
# our de repos de 24 heures, qui, tous les deux mois au moins, devra tomber sur un dimanche. Il sera i
# nterdit aux garçons et aux sommelières de boire avec les consommateurs. Les magasins de vente au dét
# ail de boissons alcooliques ne pourront vendre le dimanche, et la semaine ils ne pourront débiter ap
# rès 8 heures du soir. Ce projet de loi contribuera, s'il est adopté, à une notable amélioration des
# ... [truncated]
# ------------------

# %%
format_and_display_articles(reranked_articles_q2)
# Out:
# --- Article 1 ---
# Title: CONGRÈS À ZURICH La Suisse, château d'eau de l'Europe
# Publicationdate: 1982-09-07
# Languagecode: fr
# Transcript Length: 1809 characters
# Transcript:
# CONGRÈS À ZURICH La Suisse, château d'eau de l'Europe Zurich, 6 (ATS).-Le 14 e congrès mondial de l'
# Association des distributions d'eau (AIDE) s'est ouvert lundi à Zurich. Jusqu'au 10 septembre, plus
# de deux mille délégués de toutes les régions du monde débattront de problèmes liés au thème général
# « sans eau pas de vie ». Lors de leurs allocutions d'ouverture, le conseiller fédéral Hans Hiirliman
# n et le président de la ville de Zurich Thomas Wagner ont relevé que la Suisse peut être considérée
# comme le château d'eau de l'Europe. Les problèmes qui se posent chez nous ne touchent pas à la quant
# ité mais à la qualité. Selon M. Hùrlimann, l'exiguïté de notre pays, sa forte densité démographique
# et ses intenses activités économiques sont également sources de problèmes. Une statistique de la Soc
# iété suisse de l'industrie du gaz et des eaux montre que près de 580 millions de mètres cubes d'eau
# potable ont été distribués dans notre pays en 1981. Cela représente une consommation quotidienne de
# 248 litres par habitant. L'eau, a encore indiqué M. Hùrlimann, est la seule ressource naturelle que
# la Suisse ne doit pas importer. Mais, parallèlement à l'augmentation de la population, de la product
# ion et de la consommation, la pollution est devenue de plus en plus préoccupante. Pour faire face à
# cette situation, d'énormes efforts financiers ont été consentis. M. Hùrlimann a rappelé que plus de
# 20 milliards de francs ont été investis en Suisse pour résoudre le problème de la pollution. Cela éq
# ... [truncated]
# -----------------
#
# --- Article 2 ---
# Title: Le canton de Zurich compte 3200 débits d...
# Publicationdate: 1914-02-07
# Languagecode: fr
# Transcript Length: 1536 characters
# Transcript:
# Le canton de Zurich compte 3200 débits de boissons et 1800 magasins de vente à l'emporter de boisson
# s alcooliques, dont 1000 pour la seule ville de Zurich. Aussi ne faut-il pas s'étonner d'y voir mont
# er la marée de l'alcoolisme. Le Conseil d'Etat entend l'endiguer par une loi dont voici les disposit
# ions les plus importantes. Le nombre des débits de boissons ne pourra pas dépasser une proportion d'
# un débit pour une sphère de population de 200 âmes. Les patentes ne seront pas accordées aux établis
# sements mais aux personnes. Elles pourront définitivement être retirées aux tenanciers qui se seront
#  fait citer deux fois pour violation des règlements de police. Les communes auront le droit de fixer
#  des heures de fermeture des débits plus restrictives aue le maximum autorisé. Les débits ne pourron
# t être ouverts le dimanche et les jours fériés avant 11 heures du matin. Tout employé d'un établisse
# ment aura droit à un temps de sommeil d'au moins 8 heures, et de plus à un repos inintei-rompu de 6
# heures de temps, dont 3 pendant la journée. Toutes les trois semaines, les ployés auront droit à 1 j
# our de repos de 24 heures, qui, tous les deux mois au moins, devra tomber sur un dimanche. Il sera i
# nterdit aux garçons et aux sommelières de boire avec les consommateurs. Les magasins de vente au dét
# ail de boissons alcooliques ne pourront vendre le dimanche, et la semaine ils ne pourront débiter ap
# rès 8 heures du soir. Ce projet de loi contribuera, s'il est adopté, à une notable amélioration des
# ... [truncated]
# -----------------
#
# --- Article 3 ---
# Title: engpasse
# Publicationdate: 1976-07-07
# Languagecode: de
# Transcript Length: 967 characters
# Transcript:
# engpasse bps. Die Wasserversorgung in einigen Zürcher Quartieren ist durch den schlagartig gestiegen
# en Verbrauch an der Grenze ihrer Leistungsfähigkeit angelangt. Wie die Abteilung Wasserversorgung de
# r Industriellen Betriebe der Stadt ZUrich mitteilte, betrifft dies in erster Linie die peripher gele
# genen Versorgungsgebicte Seebach, Höngg, Waidberg, Friesenberg, Leimbach und Witikon. Wohl gehört zu
# rzeit die Wasserversorgung der Stadt Zürich zu den modernsten und leistungsfähigsten ihrer Art in Eu
# ropa. Doch die endgültige Sicherstellung der Wasserlieferungen für das gesamte Stadtgebiet wird erst
#  ab etwa 1982 bewerkstelligt sein, da sich momentan verschiedene in der Gemeindeabstimmung vom 4. Mä
# rz 1973 bewilligte Projekte noch im Stadium der Realisierung befinden. So steht beispielsweise das G
# rundwasserwerk Hardhof im Neubau. Darüberhinaus werden verschiedene Verteilanlagen wie Pumpwerke, Re
# servoire und Transportleitungen gegenwärtig erneuert. Schluss S. 14
# -----------------
#
# --- Article 4 ---
# Title: Les bains publies en Suisse
# Publicationdate: 1931-08-07
# Languagecode: fr
# Transcript Length: 2053 characters
# Transcript:
# Les bains publies en Suisse Le service de publictié des C. F. F. a organisé dans tout le pays une en
# quête sur les établissements de bain. Au total 111 villes et stations touristiques disposent de bain
# s de rivière, de plages ou de piscines, ce nombre s'est même accru depuis la fin de l'enquête. 24 de
#  ces établissements se trouvent dans la Suisse orientale entre Zurich et le lac de Constance, 19 dan
# s la Suisse centrale, 18 dans l'Oberland bernois (Berne y compris), 17 dans les Grisons, 15 dans la
# Suisse septentrionale et occidentale, 8 le long du lac Léman, etc. Il existe 19 piscines artificiell
# es, dont 6 chauffablee ; 70 autres établissements sont situés au bord des lacs, et le reste sur les
# cours d'eau. L'installation de ces bains est des plus variés ; il en est de luxueuses, de raffinées,
#  comme aussi de très simples. 6880 cabines individuelles ont été annoncées ; Bâle vient en tête avec
#  487, et Lucerne suit avec 404. Il existe en outre des cabines communes ainsi que divercabines commu
# nes ainsi que diverses installations servant de vestiaires. Il va sans dire qu'il est partout possib
# le de prendre des bains de soleil, aujourd hui si en vogue ; cependant 78 établissements disposent d
# 'emplacements spéciaux. 70 établissements ont des terrains de gymnastique ou de jeu, 92 des pelouses
# . La gymnastique enseignée dans 29 bains permet aux personnes corpulentes de perdre quelque peu de l
# eur embonpoint. 82 bains offrent les délices de la douche. 75 disposent d'engins destinés aux jeux n
# ... [truncated]
# -----------------
#
# --- Article 5 ---
# Title: Les villes suisses consomment trop
# Publicationdate: 2014-03-27
# Languagecode: fr
# Transcript Length: 1094 characters
# Transcript:
# Les villes suisses consomment trop EAU Les villes suisses consomment en moyenne plus d’eau par habit
# ant que celles des pays péens, alors que les prix y sont parfois plus élevés. Selon un audit de l’Of
# fice fédéral de la statistique, Lugano se place au premier rang, avec 250 m 3 d’eau consommés par ha
# bitant en 2012, soit le double des autres villes étudiées : dix chefs-lieux suisses et dix péens, no
# rdiques principalement. La cité tessinoise est suivie par Genève, Bâle, Lausanne, Zurich, Bienne, Lu
# cerne, Berne, Saint-Gall et Winterthour. Ces dernières villes enregistrent une consommation d’eau an
# nuelle par habitant variant entre 85 et 135 mètres cubes. En onzième place figure la ville suédoise
# de Göteborg, talonnée par Helsinki, en Finlande, les tés allemandes Stuttgart et Munich et des ville
# s belges, comme Gand et Bruxelles. La consommation d’eau n’est pas liée aux prix. A Saint-Gall, où l
# es habitants consomment en moyenne 85 m 3 d’eau par an, les prix sont aussi élevés (2,4 francs par m
#  3) qu’à Munich, où la moyenne est de 60 mètres cubes. ATS A Lugano, on aime l’eau... KEYSTONE
# -----------------
#
# --- Article 6 ---
# Title: Les villes suisses consomment trop
# Publicationdate: 2014-03-27
# Languagecode: fr
# Transcript Length: 1096 characters
# Transcript:
# Les villes suisses consomment trop EAU Les villes suisses consomment en moyenne plus d’eau par habit
# ant que celles des pays péens, alors que les prix y sont parfois plus élevés. Selon un audit de l’Of
# fice fédéral de la statistique, Lugano se place au premier rang, avec 250 m 3 d’eau consommés par ha
# bitant en 2012, soit le double des autres villes étudiées : dix chefs-lieux suisses et dix péens, no
# rdiques principalement. La cité tessinoise est suivie par Genève, Bâle, Lausanne, Zurich, Bienne, Lu
# cerne, Berne, Saint-Gall et Winterthour. Ces dernières villes enregistrent une consommation d’eau an
# nuelle par habitant variant entre 85 et 135 mètres cubes. En onzième place figure la ville suédoise
# de Göteborg, talonnée par Helsinki, en Finlande, les tés allemandes Stuttgart et Munich et des ville
# s belges, comme Gand et Bruxelles. La consommation d’eau n’est pas liée aux prix. A Saint-Gall, où l
# es habitants consomment en moyenne 85 m 3 d’eau par an, les prix sont aussi élevés ( 2, 4 francs par
#  m 3) qu’à Munich, où la moyenne est de 60 mètres cubes. ATS A Lugano, on aime l’eau... KEYSTONE
# -----------------
#
# --- Article 7 ---
# Title: Les cinémas à Zurich
# Publicationdate: 1927-03-09
# Languagecode: fr
# Transcript Length: 3722 characters
# Transcript:
# Les cinémas à Zurich CDe notre eorr. de Zurich) Il n'y a pas à dire : la ville de Zurich est en trai
# n de battre tous les records en matière d'industrie cinématographique, par quoi veuille. entendre, j
# e vous prie, le nombre d'établissements cinématographiques sollicitant la faveur du public. Une noti
# ce, parue dernièrement, n'a pas manqué de faire quelque sensation, puisqu'elle annonçait l'ouverture
#  prochaine de pas moins de six théâtres nouveaux, à côté de ceux que nous possédons déjà. A ce propo
# s, il n'est peut-être pas sans intérêt de s'arrêter à quelques chiffres _. D'après le dernier recens
# ement, la population de la ville de Zurich s'élève à 214.000 âmes ; or, pour oette population, il y
# a actuellement 14 cinématographes en exploitation, ce qui est largement suffisant. Les 20 établissem
# ents que nous" risquons de posséder prochainement contiennent environ 15.000 places, ce qui est un c
# hiffre coquet ; si l'on veut qu'elles soient occupées tous les soirs, le flot des spectateurs devra
# prendre des proportions inaccoutumées. Mais ce n'est pas tout, car nous avons à côté de cela de nomb
# reux établissements de distraction qui veulent vivre aussi. C'est tout d'abord le grand théâtre, ave
# o ses 1400 places, puis le théâtre du Pfauen, qui en compte 900 ; ensuite, il y a deux cabarets, qui
#  jouent chaque jour, et qui peuvent accueillir 550 spectateurs ; cela fait déjà des occasions de dis
# traction pour 2850 personnes. Avec les cinémas, au nombre de 20, nous arrivons ainsi à 24 théâtres,
# ... [truncated]
# -----------------
#
# --- Article 8 ---
# Title: SUSSE « Celte ville est le paradis des célibataires»
# Publicationdate: 1958-07-29
# Languagecode: fr
# Transcript Length: 2435 characters
# Transcript:
# SUSSE « Celte ville est le paradis des célibataires » Jamais la saison touristique n'a paru si animé
# e à Zurich. La SAFFA y est sans doute pour quelque chose et, grâce à cette exposition, les heures d'
# ouverture des lieux de divertissement ont été prolongées au-delà de minuit. Il est intéressant de no
# ter que les statistiques concernant les étrangers de passage donnent maintenant à Zurich là cinquièm
# e place en Europe pour le nombre des nuits d'hôtels — après Londres, Rome, Paris et Milan. Pour une
# ville qui n'a connu l'an dernier que trente-trois jours de vrai beau temps, l'arrivée de 732,231 tou
# ristes étrangers semble un paradoxe. H est vrai que le tourisme moderne attire de plus en plus de mo
# nde vers les grandes villes. Et à cet égard, Zurich offre beaucoup : plus de 1000 restaurants, repré
# sentant les cuisines les plus diverses du globe, une quarantaine de cinémas (dont le dernier vient d
# 'être ouvert à l'intérieur de la gare centrale), une trentaine de musées, galeries d'art, etc. Dans
# le dernier numéro de la Weltwoche, un article sur le développement touristique de Zurich donne d'int
# éressantes indications sur l'intérêt des Américains pour la plus grande ville de Suisse. Relevons de
# ux citations particulièrement saillantes. « Zurich est 'a seule ville d'Europe où je pourrais vivre
# », à déclaré l'écrivain Thornton Wilder. « Zurich est un paradis pour les célibataires », a écrit la
#  célèbre revue Esquire qui précisait : « Cette vilie compte entre 15,000 et 25,000 prostituées, qui
# ... [truncated]
# -----------------
#
# --- Article 9 ---
# Title: Vingt-six fontaines
# Publicationdate: 1962-08-04
# Languagecode: fr
# Transcript Length: 968 characters
# Transcript:
# Vingt-six fontaines Le Service de l'Eau nous a fourni d'intéressantes indications statistiques sur n
# os fontaines, à défaut de renseignements historiques. Par exemple, nous avons appris que l'on compta
# it 26 fontaines sur le territoire communal, desservies par le réseau public. Quelques autres fontain
# es font appel à des eaux de sources privées, telles la Bonne fontaine des Eplatures. L'ensemble de c
# es fontaines débite 200 litres / minute ; comme elles sont en service durant six mois environ, cela
# représente annuellement une quantité de 55, 000 mètres cubes d'eau. Il, faut relever encore que deux
#  grandes fontaines, la « Monu » et la fontaine du parc de la gare ( Chambre suisse de l'horlogerie),
#  fonctionnent en circuit continu ; leur eau n'est donc pas potable. Il ne s'agit que d'ouvrage décor
# atif. Trois fontaines, celles de la Place du Sentier, de la Place du Marché et du jardin de l'Ouest
# fournissent une eau destinée à l'alimentation, parfaitement potable.
# -----------------
#
# --- Article 10 ---
# Title: isi Siiiss®
# Publicationdate: 1928-07-19
# Languagecode: fr
# Transcript Length: 2732 characters
# Transcript:
# _isi _Siiiss _® Ne gaspillons pas l'eau ! ZURICH, 19. — Le Service des eaux de la ville de Zurich vi
# ent de publier un avis concernant la consommation de l'eau, avis motivé par le -fait qu'en ces temps
#  de chaleur excessive, on a coutume de mettre le lait et d'autres aliments dans l'eau courante pour
# les rafraîchir, d'arroser les jardins par trop copieusement, bref, de gaspiller l'eau. Ces jours der
# niers, la consommation d'eau a dépassé 100, 000 m 3, ce qui représente une moyenne de 425 litres par
#  personne et par jour, tandis que jusqu'ici, la consommation la plus forte n'avait pas dépassé 83 mi
# lle m 3. Zurich possède, il est vrai, un réservoir inépuisable — en l'espèce son lac — mais il n'en
# reste pas moins que les installations de filtrage et de transport ont des capacités limitées. Samedi
#  dernier, la consommation a même atteint 103, 000 m 3, ce qui est manifestement exagéré et ne corres
# pond nullement aux besoins réels de la population. Aussi la direction du Service des eaux de Zurich
# déclare-t-elle que les gaspilleurs seront punis conformément au règlement. Les merveilles du télépho
# ne. — On cause de Genève à New-York... pour commander des montres ! GENEVE, 19. — La première conver
# sation téléphonique de l'Amérique avec Genève a eu lieu hier entre la maison d'importation d'horloge
# rie Wittnauer et Cie de New-York et sa succursale de Genève. Cette conversation a duré 6 minutes et
# a coûté 495 francs. Elle fut très claire et l'on se comprit d'un bout à l'autre du fil comme s'il n'
# ... [truncated]
# ------------------
#
# --- Article 11 ---
# Title: Zürich im Schutze der Deiche «Sie sind a...
# Publicationdate: 1965-02-11
# Languagecode: de
# Transcript Length: 3118 characters
# Transcript:
# Zürich im Schutze der Deiche « Sie sind auf der Suche nach Ortschaften mit dem Namen Zürich gerade a
# n den rechten Mann gekommen, denn auch ich habe mich schon für die anderen Städte der Weltkarte, die
#  den Namen Zürich tragen, interessiert. Nicht nur habe ich des öfteren herzlichen Kontakt mit Schwei
# zer Zürchern die durch unser Darf kommen, sei es durch Zufall, oder weil sie dem Namensvetter ihrer
# Heimatstadt einen Besuch abstatten wollen. loh habe vielmehr auch selber schon einige der anderen Zü
# richs besucht. So besuchte ich im Jahre 1960 mit meiner Familie das Schweizer Zürich, wobei die Stad
# tverwaltung uns auf sehr herzliche Weise begrüsste. Unser Zürich gehört mit 26 anderen Dörfern zur G
# emeinde Wonseradeel und hat daher kein eigenes Postamt und somit auch keinen Poststempel. Die Post w
# ird vielmehr von der benachbarten Stadt Hariingen aus besangt. Leben unter der Drohung des Meeres Wo
# hl aber hat Zürich eine eigene Fahne, die ich Ihnen aufgezeichnet habe. Das brennende Rot spricht vo
# n der Gefahr die droht, wenn der brüllende Sturm das Meerwasser über die Deiche jagt. Der diagonal v
# erlaufende goldene Streifen aber bedeutet den Schutz durch den Deich — der auoh « goldenes Band » ge
# nannt wird — durch den die Bevölkerung Schutz erhält ». den Stadtpräsidenten von Yver- j don, Andre
# Martin: In verschiedenen Gebieten der Schweiz hat die Austrocknung von Quellen und die Verschmutzung
#  von Gewässern einen chronischen Wassermangel hervorgerufen. In einigen Gemeinden in der Umgebung vo
# ... [truncated]
# ------------------
#
# --- Article 12 ---
# Title: CRITIQUE ET ESSAIS Un exemple à suivre A Zurich, Services industriels [...]
# Publicationdate: 1980-07-12
# Languagecode: fr
# Transcript Length: 2754 characters
# Transcript:
# Un exemple à suivre A Zurich, Services industriels et Bureau d'archéologie travaillent de conserve L
# es canalisations du centre historique de Zurich, sur les deux rives de la Limmat, étaient plus que c
# entenaires ; une votation populaire a approuvé, en 1975, leur remplacement intégral. On aurait pu se
#  borner à défoncer les rues pour y placer de nouvelles conduites, mais on en profita pour examiner s
# cientifiquement le sous-sol urbain : l'ensemble des travaux fut planifié avec le Bureau d'archéologi
# e de la ville, ce qui permit d'explorer la totalité des voies et places faisant l'objet de l'opérati
# on et, accessoirement, de refaire tous les pavements en supprimant les trottoirs. Aujourd'hui, la pr
# emière phase est achevée, qui couvre un tiers du projet. Ses résultats sont si intéressants qu'on le
# s a exposés au public (et au contribuable), sous le titre Kanalisationssanierung und Archâologie (Ha
# us Zum Rech, Neumarkt 4, jusqu'au 23 août). On savait que Zurich constituait au Bas-Empire un point
# d'appui sur la rive occidentale de la Limmat, avec le fort de Turicum, à l'emplacement du Lindenhof.
#  Puis la bourgade réapparaissait en quelque sorte au IXe siècle après une longue éclipse documentair
# e. Les fouilles ont permis de compléter largement la connaissance de la Zurich romaine : la tête du
# pont sur la rive gauche, la position de la rive droite à la Niederdorfstrasse, diverses fondations a
# ntiques difficiles à interpréter, tels sont quelques-uns des résultats de cette première campagne. D
# ... [truncated]
# ------------------
#
# --- Article 13 ---
# Title: LE PASSE GLORIEUX ET LOINTAIN DE LA VILLE DE ZURICH
# Publicationdate: 1935-12-20
# Languagecode: fr
# Transcript Length: 5790 characters
# Transcript:
# LE PASSE GLORIEUX ET LOINTAIN DE LA VILLE DE ZURICH Promenade dans les pays suisses (De notre corres
# pondant particulier) Il m'est agréable de saisir l'occasion qui m'est offerte de rédiger un article
# sur la ville de Zurich. Je le fais avec d'autant plus de plaisir qu'établi à Zurich depuis plus de q
# uinze ans, j'ai eu l'occasion fort souvent d'apprécier l'entregent et l'esprit de bienveillance de s
# es habitants. Loin de son coin de pays, le welsche se sent toujours un peu un « déraciné » ; c'est d
# onc pour lui un grand bienfait que de se trouver au milieu d'une population cordiale, dont les quali
# tés d'assiduité et de sérieux sont bien connues. Il y aurait évidemment beaucoup à dire sur le sujet
#  faisant l'objet de la présente chronique ; je me bornerai cependant à n'insister que sur quelques f
# aits permettant de situer dans son véritable milieu l'Athènes des bords de la Limmat qui, depuis que
# lques dizaines d'années, a pris un prodigieux essor. ? * * Déjà à l'époque préhistorique, les rives
# du lac de Zurich — 40 km. de long — étaient habitées. C'est ainsi qu'en 1854 l'on a découvert à Meil
# en des restes d'habitations lacustres ; sauf erreur, cette découverte a été la première du genre. Da
# ns la suite, l'on a fait une ample récolte d'objets préhistoriques dans la région du lac inférieur,
# là même où s'élève aujourd'hui la fière et popu-JLa cathédrale de Zurich d'après une ancienne gravur
# e. Ieuse ville de Zurich. Le musée national possède du reste une incomparable collection d'objets de
# ... [truncated]
# ------------------
#
# --- Article 14 ---
# Title: Glous-slous dans la ville
# Publicationdate: 1989-07-24
# Languagecode: fr
# Transcript Length: 4715 characters
# Transcript:
# Glous-slous dans la ville Les fontaines ne coulent pas sans soucis A la claire fontaine, s'en allant
#  promener, les Chaux-de-Fonniers ont 56 sources auxquelles se rafraîchir. Leur ville, triste de ne p
# ouvoir se mirer dans les eaux d'un lac et frustrée de ne point se bercer au rythme d'une rivière, se
#  venge par ses multiples fontaines. Mais la sécheresse des dernières semaines et l'attention général
# e portée à la consommation d'eau met en pianissimo la chanson cristalline des robinets. Le service d
# e l'énergie se penche sérieusement sur ce débit et appelle le soleil à la rescousse. Dans cet invent
# aire de 56 points d'eau, les travaux publics comptabilisent tous les robinets et autres jets sur le
# domaine public ; du petit bassin de préau d'école à la Grande Fontaine en passant par les nombreuses
#  fontaines des cimetières, des parcs publics, du Bois du Petit-Château, etc. Autant d'histoires d'ea
# u s'écoulant d'une motivation des autorités. « L'eau est toujours intimement liée à la vie ; partout
#  où il y a des gens, il y a de l'eau » remarque le conseiller communal Alain Bringolf, responsable d
# es TP. Outre les fontaines inscrites dans la vie d'antan du bétail s'abreuvant et des lavandières Mi
# se en eau en juin, une ancienne fontaine agrémente la rue Fritz-Courvoisier, ajoutant son gazouillis
#  à un parc de bassins impressionnant. ( Photo Impar-Gerber) papotant, et celles placées pour l'utili
# té dans les cours d'école, parcs publics ou à proximité des piscines, d'autres bassins ont été insta
# ... [truncated]
# ------------------
#
# --- Article 15 ---
# Title: DERNIER RÊVE MUNICIPAL
# Publicationdate: 1941-05-23
# Languagecode: fr
# Transcript Length: 4052 characters
# Transcript:
# DERNIER RÊVE MUNICIPAL LETTRE DE ZURICH (De notre correspondant particulier) Il y a quelque trente à
#  trente-cinq ans, nous prenions chaque semaine le chemin du Tunnel à Lausanne pour aller nous baigne
# r en troupe, dans une sorte de buanderie, qui tenait alors lieu de piscine. Un bâtiment au teint jau
# nâtre coiffé d'une casquette grise. A travers un brouillard de vapeur, les petits grimauds de collèg
# e s'ébattaient bruyamment sous le regard de leur maître de gymnastique. Tout cela était primitif et
# touchant. Il n'en va pas de même sur les bords de la Sihl, au coeur du Grand-Zurich. Dans leur désir
#  de faire bien les choses, les autorités municipales apportent autant de soin que de temps à réalise
# r leurs grands projets. Cela peut durer vingt à trente ans et coûter quelques millions. Peu importe
# ! Aujourd'hui Zurich ne possède pas seulement son jardin zoologique et son Palais des congrès. Elle
# vient d'inaugurer une piscine communale, dont les premiers plans remontent avant la dernière guerre
# mondiale. C'est là peut-être ce qu'il y a de mieux aujourd'hui dans notre pays. Extérieurement, l'as
# pect d'une belle et vaste centrale électrique. D'immenses baies vitrées qui donnent sur les arbres d
# e la Kleine Schanze. Lorsque l'on nage dans l'eau bleutée, on croirait se baigner au milieu d'un par
# c. Le comble de l'organisation, de l'hygiène et de l'agrément. Cabines, douches d'eau tiède et d'air
#  chaud. Un univers chatoyant, animé et lumineux. Tout ici est bleu et blanc, jusqu'aux hortensias et
# ... [truncated]
# ------------------
#
# --- Article 16 ---
# Title: Une ville est née...
# Publicationdate: 1939-05-09
# Languagecode: fr
# Transcript Length: 3313 characters
# Transcript:
# Une ville est née... Sur l « s bords du lac de Zurich En l'espace de onze mois, une nouvelle cite es
# t née sur les bords du lac de Zurich. Les travaux de construction de l'Exposition nationale ont duré
#  un peu moins d'un an. Se doute-t-on de l'effort énorme qu'exige la mise au point d'une manifestatio
# n de cette envergure i Oar, a côté de tout ce qui se voit, — de tout ce qu on admire — il y a tout c
# e qui ne se voit pas, et qui représente un travail dont le profane ne se fait guère une idée.'_Quelq
# ues chiffres ue seront peut-être pas ete trop pour illustrer ce que nous venons de dire. L'Expositio
# n occupe, sur les deux rives du lac de Zurich, une superfice d'environ 300, 000 mètres carrés ; 125,
#  000 mètres carrés sont pés par des constructions, dont le volume atteint au total 700, 000 mètres c
# ubes. Pour édifier les nombreux pavillons de l'Exposition, les charpentiers ont utilisé 14, 000 mètr
# es cubes de bois l «'** de construction, et le volume du bois d oeuvre atteint 370, 000 mètres cubes
# . Voilà pour la su perstructure. Et le visiteur serait plus étonne encore s'il pouvait voir le résea
# u de canalisations qui s'étend sous ses pieds : conduites d'eau, conduites pour les eaux usées, cabl
# es électriques et câbles téléphoniques, canalisations pour le gaz, sillonnent le sous-sol de l'Expos
# ition. Les conduites d'eau — il s'agit uniquement des conduites souterraines — ont une longueur de 5
# 200 mètres, ce qui n'est pas exagéré si l'on songe que la consommation d'eau pendant la durée de l'E
# ... [truncated]
# ------------------
#
# --- Article 17 ---
# Title: Tempêtes dans des piscines
# Publicationdate: 1983-07-18
# Languagecode: fr
# Transcript Length: 1670 characters
# Transcript:
# Tempêtes dans des piscines ZURICH Zurich (de notre correspondant).-Economies d'abord, mais pas au dé
# triment de la natation et donc de la santé publique : c'est sur ce thème qu'un groupe de Zurichois v
# ient de partir en guerre contre l'Office municipal de la santé publique, qui envisage de fermer prém
# aturément à fin août un certain nombre de bains publics et de piscines en plein air de Zurich, alors
#  qu'en principe le temps de la baignade dure jusqu'à mi-septembre. La mesure s'appliquerait à des ét
# ablissements de quartiers, comme la baignade de Letten, sur la Limmat, la piscine d'Allenmoos à Œrli
# kon ou la plage de Wollishofen. Tout d'abord, l'information avait tré un scepticisme étonné, une foi
# s confirmée ce fut la levée de boucliers. 2 & ". "..'..'1 .... Les opposants, qui ont lancé une péti
# tion, font valoir que cette mesure est antisociale. Elle frappe tout d'abord le personnel, saisonnie
# r, des baignades « condamnées », mais porte préjudice à l'organisation des loisirs de nombreuses fam
# illes. En outre, les migrations, obligatoires, vers d'autres piscines encore ouvertes accroîtraient
# les frais en même temps que cela créerait à coup sûr des engorgements au bord des plans d'eau « tolé
# rés ». Les milieux politiques se sont aussi émus, et une interpellation émanant de l'Alliance des in
# dépendants exige des explications de la part des autorités. Celles-ci ont jusqu'au 15 août pour pren
# dre une décision définitive, en raison des délais de licenciement du personnel temporaire. Le chef d
# ... [truncated]
# ------------------
#
# --- Article 18 ---
# Title: Jeux de société...
# Publicationdate: 1928-01-23
# Languagecode: fr
# Transcript Length: 2714 characters
# Transcript:
# Jeux de société... CDe notro corresp. de Zurich.) Connaissez-vous le proverbe qui dit que là où deux
#  Suisses se rencontrent, ils fondent une société ? L'en a dit parfois que c'étaient de mauvaises lan
# gues qui avaient répandu ce bruit, lequel, cependant, ne me paraît pas être tout à fait une légende,
#  à en juger par le nombre de sociétés de toutes sortes dont nous sommes gratifiés. Oyez plutôt, en c
# e qui concerne la ville de Zurich. D'après une statistique qui vient d'être dressée, l'Athènes des b
# ords de la Limmat comptait dernièrement, pour une population de 220,000 âmes environ, 1150 sociétés
# et groupements divers, et dans ce chiftre ne sont pas même comprises les associations de jeunes gens
#  des deux sexes, les sous-sections, etc ., parce que celles-ci sont considérées comme se rattachant
# à d'autres sociétés ; sinon l'en arriverait à un chiffre passablement plus élevé. L'on compte : 185
# associations professionnelles, 11 sociétés dramatiques, 206 sociétés d'utilité publique, 115 société
# s de chant, 59 sociétés de divertissement, 82 caisses maladie ou de secours, 37 sociétés scientifiqu
# es, 19 sociétés militaires, 40 sociétés de musique, 47 groupements politiques, 15 sociétés de quarti
# er, 47 sociétés religieuses, 3 clubs d'échecs, 61 sociétés de tir, 67 sociétés de « port, 3 associat
# ions de sténographie, 15 sociétés universitaires, 43 sociétés de gymnastique, S sociétés patriotique
# s, 22 corporations, etc. A ees chiffres, il convient encore d'ajouter 28 sociétés de bibliothèque, p
# ... [truncated]
# ------------------
#
# --- Article 19 ---
# Title: • • 111111
# Publicationdate: 2007-04-13
# Languagecode: fr
# Transcript Length: 1445 characters
# Transcript:
# • • 111111 ret. 4. Il y a les piscines qui restent dans le domaine du confort, de la détente avec de
# s variations SPA, sauna, coin détente, massage, etc. 5 II y a, enfin, les thermes dont l'eau possède
#  des qualités curatives particulières. Parmi ceux-ci, il y a les thermes reconnus tant par les or ga
# nismes officiels que par les assurances, l'aspect thérapeutique domine. Et puis il y des centres the
# rmaux qui regroupent les qualités des cinq catégories énoncées ci-dessus. D'Yverdon-les-Bains à Brig
# erbad Parmi les lieux balnéaires qui ont une reconnaissance et surtout une histoire citons Loèche-le
# s-Bains, les- Bains, Lavey-les Bains. La première est toujours une des plus prestigieuses, elle l'ét
# ait déjà au 18 ième siècle et l'on venait de France et d'Allemagne pour s'y baigner. Brigerbad a aus
# si une histoire tandis que Saillon, même si les Romains y avaient installé des thermes et les joueur
# s du Casino de Saxon, au 19 siècle y faisaient trempette, est une création plus récente. Tout comme
# Ovronnaz ou Val-d'llliez et la plus récente : les Bains de la Gruyère à Charmey. Des projets sont en
#  cours à Crans-Montana, Griment et àThyon-les Collons. Et puis existe-t-il déjà en plus des centres
# d'eaux existants et les projets d'autres concepts dans les tiroirs ? Quoi qu'il en soit on recense d
# onc pas moins de 11 centres d'eau en Suisse romande, dont 7 en Valais, existants et en projets, c'es
# t dire l'accroissement de ce type de concept.
# ------------------
#
# --- Article 20 ---
# Title: Des fontaines dont on parle et dont on parlera
# Publicationdate: 1945-07-26
# Languagecode: fr
# Transcript Length: 956 characters
# Transcript:
# Des fontaines dont on parle et dont on parlera De tous les endroits de Suisse où les fontaines sont
# en honneur — et Dieu sait s'il en existe — il en est peu qui soient plus attirants que le Landeron,
# ce bourg gracieux, pittoresque et cossu dont le canton de Neuchâtel s'_enorgueillit si justement. Le
# s fontaines du Landeron sont en effet parmi les plus anciennes et les plus belles qui se puissent vo
# ir. Sculptées et enihiminêes, bénéficiant de la part de la population de soins attentifs et touchant
# s, elles mettent dans ce paysage de vignoble, de forêts et de lac proche le sceau d'un passé somptue
# ux et fier. A toutes ces fontaines s'en ajoutera bientôt une qui, bien que symbolique, sera bientôt
# célèbre puisque d'elle couleront te. oie et l'aisance. La loterie romande installera prochainement a
# u Landeron, en effet, sa source de chance puisque c'est là que se déroulera le prochain tirage. Hâte
# z-vous si vous voulez profiter de son débit bienfaisant.
# ------------------

# %% [markdown]
# ### Q2 - LUX

# %%
reranked_lux_articles_q2 = rerank_articles_by_other_embedding_model(result_articles_q2, question_q2, embedding_model=embedding_model_lux)
# Out:
# Spearman correlation between original and reranked rankings: 0.1835
# Overlap in top 3 results: 0
# Overlap in top 5 results: 2
# Overlap in top 10 results: 6

# %%
format_and_display_articles(reranked_articles_q2)
# Out:
# --- Article 1 ---
# Title: CONGRÈS À ZURICH La Suisse, château d'eau de l'Europe
# Publicationdate: 1982-09-07
# Languagecode: fr
# Transcript Length: 1809 characters
# Transcript:
# CONGRÈS À ZURICH La Suisse, château d'eau de l'Europe Zurich, 6 (ATS).-Le 14 e congrès mondial de l'
# Association des distributions d'eau (AIDE) s'est ouvert lundi à Zurich. Jusqu'au 10 septembre, plus
# de deux mille délégués de toutes les régions du monde débattront de problèmes liés au thème général
# « sans eau pas de vie ». Lors de leurs allocutions d'ouverture, le conseiller fédéral Hans Hiirliman
# n et le président de la ville de Zurich Thomas Wagner ont relevé que la Suisse peut être considérée
# comme le château d'eau de l'Europe. Les problèmes qui se posent chez nous ne touchent pas à la quant
# ité mais à la qualité. Selon M. Hùrlimann, l'exiguïté de notre pays, sa forte densité démographique
# et ses intenses activités économiques sont également sources de problèmes. Une statistique de la Soc
# iété suisse de l'industrie du gaz et des eaux montre que près de 580 millions de mètres cubes d'eau
# potable ont été distribués dans notre pays en 1981. Cela représente une consommation quotidienne de
# 248 litres par habitant. L'eau, a encore indiqué M. Hùrlimann, est la seule ressource naturelle que
# la Suisse ne doit pas importer. Mais, parallèlement à l'augmentation de la population, de la product
# ion et de la consommation, la pollution est devenue de plus en plus préoccupante. Pour faire face à
# cette situation, d'énormes efforts financiers ont été consentis. M. Hùrlimann a rappelé que plus de
# 20 milliards de francs ont été investis en Suisse pour résoudre le problème de la pollution. Cela éq
# ... [truncated]
# -----------------
#
# --- Article 2 ---
# Title: Le canton de Zurich compte 3200 débits d...
# Publicationdate: 1914-02-07
# Languagecode: fr
# Transcript Length: 1536 characters
# Transcript:
# Le canton de Zurich compte 3200 débits de boissons et 1800 magasins de vente à l'emporter de boisson
# s alcooliques, dont 1000 pour la seule ville de Zurich. Aussi ne faut-il pas s'étonner d'y voir mont
# er la marée de l'alcoolisme. Le Conseil d'Etat entend l'endiguer par une loi dont voici les disposit
# ions les plus importantes. Le nombre des débits de boissons ne pourra pas dépasser une proportion d'
# un débit pour une sphère de population de 200 âmes. Les patentes ne seront pas accordées aux établis
# sements mais aux personnes. Elles pourront définitivement être retirées aux tenanciers qui se seront
#  fait citer deux fois pour violation des règlements de police. Les communes auront le droit de fixer
#  des heures de fermeture des débits plus restrictives aue le maximum autorisé. Les débits ne pourron
# t être ouverts le dimanche et les jours fériés avant 11 heures du matin. Tout employé d'un établisse
# ment aura droit à un temps de sommeil d'au moins 8 heures, et de plus à un repos inintei-rompu de 6
# heures de temps, dont 3 pendant la journée. Toutes les trois semaines, les ployés auront droit à 1 j
# our de repos de 24 heures, qui, tous les deux mois au moins, devra tomber sur un dimanche. Il sera i
# nterdit aux garçons et aux sommelières de boire avec les consommateurs. Les magasins de vente au dét
# ail de boissons alcooliques ne pourront vendre le dimanche, et la semaine ils ne pourront débiter ap
# rès 8 heures du soir. Ce projet de loi contribuera, s'il est adopté, à une notable amélioration des
# ... [truncated]
# -----------------
#
# --- Article 3 ---
# Title: engpasse
# Publicationdate: 1976-07-07
# Languagecode: de
# Transcript Length: 967 characters
# Transcript:
# engpasse bps. Die Wasserversorgung in einigen Zürcher Quartieren ist durch den schlagartig gestiegen
# en Verbrauch an der Grenze ihrer Leistungsfähigkeit angelangt. Wie die Abteilung Wasserversorgung de
# r Industriellen Betriebe der Stadt ZUrich mitteilte, betrifft dies in erster Linie die peripher gele
# genen Versorgungsgebicte Seebach, Höngg, Waidberg, Friesenberg, Leimbach und Witikon. Wohl gehört zu
# rzeit die Wasserversorgung der Stadt Zürich zu den modernsten und leistungsfähigsten ihrer Art in Eu
# ropa. Doch die endgültige Sicherstellung der Wasserlieferungen für das gesamte Stadtgebiet wird erst
#  ab etwa 1982 bewerkstelligt sein, da sich momentan verschiedene in der Gemeindeabstimmung vom 4. Mä
# rz 1973 bewilligte Projekte noch im Stadium der Realisierung befinden. So steht beispielsweise das G
# rundwasserwerk Hardhof im Neubau. Darüberhinaus werden verschiedene Verteilanlagen wie Pumpwerke, Re
# servoire und Transportleitungen gegenwärtig erneuert. Schluss S. 14
# -----------------
#
# --- Article 4 ---
# Title: Les bains publies en Suisse
# Publicationdate: 1931-08-07
# Languagecode: fr
# Transcript Length: 2053 characters
# Transcript:
# Les bains publies en Suisse Le service de publictié des C. F. F. a organisé dans tout le pays une en
# quête sur les établissements de bain. Au total 111 villes et stations touristiques disposent de bain
# s de rivière, de plages ou de piscines, ce nombre s'est même accru depuis la fin de l'enquête. 24 de
#  ces établissements se trouvent dans la Suisse orientale entre Zurich et le lac de Constance, 19 dan
# s la Suisse centrale, 18 dans l'Oberland bernois (Berne y compris), 17 dans les Grisons, 15 dans la
# Suisse septentrionale et occidentale, 8 le long du lac Léman, etc. Il existe 19 piscines artificiell
# es, dont 6 chauffablee ; 70 autres établissements sont situés au bord des lacs, et le reste sur les
# cours d'eau. L'installation de ces bains est des plus variés ; il en est de luxueuses, de raffinées,
#  comme aussi de très simples. 6880 cabines individuelles ont été annoncées ; Bâle vient en tête avec
#  487, et Lucerne suit avec 404. Il existe en outre des cabines communes ainsi que divercabines commu
# nes ainsi que diverses installations servant de vestiaires. Il va sans dire qu'il est partout possib
# le de prendre des bains de soleil, aujourd hui si en vogue ; cependant 78 établissements disposent d
# 'emplacements spéciaux. 70 établissements ont des terrains de gymnastique ou de jeu, 92 des pelouses
# . La gymnastique enseignée dans 29 bains permet aux personnes corpulentes de perdre quelque peu de l
# eur embonpoint. 82 bains offrent les délices de la douche. 75 disposent d'engins destinés aux jeux n
# ... [truncated]
# -----------------
#
# --- Article 5 ---
# Title: Les villes suisses consomment trop
# Publicationdate: 2014-03-27
# Languagecode: fr
# Transcript Length: 1094 characters
# Transcript:
# Les villes suisses consomment trop EAU Les villes suisses consomment en moyenne plus d’eau par habit
# ant que celles des pays péens, alors que les prix y sont parfois plus élevés. Selon un audit de l’Of
# fice fédéral de la statistique, Lugano se place au premier rang, avec 250 m 3 d’eau consommés par ha
# bitant en 2012, soit le double des autres villes étudiées : dix chefs-lieux suisses et dix péens, no
# rdiques principalement. La cité tessinoise est suivie par Genève, Bâle, Lausanne, Zurich, Bienne, Lu
# cerne, Berne, Saint-Gall et Winterthour. Ces dernières villes enregistrent une consommation d’eau an
# nuelle par habitant variant entre 85 et 135 mètres cubes. En onzième place figure la ville suédoise
# de Göteborg, talonnée par Helsinki, en Finlande, les tés allemandes Stuttgart et Munich et des ville
# s belges, comme Gand et Bruxelles. La consommation d’eau n’est pas liée aux prix. A Saint-Gall, où l
# es habitants consomment en moyenne 85 m 3 d’eau par an, les prix sont aussi élevés (2,4 francs par m
#  3) qu’à Munich, où la moyenne est de 60 mètres cubes. ATS A Lugano, on aime l’eau... KEYSTONE
# -----------------
#
# --- Article 6 ---
# Title: Les villes suisses consomment trop
# Publicationdate: 2014-03-27
# Languagecode: fr
# Transcript Length: 1096 characters
# Transcript:
# Les villes suisses consomment trop EAU Les villes suisses consomment en moyenne plus d’eau par habit
# ant que celles des pays péens, alors que les prix y sont parfois plus élevés. Selon un audit de l’Of
# fice fédéral de la statistique, Lugano se place au premier rang, avec 250 m 3 d’eau consommés par ha
# bitant en 2012, soit le double des autres villes étudiées : dix chefs-lieux suisses et dix péens, no
# rdiques principalement. La cité tessinoise est suivie par Genève, Bâle, Lausanne, Zurich, Bienne, Lu
# cerne, Berne, Saint-Gall et Winterthour. Ces dernières villes enregistrent une consommation d’eau an
# nuelle par habitant variant entre 85 et 135 mètres cubes. En onzième place figure la ville suédoise
# de Göteborg, talonnée par Helsinki, en Finlande, les tés allemandes Stuttgart et Munich et des ville
# s belges, comme Gand et Bruxelles. La consommation d’eau n’est pas liée aux prix. A Saint-Gall, où l
# es habitants consomment en moyenne 85 m 3 d’eau par an, les prix sont aussi élevés ( 2, 4 francs par
#  m 3) qu’à Munich, où la moyenne est de 60 mètres cubes. ATS A Lugano, on aime l’eau... KEYSTONE
# -----------------
#
# --- Article 7 ---
# Title: Les cinémas à Zurich
# Publicationdate: 1927-03-09
# Languagecode: fr
# Transcript Length: 3722 characters
# Transcript:
# Les cinémas à Zurich CDe notre eorr. de Zurich) Il n'y a pas à dire : la ville de Zurich est en trai
# n de battre tous les records en matière d'industrie cinématographique, par quoi veuille. entendre, j
# e vous prie, le nombre d'établissements cinématographiques sollicitant la faveur du public. Une noti
# ce, parue dernièrement, n'a pas manqué de faire quelque sensation, puisqu'elle annonçait l'ouverture
#  prochaine de pas moins de six théâtres nouveaux, à côté de ceux que nous possédons déjà. A ce propo
# s, il n'est peut-être pas sans intérêt de s'arrêter à quelques chiffres _. D'après le dernier recens
# ement, la population de la ville de Zurich s'élève à 214.000 âmes ; or, pour oette population, il y
# a actuellement 14 cinématographes en exploitation, ce qui est largement suffisant. Les 20 établissem
# ents que nous" risquons de posséder prochainement contiennent environ 15.000 places, ce qui est un c
# hiffre coquet ; si l'on veut qu'elles soient occupées tous les soirs, le flot des spectateurs devra
# prendre des proportions inaccoutumées. Mais ce n'est pas tout, car nous avons à côté de cela de nomb
# reux établissements de distraction qui veulent vivre aussi. C'est tout d'abord le grand théâtre, ave
# o ses 1400 places, puis le théâtre du Pfauen, qui en compte 900 ; ensuite, il y a deux cabarets, qui
#  jouent chaque jour, et qui peuvent accueillir 550 spectateurs ; cela fait déjà des occasions de dis
# traction pour 2850 personnes. Avec les cinémas, au nombre de 20, nous arrivons ainsi à 24 théâtres,
# ... [truncated]
# -----------------
#
# --- Article 8 ---
# Title: SUSSE « Celte ville est le paradis des célibataires»
# Publicationdate: 1958-07-29
# Languagecode: fr
# Transcript Length: 2435 characters
# Transcript:
# SUSSE « Celte ville est le paradis des célibataires » Jamais la saison touristique n'a paru si animé
# e à Zurich. La SAFFA y est sans doute pour quelque chose et, grâce à cette exposition, les heures d'
# ouverture des lieux de divertissement ont été prolongées au-delà de minuit. Il est intéressant de no
# ter que les statistiques concernant les étrangers de passage donnent maintenant à Zurich là cinquièm
# e place en Europe pour le nombre des nuits d'hôtels — après Londres, Rome, Paris et Milan. Pour une
# ville qui n'a connu l'an dernier que trente-trois jours de vrai beau temps, l'arrivée de 732,231 tou
# ristes étrangers semble un paradoxe. H est vrai que le tourisme moderne attire de plus en plus de mo
# nde vers les grandes villes. Et à cet égard, Zurich offre beaucoup : plus de 1000 restaurants, repré
# sentant les cuisines les plus diverses du globe, une quarantaine de cinémas (dont le dernier vient d
# 'être ouvert à l'intérieur de la gare centrale), une trentaine de musées, galeries d'art, etc. Dans
# le dernier numéro de la Weltwoche, un article sur le développement touristique de Zurich donne d'int
# éressantes indications sur l'intérêt des Américains pour la plus grande ville de Suisse. Relevons de
# ux citations particulièrement saillantes. « Zurich est 'a seule ville d'Europe où je pourrais vivre
# », à déclaré l'écrivain Thornton Wilder. « Zurich est un paradis pour les célibataires », a écrit la
#  célèbre revue Esquire qui précisait : « Cette vilie compte entre 15,000 et 25,000 prostituées, qui
# ... [truncated]
# -----------------
#
# --- Article 9 ---
# Title: Vingt-six fontaines
# Publicationdate: 1962-08-04
# Languagecode: fr
# Transcript Length: 968 characters
# Transcript:
# Vingt-six fontaines Le Service de l'Eau nous a fourni d'intéressantes indications statistiques sur n
# os fontaines, à défaut de renseignements historiques. Par exemple, nous avons appris que l'on compta
# it 26 fontaines sur le territoire communal, desservies par le réseau public. Quelques autres fontain
# es font appel à des eaux de sources privées, telles la Bonne fontaine des Eplatures. L'ensemble de c
# es fontaines débite 200 litres / minute ; comme elles sont en service durant six mois environ, cela
# représente annuellement une quantité de 55, 000 mètres cubes d'eau. Il, faut relever encore que deux
#  grandes fontaines, la « Monu » et la fontaine du parc de la gare ( Chambre suisse de l'horlogerie),
#  fonctionnent en circuit continu ; leur eau n'est donc pas potable. Il ne s'agit que d'ouvrage décor
# atif. Trois fontaines, celles de la Place du Sentier, de la Place du Marché et du jardin de l'Ouest
# fournissent une eau destinée à l'alimentation, parfaitement potable.
# -----------------
#
# --- Article 10 ---
# Title: isi Siiiss®
# Publicationdate: 1928-07-19
# Languagecode: fr
# Transcript Length: 2732 characters
# Transcript:
# _isi _Siiiss _® Ne gaspillons pas l'eau ! ZURICH, 19. — Le Service des eaux de la ville de Zurich vi
# ent de publier un avis concernant la consommation de l'eau, avis motivé par le -fait qu'en ces temps
#  de chaleur excessive, on a coutume de mettre le lait et d'autres aliments dans l'eau courante pour
# les rafraîchir, d'arroser les jardins par trop copieusement, bref, de gaspiller l'eau. Ces jours der
# niers, la consommation d'eau a dépassé 100, 000 m 3, ce qui représente une moyenne de 425 litres par
#  personne et par jour, tandis que jusqu'ici, la consommation la plus forte n'avait pas dépassé 83 mi
# lle m 3. Zurich possède, il est vrai, un réservoir inépuisable — en l'espèce son lac — mais il n'en
# reste pas moins que les installations de filtrage et de transport ont des capacités limitées. Samedi
#  dernier, la consommation a même atteint 103, 000 m 3, ce qui est manifestement exagéré et ne corres
# pond nullement aux besoins réels de la population. Aussi la direction du Service des eaux de Zurich
# déclare-t-elle que les gaspilleurs seront punis conformément au règlement. Les merveilles du télépho
# ne. — On cause de Genève à New-York... pour commander des montres ! GENEVE, 19. — La première conver
# sation téléphonique de l'Amérique avec Genève a eu lieu hier entre la maison d'importation d'horloge
# rie Wittnauer et Cie de New-York et sa succursale de Genève. Cette conversation a duré 6 minutes et
# a coûté 495 francs. Elle fut très claire et l'on se comprit d'un bout à l'autre du fil comme s'il n'
# ... [truncated]
# ------------------
#
# --- Article 11 ---
# Title: Zürich im Schutze der Deiche «Sie sind a...
# Publicationdate: 1965-02-11
# Languagecode: de
# Transcript Length: 3118 characters
# Transcript:
# Zürich im Schutze der Deiche « Sie sind auf der Suche nach Ortschaften mit dem Namen Zürich gerade a
# n den rechten Mann gekommen, denn auch ich habe mich schon für die anderen Städte der Weltkarte, die
#  den Namen Zürich tragen, interessiert. Nicht nur habe ich des öfteren herzlichen Kontakt mit Schwei
# zer Zürchern die durch unser Darf kommen, sei es durch Zufall, oder weil sie dem Namensvetter ihrer
# Heimatstadt einen Besuch abstatten wollen. loh habe vielmehr auch selber schon einige der anderen Zü
# richs besucht. So besuchte ich im Jahre 1960 mit meiner Familie das Schweizer Zürich, wobei die Stad
# tverwaltung uns auf sehr herzliche Weise begrüsste. Unser Zürich gehört mit 26 anderen Dörfern zur G
# emeinde Wonseradeel und hat daher kein eigenes Postamt und somit auch keinen Poststempel. Die Post w
# ird vielmehr von der benachbarten Stadt Hariingen aus besangt. Leben unter der Drohung des Meeres Wo
# hl aber hat Zürich eine eigene Fahne, die ich Ihnen aufgezeichnet habe. Das brennende Rot spricht vo
# n der Gefahr die droht, wenn der brüllende Sturm das Meerwasser über die Deiche jagt. Der diagonal v
# erlaufende goldene Streifen aber bedeutet den Schutz durch den Deich — der auoh « goldenes Band » ge
# nannt wird — durch den die Bevölkerung Schutz erhält ». den Stadtpräsidenten von Yver- j don, Andre
# Martin: In verschiedenen Gebieten der Schweiz hat die Austrocknung von Quellen und die Verschmutzung
#  von Gewässern einen chronischen Wassermangel hervorgerufen. In einigen Gemeinden in der Umgebung vo
# ... [truncated]
# ------------------
#
# --- Article 12 ---
# Title: CRITIQUE ET ESSAIS Un exemple à suivre A Zurich, Services industriels [...]
# Publicationdate: 1980-07-12
# Languagecode: fr
# Transcript Length: 2754 characters
# Transcript:
# Un exemple à suivre A Zurich, Services industriels et Bureau d'archéologie travaillent de conserve L
# es canalisations du centre historique de Zurich, sur les deux rives de la Limmat, étaient plus que c
# entenaires ; une votation populaire a approuvé, en 1975, leur remplacement intégral. On aurait pu se
#  borner à défoncer les rues pour y placer de nouvelles conduites, mais on en profita pour examiner s
# cientifiquement le sous-sol urbain : l'ensemble des travaux fut planifié avec le Bureau d'archéologi
# e de la ville, ce qui permit d'explorer la totalité des voies et places faisant l'objet de l'opérati
# on et, accessoirement, de refaire tous les pavements en supprimant les trottoirs. Aujourd'hui, la pr
# emière phase est achevée, qui couvre un tiers du projet. Ses résultats sont si intéressants qu'on le
# s a exposés au public (et au contribuable), sous le titre Kanalisationssanierung und Archâologie (Ha
# us Zum Rech, Neumarkt 4, jusqu'au 23 août). On savait que Zurich constituait au Bas-Empire un point
# d'appui sur la rive occidentale de la Limmat, avec le fort de Turicum, à l'emplacement du Lindenhof.
#  Puis la bourgade réapparaissait en quelque sorte au IXe siècle après une longue éclipse documentair
# e. Les fouilles ont permis de compléter largement la connaissance de la Zurich romaine : la tête du
# pont sur la rive gauche, la position de la rive droite à la Niederdorfstrasse, diverses fondations a
# ntiques difficiles à interpréter, tels sont quelques-uns des résultats de cette première campagne. D
# ... [truncated]
# ------------------
#
# --- Article 13 ---
# Title: LE PASSE GLORIEUX ET LOINTAIN DE LA VILLE DE ZURICH
# Publicationdate: 1935-12-20
# Languagecode: fr
# Transcript Length: 5790 characters
# Transcript:
# LE PASSE GLORIEUX ET LOINTAIN DE LA VILLE DE ZURICH Promenade dans les pays suisses (De notre corres
# pondant particulier) Il m'est agréable de saisir l'occasion qui m'est offerte de rédiger un article
# sur la ville de Zurich. Je le fais avec d'autant plus de plaisir qu'établi à Zurich depuis plus de q
# uinze ans, j'ai eu l'occasion fort souvent d'apprécier l'entregent et l'esprit de bienveillance de s
# es habitants. Loin de son coin de pays, le welsche se sent toujours un peu un « déraciné » ; c'est d
# onc pour lui un grand bienfait que de se trouver au milieu d'une population cordiale, dont les quali
# tés d'assiduité et de sérieux sont bien connues. Il y aurait évidemment beaucoup à dire sur le sujet
#  faisant l'objet de la présente chronique ; je me bornerai cependant à n'insister que sur quelques f
# aits permettant de situer dans son véritable milieu l'Athènes des bords de la Limmat qui, depuis que
# lques dizaines d'années, a pris un prodigieux essor. ? * * Déjà à l'époque préhistorique, les rives
# du lac de Zurich — 40 km. de long — étaient habitées. C'est ainsi qu'en 1854 l'on a découvert à Meil
# en des restes d'habitations lacustres ; sauf erreur, cette découverte a été la première du genre. Da
# ns la suite, l'on a fait une ample récolte d'objets préhistoriques dans la région du lac inférieur,
# là même où s'élève aujourd'hui la fière et popu-JLa cathédrale de Zurich d'après une ancienne gravur
# e. Ieuse ville de Zurich. Le musée national possède du reste une incomparable collection d'objets de
# ... [truncated]
# ------------------
#
# --- Article 14 ---
# Title: Glous-slous dans la ville
# Publicationdate: 1989-07-24
# Languagecode: fr
# Transcript Length: 4715 characters
# Transcript:
# Glous-slous dans la ville Les fontaines ne coulent pas sans soucis A la claire fontaine, s'en allant
#  promener, les Chaux-de-Fonniers ont 56 sources auxquelles se rafraîchir. Leur ville, triste de ne p
# ouvoir se mirer dans les eaux d'un lac et frustrée de ne point se bercer au rythme d'une rivière, se
#  venge par ses multiples fontaines. Mais la sécheresse des dernières semaines et l'attention général
# e portée à la consommation d'eau met en pianissimo la chanson cristalline des robinets. Le service d
# e l'énergie se penche sérieusement sur ce débit et appelle le soleil à la rescousse. Dans cet invent
# aire de 56 points d'eau, les travaux publics comptabilisent tous les robinets et autres jets sur le
# domaine public ; du petit bassin de préau d'école à la Grande Fontaine en passant par les nombreuses
#  fontaines des cimetières, des parcs publics, du Bois du Petit-Château, etc. Autant d'histoires d'ea
# u s'écoulant d'une motivation des autorités. « L'eau est toujours intimement liée à la vie ; partout
#  où il y a des gens, il y a de l'eau » remarque le conseiller communal Alain Bringolf, responsable d
# es TP. Outre les fontaines inscrites dans la vie d'antan du bétail s'abreuvant et des lavandières Mi
# se en eau en juin, une ancienne fontaine agrémente la rue Fritz-Courvoisier, ajoutant son gazouillis
#  à un parc de bassins impressionnant. ( Photo Impar-Gerber) papotant, et celles placées pour l'utili
# té dans les cours d'école, parcs publics ou à proximité des piscines, d'autres bassins ont été insta
# ... [truncated]
# ------------------
#
# --- Article 15 ---
# Title: DERNIER RÊVE MUNICIPAL
# Publicationdate: 1941-05-23
# Languagecode: fr
# Transcript Length: 4052 characters
# Transcript:
# DERNIER RÊVE MUNICIPAL LETTRE DE ZURICH (De notre correspondant particulier) Il y a quelque trente à
#  trente-cinq ans, nous prenions chaque semaine le chemin du Tunnel à Lausanne pour aller nous baigne
# r en troupe, dans une sorte de buanderie, qui tenait alors lieu de piscine. Un bâtiment au teint jau
# nâtre coiffé d'une casquette grise. A travers un brouillard de vapeur, les petits grimauds de collèg
# e s'ébattaient bruyamment sous le regard de leur maître de gymnastique. Tout cela était primitif et
# touchant. Il n'en va pas de même sur les bords de la Sihl, au coeur du Grand-Zurich. Dans leur désir
#  de faire bien les choses, les autorités municipales apportent autant de soin que de temps à réalise
# r leurs grands projets. Cela peut durer vingt à trente ans et coûter quelques millions. Peu importe
# ! Aujourd'hui Zurich ne possède pas seulement son jardin zoologique et son Palais des congrès. Elle
# vient d'inaugurer une piscine communale, dont les premiers plans remontent avant la dernière guerre
# mondiale. C'est là peut-être ce qu'il y a de mieux aujourd'hui dans notre pays. Extérieurement, l'as
# pect d'une belle et vaste centrale électrique. D'immenses baies vitrées qui donnent sur les arbres d
# e la Kleine Schanze. Lorsque l'on nage dans l'eau bleutée, on croirait se baigner au milieu d'un par
# c. Le comble de l'organisation, de l'hygiène et de l'agrément. Cabines, douches d'eau tiède et d'air
#  chaud. Un univers chatoyant, animé et lumineux. Tout ici est bleu et blanc, jusqu'aux hortensias et
# ... [truncated]
# ------------------
#
# --- Article 16 ---
# Title: Une ville est née...
# Publicationdate: 1939-05-09
# Languagecode: fr
# Transcript Length: 3313 characters
# Transcript:
# Une ville est née... Sur l « s bords du lac de Zurich En l'espace de onze mois, une nouvelle cite es
# t née sur les bords du lac de Zurich. Les travaux de construction de l'Exposition nationale ont duré
#  un peu moins d'un an. Se doute-t-on de l'effort énorme qu'exige la mise au point d'une manifestatio
# n de cette envergure i Oar, a côté de tout ce qui se voit, — de tout ce qu on admire — il y a tout c
# e qui ne se voit pas, et qui représente un travail dont le profane ne se fait guère une idée.'_Quelq
# ues chiffres ue seront peut-être pas ete trop pour illustrer ce que nous venons de dire. L'Expositio
# n occupe, sur les deux rives du lac de Zurich, une superfice d'environ 300, 000 mètres carrés ; 125,
#  000 mètres carrés sont pés par des constructions, dont le volume atteint au total 700, 000 mètres c
# ubes. Pour édifier les nombreux pavillons de l'Exposition, les charpentiers ont utilisé 14, 000 mètr
# es cubes de bois l «'** de construction, et le volume du bois d oeuvre atteint 370, 000 mètres cubes
# . Voilà pour la su perstructure. Et le visiteur serait plus étonne encore s'il pouvait voir le résea
# u de canalisations qui s'étend sous ses pieds : conduites d'eau, conduites pour les eaux usées, cabl
# es électriques et câbles téléphoniques, canalisations pour le gaz, sillonnent le sous-sol de l'Expos
# ition. Les conduites d'eau — il s'agit uniquement des conduites souterraines — ont une longueur de 5
# 200 mètres, ce qui n'est pas exagéré si l'on songe que la consommation d'eau pendant la durée de l'E
# ... [truncated]
# ------------------
#
# --- Article 17 ---
# Title: Tempêtes dans des piscines
# Publicationdate: 1983-07-18
# Languagecode: fr
# Transcript Length: 1670 characters
# Transcript:
# Tempêtes dans des piscines ZURICH Zurich (de notre correspondant).-Economies d'abord, mais pas au dé
# triment de la natation et donc de la santé publique : c'est sur ce thème qu'un groupe de Zurichois v
# ient de partir en guerre contre l'Office municipal de la santé publique, qui envisage de fermer prém
# aturément à fin août un certain nombre de bains publics et de piscines en plein air de Zurich, alors
#  qu'en principe le temps de la baignade dure jusqu'à mi-septembre. La mesure s'appliquerait à des ét
# ablissements de quartiers, comme la baignade de Letten, sur la Limmat, la piscine d'Allenmoos à Œrli
# kon ou la plage de Wollishofen. Tout d'abord, l'information avait tré un scepticisme étonné, une foi
# s confirmée ce fut la levée de boucliers. 2 & ". "..'..'1 .... Les opposants, qui ont lancé une péti
# tion, font valoir que cette mesure est antisociale. Elle frappe tout d'abord le personnel, saisonnie
# r, des baignades « condamnées », mais porte préjudice à l'organisation des loisirs de nombreuses fam
# illes. En outre, les migrations, obligatoires, vers d'autres piscines encore ouvertes accroîtraient
# les frais en même temps que cela créerait à coup sûr des engorgements au bord des plans d'eau « tolé
# rés ». Les milieux politiques se sont aussi émus, et une interpellation émanant de l'Alliance des in
# dépendants exige des explications de la part des autorités. Celles-ci ont jusqu'au 15 août pour pren
# dre une décision définitive, en raison des délais de licenciement du personnel temporaire. Le chef d
# ... [truncated]
# ------------------
#
# --- Article 18 ---
# Title: Jeux de société...
# Publicationdate: 1928-01-23
# Languagecode: fr
# Transcript Length: 2714 characters
# Transcript:
# Jeux de société... CDe notro corresp. de Zurich.) Connaissez-vous le proverbe qui dit que là où deux
#  Suisses se rencontrent, ils fondent une société ? L'en a dit parfois que c'étaient de mauvaises lan
# gues qui avaient répandu ce bruit, lequel, cependant, ne me paraît pas être tout à fait une légende,
#  à en juger par le nombre de sociétés de toutes sortes dont nous sommes gratifiés. Oyez plutôt, en c
# e qui concerne la ville de Zurich. D'après une statistique qui vient d'être dressée, l'Athènes des b
# ords de la Limmat comptait dernièrement, pour une population de 220,000 âmes environ, 1150 sociétés
# et groupements divers, et dans ce chiftre ne sont pas même comprises les associations de jeunes gens
#  des deux sexes, les sous-sections, etc ., parce que celles-ci sont considérées comme se rattachant
# à d'autres sociétés ; sinon l'en arriverait à un chiffre passablement plus élevé. L'on compte : 185
# associations professionnelles, 11 sociétés dramatiques, 206 sociétés d'utilité publique, 115 société
# s de chant, 59 sociétés de divertissement, 82 caisses maladie ou de secours, 37 sociétés scientifiqu
# es, 19 sociétés militaires, 40 sociétés de musique, 47 groupements politiques, 15 sociétés de quarti
# er, 47 sociétés religieuses, 3 clubs d'échecs, 61 sociétés de tir, 67 sociétés de « port, 3 associat
# ions de sténographie, 15 sociétés universitaires, 43 sociétés de gymnastique, S sociétés patriotique
# s, 22 corporations, etc. A ees chiffres, il convient encore d'ajouter 28 sociétés de bibliothèque, p
# ... [truncated]
# ------------------
#
# --- Article 19 ---
# Title: • • 111111
# Publicationdate: 2007-04-13
# Languagecode: fr
# Transcript Length: 1445 characters
# Transcript:
# • • 111111 ret. 4. Il y a les piscines qui restent dans le domaine du confort, de la détente avec de
# s variations SPA, sauna, coin détente, massage, etc. 5 II y a, enfin, les thermes dont l'eau possède
#  des qualités curatives particulières. Parmi ceux-ci, il y a les thermes reconnus tant par les or ga
# nismes officiels que par les assurances, l'aspect thérapeutique domine. Et puis il y des centres the
# rmaux qui regroupent les qualités des cinq catégories énoncées ci-dessus. D'Yverdon-les-Bains à Brig
# erbad Parmi les lieux balnéaires qui ont une reconnaissance et surtout une histoire citons Loèche-le
# s-Bains, les- Bains, Lavey-les Bains. La première est toujours une des plus prestigieuses, elle l'ét
# ait déjà au 18 ième siècle et l'on venait de France et d'Allemagne pour s'y baigner. Brigerbad a aus
# si une histoire tandis que Saillon, même si les Romains y avaient installé des thermes et les joueur
# s du Casino de Saxon, au 19 siècle y faisaient trempette, est une création plus récente. Tout comme
# Ovronnaz ou Val-d'llliez et la plus récente : les Bains de la Gruyère à Charmey. Des projets sont en
#  cours à Crans-Montana, Griment et àThyon-les Collons. Et puis existe-t-il déjà en plus des centres
# d'eaux existants et les projets d'autres concepts dans les tiroirs ? Quoi qu'il en soit on recense d
# onc pas moins de 11 centres d'eau en Suisse romande, dont 7 en Valais, existants et en projets, c'es
# t dire l'accroissement de ce type de concept.
# ------------------
#
# --- Article 20 ---
# Title: Des fontaines dont on parle et dont on parlera
# Publicationdate: 1945-07-26
# Languagecode: fr
# Transcript Length: 956 characters
# Transcript:
# Des fontaines dont on parle et dont on parlera De tous les endroits de Suisse où les fontaines sont
# en honneur — et Dieu sait s'il en existe — il en est peu qui soient plus attirants que le Landeron,
# ce bourg gracieux, pittoresque et cossu dont le canton de Neuchâtel s'_enorgueillit si justement. Le
# s fontaines du Landeron sont en effet parmi les plus anciennes et les plus belles qui se puissent vo
# ir. Sculptées et enihiminêes, bénéficiant de la part de la population de soins attentifs et touchant
# s, elles mettent dans ce paysage de vignoble, de forêts et de lac proche le sceau d'un passé somptue
# ux et fier. A toutes ces fontaines s'en ajoutera bientôt une qui, bien que symbolique, sera bientôt
# célèbre puisque d'elle couleront te. oie et l'aisance. La loterie romande installera prochainement a
# u Landeron, en effet, sa source de chance puisque c'est là que se déroulera le prochain tirage. Hâte
# z-vous si vous voulez profiter de son débit bienfaisant.
# ------------------

# %% [markdown]
# ## USE CASE 1 - AI Assisted Source Finding

# %% [markdown]
# ### Q1

# %%
format_and_display_articles(result_articles_q1[:5])
RAG_input_context_q1 = format_and_display_articles(result_articles_q1[:5], return_string=True)

url_format_string = "https://dev.impresso-project.ch/app/article/{guid}"
interface_links_string_q1 = generate_interface_links(result_articles_q1[:5], url_format_string)
# Out:
# --- Article 1 ---
# Title: EN SUISSE : A ZURICH, DES ÉMEUTIERS FONT METTRE EN LIBERTÉ UN PRISONNI[...]
# Publicationdate: 1919-06-16
# Languagecode: fr
# Transcript Length: 1669 characters
# Transcript:
# ZURICH, -15 juin. — Des troubles assez sérieux ont éclaté à Zurich, où, comme on le sait, existe une
#  minorité socialiste extrémiste des plus actives. Une grande manifestation avait été organisée, vend
# redi soir, pair l'Union ouvrière zurichoise, pour honorer la mémoire de Posa Luxembourg. Le préfet d
# e police de Zurich, le socialiste Greber, sur la promesse que la manifestation se déroulerait dans l
# e calme, avait donné des instructions pour que la polioe.se tînt éloignée de la réunion. Celle-ci co
# mmença bien; mais un orateur vint annoncer que le délégué socialiste suisse. Conrad Wyss venait, en
# rentrant d'Allemagne, d'être arrêté par les autorités fédérales, pour avoir introduit des brochures
# et des tracts de propagande. Aussi tôt la foule se porta vers la prison et réclama la mi.se en liber
# té du prisonnier. Vainement les gardiens tentèrent, d'abord par des coups de feu à blanc, ensuite au
#  moyen de pompes à incendie, d'arrêter les manifestants. Pour les c'almer, Conrad Wyss fut mis en 'l
# iberté; mais cette mesure ne suffit point et il fallut se servir d'une mitrailleuse pour empêcher la
#  foule de pénétrer dans la prison. Enfin, vers 2 heures du matin, seulement. le calme revint. Ces év
# énements produisent dans toute la Suisse une grosse émotion. L'opinion générale est que tout 'le mou
# vement révolutionna.ire dont Zurich est le centre depuis plusieurs mois est organisé par 'des agents
#  de l'élrange!' et réclame une attitude énergique'de-s-autorités. Le Conseil d'Etat a pris, déjà. di
# ... [truncated]
# -----------------
#
# --- Article 2 ---
# Title: "hreuie vor
# Publicationdate: 1953-10-26
# Languagecode: de
# Transcript Length: 838 characters
# Transcript:
# hreuie vor 50 Jahren wurde Zizers von einem Großbrand heimgesucht, der vierzehn Firsten einäscherte.
#  * 40 Jahren war die Schweiz am Pariser Automobil-Salon durch die Personenwagen Martini und Picard-P
# ictet vertreten. Die am Salon ausgestellten io—12-PS-Personenwagen waren zum Preis von rund 5000 Fr.
#  erhältlich. 30 Jahren verzichtete der Stadtrat von Zürich auf die Leuchtfontäne im unteren Zürichse
# ebecken, die ein privates Komitee anläßlich der Zürcher Lichtwoche schenken wollte. 20 Jahren wurde
# bekanntgegeben, daß 3 6 Personen beim großen Eisenbahnunglück bei Evreux — dei Schnellzug Cherbourg—
# Paris entgleiste und stürzte in einen Fluß — den Tod fanden. 10 Jahren erklärte der englische Luftfa
# hrtminister Sinclair, daß in den letzten vier Wochen mehr als 17 00 c Tonnen Bomben auf deutsches Ge
# biet abgeworfen worden seien. /. G. M,
# -----------------
#
# --- Article 3 ---
# Title: L'ACTUALITÉ SUISSE
# Publicationdate: 1959-04-24
# Languagecode: fr
# Transcript Length: 969 characters
# Transcript:
# L'ACTUALITÉ SUISSE Meurtre à Zurich ZURICH, 24. — Un drame s'est produit jeudi après-midi, peu avant
#  14 heures, dans une entreprise de machines à écrire de la Schaffhauserstrasse, No 272, à Zurich.. L
# c directeur de la maison avait fait savoir à un ouvrier de 45 ans, M. Adolf Buechi, employé dans l'e
# ntreprise depuis septembre 1958, qu'il pourrait y rester jusqu'à ce qu'il ait trouvé une autre place
# . Jeudi après-midi, Buechi arriva dans la maison et tira un coup de feu sur un contremaître, M. Fran
# cesco Naegelin, âgé de 30 ans. Celuici fut atteint dans le dos et, la balle ayant sectionné, l'aorte
# , il fut tué sur le coup. Buechi se rendit alors dans une autre pièce où il menaça des ouvriers, qui
#  purent cependant s'enfuir. Le meurtrier tourna alors son arme contre lui-même cl se tira une balle
# dans la lêtc. Il est dans un état désespéré. Le contremaître tué laisse une femme et deux enfants. U
# n conflit de travail mineur semble être le motif de l'acte de Buechi.
# -----------------
#
# --- Article 4 ---
# Title: * Banque cantonale zurichoise.
# Publicationdate: 1951-02-14
# Languagecode: fr
# Transcript Length: 1944 characters
# Transcript:
# * Banque cantonale zurichoise. Après déduction et amortissements, le compte de la Banque cantonale d
# e Zurich pour l'année 1950 laisse un bénéfice net disponible de fr. 5,175,560. Suivant la loi sur la
#  banque, fr. 2 millions 200,000 vont au compte de réserve, fr. 2,200,000 au canton, dont fr. 1,760,0
# 00 à la caisse de l'Etat et fr. 440 mille au fonds cantonal d'utilité publique. D'autre part, le con
# seil de banque a décidé à l'occasion du 600 e anniversaire de l'entrée dans la Confédération de vers
# er une somme de fr. 500,000 pour améliorer la situation des tuberculeux qui ont leur domicile dans l
# e canton de Zurich ou qui, citoyens zurichois, résident en dehors du canton. Usines de I'Etzel, Eins
# icdcln. Les usines de I'Etzel ont réalisé pendant l'exercice 1949-1050 un bénéfice de fr. 842,105.5
# % iront au fonds de réserve légal et le reste, fr .. 800,000, servira au versement d'un dividende de
#  4 % sur le capital-actions de 20 millions. Au cours de cet exercice les usines ont produit 206,077
# millions de kWh. qui ont été repris en grande partie par les CFF et les usines hydrauliques du nord-
# est suisse. Au cours de l'exercice, 30,07 millions de mètres cubes d'eau ont été pompés du lac de Zu
# rich pour être déservés dans le Sihlsee, ce qui a amélioré de 15 % le niveau du petit lac. General M
# otors. Lia General Motors déclare un dividende de S 1 sur ses 88,000 actions ordinaires en circulati
# on comme premier versement pour l'exercice en cours. Ce montant est le même que celui payé en décemb
# ... [truncated]
# -----------------
#
# --- Article 5 ---
# Title: d octobre 1950 BULLETIN DE BOURSE
# Publicationdate: 1950-10-05
# Languagecode: fr
# Transcript Length: 2103 characters
# Transcript:
# d octobre 1950 BULLETIN DE BOURSE u E Zurich :. Cour _.', Obligations A 5 VA% Féd. 42 / ms 101-25 d'
# «» 3%% Féd. 43 / av. 10675 d 1 t) 6-8° 3%% Féd. 44 / mal 1 ( wfid 10 < _"° 3% Fédéral 49.. _™ _' 9°
# 104. 75 3% C. F. F. 38.. 1 t) 3 _- 65 m 50 Actions Swissair.... 220 215 d B. Com. de Bâle 263 265 Ba
# nque Fédérale 178 179 Union B. Suisses 900 902 Société B. Suisse 786 786 Crédit Suisse.. 797 796 d C
# onli Linoléum. 216 218 Electro Watt.. 715 717 interhandel... 668 667 Motor Colombus. 509 510 S. A. E
# . G. Sér. 1 66 66 Indelec.... 267 274 Italo-Suisse prior. 83 83 Réassurances.. 5650 5710 Winterthour
#  Ace. 5790 5800 Zurich Assuranc. 7900 d 7990 o Aar-Tessin i.. 1180 1180 Zurich : Cou. ra du Actions
# 4 5 Saurer ¦ _<,, 880 890 Aluminium B ¦ s 2075 2098 Bally... a a -, 725 725 Brown-Boveri.. 925 930 F
# . Mot. Suisse C. 1360 d 1360 Fischer.,, «, 890 725 Laufenburg... 1340 1355 d Linol. Giubiasco _. 118
#  118 Lonza.... t 840 850 Nestlé Alimenl.. •1440 1450 Sulzer..... 1775 1800 Baltimore. ;. „ 61 62% _P
# ennsylvanie RR > 86 87 Italo-Argentina.. 49 48 Royal Dutch, » -. 219 217 Sodec..,, » 43 43 Vt Standa
# rd-Oil. _., 363 368 Union Carbide.-> 208 209 A. E. G.... ¦ 27 27 Du Pont de Nem. 350 359 Eastman Kod
# ak. 206 203 Général Electric.. 210 210 Général Motors. 430 463 Internat. Nickel. 148 150 Kennecott..
# .. 276 281 Montgomery W.. 277 283 National Distillers 113 114 Allumettes B.,. 30 29% Un. States Staë
# l ¦ 165 173 Cours du Zurich :'7 ~ " p 4 5 AMCA, s _,. $ 28. 35 28. 45 SAFIT » s.. £ 10. 12. 6 10. 11
# ... [truncated]
# -----------------

# %% [markdown]
# ### Q2

# %%
format_and_display_articles(result_articles_q2[:5])
RAG_input_context_q2 = format_and_display_articles(result_articles_q2[:5], return_string=True)

url_format_string = "https://dev.impresso-project.ch/app/article/{guid}"
interface_links_string_q2 = generate_interface_links(result_articles_q2[:5], url_format_string)
# Out:
# --- Article 1 ---
# Title: isi Siiiss®
# Publicationdate: 1928-07-19
# Languagecode: fr
# Transcript Length: 2732 characters
# Transcript:
# _isi _Siiiss _® Ne gaspillons pas l'eau ! ZURICH, 19. — Le Service des eaux de la ville de Zurich vi
# ent de publier un avis concernant la consommation de l'eau, avis motivé par le -fait qu'en ces temps
#  de chaleur excessive, on a coutume de mettre le lait et d'autres aliments dans l'eau courante pour
# les rafraîchir, d'arroser les jardins par trop copieusement, bref, de gaspiller l'eau. Ces jours der
# niers, la consommation d'eau a dépassé 100, 000 m 3, ce qui représente une moyenne de 425 litres par
#  personne et par jour, tandis que jusqu'ici, la consommation la plus forte n'avait pas dépassé 83 mi
# lle m 3. Zurich possède, il est vrai, un réservoir inépuisable — en l'espèce son lac — mais il n'en
# reste pas moins que les installations de filtrage et de transport ont des capacités limitées. Samedi
#  dernier, la consommation a même atteint 103, 000 m 3, ce qui est manifestement exagéré et ne corres
# pond nullement aux besoins réels de la population. Aussi la direction du Service des eaux de Zurich
# déclare-t-elle que les gaspilleurs seront punis conformément au règlement. Les merveilles du télépho
# ne. — On cause de Genève à New-York... pour commander des montres ! GENEVE, 19. — La première conver
# sation téléphonique de l'Amérique avec Genève a eu lieu hier entre la maison d'importation d'horloge
# rie Wittnauer et Cie de New-York et sa succursale de Genève. Cette conversation a duré 6 minutes et
# a coûté 495 francs. Elle fut très claire et l'on se comprit d'un bout à l'autre du fil comme s'il n'
# ... [truncated]
# -----------------
#
# --- Article 2 ---
# Title: Vingt-six fontaines
# Publicationdate: 1962-08-04
# Languagecode: fr
# Transcript Length: 968 characters
# Transcript:
# Vingt-six fontaines Le Service de l'Eau nous a fourni d'intéressantes indications statistiques sur n
# os fontaines, à défaut de renseignements historiques. Par exemple, nous avons appris que l'on compta
# it 26 fontaines sur le territoire communal, desservies par le réseau public. Quelques autres fontain
# es font appel à des eaux de sources privées, telles la Bonne fontaine des Eplatures. L'ensemble de c
# es fontaines débite 200 litres / minute ; comme elles sont en service durant six mois environ, cela
# représente annuellement une quantité de 55, 000 mètres cubes d'eau. Il, faut relever encore que deux
#  grandes fontaines, la « Monu » et la fontaine du parc de la gare ( Chambre suisse de l'horlogerie),
#  fonctionnent en circuit continu ; leur eau n'est donc pas potable. Il ne s'agit que d'ouvrage décor
# atif. Trois fontaines, celles de la Place du Sentier, de la Place du Marché et du jardin de l'Ouest
# fournissent une eau destinée à l'alimentation, parfaitement potable.
# -----------------
#
# --- Article 3 ---
# Title: Les villes suisses consomment trop
# Publicationdate: 2014-03-27
# Languagecode: fr
# Transcript Length: 1094 characters
# Transcript:
# Les villes suisses consomment trop EAU Les villes suisses consomment en moyenne plus d’eau par habit
# ant que celles des pays péens, alors que les prix y sont parfois plus élevés. Selon un audit de l’Of
# fice fédéral de la statistique, Lugano se place au premier rang, avec 250 m 3 d’eau consommés par ha
# bitant en 2012, soit le double des autres villes étudiées : dix chefs-lieux suisses et dix péens, no
# rdiques principalement. La cité tessinoise est suivie par Genève, Bâle, Lausanne, Zurich, Bienne, Lu
# cerne, Berne, Saint-Gall et Winterthour. Ces dernières villes enregistrent une consommation d’eau an
# nuelle par habitant variant entre 85 et 135 mètres cubes. En onzième place figure la ville suédoise
# de Göteborg, talonnée par Helsinki, en Finlande, les tés allemandes Stuttgart et Munich et des ville
# s belges, comme Gand et Bruxelles. La consommation d’eau n’est pas liée aux prix. A Saint-Gall, où l
# es habitants consomment en moyenne 85 m 3 d’eau par an, les prix sont aussi élevés (2,4 francs par m
#  3) qu’à Munich, où la moyenne est de 60 mètres cubes. ATS A Lugano, on aime l’eau... KEYSTONE
# -----------------
#
# --- Article 4 ---
# Title: Les villes suisses consomment trop
# Publicationdate: 2014-03-27
# Languagecode: fr
# Transcript Length: 1096 characters
# Transcript:
# Les villes suisses consomment trop EAU Les villes suisses consomment en moyenne plus d’eau par habit
# ant que celles des pays péens, alors que les prix y sont parfois plus élevés. Selon un audit de l’Of
# fice fédéral de la statistique, Lugano se place au premier rang, avec 250 m 3 d’eau consommés par ha
# bitant en 2012, soit le double des autres villes étudiées : dix chefs-lieux suisses et dix péens, no
# rdiques principalement. La cité tessinoise est suivie par Genève, Bâle, Lausanne, Zurich, Bienne, Lu
# cerne, Berne, Saint-Gall et Winterthour. Ces dernières villes enregistrent une consommation d’eau an
# nuelle par habitant variant entre 85 et 135 mètres cubes. En onzième place figure la ville suédoise
# de Göteborg, talonnée par Helsinki, en Finlande, les tés allemandes Stuttgart et Munich et des ville
# s belges, comme Gand et Bruxelles. La consommation d’eau n’est pas liée aux prix. A Saint-Gall, où l
# es habitants consomment en moyenne 85 m 3 d’eau par an, les prix sont aussi élevés ( 2, 4 francs par
#  m 3) qu’à Munich, où la moyenne est de 60 mètres cubes. ATS A Lugano, on aime l’eau... KEYSTONE
# -----------------
#
# --- Article 5 ---
# Title: Une ville est née...
# Publicationdate: 1939-05-09
# Languagecode: fr
# Transcript Length: 3313 characters
# Transcript:
# Une ville est née... Sur l « s bords du lac de Zurich En l'espace de onze mois, une nouvelle cite es
# t née sur les bords du lac de Zurich. Les travaux de construction de l'Exposition nationale ont duré
#  un peu moins d'un an. Se doute-t-on de l'effort énorme qu'exige la mise au point d'une manifestatio
# n de cette envergure i Oar, a côté de tout ce qui se voit, — de tout ce qu on admire — il y a tout c
# e qui ne se voit pas, et qui représente un travail dont le profane ne se fait guère une idée.'_Quelq
# ues chiffres ue seront peut-être pas ete trop pour illustrer ce que nous venons de dire. L'Expositio
# n occupe, sur les deux rives du lac de Zurich, une superfice d'environ 300, 000 mètres carrés ; 125,
#  000 mètres carrés sont pés par des constructions, dont le volume atteint au total 700, 000 mètres c
# ubes. Pour édifier les nombreux pavillons de l'Exposition, les charpentiers ont utilisé 14, 000 mètr
# es cubes de bois l «'** de construction, et le volume du bois d oeuvre atteint 370, 000 mètres cubes
# . Voilà pour la su perstructure. Et le visiteur serait plus étonne encore s'il pouvait voir le résea
# u de canalisations qui s'étend sous ses pieds : conduites d'eau, conduites pour les eaux usées, cabl
# es électriques et câbles téléphoniques, canalisations pour le gaz, sillonnent le sous-sol de l'Expos
# ition. Les conduites d'eau — il s'agit uniquement des conduites souterraines — ont une longueur de 5
# 200 mètres, ce qui n'est pas exagéré si l'on songe que la consommation d'eau pendant la durée de l'E
# ... [truncated]
# -----------------

# %% [markdown]
# ### Q2 Reranked - Denoised Only

# %%
format_and_display_articles(reranked_articles_q2[:5])
RAG_input_context_q2_reranked = format_and_display_articles(reranked_articles_q2[:5], return_string=True)

url_format_string = "https://dev.impresso-project.ch/app/article/{guid}"
interface_links_string_q2_reranked = generate_interface_links(reranked_articles_q2[:5], url_format_string)
# Out:
# --- Article 1 ---
# Title: CONGRÈS À ZURICH La Suisse, château d'eau de l'Europe
# Publicationdate: 1982-09-07
# Languagecode: fr
# Transcript Length: 1809 characters
# Transcript:
# CONGRÈS À ZURICH La Suisse, château d'eau de l'Europe Zurich, 6 (ATS).-Le 14 e congrès mondial de l'
# Association des distributions d'eau (AIDE) s'est ouvert lundi à Zurich. Jusqu'au 10 septembre, plus
# de deux mille délégués de toutes les régions du monde débattront de problèmes liés au thème général
# « sans eau pas de vie ». Lors de leurs allocutions d'ouverture, le conseiller fédéral Hans Hiirliman
# n et le président de la ville de Zurich Thomas Wagner ont relevé que la Suisse peut être considérée
# comme le château d'eau de l'Europe. Les problèmes qui se posent chez nous ne touchent pas à la quant
# ité mais à la qualité. Selon M. Hùrlimann, l'exiguïté de notre pays, sa forte densité démographique
# et ses intenses activités économiques sont également sources de problèmes. Une statistique de la Soc
# iété suisse de l'industrie du gaz et des eaux montre que près de 580 millions de mètres cubes d'eau
# potable ont été distribués dans notre pays en 1981. Cela représente une consommation quotidienne de
# 248 litres par habitant. L'eau, a encore indiqué M. Hùrlimann, est la seule ressource naturelle que
# la Suisse ne doit pas importer. Mais, parallèlement à l'augmentation de la population, de la product
# ion et de la consommation, la pollution est devenue de plus en plus préoccupante. Pour faire face à
# cette situation, d'énormes efforts financiers ont été consentis. M. Hùrlimann a rappelé que plus de
# 20 milliards de francs ont été investis en Suisse pour résoudre le problème de la pollution. Cela éq
# ... [truncated]
# -----------------
#
# --- Article 2 ---
# Title: Le canton de Zurich compte 3200 débits d...
# Publicationdate: 1914-02-07
# Languagecode: fr
# Transcript Length: 1536 characters
# Transcript:
# Le canton de Zurich compte 3200 débits de boissons et 1800 magasins de vente à l'emporter de boisson
# s alcooliques, dont 1000 pour la seule ville de Zurich. Aussi ne faut-il pas s'étonner d'y voir mont
# er la marée de l'alcoolisme. Le Conseil d'Etat entend l'endiguer par une loi dont voici les disposit
# ions les plus importantes. Le nombre des débits de boissons ne pourra pas dépasser une proportion d'
# un débit pour une sphère de population de 200 âmes. Les patentes ne seront pas accordées aux établis
# sements mais aux personnes. Elles pourront définitivement être retirées aux tenanciers qui se seront
#  fait citer deux fois pour violation des règlements de police. Les communes auront le droit de fixer
#  des heures de fermeture des débits plus restrictives aue le maximum autorisé. Les débits ne pourron
# t être ouverts le dimanche et les jours fériés avant 11 heures du matin. Tout employé d'un établisse
# ment aura droit à un temps de sommeil d'au moins 8 heures, et de plus à un repos inintei-rompu de 6
# heures de temps, dont 3 pendant la journée. Toutes les trois semaines, les ployés auront droit à 1 j
# our de repos de 24 heures, qui, tous les deux mois au moins, devra tomber sur un dimanche. Il sera i
# nterdit aux garçons et aux sommelières de boire avec les consommateurs. Les magasins de vente au dét
# ail de boissons alcooliques ne pourront vendre le dimanche, et la semaine ils ne pourront débiter ap
# rès 8 heures du soir. Ce projet de loi contribuera, s'il est adopté, à une notable amélioration des
# ... [truncated]
# -----------------
#
# --- Article 3 ---
# Title: engpasse
# Publicationdate: 1976-07-07
# Languagecode: de
# Transcript Length: 967 characters
# Transcript:
# engpasse bps. Die Wasserversorgung in einigen Zürcher Quartieren ist durch den schlagartig gestiegen
# en Verbrauch an der Grenze ihrer Leistungsfähigkeit angelangt. Wie die Abteilung Wasserversorgung de
# r Industriellen Betriebe der Stadt ZUrich mitteilte, betrifft dies in erster Linie die peripher gele
# genen Versorgungsgebicte Seebach, Höngg, Waidberg, Friesenberg, Leimbach und Witikon. Wohl gehört zu
# rzeit die Wasserversorgung der Stadt Zürich zu den modernsten und leistungsfähigsten ihrer Art in Eu
# ropa. Doch die endgültige Sicherstellung der Wasserlieferungen für das gesamte Stadtgebiet wird erst
#  ab etwa 1982 bewerkstelligt sein, da sich momentan verschiedene in der Gemeindeabstimmung vom 4. Mä
# rz 1973 bewilligte Projekte noch im Stadium der Realisierung befinden. So steht beispielsweise das G
# rundwasserwerk Hardhof im Neubau. Darüberhinaus werden verschiedene Verteilanlagen wie Pumpwerke, Re
# servoire und Transportleitungen gegenwärtig erneuert. Schluss S. 14
# -----------------
#
# --- Article 4 ---
# Title: Les bains publies en Suisse
# Publicationdate: 1931-08-07
# Languagecode: fr
# Transcript Length: 2053 characters
# Transcript:
# Les bains publies en Suisse Le service de publictié des C. F. F. a organisé dans tout le pays une en
# quête sur les établissements de bain. Au total 111 villes et stations touristiques disposent de bain
# s de rivière, de plages ou de piscines, ce nombre s'est même accru depuis la fin de l'enquête. 24 de
#  ces établissements se trouvent dans la Suisse orientale entre Zurich et le lac de Constance, 19 dan
# s la Suisse centrale, 18 dans l'Oberland bernois (Berne y compris), 17 dans les Grisons, 15 dans la
# Suisse septentrionale et occidentale, 8 le long du lac Léman, etc. Il existe 19 piscines artificiell
# es, dont 6 chauffablee ; 70 autres établissements sont situés au bord des lacs, et le reste sur les
# cours d'eau. L'installation de ces bains est des plus variés ; il en est de luxueuses, de raffinées,
#  comme aussi de très simples. 6880 cabines individuelles ont été annoncées ; Bâle vient en tête avec
#  487, et Lucerne suit avec 404. Il existe en outre des cabines communes ainsi que divercabines commu
# nes ainsi que diverses installations servant de vestiaires. Il va sans dire qu'il est partout possib
# le de prendre des bains de soleil, aujourd hui si en vogue ; cependant 78 établissements disposent d
# 'emplacements spéciaux. 70 établissements ont des terrains de gymnastique ou de jeu, 92 des pelouses
# . La gymnastique enseignée dans 29 bains permet aux personnes corpulentes de perdre quelque peu de l
# eur embonpoint. 82 bains offrent les délices de la douche. 75 disposent d'engins destinés aux jeux n
# ... [truncated]
# -----------------
#
# --- Article 5 ---
# Title: Les villes suisses consomment trop
# Publicationdate: 2014-03-27
# Languagecode: fr
# Transcript Length: 1094 characters
# Transcript:
# Les villes suisses consomment trop EAU Les villes suisses consomment en moyenne plus d’eau par habit
# ant que celles des pays péens, alors que les prix y sont parfois plus élevés. Selon un audit de l’Of
# fice fédéral de la statistique, Lugano se place au premier rang, avec 250 m 3 d’eau consommés par ha
# bitant en 2012, soit le double des autres villes étudiées : dix chefs-lieux suisses et dix péens, no
# rdiques principalement. La cité tessinoise est suivie par Genève, Bâle, Lausanne, Zurich, Bienne, Lu
# cerne, Berne, Saint-Gall et Winterthour. Ces dernières villes enregistrent une consommation d’eau an
# nuelle par habitant variant entre 85 et 135 mètres cubes. En onzième place figure la ville suédoise
# de Göteborg, talonnée par Helsinki, en Finlande, les tés allemandes Stuttgart et Munich et des ville
# s belges, comme Gand et Bruxelles. La consommation d’eau n’est pas liée aux prix. A Saint-Gall, où l
# es habitants consomment en moyenne 85 m 3 d’eau par an, les prix sont aussi élevés (2,4 francs par m
#  3) qu’à Munich, où la moyenne est de 60 mètres cubes. ATS A Lugano, on aime l’eau... KEYSTONE
# -----------------

# %% [markdown]
# ### Q2 Reranked - Denoised and LUX

# %%
format_and_display_articles(reranked_lux_articles_q2[:5])
RAG_input_context_q2_reranked_lux = format_and_display_articles(reranked_lux_articles_q2[:5], return_string=True)

url_format_string = "https://dev.impresso-project.ch/app/article/{guid}"
interface_links_string_q2_reranked_lux = generate_interface_links(reranked_lux_articles_q2[:5], url_format_string)
# Out:
# --- Article 1 ---
# Title: engpasse
# Publicationdate: 1976-07-07
# Languagecode: de
# Transcript Length: 967 characters
# Transcript:
# engpasse bps. Die Wasserversorgung in einigen Zürcher Quartieren ist durch den schlagartig gestiegen
# en Verbrauch an der Grenze ihrer Leistungsfähigkeit angelangt. Wie die Abteilung Wasserversorgung de
# r Industriellen Betriebe der Stadt ZUrich mitteilte, betrifft dies in erster Linie die peripher gele
# genen Versorgungsgebicte Seebach, Höngg, Waidberg, Friesenberg, Leimbach und Witikon. Wohl gehört zu
# rzeit die Wasserversorgung der Stadt Zürich zu den modernsten und leistungsfähigsten ihrer Art in Eu
# ropa. Doch die endgültige Sicherstellung der Wasserlieferungen für das gesamte Stadtgebiet wird erst
#  ab etwa 1982 bewerkstelligt sein, da sich momentan verschiedene in der Gemeindeabstimmung vom 4. Mä
# rz 1973 bewilligte Projekte noch im Stadium der Realisierung befinden. So steht beispielsweise das G
# rundwasserwerk Hardhof im Neubau. Darüberhinaus werden verschiedene Verteilanlagen wie Pumpwerke, Re
# servoire und Transportleitungen gegenwärtig erneuert. Schluss S. 14
# -----------------
#
# --- Article 2 ---
# Title: CONGRÈS À ZURICH La Suisse, château d'eau de l'Europe
# Publicationdate: 1982-09-07
# Languagecode: fr
# Transcript Length: 1809 characters
# Transcript:
# CONGRÈS À ZURICH La Suisse, château d'eau de l'Europe Zurich, 6 (ATS).-Le 14 e congrès mondial de l'
# Association des distributions d'eau (AIDE) s'est ouvert lundi à Zurich. Jusqu'au 10 septembre, plus
# de deux mille délégués de toutes les régions du monde débattront de problèmes liés au thème général
# « sans eau pas de vie ». Lors de leurs allocutions d'ouverture, le conseiller fédéral Hans Hiirliman
# n et le président de la ville de Zurich Thomas Wagner ont relevé que la Suisse peut être considérée
# comme le château d'eau de l'Europe. Les problèmes qui se posent chez nous ne touchent pas à la quant
# ité mais à la qualité. Selon M. Hùrlimann, l'exiguïté de notre pays, sa forte densité démographique
# et ses intenses activités économiques sont également sources de problèmes. Une statistique de la Soc
# iété suisse de l'industrie du gaz et des eaux montre que près de 580 millions de mètres cubes d'eau
# potable ont été distribués dans notre pays en 1981. Cela représente une consommation quotidienne de
# 248 litres par habitant. L'eau, a encore indiqué M. Hùrlimann, est la seule ressource naturelle que
# la Suisse ne doit pas importer. Mais, parallèlement à l'augmentation de la population, de la product
# ion et de la consommation, la pollution est devenue de plus en plus préoccupante. Pour faire face à
# cette situation, d'énormes efforts financiers ont été consentis. M. Hùrlimann a rappelé que plus de
# 20 milliards de francs ont été investis en Suisse pour résoudre le problème de la pollution. Cela éq
# ... [truncated]
# -----------------
#
# --- Article 3 ---
# Title: Les bains publies en Suisse
# Publicationdate: 1931-08-07
# Languagecode: fr
# Transcript Length: 2053 characters
# Transcript:
# Les bains publies en Suisse Le service de publictié des C. F. F. a organisé dans tout le pays une en
# quête sur les établissements de bain. Au total 111 villes et stations touristiques disposent de bain
# s de rivière, de plages ou de piscines, ce nombre s'est même accru depuis la fin de l'enquête. 24 de
#  ces établissements se trouvent dans la Suisse orientale entre Zurich et le lac de Constance, 19 dan
# s la Suisse centrale, 18 dans l'Oberland bernois (Berne y compris), 17 dans les Grisons, 15 dans la
# Suisse septentrionale et occidentale, 8 le long du lac Léman, etc. Il existe 19 piscines artificiell
# es, dont 6 chauffablee ; 70 autres établissements sont situés au bord des lacs, et le reste sur les
# cours d'eau. L'installation de ces bains est des plus variés ; il en est de luxueuses, de raffinées,
#  comme aussi de très simples. 6880 cabines individuelles ont été annoncées ; Bâle vient en tête avec
#  487, et Lucerne suit avec 404. Il existe en outre des cabines communes ainsi que divercabines commu
# nes ainsi que diverses installations servant de vestiaires. Il va sans dire qu'il est partout possib
# le de prendre des bains de soleil, aujourd hui si en vogue ; cependant 78 établissements disposent d
# 'emplacements spéciaux. 70 établissements ont des terrains de gymnastique ou de jeu, 92 des pelouses
# . La gymnastique enseignée dans 29 bains permet aux personnes corpulentes de perdre quelque peu de l
# eur embonpoint. 82 bains offrent les délices de la douche. 75 disposent d'engins destinés aux jeux n
# ... [truncated]
# -----------------
#
# --- Article 4 ---
# Title: Vingt-six fontaines
# Publicationdate: 1962-08-04
# Languagecode: fr
# Transcript Length: 968 characters
# Transcript:
# Vingt-six fontaines Le Service de l'Eau nous a fourni d'intéressantes indications statistiques sur n
# os fontaines, à défaut de renseignements historiques. Par exemple, nous avons appris que l'on compta
# it 26 fontaines sur le territoire communal, desservies par le réseau public. Quelques autres fontain
# es font appel à des eaux de sources privées, telles la Bonne fontaine des Eplatures. L'ensemble de c
# es fontaines débite 200 litres / minute ; comme elles sont en service durant six mois environ, cela
# représente annuellement une quantité de 55, 000 mètres cubes d'eau. Il, faut relever encore que deux
#  grandes fontaines, la « Monu » et la fontaine du parc de la gare ( Chambre suisse de l'horlogerie),
#  fonctionnent en circuit continu ; leur eau n'est donc pas potable. Il ne s'agit que d'ouvrage décor
# atif. Trois fontaines, celles de la Place du Sentier, de la Place du Marché et du jardin de l'Ouest
# fournissent une eau destinée à l'alimentation, parfaitement potable.
# -----------------
#
# --- Article 5 ---
# Title: Les villes suisses consomment trop
# Publicationdate: 2014-03-27
# Languagecode: fr
# Transcript Length: 1096 characters
# Transcript:
# Les villes suisses consomment trop EAU Les villes suisses consomment en moyenne plus d’eau par habit
# ant que celles des pays péens, alors que les prix y sont parfois plus élevés. Selon un audit de l’Of
# fice fédéral de la statistique, Lugano se place au premier rang, avec 250 m 3 d’eau consommés par ha
# bitant en 2012, soit le double des autres villes étudiées : dix chefs-lieux suisses et dix péens, no
# rdiques principalement. La cité tessinoise est suivie par Genève, Bâle, Lausanne, Zurich, Bienne, Lu
# cerne, Berne, Saint-Gall et Winterthour. Ces dernières villes enregistrent une consommation d’eau an
# nuelle par habitant variant entre 85 et 135 mètres cubes. En onzième place figure la ville suédoise
# de Göteborg, talonnée par Helsinki, en Finlande, les tés allemandes Stuttgart et Munich et des ville
# s belges, comme Gand et Bruxelles. La consommation d’eau n’est pas liée aux prix. A Saint-Gall, où l
# es habitants consomment en moyenne 85 m 3 d’eau par an, les prix sont aussi élevés ( 2, 4 francs par
#  m 3) qu’à Munich, où la moyenne est de 60 mètres cubes. ATS A Lugano, on aime l’eau... KEYSTONE
# -----------------

# %% [markdown]
# ### OPENROUTER VERSION

# %%
import openai
import getpass
import os

# 2. Securely get your API key
# When you run this, a password-style box will appear.
# Paste your OpenRouter API key there and press Enter.
if "OPENROUTER_API_KEY" not in os.environ:
  os.environ["OPENROUTER_API_KEY"] = getpass.getpass("Enter your OpenRouter API Key: ")

# 3. Configure the OpenAI client to use OpenRouter
client = openai.OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=os.environ["OPENROUTER_API_KEY"],
)

# 4. Set up your request
model_id = "google/gemma-3-27b-it:free"
core_input = "Summarize how the following articles that might contain OCR errors and relate these articles to the question of the user. \n"
# Out:
# Enter your OpenRouter API Key: ··········

# %% [markdown]
# #### Q1

# %%
input_with_context = core_input + " Question: " + question_q1 + "\n Retrieved Context: " + RAG_input_context_q1 + "\n"

print(f"Sending request to model: {model_id}...")

try:
  completion = client.chat.completions.create(
    model=model_id,
    messages=[
      {
        "role": "user",
        "content": input_with_context
      },
    ],
  )

  # 6. Print the model's response
  response_text = completion.choices[0].message.content
  print(("\n--- Core input of task ---"))
  print(core_input)
  print(("\n--- Question ---"))
  print(question_q1)
  print("\n--- Model Response ---")
  print(response_text)
  print("----------------------")
  print("\n--- Source Article Links ---")
  print(interface_links_string_q1)

except openai.AuthenticationError:
  print("AuthenticationError: Invalid API key. Please check your OpenRouter API key.")
except Exception as e:
  print(f"An error occurred: {e}")
# Out:
# Sending request to model: google/gemma-3-27b-it:free...
#
# --- Core input of task ---
# Summarize how the following articles that might contain OCR errors and relate these articles to the question of the user.
#
#
# --- Question ---
# What happened in Zurich in the year 1950?
#
# --- Model Response ---
#
#
# ## Summary of Articles & Relation to Your Question (What happened in Zurich in 1950?)
#
# Here's a breakdown of each article and how it relates to your question about events in Zurich in 1950:
#
# **1. Article 1 (1919-06-16):** This article details riots in Zurich in *1919*, related to a socialist demonstration honoring Rosa Luxembourg. It's **not relevant** to your 1950 question.
#
# **2. Article 2 (1953-10-26):** This is a "looking back" piece, mentioning events from 50 years prior (around 1903) and other anniversaries (40, 30, 20, and 10 years before 1953). It doesn’t specifically focus on 1950. It only briefly mentions events spanning decades and isn’t useful. **Not relevant** to your question.
#
# **3. Article 3 (1959-04-24):** This reports on a *1959* murder in Zurich.  **Not relevant** to your 1950 question.
#
# **4. Article 4 (1951-02-14):** This article details the financial results of the *Banque Cantonale Zurichoise* *for the year 1950*.  It reports a net profit of 5,175,560 francs and details how the funds were allocated, including a donation towards tuberculosis treatment in the canton. This is **directly relevant** to your question, as it documents financial activity in Zurich in 1950. It also mentions production figures for *Usines de I'Etzel* for 1949-1950.
#
# **5. Article 5 (1950-10-05):**  This is a stock market report from *October 5th, 1950*, specifically focused on the Zurich exchange. It lists stock prices for numerous Swiss and international companies. This is **relevant** to your question, as it provides a snapshot of the economic activity happening in Zurich *during* 1950.
#
#
#
# **In conclusion:**
#
# The most significant event reported concerning Zurich in 1950 comes from **Article 4**, detailing the financial performance of the *Banque Cantonale Zurichoise*. **Article 5** gives a snapshot of the stock market activity in Zurich *during* 1950. These two articles provide the most concrete information relating to your question.
#
#
#
#
# ----------------------
#
# --- Source Article Links ---
# https://dev.impresso-project.ch/app/article/excelsior-1919-06-16-a-i0030
# https://dev.impresso-project.ch/app/article/DTT-1953-10-26-a-i0089
# https://dev.impresso-project.ch/app/article/IMP-1959-04-24-a-i0042
# https://dev.impresso-project.ch/app/article/GDL-1951-02-14-a-i0052
# https://dev.impresso-project.ch/app/article/IMP-1950-10-05-a-i0074

# %% [markdown]
# #### Q2

# %%
input_with_context = core_input + " Question: " + question_q2 + "\n Retrieved Context: " + RAG_input_context_q2 + "\n"

print(f"Sending request to model: {model_id}...")

try:
  completion = client.chat.completions.create(
    model=model_id,
    messages=[
      {
        "role": "user",
        "content": input_with_context
      },
    ],
  )

  # 6. Print the model's response
  response_text = completion.choices[0].message.content
  print(("\n--- Core input of task ---"))
  print(core_input)
  print(("\n--- Question ---"))
  print(question_q2)
  print("\n--- Model Response ---")
  print(response_text)
  print("----------------------")
  print("\n--- Source Article Links ---")
  print(interface_links_string_q2)

except openai.AuthenticationError:
  print("AuthenticationError: Invalid API key. Please check your OpenRouter API key.")
except Exception as e:
  print(f"An error occurred: {e}")
# Out:
# Sending request to model: google/gemma-3-27b-it:free...
#
# --- Core input of task ---
# Summarize how the following articles that might contain OCR errors and relate these articles to the question of the user.
#
#
# --- Question ---
# How many water fountains are there in Zurich?
#
# --- Model Response ---
# Okay, here's a summary of the articles and how they relate to the question "How many water fountains are there in Zurich?".  I'll also note potential OCR issues.
#
# **Summary of Articles:**
#
# * **Article 1 (1928-07-19):** This article discusses water *consumption* in Zurich during a heatwave. It notes that consumption exceeded 100,000 m³ and 425 liters per person per day. It mentions Zurich has the lake as a reservoir but filtration/transport capacity is limited. It's about overall water usage, not fountains specifically.  OCR issues: "isi Siiiss" likely should be "ici Suisse".
# * **Article 2 (1962-08-04):** **This is the most relevant article.** It states that Zurich had **26 public fountains** connected to the public water network in 1962. It also mentions some private fountains and details about water flow (200 liters/minute total, 55,000 m³ annually). It distinguishes between decorative fountains (not potable) and those providing drinking water.
# * **Article 3 & 4 (2014-03-27):** These are identical articles. They discuss overall water *consumption* per capita in various Swiss cities, including Zurich, compared to cities in other countries. Zurich's consumption is listed as between 85-135 m³ per inhabitant annually.  They don't mention the number of fountains.
# * **Article 5 (1939-05-09):** This article describes the construction of the Swiss National Exhibition on the shores of Lake Zurich. It details the scale of the construction (area, volume of buildings, materials used, length of underground pipes – 5200 meters of water pipes). It doesn't mention fountains. OCR issues: Numerous apparent errors, like "pés" instead of "posés", "l «'** de construction" is garbled.
#
# **Answer to the Question "How many water fountains are there in Zurich?":**
#
# Based on the provided articles, the best answer is **26**, as stated in Article 2, published in 1962.
#
# **Important Considerations:**
#
# * **Date:** The 1962 figure is the only specific number provided. The number of fountains in Zurich today could be significantly different.
# * **Scope:** Article 2 specifies "26 fountains on the communal territory, served by the public network." There may be additional fountains not included in this count (e.g., those on private property).
# * **OCR Errors:** The OCR quality is variable. While I've tried to account for likely errors, there's a chance some details are misinterpreted.
#
#
#
#
# ----------------------
#
# --- Source Article Links ---
# https://dev.impresso-project.ch/app/article/IMP-1928-07-19-a-i0112
# https://dev.impresso-project.ch/app/article/IMP-1962-08-04-a-i0149
# https://dev.impresso-project.ch/app/article/EXP-2014-03-27-a-i0184
# https://dev.impresso-project.ch/app/article/IMP-2014-03-27-a-i0181
# https://dev.impresso-project.ch/app/article/IMP-1939-05-09-a-i0097

# %% [markdown]
# #### Q2 Reranked Denoising

# %%
input_with_context = core_input + " Question: " + question_q2 + "\n Retrieved Context: " + RAG_input_context_q2_reranked + "\n"

print(f"Sending request to model: {model_id}...")

try:
  completion = client.chat.completions.create(
    model=model_id,
    messages=[
      {
        "role": "user",
        "content": input_with_context
      },
    ],
  )

  # 6. Print the model's response
  response_text = completion.choices[0].message.content
  print(("\n--- Core input of task ---"))
  print(core_input)
  print(("\n--- Question ---"))
  print(question_q2)
  print("\n--- Model Response ---")
  print(response_text)
  print("----------------------")
  print("\n--- Source Article Links ---")
  print(interface_links_string_q2_reranked)

except openai.AuthenticationError:
  print("AuthenticationError: Invalid API key. Please check your OpenRouter API key.")
except Exception as e:
  print(f"An error occurred: {e}")
# Out:
# Sending request to model: google/gemma-3-27b-it:free...
#
# --- Core input of task ---
# Summarize how the following articles that might contain OCR errors and relate these articles to the question of the user.
#
#
# --- Question ---
# How many water fountains are there in Zurich?
#
# --- Model Response ---
#
#
# Here's a summary of the articles and their relevance to the question "How many water fountains are there in Zurich?":
#
# **Summary of Articles:**
#
# * **Article 1 (1982):** Discusses a water distribution congress in Zurich and Switzerland's position as a "water castle" of Europe. It mentions water consumption statistics (248 liters/person/day) and investment in pollution control.  It doesn't mention fountains.
# * **Article 2 (1914):** Focuses on the number of alcohol vendors (pubs/shops) in the canton and city of Zurich, aiming to regulate alcohol consumption. Completely irrelevant to water fountains.
# * **Article 3 (1976):** Reports on water supply limitations in some Zurich districts due to increased consumption.  Mentions upgrades to the city's water infrastructure but makes no reference to fountains.
# * **Article 4 (1931):**  Surveys public bathing facilities (river baths, beaches, and swimming pools) across Switzerland, including the number of changing cabins in various cities like Basel and Lucerne.  Doesn't discuss drinking water fountains.
# * **Article 5 (2014):** Compares water consumption in Swiss cities to those in Northern Europe, highlighting Lugano and Zurich as high consumers.  Again, focuses on overall water *use*, not fountains.
#
# **Relevance to the Question:**
#
# Unfortunately, **none of these articles provide information about the number of water fountains in Zurich.** They all relate to water in some way – distribution, supply, consumption, or bathing facilities – but they don't address the specific question of how many public drinking water fountains exist in the city.
#
# The articles indicate Zurich is concerned with water management and has a modern water supply system, but this doesn't translate to knowing the number of fountains.
#
#
#
#
# ----------------------
#
# --- Source Article Links ---
# https://dev.impresso-project.ch/app/article/GDL-1982-09-07-a-i0120
# https://dev.impresso-project.ch/app/article/LES-1914-02-07-a-i0016
# https://dev.impresso-project.ch/app/article/DTT-1976-07-07-a-i0154
# https://dev.impresso-project.ch/app/article/EXP-1931-08-07-a-i0091
# https://dev.impresso-project.ch/app/article/EXP-2014-03-27-a-i0184

# %% [markdown]
# #### Q2 Reranked Denoising Lux

# %%
input_with_context = core_input + " Question: " + question_q2 + "\n Retrieved Context: " + RAG_input_context_q2_reranked_lux + "\n"

print(f"Sending request to model: {model_id}...")

try:
  completion = client.chat.completions.create(
    model=model_id,
    messages=[
      {
        "role": "user",
        "content": input_with_context
      },
    ],
  )

  # 6. Print the model's response
  response_text = completion.choices[0].message.content
  print(("\n--- Core input of task ---"))
  print(core_input)
  print(("\n--- Question ---"))
  print(question_q2)
  print("\n--- Model Response ---")
  print(response_text)
  print("----------------------")
  print("\n--- Source Article Links ---")
  print(interface_links_string_q2_reranked_lux)

except openai.AuthenticationError:
  print("AuthenticationError: Invalid API key. Please check your OpenRouter API key.")
except Exception as e:
  print(f"An error occurred: {e}")
# Out:
# Sending request to model: google/gemma-3-27b-it:free...
#
# --- Core input of task ---
# Summarize how the following articles that might contain OCR errors and relate these articles to the question of the user.
#
#
# --- Question ---
# How many water fountains are there in Zurich?
#
# --- Model Response ---
#
#
# Okay, here's a summary of the articles and how they relate to the question "How many water fountains are there in Zurich?":
#
# **Summary of Articles:**
#
# * **Article 1 (engpasse - 1976):**  Discusses water supply issues in Zurich's outer districts due to increased consumption. It mentions upgrades to the water infrastructure (groundwater works, pumping stations, reservoirs, pipelines) but **doesn't mention the number of fountains.**
# * **Article 2 (CONGRÈS À ZURICH - 1982):** Reports on a water distribution congress held in Zurich. Focuses on Switzerland as a "water castle" of Europe, water consumption statistics (580 million cubic meters nationally in 1981, 248 liters/person/day), and pollution concerns. **No information on fountains.**
# * **Article 3 (Les bains publies en Suisse - 1931):**  Details public bathing facilities (rivers, lakes, pools) across Switzerland, including statistics on the number of establishments and amenities (cabins, sunbathing areas, etc.). Includes numbers for Swiss cities, including Zurich, but relates to *bathing facilities,* not drinking water fountains. **Does not answer the question.**
# * **Article 4 (Vingt-six fontaines - 1962):** **This is the most relevant article.** It *specifically* states that there were **26 fountains** within the Zurich municipal area in 1962, served by the public network. It also notes a few other fountains use private sources.  It adds details about water flow volume and which fountains provide potable water.
# * **Article 5 (Les villes suisses consomment trop - 2014):** Discusses water *consumption* in Swiss cities, comparing it to European averages, and specifically mentioning Zurich. It focuses on volume of water used per capita, not the number of fountains. **Does not answer the question.**
#
# **Answer to the Question:**
#
# Based on the provided articles, the best available answer to "How many water fountains are there in Zurich?" is **26**, as stated in Article 4 from 1962.
#
# **Important Considerations:**
#
# * **Date:** The information is from 1962. It's *highly* likely the number of fountains has changed since then.  These articles provide no indication of current numbers.
# * **Scope:** Article 4 specifies fountains served by the public network *within the municipal area*. There might be others not included in that count, as the article mentions fountains using private sources.
# * **OCR Errors:** Given the note regarding potential OCR errors, there's a slight chance the number "26" itself could be incorrect. However, it's the most direct piece of evidence available.
#
#
#
#
# ----------------------
#
# --- Source Article Links ---
# https://dev.impresso-project.ch/app/article/DTT-1976-07-07-a-i0154
# https://dev.impresso-project.ch/app/article/GDL-1982-09-07-a-i0120
# https://dev.impresso-project.ch/app/article/EXP-1931-08-07-a-i0091
# https://dev.impresso-project.ch/app/article/IMP-1962-08-04-a-i0149
# https://dev.impresso-project.ch/app/article/IMP-2014-03-27-a-i0181
